# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter
import timm
from timm.scheduler import CosineLRScheduler
#from torchvision.models import wide_resnet50_2, resnet18
#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
import common as com
import pytorch_modeler as modeler
from pytorch_model import EfficientNet_b1 as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %%
# effnet1 = timm.create_model('efficientnet_b1', pretrained=True)
# # M7:block[5], M8:block[6], M9:conv_head
# effnet1

# %%
log_folder = config['IO_OPTION']['OUTPUT_ROOT']+'/{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_folder, '00_train.py')

# %% [markdown]
# ## load config and set logger

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(42)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
dev_dir = INPUT_ROOT + "/dev_data"
add_dev_dir = INPUT_ROOT + "/add_dev_data"
PREMODEL_ROOT = config['IO_OPTION']['PREMODEL_ROOT']
# machine type
machine_types = os.listdir(dev_dir)
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['SRC_OUTPUT_ROOT']
MODEL_DIR = OUTPUT_ROOT + '/models'

TB_DIR = OUTPUT_ROOT + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
PRED_DIR = OUTPUT_ROOT + '/pred'
SCORE_DIR = OUTPUT_ROOT + '/score'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
os.makedirs(PRED_DIR, exist_ok=True)
os.makedirs(SCORE_DIR, exist_ok=True)

# copy config
# shutil.copy('./config.yaml', OUTPUT_ROOT)

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## make path list

# %% [markdown]
# - __train_paths__ ([dict]): Each Machine Type
#     - __ToyCar__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) :paths
#     - __ToyTrain__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) : paths
#     - ...

# %%
percent = 0.1

# %%
dev_paths = {}

for machine_type in machine_types:
    # dev train
    dev_train_paths = [f"{dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/train")]
    dev_train_paths = sorted(dev_train_paths)
    
    print(f'Machine {machine_type}', end=',')
    print(f'dev_train_size : {len(dev_train_paths)}', end=', ')
    dev_train_source_paths = [path for path in dev_train_paths if 'source' in path]
    print(f'source_size : {len(dev_train_source_paths)}', end=', ')
    dev_train_target_paths = [path for path in dev_train_paths if 'target' in path]
    print(f'target_size : {len(dev_train_target_paths)}', end=', ')
    # increse tgt
    num_increse_tgt = int(len(dev_train_source_paths) * percent)
    increse_dev_train_target_paths = dev_train_target_paths * num_increse_tgt
    # concat
    dev_train_paths = dev_train_source_paths + increse_dev_train_target_paths
    
    # add_dev train
    add_dev_paths = [f"{add_dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{add_dev_dir}/{machine_type}/train")]
    add_dev_paths = sorted(add_dev_paths)
    print(f'adddev_train_size : {len(add_dev_paths)}', end=', ')
    add_dev_source_paths = [path for path in add_dev_paths if 'source' in path]
    print(f'source_size : {len(add_dev_source_paths)}', end=', ')
    add_dev_target_paths = [path for path in add_dev_paths if 'target' in path]
    print(f'target_size : {len(add_dev_target_paths)}')
    # increse tgt
    num_increse_tgt = int(len(add_dev_source_paths) * percent)
    increse_add_dev_target_paths = add_dev_target_paths * num_increse_tgt
    # concat
    add_dev_paths = add_dev_source_paths + increse_add_dev_target_paths

    print('==============================================================')
    
    # dev_source valid
    dev_source_paths = [f"{dev_dir}/{machine_type}/source_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/source_test")]
    dev_source_paths = sorted(dev_source_paths)
    
    # dev_target valid
    dev_target_paths = [f"{dev_dir}/{machine_type}/target_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/target_test")]
    dev_target_paths = sorted(dev_target_paths)
    
    # bundle
    dev_paths[machine_type] = {}
    dev_paths[machine_type]['train'] = dev_train_paths + add_dev_paths
    dev_paths[machine_type]['valid_source'] = dev_source_paths
    dev_paths[machine_type]['valid_target'] = dev_target_paths
# Out:
# Machine pump,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine gearbox,dev_train_size : 3026, source_size : 3017, target_size : 9, adddev_train_size : 3114, source_size : 3105, target_size : 9
# ==============================================================
# Machine slider,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyCar,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine valve,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyTrain,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine fan,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================

# %%
machine_types
# Out:
# ['pump', 'gearbox', 'slider', 'ToyCar', 'valve', 'ToyTrain', 'fan']

# %%
#############################################################################
# run
#############################################################################
def run(machine_type, dev_paths):
    com.tic()
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dev_train_paths
    dataloaders_dict = modeler.make_dataloader(dev_paths, machine_type)
    # parameter setting
    logger.info('TRAINING')
    
    model = Model(n_classes=6)
    pretrained_dict = torch.load(config['IO_OPTION']['PREMODEL_ROOT'] + f'/{machine_type}_model.pkl')
    model.load_state_dict(pretrained_dict, strict=False)
    
#     for param in model.parameters():
#         param.requires_grad = False
#     for param in model.fc_block.parameters():
#         param.requires_grad = True
#     for param in model.CenterLoss.parameters():
#         param.requires_grad = True
    
    optimizer = torch.optim.Adam(model.parameters(),lr=1e-3)
    scheduler = CosineLRScheduler(optimizer, t_initial=100, lr_min=1e-4, 
                                  warmup_t=10, warmup_lr_init=5e-5, warmup_prefix=True)
    output_dict, model, pred_df, score_df = modeler.run_training(model, dataloaders_dict, writer, optimizer, scheduler)
    
    # output
    feature_out_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
    model_out_path = f'{MODEL_DIR}/{machine_type}_model.pkl'
    pred_out_path = f'{PRED_DIR}/{machine_type}_pred.csv'
    score_out_path = f'{SCORE_DIR}/{machine_type}_pred.csv'
    # save
    pd.to_pickle(output_dict, feature_out_path)
    torch.save(model.state_dict(), model_out_path)
    pred_df.to_csv(pred_out_path)
    score_df.to_csv(score_out_path)
    logger.info(f'SAVE SUCCESS : {model_out_path}')
    
    com.toc()

# %%
#run(machine_types[0], dev_paths)

# %%
for machine_type in machine_types[0:]:
    run(machine_type, dev_paths)
# Out:
# 2021-11-08 01:05:08,709 - 00_train.py - INFO - TARGET MACHINE_TYPE: pump
# 2021-11-08 01:05:08,710 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-11-08 01:05:08,716 - 00_train.py - INFO - TRAINING
# use: cuda:0
# 100%|██████████| 24/24 [00:16<00:00,  1.46it/s]
# 100%|██████████| 600/600 [01:00<00:00,  9.86it/s]
# 100%|██████████| 600/600 [01:00<00:00,  9.92it/s]
# 2021-11-08 01:07:30,927 - pytorch_modeler.py - INFO - epoch:1/100, tr_loss:0.771687, src_loss:0.411626, src_mean_auc:0.839400, tgt_loss:0.740827, tgt_mean_auc:0.510900, mean_auc:0.675150,
#                AUC      pAUC
# Source_0  0.815000  0.588421
# Source_1  0.965700  0.867368
# Source_2  0.737500  0.532632
# Target_0  0.685800  0.624737
# Target_1  0.259200  0.473684
# Target_2  0.587700  0.557368
# mean      0.675150  0.607368
# h_mean    0.564113  0.586179
# 100%|██████████| 24/24 [00:16<00:00,  1.50it/s]
# 2021-11-08 01:07:47,136 - pytorch_modeler.py - INFO - epoch:2/100, tr_loss:0.352979, src_loss:0.411626, src_mean_auc:0.839400, tgt_loss:0.740827, tgt_mean_auc:0.510900, mean_auc:0.675150,
#                AUC      pAUC
# Source_0  0.815000  0.588421
# Source_1  0.965700  0.867368
# Source_2  0.737500  0.532632
# Target_0  0.685800  0.624737
# Target_1  0.259200  0.473684
# Target_2  0.587700  0.557368
# mean      0.675150  0.607368
# h_mean    0.564113  0.586179
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:08:03,261 - pytorch_modeler.py - INFO - epoch:3/100, tr_loss:0.300318, src_loss:0.411626, src_mean_auc:0.839400, tgt_loss:0.740827, tgt_mean_auc:0.510900, mean_auc:0.675150,
#                AUC      pAUC
# Source_0  0.815000  0.588421
# Source_1  0.965700  0.867368
# Source_2  0.737500  0.532632
# Target_0  0.685800  0.624737
# Target_1  0.259200  0.473684
# Target_2  0.587700  0.557368
# mean      0.675150  0.607368
# h_mean    0.564113  0.586179
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:08:19,428 - pytorch_modeler.py - INFO - epoch:4/100, tr_loss:0.288900, src_loss:0.411626, src_mean_auc:0.839400, tgt_loss:0.740827, tgt_mean_auc:0.510900, mean_auc:0.675150,
#                AUC      pAUC
# Source_0  0.815000  0.588421
# Source_1  0.965700  0.867368
# Source_2  0.737500  0.532632
# Target_0  0.685800  0.624737
# Target_1  0.259200  0.473684
# Target_2  0.587700  0.557368
# mean      0.675150  0.607368
# h_mean    0.564113  0.586179
# 100%|██████████| 24/24 [00:15<00:00,  1.50it/s]
# 2021-11-08 01:08:35,605 - pytorch_modeler.py - INFO - epoch:5/100, tr_loss:0.293992, src_loss:0.411626, src_mean_auc:0.839400, tgt_loss:0.740827, tgt_mean_auc:0.510900, mean_auc:0.675150,
#                AUC      pAUC
# Source_0  0.815000  0.588421
# Source_1  0.965700  0.867368
# Source_2  0.737500  0.532632
# Target_0  0.685800  0.624737
# Target_1  0.259200  0.473684
# Target_2  0.587700  0.557368
# mean      0.675150  0.607368
# h_mean    0.564113  0.586179
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:08:51,736 - pytorch_modeler.py - INFO - epoch:6/100, tr_loss:0.286834, src_loss:0.411626, src_mean_auc:0.839400, tgt_loss:0.740827, tgt_mean_auc:0.510900, mean_auc:0.675150,
#                AUC      pAUC
# Source_0  0.815000  0.588421
# Source_1  0.965700  0.867368
# Source_2  0.737500  0.532632
# Target_0  0.685800  0.624737
# Target_1  0.259200  0.473684
# Target_2  0.587700  0.557368
# mean      0.675150  0.607368
# h_mean    0.564113  0.586179
# 100%|██████████| 24/24 [00:16<00:00,  1.49it/s]
# 2021-11-08 01:09:08,037 - pytorch_modeler.py - INFO - epoch:7/100, tr_loss:0.285095, src_loss:0.411626, src_mean_auc:0.839400, tgt_loss:0.740827, tgt_mean_auc:0.510900, mean_auc:0.675150,
#                AUC      pAUC
# Source_0  0.815000  0.588421
# Source_1  0.965700  0.867368
# Source_2  0.737500  0.532632
# Target_0  0.685800  0.624737
# Target_1  0.259200  0.473684
# Target_2  0.587700  0.557368
# mean      0.675150  0.607368
# h_mean    0.564113  0.586179
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:09:24,141 - pytorch_modeler.py - INFO - epoch:8/100, tr_loss:0.277617, src_loss:0.411626, src_mean_auc:0.839400, tgt_loss:0.740827, tgt_mean_auc:0.510900, mean_auc:0.675150,
#                AUC      pAUC
# Source_0  0.815000  0.588421
# Source_1  0.965700  0.867368
# Source_2  0.737500  0.532632
# Target_0  0.685800  0.624737
# Target_1  0.259200  0.473684
# Target_2  0.587700  0.557368
# mean      0.675150  0.607368
# h_mean    0.564113  0.586179
# 100%|██████████| 24/24 [00:15<00:00,  1.52it/s]
# 2021-11-08 01:09:40,186 - pytorch_modeler.py - INFO - epoch:9/100, tr_loss:0.272782, src_loss:0.411626, src_mean_auc:0.839400, tgt_loss:0.740827, tgt_mean_auc:0.510900, mean_auc:0.675150,
#                AUC      pAUC
# Source_0  0.815000  0.588421
# Source_1  0.965700  0.867368
# Source_2  0.737500  0.532632
# Target_0  0.685800  0.624737
# Target_1  0.259200  0.473684
# Target_2  0.587700  0.557368
# mean      0.675150  0.607368
# h_mean    0.564113  0.586179
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 100%|██████████| 600/600 [01:00<00:00,  9.84it/s]
# 100%|██████████| 600/600 [01:00<00:00,  9.93it/s]
# 2021-11-08 01:11:57,679 - pytorch_modeler.py - INFO - epoch:10/100, tr_loss:0.267882, src_loss:0.237384, src_mean_auc:0.745333, tgt_loss:0.175583, tgt_mean_auc:0.593967, mean_auc:0.669650,
#                AUC      pAUC
# Source_0  0.809800  0.714211
# Source_1  0.718000  0.720000
# Source_2  0.708200  0.534211
# Target_0  0.653800  0.568421
# Target_1  0.595300  0.623158
# Target_2  0.532800  0.523684
# mean      0.669650  0.613947
# h_mean    0.657471  0.603956
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:12:13,788 - pytorch_modeler.py - INFO - epoch:11/100, tr_loss:0.260446, src_loss:0.237384, src_mean_auc:0.745333, tgt_loss:0.175583, tgt_mean_auc:0.593967, mean_auc:0.669650,
#                AUC      pAUC
# Source_0  0.809800  0.714211
# Source_1  0.718000  0.720000
# Source_2  0.708200  0.534211
# Target_0  0.653800  0.568421
# Target_1  0.595300  0.623158
# Target_2  0.532800  0.523684
# mean      0.669650  0.613947
# h_mean    0.657471  0.603956
# 100%|██████████| 24/24 [00:15<00:00,  1.52it/s]
# 2021-11-08 01:12:29,816 - pytorch_modeler.py - INFO - epoch:12/100, tr_loss:0.246756, src_loss:0.237384, src_mean_auc:0.745333, tgt_loss:0.175583, tgt_mean_auc:0.593967, mean_auc:0.669650,
#                AUC      pAUC
# Source_0  0.809800  0.714211
# Source_1  0.718000  0.720000
# Source_2  0.708200  0.534211
# Target_0  0.653800  0.568421
# Target_1  0.595300  0.623158
# Target_2  0.532800  0.523684
# mean      0.669650  0.613947
# h_mean    0.657471  0.603956
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:12:45,884 - pytorch_modeler.py - INFO - epoch:13/100, tr_loss:0.236006, src_loss:0.237384, src_mean_auc:0.745333, tgt_loss:0.175583, tgt_mean_auc:0.593967, mean_auc:0.669650,
#                AUC      pAUC
# Source_0  0.809800  0.714211
# Source_1  0.718000  0.720000
# Source_2  0.708200  0.534211
# Target_0  0.653800  0.568421
# Target_1  0.595300  0.623158
# Target_2  0.532800  0.523684
# mean      0.669650  0.613947
# h_mean    0.657471  0.603956
# 100%|██████████| 24/24 [00:15<00:00,  1.52it/s]
# 2021-11-08 01:13:01,823 - pytorch_modeler.py - INFO - epoch:14/100, tr_loss:0.230628, src_loss:0.237384, src_mean_auc:0.745333, tgt_loss:0.175583, tgt_mean_auc:0.593967, mean_auc:0.669650,
#                AUC      pAUC
# Source_0  0.809800  0.714211
# Source_1  0.718000  0.720000
# Source_2  0.708200  0.534211
# Target_0  0.653800  0.568421
# Target_1  0.595300  0.623158
# Target_2  0.532800  0.523684
# mean      0.669650  0.613947
# h_mean    0.657471  0.603956
# 100%|██████████| 24/24 [00:15<00:00,  1.52it/s]
# 2021-11-08 01:13:17,871 - pytorch_modeler.py - INFO - epoch:15/100, tr_loss:0.222452, src_loss:0.237384, src_mean_auc:0.745333, tgt_loss:0.175583, tgt_mean_auc:0.593967, mean_auc:0.669650,
#                AUC      pAUC
# Source_0  0.809800  0.714211
# Source_1  0.718000  0.720000
# Source_2  0.708200  0.534211
# Target_0  0.653800  0.568421
# Target_1  0.595300  0.623158
# Target_2  0.532800  0.523684
# mean      0.669650  0.613947
# h_mean    0.657471  0.603956
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:13:33,984 - pytorch_modeler.py - INFO - epoch:16/100, tr_loss:0.211482, src_loss:0.237384, src_mean_auc:0.745333, tgt_loss:0.175583, tgt_mean_auc:0.593967, mean_auc:0.669650,
#                AUC      pAUC
# Source_0  0.809800  0.714211
# Source_1  0.718000  0.720000
# Source_2  0.708200  0.534211
# Target_0  0.653800  0.568421
# Target_1  0.595300  0.623158
# Target_2  0.532800  0.523684
# mean      0.669650  0.613947
# h_mean    0.657471  0.603956
# 100%|██████████| 24/24 [00:15<00:00,  1.53it/s]
# 2021-11-08 01:13:49,942 - pytorch_modeler.py - INFO - epoch:17/100, tr_loss:0.202217, src_loss:0.237384, src_mean_auc:0.745333, tgt_loss:0.175583, tgt_mean_auc:0.593967, mean_auc:0.669650,
#                AUC      pAUC
# Source_0  0.809800  0.714211
# Source_1  0.718000  0.720000
# Source_2  0.708200  0.534211
# Target_0  0.653800  0.568421
# Target_1  0.595300  0.623158
# Target_2  0.532800  0.523684
# mean      0.669650  0.613947
# h_mean    0.657471  0.603956
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:14:06,021 - pytorch_modeler.py - INFO - epoch:18/100, tr_loss:0.197246, src_loss:0.237384, src_mean_auc:0.745333, tgt_loss:0.175583, tgt_mean_auc:0.593967, mean_auc:0.669650,
#                AUC      pAUC
# Source_0  0.809800  0.714211
# Source_1  0.718000  0.720000
# Source_2  0.708200  0.534211
# Target_0  0.653800  0.568421
# Target_1  0.595300  0.623158
# Target_2  0.532800  0.523684
# mean      0.669650  0.613947
# h_mean    0.657471  0.603956
# 100%|██████████| 24/24 [00:15<00:00,  1.52it/s]
# 2021-11-08 01:14:22,066 - pytorch_modeler.py - INFO - epoch:19/100, tr_loss:0.189139, src_loss:0.237384, src_mean_auc:0.745333, tgt_loss:0.175583, tgt_mean_auc:0.593967, mean_auc:0.669650,
#                AUC      pAUC
# Source_0  0.809800  0.714211
# Source_1  0.718000  0.720000
# Source_2  0.708200  0.534211
# Target_0  0.653800  0.568421
# Target_1  0.595300  0.623158
# Target_2  0.532800  0.523684
# mean      0.669650  0.613947
# h_mean    0.657471  0.603956
# 100%|██████████| 24/24 [00:15<00:00,  1.52it/s]
# 100%|██████████| 600/600 [01:00<00:00,  9.97it/s]
# 100%|██████████| 600/600 [01:00<00:00,  9.97it/s]
# 2021-11-08 01:16:38,485 - pytorch_modeler.py - INFO - epoch:20/100, tr_loss:0.181666, src_loss:0.171112, src_mean_auc:0.740600, tgt_loss:0.118532, tgt_mean_auc:0.651433, mean_auc:0.696017,
#                AUC      pAUC
# Source_0  0.723700  0.571053
# Source_1  0.760200  0.768421
# Source_2  0.737900  0.518947
# Target_0  0.693000  0.597368
# Target_1  0.665400  0.687368
# Target_2  0.595900  0.531053
# mean      0.696017  0.612368
# h_mean    0.691530  0.600517
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:16:54,539 - pytorch_modeler.py - INFO - epoch:21/100, tr_loss:0.176608, src_loss:0.171112, src_mean_auc:0.740600, tgt_loss:0.118532, tgt_mean_auc:0.651433, mean_auc:0.696017,
#                AUC      pAUC
# Source_0  0.723700  0.571053
# Source_1  0.760200  0.768421
# Source_2  0.737900  0.518947
# Target_0  0.693000  0.597368
# Target_1  0.665400  0.687368
# Target_2  0.595900  0.531053
# mean      0.696017  0.612368
# h_mean    0.691530  0.600517
# 100%|██████████| 24/24 [00:15<00:00,  1.52it/s]
# 2021-11-08 01:17:10,558 - pytorch_modeler.py - INFO - epoch:22/100, tr_loss:0.171979, src_loss:0.171112, src_mean_auc:0.740600, tgt_loss:0.118532, tgt_mean_auc:0.651433, mean_auc:0.696017,
#                AUC      pAUC
# Source_0  0.723700  0.571053
# Source_1  0.760200  0.768421
# Source_2  0.737900  0.518947
# Target_0  0.693000  0.597368
# Target_1  0.665400  0.687368
# Target_2  0.595900  0.531053
# mean      0.696017  0.612368
# h_mean    0.691530  0.600517
# 100%|██████████| 24/24 [00:15<00:00,  1.52it/s]
# 2021-11-08 01:17:26,600 - pytorch_modeler.py - INFO - epoch:23/100, tr_loss:0.166013, src_loss:0.171112, src_mean_auc:0.740600, tgt_loss:0.118532, tgt_mean_auc:0.651433, mean_auc:0.696017,
#                AUC      pAUC
# Source_0  0.723700  0.571053
# Source_1  0.760200  0.768421
# Source_2  0.737900  0.518947
# Target_0  0.693000  0.597368
# Target_1  0.665400  0.687368
# Target_2  0.595900  0.531053
# mean      0.696017  0.612368
# h_mean    0.691530  0.600517
# 100%|██████████| 24/24 [00:15<00:00,  1.52it/s]
# 2021-11-08 01:17:42,589 - pytorch_modeler.py - INFO - epoch:24/100, tr_loss:0.158181, src_loss:0.171112, src_mean_auc:0.740600, tgt_loss:0.118532, tgt_mean_auc:0.651433, mean_auc:0.696017,
#                AUC      pAUC
# Source_0  0.723700  0.571053
# Source_1  0.760200  0.768421
# Source_2  0.737900  0.518947
# Target_0  0.693000  0.597368
# Target_1  0.665400  0.687368
# Target_2  0.595900  0.531053
# mean      0.696017  0.612368
# h_mean    0.691530  0.600517
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:17:58,650 - pytorch_modeler.py - INFO - epoch:25/100, tr_loss:0.150381, src_loss:0.171112, src_mean_auc:0.740600, tgt_loss:0.118532, tgt_mean_auc:0.651433, mean_auc:0.696017,
#                AUC      pAUC
# Source_0  0.723700  0.571053
# Source_1  0.760200  0.768421
# Source_2  0.737900  0.518947
# Target_0  0.693000  0.597368
# Target_1  0.665400  0.687368
# Target_2  0.595900  0.531053
# mean      0.696017  0.612368
# h_mean    0.691530  0.600517
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:18:14,730 - pytorch_modeler.py - INFO - epoch:26/100, tr_loss:0.148554, src_loss:0.171112, src_mean_auc:0.740600, tgt_loss:0.118532, tgt_mean_auc:0.651433, mean_auc:0.696017,
#                AUC      pAUC
# Source_0  0.723700  0.571053
# Source_1  0.760200  0.768421
# Source_2  0.737900  0.518947
# Target_0  0.693000  0.597368
# Target_1  0.665400  0.687368
# Target_2  0.595900  0.531053
# mean      0.696017  0.612368
# h_mean    0.691530  0.600517
# 100%|██████████| 24/24 [00:15<00:00,  1.52it/s]
# 2021-11-08 01:18:30,766 - pytorch_modeler.py - INFO - epoch:27/100, tr_loss:0.143613, src_loss:0.171112, src_mean_auc:0.740600, tgt_loss:0.118532, tgt_mean_auc:0.651433, mean_auc:0.696017,
#                AUC      pAUC
# Source_0  0.723700  0.571053
# Source_1  0.760200  0.768421
# Source_2  0.737900  0.518947
# Target_0  0.693000  0.597368
# Target_1  0.665400  0.687368
# Target_2  0.595900  0.531053
# mean      0.696017  0.612368
# h_mean    0.691530  0.600517
# 100%|██████████| 24/24 [00:15<00:00,  1.52it/s]
# 2021-11-08 01:18:46,766 - pytorch_modeler.py - INFO - epoch:28/100, tr_loss:0.139300, src_loss:0.171112, src_mean_auc:0.740600, tgt_loss:0.118532, tgt_mean_auc:0.651433, mean_auc:0.696017,
#                AUC      pAUC
# Source_0  0.723700  0.571053
# Source_1  0.760200  0.768421
# Source_2  0.737900  0.518947
# Target_0  0.693000  0.597368
# Target_1  0.665400  0.687368
# Target_2  0.595900  0.531053
# mean      0.696017  0.612368
# h_mean    0.691530  0.600517
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:19:02,870 - pytorch_modeler.py - INFO - epoch:29/100, tr_loss:0.131606, src_loss:0.171112, src_mean_auc:0.740600, tgt_loss:0.118532, tgt_mean_auc:0.651433, mean_auc:0.696017,
#                AUC      pAUC
# Source_0  0.723700  0.571053
# Source_1  0.760200  0.768421
# Source_2  0.737900  0.518947
# Target_0  0.693000  0.597368
# Target_1  0.665400  0.687368
# Target_2  0.595900  0.531053
# mean      0.696017  0.612368
# h_mean    0.691530  0.600517
# 100%|██████████| 24/24 [00:15<00:00,  1.52it/s]
# 100%|██████████| 600/600 [01:00<00:00,  9.96it/s]
# 100%|██████████| 600/600 [01:00<00:00,  9.87it/s]
# 2021-11-08 01:21:19,951 - pytorch_modeler.py - INFO - epoch:30/100, tr_loss:0.126146, src_loss:0.105349, src_mean_auc:0.798367, tgt_loss:0.081003, tgt_mean_auc:0.550600, mean_auc:0.674483,
#                AUC      pAUC
# Source_0  0.716200  0.596316
# Source_1  0.928500  0.832105
# Source_2  0.750400  0.542632
# Target_0  0.652100  0.563684
# Target_1  0.348200  0.516842
# Target_2  0.651500  0.537368
# mean      0.674483  0.598158
# h_mean    0.615623  0.583011
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:21:36,028 - pytorch_modeler.py - INFO - epoch:31/100, tr_loss:0.124323, src_loss:0.105349, src_mean_auc:0.798367, tgt_loss:0.081003, tgt_mean_auc:0.550600, mean_auc:0.674483,
#                AUC      pAUC
# Source_0  0.716200  0.596316
# Source_1  0.928500  0.832105
# Source_2  0.750400  0.542632
# Target_0  0.652100  0.563684
# Target_1  0.348200  0.516842
# Target_2  0.651500  0.537368
# mean      0.674483  0.598158
# h_mean    0.615623  0.583011
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:21:52,144 - pytorch_modeler.py - INFO - epoch:32/100, tr_loss:0.119190, src_loss:0.105349, src_mean_auc:0.798367, tgt_loss:0.081003, tgt_mean_auc:0.550600, mean_auc:0.674483,
#                AUC      pAUC
# Source_0  0.716200  0.596316
# Source_1  0.928500  0.832105
# Source_2  0.750400  0.542632
# Target_0  0.652100  0.563684
# Target_1  0.348200  0.516842
# Target_2  0.651500  0.537368
# mean      0.674483  0.598158
# h_mean    0.615623  0.583011
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:22:08,244 - pytorch_modeler.py - INFO - epoch:33/100, tr_loss:0.115558, src_loss:0.105349, src_mean_auc:0.798367, tgt_loss:0.081003, tgt_mean_auc:0.550600, mean_auc:0.674483,
#                AUC      pAUC
# Source_0  0.716200  0.596316
# Source_1  0.928500  0.832105
# Source_2  0.750400  0.542632
# Target_0  0.652100  0.563684
# Target_1  0.348200  0.516842
# Target_2  0.651500  0.537368
# mean      0.674483  0.598158
# h_mean    0.615623  0.583011
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:22:24,349 - pytorch_modeler.py - INFO - epoch:34/100, tr_loss:0.111288, src_loss:0.105349, src_mean_auc:0.798367, tgt_loss:0.081003, tgt_mean_auc:0.550600, mean_auc:0.674483,
#                AUC      pAUC
# Source_0  0.716200  0.596316
# Source_1  0.928500  0.832105
# Source_2  0.750400  0.542632
# Target_0  0.652100  0.563684
# Target_1  0.348200  0.516842
# Target_2  0.651500  0.537368
# mean      0.674483  0.598158
# h_mean    0.615623  0.583011
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:22:40,431 - pytorch_modeler.py - INFO - epoch:35/100, tr_loss:0.107318, src_loss:0.105349, src_mean_auc:0.798367, tgt_loss:0.081003, tgt_mean_auc:0.550600, mean_auc:0.674483,
#                AUC      pAUC
# Source_0  0.716200  0.596316
# Source_1  0.928500  0.832105
# Source_2  0.750400  0.542632
# Target_0  0.652100  0.563684
# Target_1  0.348200  0.516842
# Target_2  0.651500  0.537368
# mean      0.674483  0.598158
# h_mean    0.615623  0.583011
# 100%|██████████| 24/24 [00:15<00:00,  1.52it/s]
# 2021-11-08 01:22:56,445 - pytorch_modeler.py - INFO - epoch:36/100, tr_loss:0.104510, src_loss:0.105349, src_mean_auc:0.798367, tgt_loss:0.081003, tgt_mean_auc:0.550600, mean_auc:0.674483,
#                AUC      pAUC
# Source_0  0.716200  0.596316
# Source_1  0.928500  0.832105
# Source_2  0.750400  0.542632
# Target_0  0.652100  0.563684
# Target_1  0.348200  0.516842
# Target_2  0.651500  0.537368
# mean      0.674483  0.598158
# h_mean    0.615623  0.583011
# 100%|██████████| 24/24 [00:15<00:00,  1.52it/s]
# 2021-11-08 01:23:12,497 - pytorch_modeler.py - INFO - epoch:37/100, tr_loss:0.100134, src_loss:0.105349, src_mean_auc:0.798367, tgt_loss:0.081003, tgt_mean_auc:0.550600, mean_auc:0.674483,
#                AUC      pAUC
# Source_0  0.716200  0.596316
# Source_1  0.928500  0.832105
# Source_2  0.750400  0.542632
# Target_0  0.652100  0.563684
# Target_1  0.348200  0.516842
# Target_2  0.651500  0.537368
# mean      0.674483  0.598158
# h_mean    0.615623  0.583011
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:23:28,628 - pytorch_modeler.py - INFO - epoch:38/100, tr_loss:0.097041, src_loss:0.105349, src_mean_auc:0.798367, tgt_loss:0.081003, tgt_mean_auc:0.550600, mean_auc:0.674483,
#                AUC      pAUC
# Source_0  0.716200  0.596316
# Source_1  0.928500  0.832105
# Source_2  0.750400  0.542632
# Target_0  0.652100  0.563684
# Target_1  0.348200  0.516842
# Target_2  0.651500  0.537368
# mean      0.674483  0.598158
# h_mean    0.615623  0.583011
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:23:44,694 - pytorch_modeler.py - INFO - epoch:39/100, tr_loss:0.094930, src_loss:0.105349, src_mean_auc:0.798367, tgt_loss:0.081003, tgt_mean_auc:0.550600, mean_auc:0.674483,
#                AUC      pAUC
# Source_0  0.716200  0.596316
# Source_1  0.928500  0.832105
# Source_2  0.750400  0.542632
# Target_0  0.652100  0.563684
# Target_1  0.348200  0.516842
# Target_2  0.651500  0.537368
# mean      0.674483  0.598158
# h_mean    0.615623  0.583011
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 100%|██████████| 600/600 [01:00<00:00,  9.92it/s]
# 100%|██████████| 600/600 [01:00<00:00,  9.92it/s]
# 2021-11-08 01:26:01,758 - pytorch_modeler.py - INFO - epoch:40/100, tr_loss:0.090580, src_loss:0.079111, src_mean_auc:0.788400, tgt_loss:0.106281, tgt_mean_auc:0.668933, mean_auc:0.728667,
#                AUC      pAUC
# Source_0  0.798500  0.644737
# Source_1  0.871000  0.825263
# Source_2  0.695700  0.546316
# Target_0  0.649800  0.595263
# Target_1  0.782000  0.636842
# Target_2  0.575000  0.532105
# mean      0.728667  0.630088
# h_mean    0.714737  0.617112
# 100%|██████████| 24/24 [00:15<00:00,  1.50it/s]
# 2021-11-08 01:26:17,914 - pytorch_modeler.py - INFO - epoch:41/100, tr_loss:0.089903, src_loss:0.079111, src_mean_auc:0.788400, tgt_loss:0.106281, tgt_mean_auc:0.668933, mean_auc:0.728667,
#                AUC      pAUC
# Source_0  0.798500  0.644737
# Source_1  0.871000  0.825263
# Source_2  0.695700  0.546316
# Target_0  0.649800  0.595263
# Target_1  0.782000  0.636842
# Target_2  0.575000  0.532105
# mean      0.728667  0.630088
# h_mean    0.714737  0.617112
# 100%|██████████| 24/24 [00:15<00:00,  1.52it/s]
# 2021-11-08 01:26:33,863 - pytorch_modeler.py - INFO - epoch:42/100, tr_loss:0.084475, src_loss:0.079111, src_mean_auc:0.788400, tgt_loss:0.106281, tgt_mean_auc:0.668933, mean_auc:0.728667,
#                AUC      pAUC
# Source_0  0.798500  0.644737
# Source_1  0.871000  0.825263
# Source_2  0.695700  0.546316
# Target_0  0.649800  0.595263
# Target_1  0.782000  0.636842
# Target_2  0.575000  0.532105
# mean      0.728667  0.630088
# h_mean    0.714737  0.617112
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:26:49,955 - pytorch_modeler.py - INFO - epoch:43/100, tr_loss:0.082844, src_loss:0.079111, src_mean_auc:0.788400, tgt_loss:0.106281, tgt_mean_auc:0.668933, mean_auc:0.728667,
#                AUC      pAUC
# Source_0  0.798500  0.644737
# Source_1  0.871000  0.825263
# Source_2  0.695700  0.546316
# Target_0  0.649800  0.595263
# Target_1  0.782000  0.636842
# Target_2  0.575000  0.532105
# mean      0.728667  0.630088
# h_mean    0.714737  0.617112
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:27:06,061 - pytorch_modeler.py - INFO - epoch:44/100, tr_loss:0.079748, src_loss:0.079111, src_mean_auc:0.788400, tgt_loss:0.106281, tgt_mean_auc:0.668933, mean_auc:0.728667,
#                AUC      pAUC
# Source_0  0.798500  0.644737
# Source_1  0.871000  0.825263
# Source_2  0.695700  0.546316
# Target_0  0.649800  0.595263
# Target_1  0.782000  0.636842
# Target_2  0.575000  0.532105
# mean      0.728667  0.630088
# h_mean    0.714737  0.617112
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:27:22,150 - pytorch_modeler.py - INFO - epoch:45/100, tr_loss:0.078102, src_loss:0.079111, src_mean_auc:0.788400, tgt_loss:0.106281, tgt_mean_auc:0.668933, mean_auc:0.728667,
#                AUC      pAUC
# Source_0  0.798500  0.644737
# Source_1  0.871000  0.825263
# Source_2  0.695700  0.546316
# Target_0  0.649800  0.595263
# Target_1  0.782000  0.636842
# Target_2  0.575000  0.532105
# mean      0.728667  0.630088
# h_mean    0.714737  0.617112
# 100%|██████████| 24/24 [00:15<00:00,  1.52it/s]
# 2021-11-08 01:27:38,209 - pytorch_modeler.py - INFO - epoch:46/100, tr_loss:0.074101, src_loss:0.079111, src_mean_auc:0.788400, tgt_loss:0.106281, tgt_mean_auc:0.668933, mean_auc:0.728667,
#                AUC      pAUC
# Source_0  0.798500  0.644737
# Source_1  0.871000  0.825263
# Source_2  0.695700  0.546316
# Target_0  0.649800  0.595263
# Target_1  0.782000  0.636842
# Target_2  0.575000  0.532105
# mean      0.728667  0.630088
# h_mean    0.714737  0.617112
# 100%|██████████| 24/24 [00:15<00:00,  1.52it/s]
# 2021-11-08 01:27:54,221 - pytorch_modeler.py - INFO - epoch:47/100, tr_loss:0.074385, src_loss:0.079111, src_mean_auc:0.788400, tgt_loss:0.106281, tgt_mean_auc:0.668933, mean_auc:0.728667,
#                AUC      pAUC
# Source_0  0.798500  0.644737
# Source_1  0.871000  0.825263
# Source_2  0.695700  0.546316
# Target_0  0.649800  0.595263
# Target_1  0.782000  0.636842
# Target_2  0.575000  0.532105
# mean      0.728667  0.630088
# h_mean    0.714737  0.617112
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:28:10,338 - pytorch_modeler.py - INFO - epoch:48/100, tr_loss:0.071370, src_loss:0.079111, src_mean_auc:0.788400, tgt_loss:0.106281, tgt_mean_auc:0.668933, mean_auc:0.728667,
#                AUC      pAUC
# Source_0  0.798500  0.644737
# Source_1  0.871000  0.825263
# Source_2  0.695700  0.546316
# Target_0  0.649800  0.595263
# Target_1  0.782000  0.636842
# Target_2  0.575000  0.532105
# mean      0.728667  0.630088
# h_mean    0.714737  0.617112
# 100%|██████████| 24/24 [00:15<00:00,  1.51it/s]
# 2021-11-08 01:28:26,456 - pytorch_modeler.py - INFO - epoch:49/100, tr_loss:0.068806, src_loss:0.079111, src_mean_auc:0.788400, tgt_loss:0.106281, tgt_mean_auc:0.668933, mean_auc:0.728667,
#                AUC      pAUC
# Source_0  0.798500  0.644737
# Source_1  0.871000  0.825263
# Source_2  0.695700  0.546316
# Target_0  0.649800  0.595263
# Target_1  0.782000  0.636842
# Target_2  0.575000  0.532105
# mean      0.728667  0.630088
# h_mean    0.714737  0.617112
#  46%|████▌     | 11/24 [00:08<00:10,  1.30it/s]

# %%
#run(machine_types[0], dev_paths)

# %% [markdown]
# # run

# %% [raw]
# # debug
# import dcase_util
# import pandas as pd
#
# sample = pd.read_pickle('/media/hiroki/HDD1TB/research/DCASE_experiments/domain_adaptation/exp2/extraction_features/ToyCar_features.pkl')
# sample = sample['val_src']
#
# src_pred_df = dcase_util.make_pred_df(sample['wav_name'], sample['section_label'], sample['domain_label'], sample['label'], sample['label'])
#
# df1 = dcase_util.calc_dcase2021_task2_score(src_pred_df, prefix='Source')
# df2 = dcase_util.calc_dcase2021_task2_score(src_pred_df, prefix='Target')
# score = pd.concat([df1, df2])
# mean = pd.DataFrame([score.mean()], index=['mean'])
# hmean = scipy.stats.hmean(score, axis=0)
# hmean = pd.DataFrame([hmean], columns=['AUC', 'pAUC'], index=['h_mean'])
# score = score.append([mean, hmean])
