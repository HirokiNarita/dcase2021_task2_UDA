# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """

# %%
OUTPUT_ROOT = config['IO_OPTION']['SRC_OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)
OUTPUT_ROOT = config['IO_OPTION']['TGT_OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter
import timm
from timm.scheduler import CosineLRScheduler
#from torchvision.models import wide_resnet50_2, resnet18
#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
import common as com
import pytorch_modeler as modeler
from pytorch_model import EfficientNet_b1 as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %%
# effnet1 = timm.create_model('efficientnet_b1', pretrained=True)
# # M7:block[5], M8:block[6], M9:conv_head
# effnet1

# %% [markdown]
# ## load config and set logger

# %%
log_folder = config['IO_OPTION']['SRC_OUTPUT_ROOT']+'/{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_folder, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(42)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
dev_dir = INPUT_ROOT + "/dev_data"
add_dev_dir = INPUT_ROOT + "/add_dev_data"
PREMODEL_ROOT = config['IO_OPTION']['PREMODEL_ROOT']
# machine type
machine_types = os.listdir(dev_dir)
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['SRC_OUTPUT_ROOT']
MODEL_DIR = OUTPUT_ROOT + '/models'

TB_DIR = OUTPUT_ROOT + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
PRED_DIR = OUTPUT_ROOT + '/pred'
SCORE_DIR = OUTPUT_ROOT + '/score'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
os.makedirs(PRED_DIR, exist_ok=True)
os.makedirs(SCORE_DIR, exist_ok=True)

# copy config
# shutil.copy('./config.yaml', OUTPUT_ROOT)

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## make path list

# %% [markdown]
# - __train_paths__ ([dict]): Each Machine Type
#     - __ToyCar__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) :paths
#     - __ToyTrain__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) : paths
#     - ...

# %%
percent = 0.1

# %%
dev_paths = {}

for machine_type in machine_types:
    # dev train
    dev_train_paths = [f"{dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/train")]
    dev_train_paths = sorted(dev_train_paths)
    
    print(f'Machine {machine_type}', end=',')
    print(f'dev_train_size : {len(dev_train_paths)}', end=', ')
    dev_train_source_paths = [path for path in dev_train_paths if 'source' in path]
    print(f'source_size : {len(dev_train_source_paths)}', end=', ')
    dev_train_target_paths = [path for path in dev_train_paths if 'target' in path]
    print(f'target_size : {len(dev_train_target_paths)}', end=', ')
    # increse tgt
    num_increse_tgt = int(len(dev_train_source_paths) * percent)
    increse_dev_train_target_paths = dev_train_target_paths * num_increse_tgt
    # concat
    dev_train_paths = dev_train_source_paths + increse_dev_train_target_paths
    
    # add_dev train
    add_dev_paths = [f"{add_dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{add_dev_dir}/{machine_type}/train")]
    add_dev_paths = sorted(add_dev_paths)
    print(f'adddev_train_size : {len(add_dev_paths)}', end=', ')
    add_dev_source_paths = [path for path in add_dev_paths if 'source' in path]
    print(f'source_size : {len(add_dev_source_paths)}', end=', ')
    add_dev_target_paths = [path for path in add_dev_paths if 'target' in path]
    print(f'target_size : {len(add_dev_target_paths)}')
    # increse tgt
    num_increse_tgt = int(len(add_dev_source_paths) * percent)
    increse_add_dev_target_paths = add_dev_target_paths * num_increse_tgt
    # concat
    add_dev_paths = add_dev_source_paths + increse_add_dev_target_paths

    print('==============================================================')
    
    # dev_source valid
    dev_source_paths = [f"{dev_dir}/{machine_type}/source_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/source_test")]
    dev_source_paths = sorted(dev_source_paths)
    
    # dev_target valid
    dev_target_paths = [f"{dev_dir}/{machine_type}/target_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/target_test")]
    dev_target_paths = sorted(dev_target_paths)
    
    # bundle
    dev_paths[machine_type] = {}
    dev_paths[machine_type]['train'] = dev_train_paths + add_dev_paths
    dev_paths[machine_type]['valid_source'] = dev_source_paths
    dev_paths[machine_type]['valid_target'] = dev_target_paths
# Out:
# Machine pump,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine gearbox,dev_train_size : 3026, source_size : 3017, target_size : 9, adddev_train_size : 3114, source_size : 3105, target_size : 9
# ==============================================================
# Machine slider,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyCar,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine valve,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyTrain,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine fan,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================

# %%
machine_types
# Out:
# ['pump', 'gearbox', 'slider', 'ToyCar', 'valve', 'ToyTrain', 'fan']

# %%
#############################################################################
# run
#############################################################################
def run(machine_type, dev_paths):
    com.tic()
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dev_train_paths
    dataloaders_dict = modeler.make_dataloader(dev_paths, machine_type)
    # parameter setting
    logger.info('TRAINING')
    
    model = Model(n_classes=6)
    pretrained_dict = torch.load(config['IO_OPTION']['PREMODEL_ROOT'] + f'/{machine_type}_model.pkl')
    model.load_state_dict(pretrained_dict, strict=False)
    
    for param in model.parameters():
        param.requires_grad = False
    for param in model.ae.parameters():
        param.requires_grad = True
#     for param in model.CenterLoss.parameters():
#         param.requires_grad = True
    
    optimizer = torch.optim.Adam(model.parameters(),lr=1e-3)
    scheduler = CosineLRScheduler(optimizer, t_initial=100, lr_min=1e-5, 
                                  warmup_t=10, warmup_lr_init=5e-5, warmup_prefix=True)
    output_dict, model, pred_df, score_df = modeler.run_training(model, dataloaders_dict, writer, optimizer, scheduler)
    
    # output
    feature_out_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
    model_out_path = f'{MODEL_DIR}/{machine_type}_model.pkl'
    pred_out_path = f'{PRED_DIR}/{machine_type}_pred.csv'
    score_out_path = f'{SCORE_DIR}/{machine_type}_pred.csv'
    # save
    pd.to_pickle(output_dict, feature_out_path)
    torch.save(model.state_dict(), model_out_path)
    pred_df.to_csv(pred_out_path)
    score_df.to_csv(score_out_path)
    logger.info(f'SAVE SUCCESS : {model_out_path}')
    
    com.toc()

# %%
#run(machine_types[0], dev_paths)

# %%
for machine_type in machine_types[0:]:
    run(machine_type, dev_paths)
# Out:
# 2021-11-09 13:10:57,646 - 00_train.py - INFO - TARGET MACHINE_TYPE: pump
# 2021-11-09 13:10:57,647 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-11-09 13:10:57,651 - 00_train.py - INFO - TRAINING
# use: cuda:0
# 100%|██████████| 24/24 [00:06<00:00,  3.80it/s]
# 100%|██████████| 600/600 [00:59<00:00, 10.08it/s]
# 100%|██████████| 600/600 [00:58<00:00, 10.19it/s]
# 2021-11-09 13:13:05,369 - pytorch_modeler.py - INFO - epoch:1/200, tr_loss:17.995496, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.74it/s]
# 2021-11-09 13:13:11,937 - pytorch_modeler.py - INFO - epoch:2/200, tr_loss:4.752956, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.88it/s]
# 2021-11-09 13:13:18,307 - pytorch_modeler.py - INFO - epoch:3/200, tr_loss:1.386628, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.78it/s]
# 2021-11-09 13:13:24,824 - pytorch_modeler.py - INFO - epoch:4/200, tr_loss:0.755887, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.78it/s]
# 2021-11-09 13:13:31,338 - pytorch_modeler.py - INFO - epoch:5/200, tr_loss:0.471110, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.75it/s]
# 2021-11-09 13:13:37,899 - pytorch_modeler.py - INFO - epoch:6/200, tr_loss:0.344241, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.90it/s]
# 2021-11-09 13:13:44,225 - pytorch_modeler.py - INFO - epoch:7/200, tr_loss:0.269752, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.90it/s]
# 2021-11-09 13:13:50,547 - pytorch_modeler.py - INFO - epoch:8/200, tr_loss:0.216995, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.83it/s]
# 2021-11-09 13:13:56,990 - pytorch_modeler.py - INFO - epoch:9/200, tr_loss:0.178068, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.86it/s]
# 2021-11-09 13:14:03,368 - pytorch_modeler.py - INFO - epoch:10/200, tr_loss:0.150338, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.85it/s]
# 2021-11-09 13:14:09,772 - pytorch_modeler.py - INFO - epoch:11/200, tr_loss:0.128228, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.88it/s]
# 2021-11-09 13:14:16,121 - pytorch_modeler.py - INFO - epoch:12/200, tr_loss:0.114565, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.66it/s]
# 2021-11-09 13:14:22,854 - pytorch_modeler.py - INFO - epoch:13/200, tr_loss:0.102083, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.65it/s]
# 2021-11-09 13:14:29,614 - pytorch_modeler.py - INFO - epoch:14/200, tr_loss:0.095956, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.68it/s]
# 2021-11-09 13:14:36,301 - pytorch_modeler.py - INFO - epoch:15/200, tr_loss:0.087767, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.80it/s]
# 2021-11-09 13:14:42,771 - pytorch_modeler.py - INFO - epoch:16/200, tr_loss:0.078427, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.78it/s]
# 2021-11-09 13:14:49,292 - pytorch_modeler.py - INFO - epoch:17/200, tr_loss:0.074586, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.75it/s]
# 2021-11-09 13:14:55,905 - pytorch_modeler.py - INFO - epoch:18/200, tr_loss:0.068319, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.73it/s]
# 2021-11-09 13:15:02,499 - pytorch_modeler.py - INFO - epoch:19/200, tr_loss:0.065584, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.77it/s]
# 2021-11-09 13:15:09,042 - pytorch_modeler.py - INFO - epoch:20/200, tr_loss:0.062025, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.81it/s]
# 2021-11-09 13:15:15,508 - pytorch_modeler.py - INFO - epoch:21/200, tr_loss:0.059523, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.92it/s]
# 2021-11-09 13:15:21,800 - pytorch_modeler.py - INFO - epoch:22/200, tr_loss:0.056323, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.87it/s]
# 2021-11-09 13:15:28,167 - pytorch_modeler.py - INFO - epoch:23/200, tr_loss:0.053582, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.89it/s]
# 2021-11-09 13:15:34,517 - pytorch_modeler.py - INFO - epoch:24/200, tr_loss:0.051579, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.68it/s]
# 2021-11-09 13:15:41,201 - pytorch_modeler.py - INFO - epoch:25/200, tr_loss:0.051308, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.88it/s]
# 2021-11-09 13:15:47,573 - pytorch_modeler.py - INFO - epoch:26/200, tr_loss:0.048919, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.75it/s]
# 2021-11-09 13:15:54,158 - pytorch_modeler.py - INFO - epoch:27/200, tr_loss:0.046858, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.80it/s]
# 2021-11-09 13:16:00,647 - pytorch_modeler.py - INFO - epoch:28/200, tr_loss:0.045819, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.87it/s]
# 2021-11-09 13:16:07,036 - pytorch_modeler.py - INFO - epoch:29/200, tr_loss:0.044126, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.76it/s]
# 2021-11-09 13:16:13,589 - pytorch_modeler.py - INFO - epoch:30/200, tr_loss:0.043100, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.71it/s]
# 2021-11-09 13:16:20,229 - pytorch_modeler.py - INFO - epoch:31/200, tr_loss:0.042918, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.74it/s]
# 2021-11-09 13:16:26,830 - pytorch_modeler.py - INFO - epoch:32/200, tr_loss:0.044180, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.88it/s]
# 2021-11-09 13:16:33,182 - pytorch_modeler.py - INFO - epoch:33/200, tr_loss:0.041728, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.44it/s]
# 2021-11-09 13:16:40,310 - pytorch_modeler.py - INFO - epoch:34/200, tr_loss:0.041686, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.76it/s]
# 2021-11-09 13:16:46,878 - pytorch_modeler.py - INFO - epoch:35/200, tr_loss:0.040453, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.54it/s]
# 2021-11-09 13:16:53,844 - pytorch_modeler.py - INFO - epoch:36/200, tr_loss:0.040338, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.86it/s]
# 2021-11-09 13:17:00,258 - pytorch_modeler.py - INFO - epoch:37/200, tr_loss:0.040864, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.82it/s]
# 2021-11-09 13:17:06,708 - pytorch_modeler.py - INFO - epoch:38/200, tr_loss:0.039965, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.74it/s]
# 2021-11-09 13:17:13,302 - pytorch_modeler.py - INFO - epoch:39/200, tr_loss:0.039890, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.78it/s]
# 2021-11-09 13:17:19,838 - pytorch_modeler.py - INFO - epoch:40/200, tr_loss:0.038718, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.81it/s]
# 2021-11-09 13:17:26,305 - pytorch_modeler.py - INFO - epoch:41/200, tr_loss:0.037965, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.88it/s]
# 2021-11-09 13:17:32,669 - pytorch_modeler.py - INFO - epoch:42/200, tr_loss:0.037777, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.88it/s]
# 2021-11-09 13:17:39,026 - pytorch_modeler.py - INFO - epoch:43/200, tr_loss:0.038010, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.82it/s]
# 2021-11-09 13:17:45,491 - pytorch_modeler.py - INFO - epoch:44/200, tr_loss:0.037383, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.47it/s]
# 2021-11-09 13:17:52,590 - pytorch_modeler.py - INFO - epoch:45/200, tr_loss:0.036773, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.90it/s]
# 2021-11-09 13:17:58,909 - pytorch_modeler.py - INFO - epoch:46/200, tr_loss:0.037367, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.82it/s]
# 2021-11-09 13:18:05,370 - pytorch_modeler.py - INFO - epoch:47/200, tr_loss:0.036832, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.81it/s]
# 2021-11-09 13:18:11,850 - pytorch_modeler.py - INFO - epoch:48/200, tr_loss:0.034975, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.92it/s]
# 2021-11-09 13:18:18,150 - pytorch_modeler.py - INFO - epoch:49/200, tr_loss:0.036424, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.80it/s]
# 2021-11-09 13:18:24,642 - pytorch_modeler.py - INFO - epoch:50/200, tr_loss:0.035920, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.80it/s]
# 2021-11-09 13:18:31,141 - pytorch_modeler.py - INFO - epoch:51/200, tr_loss:0.034985, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.93it/s]
# 2021-11-09 13:18:37,428 - pytorch_modeler.py - INFO - epoch:52/200, tr_loss:0.034959, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.89it/s]
# 2021-11-09 13:18:43,781 - pytorch_modeler.py - INFO - epoch:53/200, tr_loss:0.034167, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.81it/s]
# 2021-11-09 13:18:50,264 - pytorch_modeler.py - INFO - epoch:54/200, tr_loss:0.034731, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.92it/s]
# 2021-11-09 13:18:56,550 - pytorch_modeler.py - INFO - epoch:55/200, tr_loss:0.034190, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.81it/s]
# 2021-11-09 13:19:03,018 - pytorch_modeler.py - INFO - epoch:56/200, tr_loss:0.033622, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.71it/s]
# 2021-11-09 13:19:09,681 - pytorch_modeler.py - INFO - epoch:57/200, tr_loss:0.032983, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.52it/s]
# 2021-11-09 13:19:16,686 - pytorch_modeler.py - INFO - epoch:58/200, tr_loss:0.034292, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.60it/s]
# 2021-11-09 13:19:23,513 - pytorch_modeler.py - INFO - epoch:59/200, tr_loss:0.033376, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.48it/s]
# 2021-11-09 13:19:30,577 - pytorch_modeler.py - INFO - epoch:60/200, tr_loss:0.033178, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.98it/s]
# 2021-11-09 13:19:36,796 - pytorch_modeler.py - INFO - epoch:61/200, tr_loss:0.033736, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.90it/s]
# 2021-11-09 13:19:43,121 - pytorch_modeler.py - INFO - epoch:62/200, tr_loss:0.033355, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.56it/s]
# 2021-11-09 13:19:50,040 - pytorch_modeler.py - INFO - epoch:63/200, tr_loss:0.033099, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.86it/s]
# 2021-11-09 13:19:56,442 - pytorch_modeler.py - INFO - epoch:64/200, tr_loss:0.033966, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.68it/s]
# 2021-11-09 13:20:03,145 - pytorch_modeler.py - INFO - epoch:65/200, tr_loss:0.034200, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.66it/s]
# 2021-11-09 13:20:09,878 - pytorch_modeler.py - INFO - epoch:66/200, tr_loss:0.033179, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.82it/s]
# 2021-11-09 13:20:16,336 - pytorch_modeler.py - INFO - epoch:67/200, tr_loss:0.032628, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.72it/s]
# 2021-11-09 13:20:22,963 - pytorch_modeler.py - INFO - epoch:68/200, tr_loss:0.032562, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.66it/s]
# 2021-11-09 13:20:29,686 - pytorch_modeler.py - INFO - epoch:69/200, tr_loss:0.032280, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.70it/s]
# 2021-11-09 13:20:36,323 - pytorch_modeler.py - INFO - epoch:70/200, tr_loss:0.032344, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.74it/s]
# 2021-11-09 13:20:42,898 - pytorch_modeler.py - INFO - epoch:71/200, tr_loss:0.031835, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.87it/s]
# 2021-11-09 13:20:49,256 - pytorch_modeler.py - INFO - epoch:72/200, tr_loss:0.031726, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.89it/s]
# 2021-11-09 13:20:55,590 - pytorch_modeler.py - INFO - epoch:73/200, tr_loss:0.032073, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.86it/s]
# 2021-11-09 13:21:02,005 - pytorch_modeler.py - INFO - epoch:74/200, tr_loss:0.031126, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.73it/s]
# 2021-11-09 13:21:08,615 - pytorch_modeler.py - INFO - epoch:75/200, tr_loss:0.031504, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.77it/s]
# 2021-11-09 13:21:15,169 - pytorch_modeler.py - INFO - epoch:76/200, tr_loss:0.032262, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.81it/s]
# 2021-11-09 13:21:21,636 - pytorch_modeler.py - INFO - epoch:77/200, tr_loss:0.031078, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.82it/s]
# 2021-11-09 13:21:28,093 - pytorch_modeler.py - INFO - epoch:78/200, tr_loss:0.031219, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.65it/s]
# 2021-11-09 13:21:34,854 - pytorch_modeler.py - INFO - epoch:79/200, tr_loss:0.031670, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.73it/s]
# 2021-11-09 13:21:41,477 - pytorch_modeler.py - INFO - epoch:80/200, tr_loss:0.031649, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.80it/s]
# 2021-11-09 13:21:47,947 - pytorch_modeler.py - INFO - epoch:81/200, tr_loss:0.031398, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.84it/s]
# 2021-11-09 13:21:54,372 - pytorch_modeler.py - INFO - epoch:82/200, tr_loss:0.032322, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.83it/s]
# 2021-11-09 13:22:00,830 - pytorch_modeler.py - INFO - epoch:83/200, tr_loss:0.030964, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.88it/s]
# 2021-11-09 13:22:07,177 - pytorch_modeler.py - INFO - epoch:84/200, tr_loss:0.028958, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.83it/s]
# 2021-11-09 13:22:13,621 - pytorch_modeler.py - INFO - epoch:85/200, tr_loss:0.030913, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.87it/s]
# 2021-11-09 13:22:19,997 - pytorch_modeler.py - INFO - epoch:86/200, tr_loss:0.030370, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.77it/s]
# 2021-11-09 13:22:26,533 - pytorch_modeler.py - INFO - epoch:87/200, tr_loss:0.030309, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.75it/s]
# 2021-11-09 13:22:33,125 - pytorch_modeler.py - INFO - epoch:88/200, tr_loss:0.030445, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.74it/s]
# 2021-11-09 13:22:39,734 - pytorch_modeler.py - INFO - epoch:89/200, tr_loss:0.030859, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.89it/s]
# 2021-11-09 13:22:46,061 - pytorch_modeler.py - INFO - epoch:90/200, tr_loss:0.030078, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.66it/s]
# 2021-11-09 13:22:52,804 - pytorch_modeler.py - INFO - epoch:91/200, tr_loss:0.029801, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.65it/s]
# 2021-11-09 13:22:59,557 - pytorch_modeler.py - INFO - epoch:92/200, tr_loss:0.030220, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.71it/s]
# 2021-11-09 13:23:06,197 - pytorch_modeler.py - INFO - epoch:93/200, tr_loss:0.030386, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.83it/s]
# 2021-11-09 13:23:12,632 - pytorch_modeler.py - INFO - epoch:94/200, tr_loss:0.030480, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.78it/s]
# 2021-11-09 13:23:19,152 - pytorch_modeler.py - INFO - epoch:95/200, tr_loss:0.029532, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.59it/s]
# 2021-11-09 13:23:26,006 - pytorch_modeler.py - INFO - epoch:96/200, tr_loss:0.030216, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.50it/s]
# 2021-11-09 13:23:33,056 - pytorch_modeler.py - INFO - epoch:97/200, tr_loss:0.029165, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# Source_0  0.20630  0.473684
# Source_1  0.03850  0.478947
# Source_2  0.25460  0.484737
# Target_0  0.26920  0.473684
# Target_1  0.12460  0.477368
# Target_2  0.37220  0.485263
# mean      0.21090  0.478947
# h_mean    0.12201  0.478902
# 100%|██████████| 24/24 [00:06<00:00,  3.83it/s]
# 2021-11-09 13:23:39,488 - pytorch_modeler.py - INFO - epoch:98/200, tr_loss:0.030491, src_loss:2.315667, src_mean_auc:0.166467, tgt_loss:2.220407, tgt_mean_auc:0.255333, mean_auc:0.210900,
#               AUC      pAUC
# ...
# 2021-11-09 14:06:38,965 - pytorch_modeler.py - INFO - epoch:104/200, tr_loss:0.028924, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.89it/s]
# 2021-11-09 14:06:45,293 - pytorch_modeler.py - INFO - epoch:105/200, tr_loss:0.028421, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.82it/s]
# 2021-11-09 14:06:51,738 - pytorch_modeler.py - INFO - epoch:106/200, tr_loss:0.028755, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.92it/s]
# 2021-11-09 14:06:58,050 - pytorch_modeler.py - INFO - epoch:107/200, tr_loss:0.029620, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.93it/s]
# 2021-11-09 14:07:04,317 - pytorch_modeler.py - INFO - epoch:108/200, tr_loss:0.029257, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.89it/s]
# 2021-11-09 14:07:10,653 - pytorch_modeler.py - INFO - epoch:109/200, tr_loss:0.029318, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.86it/s]
# 2021-11-09 14:07:17,030 - pytorch_modeler.py - INFO - epoch:110/200, tr_loss:0.028737, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.82it/s]
# 2021-11-09 14:07:23,463 - pytorch_modeler.py - INFO - epoch:111/200, tr_loss:0.086560, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.86it/s]
# 2021-11-09 14:07:29,853 - pytorch_modeler.py - INFO - epoch:112/200, tr_loss:0.040781, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.85it/s]
# 2021-11-09 14:07:36,242 - pytorch_modeler.py - INFO - epoch:113/200, tr_loss:0.033871, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.87it/s]
# 2021-11-09 14:07:42,608 - pytorch_modeler.py - INFO - epoch:114/200, tr_loss:0.032405, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.88it/s]
# 2021-11-09 14:07:48,989 - pytorch_modeler.py - INFO - epoch:115/200, tr_loss:0.032524, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.78it/s]
# 2021-11-09 14:07:55,503 - pytorch_modeler.py - INFO - epoch:116/200, tr_loss:0.031180, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.86it/s]
# 2021-11-09 14:08:01,896 - pytorch_modeler.py - INFO - epoch:117/200, tr_loss:0.030949, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.76it/s]
# 2021-11-09 14:08:08,428 - pytorch_modeler.py - INFO - epoch:118/200, tr_loss:0.031095, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.80it/s]
# 2021-11-09 14:08:14,902 - pytorch_modeler.py - INFO - epoch:119/200, tr_loss:0.029927, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.78it/s]
# 2021-11-09 14:08:21,428 - pytorch_modeler.py - INFO - epoch:120/200, tr_loss:0.030126, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.87it/s]
# 2021-11-09 14:08:27,802 - pytorch_modeler.py - INFO - epoch:121/200, tr_loss:0.030624, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.78it/s]
# 2021-11-09 14:08:34,301 - pytorch_modeler.py - INFO - epoch:122/200, tr_loss:0.029770, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.88it/s]
# 2021-11-09 14:08:40,653 - pytorch_modeler.py - INFO - epoch:123/200, tr_loss:0.029284, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.77it/s]
# 2021-11-09 14:08:47,170 - pytorch_modeler.py - INFO - epoch:124/200, tr_loss:0.029658, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.79it/s]
# 2021-11-09 14:08:53,664 - pytorch_modeler.py - INFO - epoch:125/200, tr_loss:0.028490, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.81it/s]
# 2021-11-09 14:09:00,123 - pytorch_modeler.py - INFO - epoch:126/200, tr_loss:0.029260, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.76it/s]
# 2021-11-09 14:09:06,662 - pytorch_modeler.py - INFO - epoch:127/200, tr_loss:0.029089, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.88it/s]
# 2021-11-09 14:09:13,031 - pytorch_modeler.py - INFO - epoch:128/200, tr_loss:0.028810, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.92it/s]
# 2021-11-09 14:09:19,308 - pytorch_modeler.py - INFO - epoch:129/200, tr_loss:0.027963, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.87it/s]
# 2021-11-09 14:09:25,675 - pytorch_modeler.py - INFO - epoch:130/200, tr_loss:0.028378, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.83it/s]
# 2021-11-09 14:09:32,112 - pytorch_modeler.py - INFO - epoch:131/200, tr_loss:0.027394, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.74it/s]
# 2021-11-09 14:09:38,676 - pytorch_modeler.py - INFO - epoch:132/200, tr_loss:0.028864, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.83it/s]
# 2021-11-09 14:09:45,091 - pytorch_modeler.py - INFO - epoch:133/200, tr_loss:0.028185, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.88it/s]
# 2021-11-09 14:09:51,440 - pytorch_modeler.py - INFO - epoch:134/200, tr_loss:0.027735, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
# 100%|██████████| 24/24 [00:06<00:00,  3.90it/s]
# 2021-11-09 14:09:57,760 - pytorch_modeler.py - INFO - epoch:135/200, tr_loss:0.027897, src_loss:0.057128, src_mean_auc:0.783417, tgt_loss:0.056080, tgt_mean_auc:0.758916, mean_auc:0.771167,
#                AUC      pAUC
# Source_0  0.831111  0.719427
# Source_1  0.827246  0.597953
# Source_2  0.691895  0.518956
# Target_0  0.766590  0.541403
# Target_1  0.761746  0.567089
# Target_2  0.748413  0.539474
# mean      0.771167  0.580717
# h_mean    0.768171  0.573975
#  88%|████████▊ | 21/24 [00:05<00:00,  4.90it/s]

# %%
#run(machine_types[0], dev_paths)

# %% [markdown]
# # run

# %% [raw]
# # debug
# import dcase_util
# import pandas as pd
#
# sample = pd.read_pickle('/media/hiroki/HDD1TB/research/DCASE_experiments/domain_adaptation/exp2/extraction_features/ToyCar_features.pkl')
# sample = sample['val_src']
#
# src_pred_df = dcase_util.make_pred_df(sample['wav_name'], sample['section_label'], sample['domain_label'], sample['label'], sample['label'])
#
# df1 = dcase_util.calc_dcase2021_task2_score(src_pred_df, prefix='Source')
# df2 = dcase_util.calc_dcase2021_task2_score(src_pred_df, prefix='Target')
# score = pd.concat([df1, df2])
# mean = pd.DataFrame([score.mean()], index=['mean'])
# hmean = scipy.stats.hmean(score, axis=0)
# hmean = pd.DataFrame([hmean], columns=['AUC', 'pAUC'], index=['h_mean'])
# score = score.append([mean, hmean])
