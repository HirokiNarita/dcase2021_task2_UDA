# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter
import timm
import torch_optimizer
#from torchvision.models import wide_resnet50_2, resnet18
#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
import common as com
import pytorch_modeler as modeler
from pytorch_model import IDNN as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %% [markdown]
# ## load config and set logger

# %%
log_folder = config['IO_OPTION']['OUTPUT_ROOT']+'/{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_folder, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(42)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
dev_dir = INPUT_ROOT + "/dev_data"
add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = os.listdir(dev_dir)
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'

TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
PRED_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/pred'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
os.makedirs(PRED_DIR, exist_ok=True)

# copy config
shutil.copy('./config.yaml', OUTPUT_ROOT)
# Out:
# '/media/hiroki/HDD1TB/research/DCASE_experiments/domain_adaptation/IDNN/baseline/config.yaml'

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## make path list

# %% [markdown]
# - __train_paths__ ([dict]): Each Machine Type
#     - __ToyCar__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) :paths
#     - __ToyTrain__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) : paths
#     - ...

# %%
dev_paths = {}

for machine_type in machine_types:
    # dev train
    dev_train_paths = [f"{dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/train")]
    dev_train_paths = sorted(dev_train_paths)
    
    print(f'Machine {machine_type}', end=',')
    print(f'dev_train_size : {len(dev_train_paths)}', end=', ')
    dev_train_source_paths = [path for path in dev_train_paths if 'source' in path]
    print(f'source_size : {len(dev_train_source_paths)}', end=', ')
    dev_train_target_paths = [path for path in dev_train_paths if 'target' in path]
    print(f'target_size : {len(dev_train_target_paths)}', end=', ')
    # source mode
    dev_train_paths = dev_train_source_paths + dev_train_target_paths
    
    # add_dev train
    add_dev_paths = [f"{add_dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{add_dev_dir}/{machine_type}/train")]
    add_dev_paths = sorted(add_dev_paths)
    print(f'adddev_train_size : {len(dev_train_paths)}', end=', ')
    add_dev_source_paths = [path for path in add_dev_paths if 'source' in path]
    print(f'source_size : {len(add_dev_source_paths)}', end=', ')
    add_dev_target_paths = [path for path in add_dev_paths if 'target' in path]
    print(f'target_size : {len(add_dev_target_paths)}')
    # source mode
    add_dev_paths = add_dev_source_paths + add_dev_target_paths
    print('==============================================================')
    
    # dev_source valid
    dev_source_paths = [f"{dev_dir}/{machine_type}/source_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/source_test")]
    dev_source_paths = sorted(dev_source_paths)
    
    # dev_target valid
    dev_target_paths = [f"{dev_dir}/{machine_type}/target_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/target_test")]
    dev_target_paths = sorted(dev_target_paths)
    
    # bundle
    dev_paths[machine_type] = {}
    dev_paths[machine_type]['train'] = dev_train_paths + add_dev_paths
    dev_paths[machine_type]['valid_source'] = dev_source_paths
    dev_paths[machine_type]['valid_target'] = dev_target_paths
# Out:
# Machine fan,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine gearbox,dev_train_size : 3026, source_size : 3017, target_size : 9, adddev_train_size : 3026, source_size : 3105, target_size : 9
# ==============================================================
# Machine pump,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine slider,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyCar,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyTrain,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine valve,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================

# %%
machine_types
# Out:
# ['fan', 'gearbox', 'pump', 'slider', 'ToyCar', 'ToyTrain', 'valve']

# %%
#############################################################################
# run
#############################################################################
def run(machine_type, dev_paths):
    com.tic()
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dev_train_paths
    dataloaders_dict = modeler.make_dataloader(dev_paths, machine_type)
    # parameter setting
    logger.info('TRAINING')
    model = Model(in_size=512, out_size=128)
    
    optimizer = torch.optim.Adam(model.parameters(),lr=1e-3)
    output_dict, model, pred_df = modeler.run_training(model, dataloaders_dict, writer, optimizer)
    
    # output
    feature_out_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
    model_out_path = f'{MODEL_DIR}/{machine_type}_model.pkl'
    pred_out_path = f'{PRED_DIR}/{machine_type}_pred.csv'
    # save
    pd.to_pickle(output_dict, feature_out_path)
    torch.save(model.state_dict(), model_out_path)
    pred_df.to_csv(pred_out_path)
    logger.info(f'SAVE SUCCESS : {model_out_path}')
    
    com.toc()

# %% [raw]
# # debug
# import dcase_util
# import pandas as pd
#
# sample = pd.read_pickle('/media/hiroki/HDD1TB/research/DCASE_experiments/domain_adaptation/exp2/extraction_features/ToyCar_features.pkl')
# sample = sample['val_src']
#
# src_pred_df = dcase_util.make_pred_df(sample['wav_name'], sample['section_label'], sample['domain_label'], sample['label'], sample['label'])
#
# df1 = dcase_util.calc_dcase2021_task2_score(src_pred_df, prefix='Source')
# df2 = dcase_util.calc_dcase2021_task2_score(src_pred_df, prefix='Target')
# score = pd.concat([df1, df2])
# mean = pd.DataFrame([score.mean()], index=['mean'])
# hmean = scipy.stats.hmean(score, axis=0)
# hmean = pd.DataFrame([hmean], columns=['AUC', 'pAUC'], index=['h_mean'])
# score = score.append([mean, hmean])

# %% [markdown]
# # run

# %%
for machine_type in machine_types:
    run(machine_type, dev_paths)
# Out:
# 2021-09-30 00:16:40,796 - 00_train.py - INFO - TARGET MACHINE_TYPE: fan
# 2021-09-30 00:16:40,796 - 00_train.py - INFO - MAKE DATA_LOADER
# 100%|██████████| 6018/6018 [01:10<00:00, 85.14it/s]
# 100%|██████████| 600/600 [00:05<00:00, 110.44it/s]
# 100%|██████████| 600/600 [00:04<00:00, 125.80it/s]
# 2021-09-30 00:18:01,690 - 00_train.py - INFO - TRAINING
# use: cuda:0
# 100%|██████████| 454/454 [00:11<00:00, 40.64it/s]
# 100%|██████████| 600/600 [00:01<00:00, 329.31it/s]
# 100%|██████████| 600/600 [00:01<00:00, 329.68it/s]
# 2021-09-30 00:18:20,237 - pytorch_modeler.py - INFO - epoch:1/100, tr_loss:218.110613, src_loss:16.572156, src_mean_auc:0.533433, tgt_loss:15.701658, tgt_mean_auc:0.571767,
#                AUC      pAUC
# Source_0  0.556900  0.505789
# Source_1  0.464900  0.494211
# Source_2  0.578500  0.497895
# Target_0  0.654200  0.522105
# Target_1  0.487600  0.508421
# Target_2  0.573500  0.520000
# mean      0.552600  0.508070
# h_mean    0.545534  0.507861
# 100%|██████████| 454/454 [00:11<00:00, 39.27it/s]
# 100%|██████████| 600/600 [00:01<00:00, 330.35it/s]
# 100%|██████████| 600/600 [00:01<00:00, 338.29it/s]
# 2021-09-30 00:18:46,921 - pytorch_modeler.py - INFO - epoch:2/100, tr_loss:13.527389, src_loss:13.198435, src_mean_auc:0.529200, tgt_loss:13.181552, tgt_mean_auc:0.586933,
#                AUC      pAUC
# Source_0  0.562000  0.517895
# Source_1  0.490700  0.493684
# Source_2  0.534900  0.506316
# Target_0  0.637300  0.526316
# Target_1  0.498300  0.500526
# Target_2  0.625200  0.544211
# mean      0.558067  0.514825
# h_mean    0.552374  0.514273
# 100%|██████████| 454/454 [00:11<00:00, 39.35it/s]
# 100%|██████████| 600/600 [00:01<00:00, 321.11it/s]
# 100%|██████████| 600/600 [00:01<00:00, 330.17it/s]
# 2021-09-30 00:19:05,295 - pytorch_modeler.py - INFO - epoch:3/100, tr_loss:12.102414, src_loss:12.027904, src_mean_auc:0.544967, tgt_loss:12.135735, tgt_mean_auc:0.586800,
#                AUC      pAUC
# Source_0  0.589000  0.525789
# Source_1  0.511300  0.484211
# Source_2  0.534600  0.503684
# Target_0  0.644600  0.524211
# Target_1  0.476800  0.486316
# Target_2  0.639000  0.551053
# mean      0.565883  0.512544
# h_mean    0.558776  0.511461
# 100%|██████████| 454/454 [00:11<00:00, 39.31it/s]
# 100%|██████████| 600/600 [00:01<00:00, 333.29it/s]
# 100%|██████████| 600/600 [00:01<00:00, 320.31it/s]
# 2021-09-30 00:19:26,693 - pytorch_modeler.py - INFO - epoch:4/100, tr_loss:11.288193, src_loss:11.284186, src_mean_auc:0.556933, tgt_loss:11.570664, tgt_mean_auc:0.599533,
#                AUC      pAUC
# Source_0  0.600700  0.542105
# Source_1  0.527800  0.491579
# Source_2  0.542300  0.505263
# Target_0  0.640500  0.518421
# Target_1  0.483600  0.488947
# Target_2  0.674500  0.566316
# mean      0.578233  0.518772
# h_mean    0.570610  0.517329
# 100%|██████████| 454/454 [00:12<00:00, 37.09it/s]
# 100%|██████████| 600/600 [00:01<00:00, 327.31it/s]
# 100%|██████████| 600/600 [00:01<00:00, 324.40it/s]
# 2021-09-30 00:19:52,305 - pytorch_modeler.py - INFO - epoch:5/100, tr_loss:10.816420, src_loss:10.907209, src_mean_auc:0.569500, tgt_loss:11.307247, tgt_mean_auc:0.600833,
#                AUC      pAUC
# Source_0  0.617200  0.548947
# Source_1  0.544700  0.499474
# Source_2  0.546600  0.514737
# Target_0  0.633500  0.521579
# Target_1  0.486400  0.487895
# Target_2  0.682600  0.575789
# mean      0.585167  0.524737
# h_mean    0.577755  0.523097
# 100%|██████████| 454/454 [00:11<00:00, 38.68it/s]
# 100%|██████████| 600/600 [00:01<00:00, 322.91it/s]
# 100%|██████████| 600/600 [00:01<00:00, 318.32it/s]
# 2021-09-30 00:20:16,025 - pytorch_modeler.py - INFO - epoch:6/100, tr_loss:10.538256, src_loss:10.761642, src_mean_auc:0.580900, tgt_loss:11.208207, tgt_mean_auc:0.599400,
#                AUC      pAUC
# Source_0  0.626000  0.548947
# Source_1  0.555800  0.505263
# Source_2  0.560900  0.520526
# Target_0  0.639100  0.531053
# Target_1  0.481800  0.483684
# Target_2  0.677300  0.578421
# mean      0.590150  0.527982
# h_mean    0.582739  0.526254
# 100%|██████████| 454/454 [00:12<00:00, 35.14it/s]
# 100%|██████████| 600/600 [00:01<00:00, 329.60it/s]
# 100%|██████████| 600/600 [00:01<00:00, 326.92it/s]
# 2021-09-30 00:20:42,737 - pytorch_modeler.py - INFO - epoch:7/100, tr_loss:10.354192, src_loss:10.573326, src_mean_auc:0.589033, tgt_loss:11.044536, tgt_mean_auc:0.590233,
#                AUC      pAUC
# Source_0  0.630800  0.546316
# Source_1  0.565100  0.508947
# Source_2  0.571200  0.519474
# Target_0  0.640800  0.538947
# Target_1  0.477100  0.483684
# Target_2  0.652800  0.565789
# mean      0.589633  0.527193
# h_mean    0.582864  0.525823
# 100%|██████████| 454/454 [00:13<00:00, 33.91it/s]
# 100%|██████████| 600/600 [00:01<00:00, 326.41it/s]
# 100%|██████████| 600/600 [00:01<00:00, 329.37it/s]
# 2021-09-30 00:21:08,798 - pytorch_modeler.py - INFO - epoch:8/100, tr_loss:10.208050, src_loss:10.476346, src_mean_auc:0.603933, tgt_loss:10.989319, tgt_mean_auc:0.592800,
#                AUC      pAUC
# Source_0  0.653200  0.551053
# Source_1  0.578400  0.505263
# Source_2  0.580200  0.523158
# Target_0  0.659100  0.543684
# Target_1  0.476100  0.481053
# Target_2  0.643200  0.567368
# mean      0.598367  0.528596
# h_mean    0.590800  0.526965
# 100%|██████████| 454/454 [00:12<00:00, 37.64it/s]
# 100%|██████████| 600/600 [00:01<00:00, 329.44it/s]
# 100%|██████████| 600/600 [00:01<00:00, 324.43it/s]
# 2021-09-30 00:21:36,505 - pytorch_modeler.py - INFO - epoch:9/100, tr_loss:10.096900, src_loss:10.357252, src_mean_auc:0.597367, tgt_loss:10.862201, tgt_mean_auc:0.593833,
#                AUC      pAUC
# Source_0  0.641000  0.546842
# Source_1  0.568300  0.507368
# Source_2  0.582800  0.532632
# Target_0  0.652700  0.541579
# Target_1  0.471500  0.481053
# Target_2  0.657300  0.563684
# mean      0.595600  0.528860
# h_mean    0.587664  0.527409
# 100%|██████████| 454/454 [00:13<00:00, 33.40it/s]
# 100%|██████████| 600/600 [00:01<00:00, 337.13it/s]
# 100%|██████████| 600/600 [00:01<00:00, 340.48it/s]
# 2021-09-30 00:22:04,259 - pytorch_modeler.py - INFO - epoch:10/100, tr_loss:10.006848, src_loss:10.236642, src_mean_auc:0.603700, tgt_loss:10.801708, tgt_mean_auc:0.593067,
#                AUC      pAUC
# Source_0  0.653100  0.546316
# Source_1  0.578900  0.506316
# Source_2  0.579100  0.533158
# Target_0  0.656100  0.540000
# Target_1  0.467200  0.480000
# Target_2  0.655900  0.563684
# mean      0.598383  0.528246
# h_mean    0.589705  0.526762
# 100%|██████████| 454/454 [00:11<00:00, 39.08it/s]
# 100%|██████████| 600/600 [00:01<00:00, 338.63it/s]
# 100%|██████████| 600/600 [00:01<00:00, 343.86it/s]
# 2021-09-30 00:22:29,872 - pytorch_modeler.py - INFO - epoch:11/100, tr_loss:9.925150, src_loss:10.279627, src_mean_auc:0.609100, tgt_loss:10.822655, tgt_mean_auc:0.593433,
#                AUC      pAUC
# Source_0  0.655200  0.555263
# Source_1  0.576600  0.508421
# Source_2  0.595500  0.536316
# Target_0  0.670600  0.541053
# Target_1  0.464000  0.479474
# Target_2  0.645700  0.561053
# mean      0.601267  0.530263
# h_mean    0.592014  0.528698
# 100%|██████████| 454/454 [00:11<00:00, 39.55it/s]
# 100%|██████████| 600/600 [00:01<00:00, 342.67it/s]
# 100%|██████████| 600/600 [00:01<00:00, 343.76it/s]
# 2021-09-30 00:22:54,489 - pytorch_modeler.py - INFO - epoch:12/100, tr_loss:9.848513, src_loss:10.104182, src_mean_auc:0.610267, tgt_loss:10.661731, tgt_mean_auc:0.591867,
#                AUC      pAUC
# Source_0  0.640300  0.556316
# Source_1  0.591500  0.503684
# Source_2  0.599000  0.538421
# Target_0  0.661000  0.546842
# Target_1  0.461900  0.477895
# Target_2  0.652700  0.560526
# mean      0.601067  0.530614
# h_mean    0.592197  0.528848
# 100%|██████████| 454/454 [00:11<00:00, 40.21it/s]
# 100%|██████████| 600/600 [00:01<00:00, 321.05it/s]
# 100%|██████████| 600/600 [00:01<00:00, 331.75it/s]
# 2021-09-30 00:23:21,610 - pytorch_modeler.py - INFO - epoch:13/100, tr_loss:9.784413, src_loss:10.017201, src_mean_auc:0.614867, tgt_loss:10.583856, tgt_mean_auc:0.597133,
#                AUC      pAUC
# Source_0  0.659200  0.561579
# Source_1  0.588500  0.504211
# Source_2  0.596900  0.544737
# Target_0  0.668000  0.543158
# Target_1  0.468700  0.478947
# Target_2  0.654700  0.557895
# mean      0.606000  0.531754
# h_mean    0.597043  0.529980
# 100%|██████████| 454/454 [00:13<00:00, 33.33it/s]
# 100%|██████████| 600/600 [00:01<00:00, 317.79it/s]
# 100%|██████████| 600/600 [00:01<00:00, 342.41it/s]
# 2021-09-30 00:23:51,270 - pytorch_modeler.py - INFO - epoch:14/100, tr_loss:9.730103, src_loss:10.105092, src_mean_auc:0.625900, tgt_loss:10.713684, tgt_mean_auc:0.597567,
#                AUC      pAUC
# Source_0  0.668400  0.558421
# Source_1  0.606200  0.499474
# Source_2  0.603100  0.549474
# Target_0  0.675500  0.544737
# Target_1  0.467500  0.478421
# Target_2  0.649700  0.558947
# mean      0.611733  0.531579
# h_mean    0.602263  0.529669
# 100%|██████████| 454/454 [00:12<00:00, 37.40it/s]
# 100%|██████████| 600/600 [00:01<00:00, 324.79it/s]
# 100%|██████████| 600/600 [00:01<00:00, 338.14it/s]
# 2021-09-30 00:24:15,856 - pytorch_modeler.py - INFO - epoch:15/100, tr_loss:9.692059, src_loss:10.044183, src_mean_auc:0.608267, tgt_loss:10.587450, tgt_mean_auc:0.602600,
#                AUC      pAUC
# Source_0  0.628700  0.561579
# Source_1  0.585200  0.505263
# Source_2  0.610900  0.564211
# Target_0  0.649500  0.543684
# Target_1  0.479600  0.478421
# Target_2  0.678700  0.571579
# mean      0.605433  0.537456
# h_mean    0.597940  0.535174
# 100%|██████████| 454/454 [00:11<00:00, 40.05it/s]
# 100%|██████████| 600/600 [00:01<00:00, 337.55it/s]
# 100%|██████████| 600/600 [00:01<00:00, 329.65it/s]
# 2021-09-30 00:24:41,658 - pytorch_modeler.py - INFO - epoch:16/100, tr_loss:9.653858, src_loss:9.930353, src_mean_auc:0.626500, tgt_loss:10.501579, tgt_mean_auc:0.604933,
#                AUC      pAUC
# Source_0  0.649200  0.569474
# Source_1  0.617800  0.504211
# Source_2  0.612500  0.556842
# Target_0  0.674200  0.544737
# Target_1  0.484400  0.478947
# Target_2  0.656200  0.565263
# mean      0.615717  0.536579
# h_mean    0.608320  0.534383
# 100%|██████████| 454/454 [00:11<00:00, 40.27it/s]
# 100%|██████████| 600/600 [00:01<00:00, 336.63it/s]
# 100%|██████████| 600/600 [00:01<00:00, 320.40it/s]
# 2021-09-30 00:25:08,109 - pytorch_modeler.py - INFO - epoch:17/100, tr_loss:9.620330, src_loss:9.915289, src_mean_auc:0.624400, tgt_loss:10.513109, tgt_mean_auc:0.590133,
#                AUC      pAUC
# Source_0  0.652100  0.567368
# Source_1  0.614200  0.503684
# Source_2  0.606900  0.552632
# Target_0  0.670900  0.543158
# Target_1  0.445400  0.478421
# Target_2  0.654100  0.555789
# mean      0.607267  0.533509
# h_mean    0.595599  0.531540
# 100%|██████████| 454/454 [00:11<00:00, 40.18it/s]
# 100%|██████████| 600/600 [00:01<00:00, 306.33it/s]
# 100%|██████████| 600/600 [00:02<00:00, 270.08it/s]
# 2021-09-30 00:25:33,048 - pytorch_modeler.py - INFO - epoch:18/100, tr_loss:9.593041, src_loss:9.834726, src_mean_auc:0.627700, tgt_loss:10.411405, tgt_mean_auc:0.594033,
#                AUC      pAUC
# Source_0  0.658000  0.565263
# Source_1  0.614400  0.504211
# Source_2  0.610700  0.556316
# Target_0  0.678400  0.544737
# Target_1  0.466100  0.478947
# Target_2  0.637600  0.555789
# mean      0.610867  0.534211
# h_mean    0.601641  0.532253
# 100%|██████████| 454/454 [00:11<00:00, 39.23it/s]
# 100%|██████████| 600/600 [00:01<00:00, 340.01it/s]
# 100%|██████████| 600/600 [00:01<00:00, 327.86it/s]
# 2021-09-30 00:26:04,524 - pytorch_modeler.py - INFO - epoch:19/100, tr_loss:9.569630, src_loss:9.859001, src_mean_auc:0.621733, tgt_loss:10.419668, tgt_mean_auc:0.594033,
#                AUC      pAUC
# Source_0  0.649500  0.569474
# Source_1  0.618400  0.505789
# Source_2  0.597300  0.563684
# Target_0  0.677500  0.547368
# Target_1  0.463100  0.478947
# Target_2  0.641500  0.574211
# mean      0.607883  0.539912
# h_mean    0.598495  0.537465
# 100%|██████████| 454/454 [00:11<00:00, 39.08it/s]
# 100%|██████████| 600/600 [00:01<00:00, 339.06it/s]
# 100%|██████████| 600/600 [00:01<00:00, 340.69it/s]
# 2021-09-30 00:26:28,899 - pytorch_modeler.py - INFO - epoch:20/100, tr_loss:9.544315, src_loss:9.828734, src_mean_auc:0.630900, tgt_loss:10.427112, tgt_mean_auc:0.593367,
#                AUC      pAUC
# Source_0  0.641600  0.566842
# Source_1  0.626100  0.506316
# Source_2  0.625000  0.557368
# Target_0  0.664200  0.546316
# Target_1  0.463800  0.478947
# Target_2  0.652100  0.543684
# mean      0.612133  0.533246
# h_mean    0.602956  0.531396
# 100%|██████████| 454/454 [00:11<00:00, 39.38it/s]
# 100%|██████████| 600/600 [00:01<00:00, 339.03it/s]
# 100%|██████████| 600/600 [00:01<00:00, 330.47it/s]
# 2021-09-30 00:26:55,072 - pytorch_modeler.py - INFO - epoch:21/100, tr_loss:9.524745, src_loss:9.868908, src_mean_auc:0.622867, tgt_loss:10.440511, tgt_mean_auc:0.588200,
#                AUC      pAUC
# Source_0  0.646900  0.574737
# Source_1  0.605700  0.507368
# Source_2  0.616000  0.564211
# Target_0  0.668800  0.545789
# Target_1  0.462900  0.478947
# Target_2  0.632900  0.549474
# mean      0.605533  0.536754
# h_mean    0.596675  0.534602
# 100%|██████████| 454/454 [00:12<00:00, 37.77it/s]
# 100%|██████████| 600/600 [00:01<00:00, 333.70it/s]
# 100%|██████████| 600/600 [00:01<00:00, 330.43it/s]
# 2021-09-30 00:27:20,584 - pytorch_modeler.py - INFO - epoch:22/100, tr_loss:9.508053, src_loss:9.767061, src_mean_auc:0.618800, tgt_loss:10.321712, tgt_mean_auc:0.599667,
#                AUC      pAUC
# Source_0  0.644000  0.565789
# Source_1  0.607700  0.506842
# Source_2  0.604700  0.556316
# Target_0  0.678400  0.546316
# Target_1  0.458000  0.477368
# Target_2  0.662600  0.555263
# mean      0.609233  0.534649
# h_mean    0.598879  0.532661
# 100%|██████████| 454/454 [00:12<00:00, 36.21it/s]
# 100%|██████████| 600/600 [00:01<00:00, 338.86it/s]
# 100%|██████████| 600/600 [00:01<00:00, 335.64it/s]
# 2021-09-30 00:27:48,336 - pytorch_modeler.py - INFO - epoch:23/100, tr_loss:9.492073, src_loss:9.854317, src_mean_auc:0.624633, tgt_loss:10.414559, tgt_mean_auc:0.599633,
#                AUC      pAUC
# Source_0  0.643600  0.575263
# Source_1  0.609500  0.510000
# Source_2  0.620800  0.562105
# Target_0  0.682400  0.544737
# Target_1  0.466700  0.478947
# Target_2  0.649800  0.562632
# mean      0.612133  0.538947
# h_mean    0.602874  0.536713
# 100%|██████████| 454/454 [00:11<00:00, 39.46it/s]
# 100%|██████████| 600/600 [00:01<00:00, 326.86it/s]
# 100%|██████████| 600/600 [00:01<00:00, 334.34it/s]
# 2021-09-30 00:28:15,176 - pytorch_modeler.py - INFO - epoch:24/100, tr_loss:9.484078, src_loss:9.732360, src_mean_auc:0.622800, tgt_loss:10.291228, tgt_mean_auc:0.589867,
#                AUC      pAUC
# Source_0  0.652300  0.568421
# Source_1  0.606200  0.507368
# Source_2  0.609900  0.555789
# Target_0  0.678900  0.546316
# Target_1  0.451100  0.477895
# Target_2  0.639600  0.563684
# mean      0.606333  0.536579
# h_mean    0.595503  0.534452
# 100%|██████████| 454/454 [00:11<00:00, 40.21it/s]
# 100%|██████████| 600/600 [00:01<00:00, 329.79it/s]
# 100%|██████████| 600/600 [00:01<00:00, 338.74it/s]
# 2021-09-30 00:28:40,712 - pytorch_modeler.py - INFO - epoch:25/100, tr_loss:9.468210, src_loss:9.758696, src_mean_auc:0.629967, tgt_loss:10.321507, tgt_mean_auc:0.583700,
#                AUC      pAUC
# Source_0  0.654800  0.571579
# Source_1  0.629900  0.507895
# Source_2  0.605200  0.550526
# Target_0  0.680200  0.546842
# Target_1  0.461800  0.478421
# Target_2  0.609100  0.547895
# mean      0.606833  0.533860
# h_mean    0.597345  0.531964
# 100%|██████████| 454/454 [00:11<00:00, 39.94it/s]
# 100%|██████████| 600/600 [00:01<00:00, 329.62it/s]
# 100%|██████████| 600/600 [00:01<00:00, 337.07it/s]
# 2021-09-30 00:29:07,036 - pytorch_modeler.py - INFO - epoch:26/100, tr_loss:9.454528, src_loss:9.807805, src_mean_auc:0.630400, tgt_loss:10.335793, tgt_mean_auc:0.599833,
#                AUC      pAUC
# Source_0  0.664500  0.571053
# Source_1  0.607800  0.506842
# Source_2  0.618900  0.552105
# Target_0  0.683100  0.548421
# Target_1  0.453600  0.477895
# Target_2  0.662800  0.566842
# mean      0.615117  0.537193
# h_mean    0.603428  0.534974
# 100%|██████████| 454/454 [00:11<00:00, 39.38it/s]
# 100%|██████████| 600/600 [00:02<00:00, 286.59it/s]
# 100%|██████████| 600/600 [00:01<00:00, 331.20it/s]
# 2021-09-30 00:29:35,112 - pytorch_modeler.py - INFO - epoch:27/100, tr_loss:9.445048, src_loss:9.728747, src_mean_auc:0.627167, tgt_loss:10.265567, tgt_mean_auc:0.595400,
#                AUC      pAUC
# Source_0  0.653900  0.567895
# Source_1  0.620200  0.508421
# Source_2  0.607400  0.555789
# Target_0  0.678800  0.545789
# Target_1  0.454800  0.479474
# Target_2  0.652600  0.562105
# mean      0.611283  0.536579
# h_mean    0.600461  0.534575
# 100%|██████████| 454/454 [00:11<00:00, 39.66it/s]
# 100%|██████████| 600/600 [00:01<00:00, 340.19it/s]
# 100%|██████████| 600/600 [00:01<00:00, 328.06it/s]
# 2021-09-30 00:30:05,967 - pytorch_modeler.py - INFO - epoch:28/100, tr_loss:9.435266, src_loss:9.739474, src_mean_auc:0.622533, tgt_loss:10.292954, tgt_mean_auc:0.587900,
#                AUC      pAUC
# Source_0  0.649700  0.568421
# Source_1  0.612000  0.508947
# Source_2  0.605900  0.548421
# Target_0  0.677900  0.542105
# Target_1  0.451100  0.479474
# Target_2  0.634700  0.562105
# mean      0.605217  0.534912
# h_mean    0.594584  0.533010
# 100%|██████████| 454/454 [00:11<00:00, 38.64it/s]
# 100%|██████████| 600/600 [00:01<00:00, 343.47it/s]
# 100%|██████████| 600/600 [00:01<00:00, 326.05it/s]
# 2021-09-30 00:30:33,510 - pytorch_modeler.py - INFO - epoch:29/100, tr_loss:9.425334, src_loss:9.681047, src_mean_auc:0.627433, tgt_loss:10.236978, tgt_mean_auc:0.584767,
#                AUC      pAUC
# Source_0  0.646500  0.567368
# Source_1  0.617300  0.506842
# Source_2  0.618500  0.548421
# Target_0  0.682200  0.544211
# Target_1  0.447600  0.480526
# Target_2  0.624500  0.556316
# mean      0.606100  0.533947
# h_mean    0.594953  0.532148
# 100%|██████████| 454/454 [00:13<00:00, 33.81it/s]
# 100%|██████████| 600/600 [00:01<00:00, 317.28it/s]
# 100%|██████████| 600/600 [00:01<00:00, 320.00it/s]
# 2021-09-30 00:31:01,471 - pytorch_modeler.py - INFO - epoch:30/100, tr_loss:9.414446, src_loss:9.685517, src_mean_auc:0.631933, tgt_loss:10.212513, tgt_mean_auc:0.583367,
#                AUC      pAUC
# Source_0  0.664300  0.573158
# Source_1  0.619500  0.507895
# Source_2  0.612000  0.555789
# Target_0  0.683900  0.545263
# Target_1  0.453000  0.481053
# Target_2  0.613200  0.555789
# mean      0.607650  0.536491
# h_mean    0.596775  0.534527
# 100%|██████████| 454/454 [00:13<00:00, 33.83it/s]
# 100%|██████████| 600/600 [00:01<00:00, 314.03it/s]
# 100%|██████████| 600/600 [00:01<00:00, 300.16it/s]
# 2021-09-30 00:31:29,225 - pytorch_modeler.py - INFO - epoch:31/100, tr_loss:9.404386, src_loss:9.700801, src_mean_auc:0.636500, tgt_loss:10.261819, tgt_mean_auc:0.587467,
#                AUC      pAUC
# Source_0  0.644500  0.564737
# Source_1  0.633800  0.508421
# Source_2  0.631200  0.560000
# Target_0  0.686800  0.547368
# Target_1  0.453100  0.481579
# Target_2  0.622500  0.558421
# mean      0.611983  0.536754
# h_mean    0.601014  0.534878
# 100%|██████████| 454/454 [00:13<00:00, 34.02it/s]
# 100%|██████████| 600/600 [00:02<00:00, 295.11it/s]
# 100%|██████████| 600/600 [00:01<00:00, 326.07it/s]
# 2021-09-30 00:31:59,920 - pytorch_modeler.py - INFO - epoch:32/100, tr_loss:9.394332, src_loss:9.693775, src_mean_auc:0.635900, tgt_loss:10.251052, tgt_mean_auc:0.603667,
#                AUC      pAUC
# Source_0  0.664400  0.573684
# Source_1  0.622100  0.507895
# Source_2  0.621200  0.553158
# Target_0  0.680300  0.545789
# Target_1  0.452200  0.480000
# Target_2  0.678500  0.583684
# mean      0.619783  0.540702
# h_mean    0.607438  0.538183
# 100%|██████████| 454/454 [00:11<00:00, 37.97it/s]
# 100%|██████████| 600/600 [00:01<00:00, 307.73it/s]
# 100%|██████████| 600/600 [00:02<00:00, 299.39it/s]
# 2021-09-30 00:32:23,804 - pytorch_modeler.py - INFO - epoch:33/100, tr_loss:9.388196, src_loss:9.673368, src_mean_auc:0.631833, tgt_loss:10.230829, tgt_mean_auc:0.602683,
#                AUC      pAUC
# Source_0  0.649600  0.567368
# Source_1  0.624400  0.504211
# Source_2  0.621500  0.554737
# Target_0  0.684200  0.546842
# Target_1  0.450200  0.481579
# Target_2  0.673650  0.563684
# mean      0.617258  0.536404
# h_mean    0.605009  0.534392
# 100%|██████████| 454/454 [00:12<00:00, 37.43it/s]
# 100%|██████████| 600/600 [00:01<00:00, 316.78it/s]
# 100%|██████████| 600/600 [00:01<00:00, 306.51it/s]
# 2021-09-30 00:32:52,110 - pytorch_modeler.py - INFO - epoch:34/100, tr_loss:9.382080, src_loss:9.654960, src_mean_auc:0.625967, tgt_loss:10.197021, tgt_mean_auc:0.589000,
#                AUC      pAUC
# Source_0  0.654300  0.566316
# Source_1  0.614500  0.506842
# Source_2  0.609100  0.554737
# Target_0  0.672500  0.547895
# Target_1  0.448300  0.480000
# Target_2  0.646200  0.562632
# mean      0.607483  0.536404
# h_mean    0.596267  0.534411
# 100%|██████████| 454/454 [00:12<00:00, 36.56it/s]
# 100%|██████████| 600/600 [00:01<00:00, 313.34it/s]
# 100%|██████████| 600/600 [00:01<00:00, 326.52it/s]
# 2021-09-30 00:33:21,903 - pytorch_modeler.py - INFO - epoch:35/100, tr_loss:9.375401, src_loss:9.660075, src_mean_auc:0.632633, tgt_loss:10.225312, tgt_mean_auc:0.594567,
#                AUC      pAUC
# Source_0  0.655400  0.567895
# Source_1  0.624900  0.508421
# Source_2  0.617600  0.551579
# Target_0  0.684400  0.543158
# Target_1  0.452200  0.480000
# Target_2  0.647100  0.555263
# mean      0.613600  0.534386
# h_mean    0.602221  0.532571
# 100%|██████████| 454/454 [00:12<00:00, 36.10it/s]
# 100%|██████████| 600/600 [00:01<00:00, 309.35it/s]
# 100%|██████████| 600/600 [00:01<00:00, 313.96it/s]
# 2021-09-30 00:33:50,174 - pytorch_modeler.py - INFO - epoch:36/100, tr_loss:9.363935, src_loss:9.665976, src_mean_auc:0.631033, tgt_loss:10.220270, tgt_mean_auc:0.582567,
#                AUC      pAUC
# Source_0  0.656600  0.560526
# Source_1  0.624200  0.506842
# Source_2  0.612300  0.550526
# Target_0  0.677200  0.542105
# Target_1  0.446600  0.481579
# Target_2  0.623900  0.557368
# mean      0.606800  0.533158
# h_mean    0.595423  0.531501
# 100%|██████████| 454/454 [00:11<00:00, 38.29it/s]
# 100%|██████████| 600/600 [00:01<00:00, 312.86it/s]
# 100%|██████████| 600/600 [00:01<00:00, 323.60it/s]
# 2021-09-30 00:34:18,459 - pytorch_modeler.py - INFO - epoch:37/100, tr_loss:9.361172, src_loss:9.662862, src_mean_auc:0.624700, tgt_loss:10.199927, tgt_mean_auc:0.589967,
#                AUC      pAUC
# Source_0  0.655600  0.570526
# Source_1  0.615900  0.505789
# Source_2  0.602600  0.548421
# Target_0  0.680600  0.550526
# Target_1  0.457300  0.482105
# Target_2  0.632000  0.554211
# mean      0.607333  0.535263
# h_mean    0.597208  0.533412
# 100%|██████████| 454/454 [00:12<00:00, 36.17it/s]
# 100%|██████████| 600/600 [00:01<00:00, 316.33it/s]
# 100%|██████████| 600/600 [00:01<00:00, 323.09it/s]
# 2021-09-30 00:34:47,065 - pytorch_modeler.py - INFO - epoch:38/100, tr_loss:9.354577, src_loss:9.633010, src_mean_auc:0.634133, tgt_loss:10.167183, tgt_mean_auc:0.583800,
#                AUC      pAUC
# Source_0  0.653100  0.567368
# Source_1  0.629200  0.506842
# Source_2  0.620100  0.552632
# Target_0  0.679000  0.545263
# Target_1  0.452100  0.480000
# Target_2  0.620300  0.557895
# mean      0.608967  0.535000
# h_mean    0.598211  0.533105
# 100%|██████████| 454/454 [00:11<00:00, 38.73it/s]
# 100%|██████████| 600/600 [00:01<00:00, 310.83it/s]
# 100%|██████████| 600/600 [00:01<00:00, 313.59it/s]
# 2021-09-30 00:35:16,569 - pytorch_modeler.py - INFO - epoch:39/100, tr_loss:9.347177, src_loss:9.617998, src_mean_auc:0.634433, tgt_loss:10.197663, tgt_mean_auc:0.597933,
#                AUC      pAUC
# Source_0  0.653000  0.564211
# Source_1  0.642100  0.508947
# Source_2  0.608200  0.543684
# Target_0  0.677900  0.547895
# Target_1  0.461700  0.481579
# Target_2  0.654200  0.567368
# mean      0.616183  0.535614
# h_mean    0.605900  0.533773
# 100%|██████████| 454/454 [00:11<00:00, 38.20it/s]
# 100%|██████████| 600/600 [00:01<00:00, 315.88it/s]
# 100%|██████████| 600/600 [00:01<00:00, 307.80it/s]
# 2021-09-30 00:35:41,500 - pytorch_modeler.py - INFO - epoch:40/100, tr_loss:9.341236, src_loss:9.606456, src_mean_auc:0.636283, tgt_loss:10.160678, tgt_mean_auc:0.598867,
#                AUC      pAUC
# Source_0  0.658600  0.568421
# Source_1  0.635150  0.505789
# Source_2  0.615100  0.546842
# Target_0  0.677500  0.545789
# Target_1  0.451300  0.480526
# Target_2  0.667800  0.566842
# mean      0.617575  0.535702
# h_mean    0.605581  0.533691
# 100%|██████████| 454/454 [00:11<00:00, 38.32it/s]
# 100%|██████████| 600/600 [00:01<00:00, 323.12it/s]
# 100%|██████████| 600/600 [00:01<00:00, 321.89it/s]
# 2021-09-30 00:36:07,474 - pytorch_modeler.py - INFO - epoch:41/100, tr_loss:9.336127, src_loss:9.610098, src_mean_auc:0.633433, tgt_loss:10.162249, tgt_mean_auc:0.595700,
#                AUC      pAUC
# Source_0  0.653700  0.571579
# Source_1  0.631300  0.508421
# Source_2  0.615300  0.548947
# Target_0  0.677800  0.543684
# Target_1  0.449200  0.480000
# Target_2  0.660100  0.555263
# mean      0.614567  0.534649
# h_mean    0.602684  0.532781
# 100%|██████████| 454/454 [00:12<00:00, 36.84it/s]
# 100%|██████████| 600/600 [00:01<00:00, 320.05it/s]
# 100%|██████████| 600/600 [00:01<00:00, 319.93it/s]
# 2021-09-30 00:36:37,304 - pytorch_modeler.py - INFO - epoch:42/100, tr_loss:9.335556, src_loss:9.646666, src_mean_auc:0.630633, tgt_loss:10.168460, tgt_mean_auc:0.577500,
#                AUC      pAUC
# Source_0  0.668300  0.566316
# Source_1  0.618400  0.507368
# Source_2  0.605200  0.546842
# Target_0  0.681800  0.542105
# Target_1  0.450200  0.480526
# Target_2  0.600500  0.548947
# mean      0.604067  0.532018
# h_mean    0.592945  0.530372
# 100%|██████████| 454/454 [00:11<00:00, 38.58it/s]
# 100%|██████████| 600/600 [00:01<00:00, 325.64it/s]
# 100%|██████████| 600/600 [00:01<00:00, 324.51it/s]
# 2021-09-30 00:37:04,993 - pytorch_modeler.py - INFO - epoch:43/100, tr_loss:9.325303, src_loss:9.615893, src_mean_auc:0.641767, tgt_loss:10.154879, tgt_mean_auc:0.593400,
#                AUC      pAUC
# Source_0  0.669700  0.572105
# Source_1  0.637000  0.506316
# Source_2  0.618600  0.553158
# Target_0  0.689100  0.545263
# Target_1  0.455100  0.481053
# Target_2  0.636000  0.556842
# mean      0.617583  0.535789
# h_mean    0.606034  0.533837
# 100%|██████████| 454/454 [00:11<00:00, 38.34it/s]
# 100%|██████████| 600/600 [00:02<00:00, 292.13it/s]
# 100%|██████████| 600/600 [00:01<00:00, 323.23it/s]
# 2021-09-30 00:37:35,530 - pytorch_modeler.py - INFO - epoch:44/100, tr_loss:9.324129, src_loss:9.611420, src_mean_auc:0.635700, tgt_loss:10.183316, tgt_mean_auc:0.586967,
#                AUC      pAUC
# Source_0  0.662900  0.568421
# Source_1  0.639000  0.507895
# Source_2  0.605200  0.548947
# Target_0  0.685700  0.545263
# Target_1  0.456300  0.482105
# Target_2  0.618900  0.541053
# mean      0.611333  0.532281
# h_mean    0.600511  0.530678
# 100%|██████████| 454/454 [00:12<00:00, 37.58it/s]
# 100%|██████████| 600/600 [00:01<00:00, 319.00it/s]
# 100%|██████████| 600/600 [00:01<00:00, 326.42it/s]
# 2021-09-30 00:38:02,066 - pytorch_modeler.py - INFO - epoch:45/100, tr_loss:9.320193, src_loss:9.576344, src_mean_auc:0.634733, tgt_loss:10.126099, tgt_mean_auc:0.586967,
#                AUC      pAUC
# Source_0  0.665000  0.568947
# Source_1  0.638200  0.506316
# Source_2  0.601000  0.547895
# Target_0  0.689000  0.548421
# Target_1  0.454000  0.481579
# Target_2  0.617900  0.554211
# mean      0.610850  0.534561
# h_mean    0.599582  0.532758
# 100%|██████████| 454/454 [00:11<00:00, 39.37it/s]
# 100%|██████████| 600/600 [00:01<00:00, 329.52it/s]
# 100%|██████████| 600/600 [00:01<00:00, 335.07it/s]
# 2021-09-30 00:38:33,030 - pytorch_modeler.py - INFO - epoch:46/100, tr_loss:9.315526, src_loss:9.612303, src_mean_auc:0.637033, tgt_loss:10.153141, tgt_mean_auc:0.591967,
#                AUC      pAUC
# Source_0  0.660900  0.567895
# Source_1  0.643300  0.509474
# Source_2  0.606900  0.550526
# Target_0  0.694000  0.548421
# Target_1  0.451400  0.483158
# Target_2  0.630500  0.541579
# mean      0.614500  0.533509
# h_mean    0.602556  0.531928
# 100%|██████████| 454/454 [00:11<00:00, 38.43it/s]
# 100%|██████████| 600/600 [00:01<00:00, 328.83it/s]
# 100%|██████████| 600/600 [00:01<00:00, 336.57it/s]
# 2021-09-30 00:39:01,323 - pytorch_modeler.py - INFO - epoch:47/100, tr_loss:9.310800, src_loss:9.640950, src_mean_auc:0.640533, tgt_loss:10.163746, tgt_mean_auc:0.590933,
#                AUC      pAUC
# Source_0  0.671700  0.571579
# Source_1  0.641000  0.504737
# Source_2  0.608900  0.555789
# Target_0  0.698400  0.548947
# Target_1  0.450900  0.482632
# Target_2  0.623500  0.551579
# mean      0.615733  0.535877
# h_mean    0.603342  0.533968
# 100%|██████████| 454/454 [00:11<00:00, 40.13it/s]
# 100%|██████████| 600/600 [00:01<00:00, 328.51it/s]
# 100%|██████████| 600/600 [00:01<00:00, 336.70it/s]
# 2021-09-30 00:39:27,416 - pytorch_modeler.py - INFO - epoch:48/100, tr_loss:9.305185, src_loss:9.568076, src_mean_auc:0.636733, tgt_loss:10.127953, tgt_mean_auc:0.586567,
#                AUC      pAUC
# Source_0  0.661200  0.572105
# Source_1  0.633600  0.507368
# Source_2  0.615400  0.552632
# Target_0  0.680700  0.546842
# Target_1  0.450100  0.481579
# Target_2  0.628900  0.556316
# mean      0.611650  0.536140
# h_mean    0.600208  0.534229
# 100%|██████████| 454/454 [00:12<00:00, 35.56it/s]
# 100%|██████████| 600/600 [00:01<00:00, 323.36it/s]
# 100%|██████████| 600/600 [00:01<00:00, 331.19it/s]
# 2021-09-30 00:39:57,743 - pytorch_modeler.py - INFO - epoch:49/100, tr_loss:9.303015, src_loss:9.600411, src_mean_auc:0.634600, tgt_loss:10.125382, tgt_mean_auc:0.584700,
#                AUC      pAUC
# Source_0  0.662500  0.575789
# Source_1  0.631500  0.505263
# Source_2  0.609800  0.551579
# Target_0  0.692300  0.550526
# Target_1  0.450100  0.482105
# Target_2  0.611700  0.551579
# mean      0.609650  0.536140
# h_mean    0.597977  0.534162
# 100%|██████████| 454/454 [00:11<00:00, 39.56it/s]
# 100%|██████████| 600/600 [00:01<00:00, 318.87it/s]
# 100%|██████████| 600/600 [00:01<00:00, 339.02it/s]
# 2021-09-30 00:40:24,066 - pytorch_modeler.py - INFO - epoch:50/100, tr_loss:9.299460, src_loss:9.588411, src_mean_auc:0.650033, tgt_loss:10.107066, tgt_mean_auc:0.581400,
#                AUC      pAUC
# Source_0  0.682300  0.565789
# Source_1  0.640400  0.505263
# Source_2  0.627400  0.557368
# Target_0  0.697500  0.547895
# Target_1  0.449200  0.480526
# Target_2  0.597500  0.548947
# mean      0.615717  0.534298
# h_mean    0.602740  0.532451
# 100%|██████████| 454/454 [00:11<00:00, 38.89it/s]
# 100%|██████████| 600/600 [00:01<00:00, 332.03it/s]
# 100%|██████████| 600/600 [00:01<00:00, 320.78it/s]
# 2021-09-30 00:40:55,056 - pytorch_modeler.py - INFO - epoch:51/100, tr_loss:9.294782, src_loss:9.569453, src_mean_auc:0.639133, tgt_loss:10.128245, tgt_mean_auc:0.587800,
#                AUC      pAUC
# Source_0  0.670300  0.570000
# Source_1  0.629400  0.506842
# Source_2  0.617700  0.553684
# Target_0  0.694600  0.548421
# Target_1  0.455200  0.482105
# Target_2  0.613600  0.553684
# mean      0.613467  0.535789
# h_mean    0.602057  0.533941
# 100%|██████████| 454/454 [00:11<00:00, 39.42it/s]
# 100%|██████████| 600/600 [00:01<00:00, 330.48it/s]
# 100%|██████████| 600/600 [00:01<00:00, 328.91it/s]
# 2021-09-30 00:41:22,763 - pytorch_modeler.py - INFO - epoch:52/100, tr_loss:9.291291, src_loss:9.627016, src_mean_auc:0.637467, tgt_loss:10.135602, tgt_mean_auc:0.577600,
#                AUC      pAUC
# Source_0  0.664700  0.570526
# Source_1  0.626200  0.502632
# Source_2  0.621500  0.554737
# Target_0  0.698800  0.552632
# Target_1  0.445800  0.482105
# Target_2  0.588200  0.548421
# mean      0.607533  0.535175
# h_mean    0.594963  0.533232
# 100%|██████████| 454/454 [00:12<00:00, 37.34it/s]
# 100%|██████████| 600/600 [00:01<00:00, 325.88it/s]
# 100%|██████████| 600/600 [00:01<00:00, 327.91it/s]
# 2021-09-30 00:41:51,538 - pytorch_modeler.py - INFO - epoch:53/100, tr_loss:9.289994, src_loss:9.599585, src_mean_auc:0.635400, tgt_loss:10.128835, tgt_mean_auc:0.584700,
#                AUC      pAUC
# Source_0  0.667900  0.568421
# Source_1  0.621600  0.506842
# Source_2  0.616700  0.549474
# Target_0  0.691400  0.546842
# Target_1  0.448700  0.481579
# Target_2  0.614000  0.552632
# mean      0.610050  0.534298
# h_mean    0.598135  0.532534
# 100%|██████████| 454/454 [00:11<00:00, 39.45it/s]
# 100%|██████████| 600/600 [00:01<00:00, 329.60it/s]
# 100%|██████████| 600/600 [00:01<00:00, 329.77it/s]
# 2021-09-30 00:42:20,632 - pytorch_modeler.py - INFO - epoch:54/100, tr_loss:9.288569, src_loss:9.564295, src_mean_auc:0.637933, tgt_loss:10.095799, tgt_mean_auc:0.587033,
#                AUC      pAUC
# Source_0  0.662900  0.573158
# Source_1  0.631300  0.505263
# Source_2  0.619600  0.553158
# Target_0  0.683700  0.545789
# Target_1  0.456200  0.481053
# Target_2  0.621200  0.563158
# mean      0.612483  0.536930
# h_mean    0.601749  0.534837
# 100%|██████████| 454/454 [00:11<00:00, 39.51it/s]
# 100%|██████████| 600/600 [00:01<00:00, 336.16it/s]
# 100%|██████████| 600/600 [00:01<00:00, 333.93it/s]
# 2021-09-30 00:42:46,879 - pytorch_modeler.py - INFO - epoch:55/100, tr_loss:9.282488, src_loss:9.587683, src_mean_auc:0.643667, tgt_loss:10.122799, tgt_mean_auc:0.591867,
#                AUC      pAUC
# Source_0  0.666800  0.573684
# Source_1  0.630700  0.506316
# Source_2  0.633500  0.548947
# Target_0  0.687000  0.544737
# Target_1  0.455400  0.481053
# Target_2  0.633200  0.561579
# mean      0.617767  0.536053
# h_mean    0.606396  0.534043
# 100%|██████████| 454/454 [00:11<00:00, 39.53it/s]
# 100%|██████████| 600/600 [00:01<00:00, 341.94it/s]
# 100%|██████████| 600/600 [00:01<00:00, 338.84it/s]
# 2021-09-30 00:43:12,596 - pytorch_modeler.py - INFO - epoch:56/100, tr_loss:9.279109, src_loss:9.589050, src_mean_auc:0.642367, tgt_loss:10.127666, tgt_mean_auc:0.590000,
#                AUC      pAUC
# Source_0  0.678700  0.578421
# Source_1  0.630800  0.504211
# Source_2  0.617600  0.557895
# Target_0  0.691700  0.544737
# Target_1  0.450000  0.479474
# Target_2  0.628300  0.558947
# mean      0.616183  0.537281
# h_mean    0.603780  0.534996
# 100%|██████████| 454/454 [00:11<00:00, 39.16it/s]
# 100%|██████████| 600/600 [00:01<00:00, 336.96it/s]
# 100%|██████████| 600/600 [00:01<00:00, 325.96it/s]
# 2021-09-30 00:43:37,783 - pytorch_modeler.py - INFO - epoch:57/100, tr_loss:9.277492, src_loss:9.535607, src_mean_auc:0.643033, tgt_loss:10.081086, tgt_mean_auc:0.591533,
#                AUC      pAUC
# Source_0  0.671100  0.577895
# Source_1  0.632000  0.503684
# Source_2  0.626000  0.557368
# Target_0  0.694700  0.548421
# Target_1  0.450800  0.481053
# Target_2  0.629100  0.564211
# mean      0.617283  0.538772
# h_mean    0.605013  0.536456
# 100%|██████████| 454/454 [00:11<00:00, 39.08it/s]
# 100%|██████████| 600/600 [00:01<00:00, 327.86it/s]
# 100%|██████████| 600/600 [00:01<00:00, 335.73it/s]
# 2021-09-30 00:44:05,424 - pytorch_modeler.py - INFO - epoch:58/100, tr_loss:9.274077, src_loss:9.540105, src_mean_auc:0.642700, tgt_loss:10.104887, tgt_mean_auc:0.608867,
#                AUC      pAUC
# Source_0  0.669600  0.571053
# Source_1  0.641600  0.502632
# Source_2  0.616900  0.548421
# Target_0  0.696400  0.546842
# Target_1  0.456000  0.480526
# Target_2  0.674200  0.576316
# mean      0.625783  0.537632
# h_mean    0.613170  0.535285
# 100%|██████████| 454/454 [00:11<00:00, 39.49it/s]
# 100%|██████████| 600/600 [00:01<00:00, 324.10it/s]
# 100%|██████████| 600/600 [00:01<00:00, 337.31it/s]
# 2021-09-30 00:44:29,459 - pytorch_modeler.py - INFO - epoch:59/100, tr_loss:9.270373, src_loss:9.541404, src_mean_auc:0.642967, tgt_loss:10.075937, tgt_mean_auc:0.598100,
#                AUC      pAUC
# Source_0  0.670200  0.580000
# Source_1  0.630500  0.505263
# Source_2  0.628200  0.555263
# Target_0  0.697300  0.553684
# Target_1  0.454400  0.481053
# Target_2  0.642600  0.574211
# mean      0.620533  0.541579
# h_mean    0.608459  0.539053
# 100%|██████████| 454/454 [00:11<00:00, 40.03it/s]
# 100%|██████████| 600/600 [00:01<00:00, 324.48it/s]
# 100%|██████████| 600/600 [00:01<00:00, 334.16it/s]
# 2021-09-30 00:44:57,669 - pytorch_modeler.py - INFO - epoch:60/100, tr_loss:9.267828, src_loss:9.539293, src_mean_auc:0.652267, tgt_loss:10.116813, tgt_mean_auc:0.584033,
#                AUC      pAUC
# Source_0  0.682600  0.572105
# Source_1  0.646800  0.501053
# Source_2  0.627400  0.547895
# Target_0  0.696200  0.543684
# Target_1  0.449200  0.482105
# Target_2  0.606700  0.544737
# mean      0.618150  0.531930
# h_mean    0.605098  0.530120
# 100%|██████████| 454/454 [00:12<00:00, 37.41it/s]
# 100%|██████████| 600/600 [00:01<00:00, 327.20it/s]
# 100%|██████████| 600/600 [00:01<00:00, 332.26it/s]
# 2021-09-30 00:45:26,054 - pytorch_modeler.py - INFO - epoch:61/100, tr_loss:9.265075, src_loss:9.552775, src_mean_auc:0.639867, tgt_loss:10.116333, tgt_mean_auc:0.577333,
#                AUC      pAUC
# Source_0  0.666500  0.575263
# Source_1  0.640100  0.504211
# Source_2  0.613000  0.552105
# Target_0  0.686200  0.544211
# Target_1  0.451200  0.481579
# Target_2  0.594600  0.541579
# mean      0.608600  0.533158
# h_mean    0.597052  0.531286
# 100%|██████████| 454/454 [00:12<00:00, 37.57it/s]
# 100%|██████████| 600/600 [00:01<00:00, 328.82it/s]
# 100%|██████████| 600/600 [00:01<00:00, 335.54it/s]
# 2021-09-30 00:45:54,068 - pytorch_modeler.py - INFO - epoch:62/100, tr_loss:9.262839, src_loss:9.526635, src_mean_auc:0.637833, tgt_loss:10.063226, tgt_mean_auc:0.588767,
#                AUC      pAUC
# Source_0  0.668600  0.574211
# Source_1  0.624900  0.502105
# Source_2  0.620000  0.547895
# Target_0  0.690800  0.543158
# Target_1  0.452100  0.481053
# Target_2  0.623400  0.560000
# mean      0.613300  0.534737
# h_mean    0.601659  0.532676
# 100%|██████████| 454/454 [00:11<00:00, 39.79it/s]
# 100%|██████████| 600/600 [00:01<00:00, 335.35it/s]
# 100%|██████████| 600/600 [00:01<00:00, 331.75it/s]
# 2021-09-30 00:46:21,849 - pytorch_modeler.py - INFO - epoch:63/100, tr_loss:9.261873, src_loss:9.503734, src_mean_auc:0.643733, tgt_loss:10.034553, tgt_mean_auc:0.590367,
#                AUC      pAUC
# Source_0  0.674000  0.573684
# Source_1  0.637900  0.502632
# Source_2  0.619300  0.547895
# Target_0  0.690800  0.543684
# Target_1  0.446400  0.482105
# Target_2  0.633900  0.563684
# mean      0.617050  0.535614
# h_mean    0.604149  0.533552
# 100%|██████████| 454/454 [00:11<00:00, 40.15it/s]
# 100%|██████████| 600/600 [00:01<00:00, 338.00it/s]
# 100%|██████████| 600/600 [00:01<00:00, 317.09it/s]
# 2021-09-30 00:46:50,886 - pytorch_modeler.py - INFO - epoch:64/100, tr_loss:9.256354, src_loss:9.498731, src_mean_auc:0.647100, tgt_loss:10.032194, tgt_mean_auc:0.590567,
#                AUC      pAUC
# Source_0  0.676400  0.571053
# Source_1  0.637800  0.503684
# Source_2  0.627100  0.552632
# Target_0  0.691400  0.546316
# Target_1  0.449200  0.482632
# Target_2  0.631100  0.555789
# mean      0.618833  0.535351
# h_mean    0.606183  0.533442
# 100%|██████████| 454/454 [00:11<00:00, 40.07it/s]
# 100%|██████████| 600/600 [00:01<00:00, 316.05it/s]
# 100%|██████████| 600/600 [00:01<00:00, 326.98it/s]
# 2021-09-30 00:47:17,076 - pytorch_modeler.py - INFO - epoch:65/100, tr_loss:9.254298, src_loss:9.558405, src_mean_auc:0.650100, tgt_loss:10.104557, tgt_mean_auc:0.593967,
#                AUC      pAUC
# Source_0  0.693700  0.572632
# Source_1  0.636300  0.501579
# Source_2  0.620300  0.552632
# Target_0  0.695700  0.546316
# Target_1  0.444900  0.482105
# Target_2  0.641300  0.571579
# mean      0.622033  0.537807
# h_mean    0.607922  0.535534
# 100%|██████████| 454/454 [00:11<00:00, 38.57it/s]
# 100%|██████████| 600/600 [00:01<00:00, 336.01it/s]
# 100%|██████████| 600/600 [00:01<00:00, 326.06it/s]
# 2021-09-30 00:47:42,656 - pytorch_modeler.py - INFO - epoch:66/100, tr_loss:9.252774, src_loss:9.567177, src_mean_auc:0.633567, tgt_loss:10.095749, tgt_mean_auc:0.598300,
#                AUC      pAUC
# Source_0  0.664100  0.581053
# Source_1  0.617600  0.506316
# Source_2  0.619000  0.552632
# Target_0  0.689100  0.550000
# Target_1  0.455000  0.482105
# Target_2  0.650800  0.574211
# mean      0.615933  0.541053
# h_mean    0.604472  0.538622
# 100%|██████████| 454/454 [00:11<00:00, 39.27it/s]
# 100%|██████████| 600/600 [00:01<00:00, 335.93it/s]
# 100%|██████████| 600/600 [00:01<00:00, 329.86it/s]
# 2021-09-30 00:48:08,186 - pytorch_modeler.py - INFO - epoch:67/100, tr_loss:9.252652, src_loss:9.498439, src_mean_auc:0.645433, tgt_loss:10.036017, tgt_mean_auc:0.603933,
#                AUC      pAUC
# Source_0  0.680000  0.574737
# Source_1  0.634900  0.502632
# Source_2  0.621400  0.553158
# Target_0  0.690700  0.547895
# Target_1  0.450100  0.482632
# Target_2  0.671000  0.576842
# mean      0.624683  0.539649
# h_mean    0.611324  0.537250
# 100%|██████████| 454/454 [00:11<00:00, 39.55it/s]
# 100%|██████████| 600/600 [00:01<00:00, 328.11it/s]
# 100%|██████████| 600/600 [00:01<00:00, 323.00it/s]
# 2021-09-30 00:48:34,535 - pytorch_modeler.py - INFO - epoch:68/100, tr_loss:9.249123, src_loss:9.482865, src_mean_auc:0.648533, tgt_loss:10.012432, tgt_mean_auc:0.599633,
#                AUC      pAUC
# Source_0  0.669600  0.577368
# Source_1  0.646100  0.502632
# Source_2  0.629900  0.549474
# Target_0  0.697600  0.545263
# Target_1  0.451300  0.482105
# Target_2  0.650000  0.573684
# mean      0.624083  0.538421
# h_mean    0.611216  0.536060
# 100%|██████████| 454/454 [00:11<00:00, 39.54it/s]
# 100%|██████████| 600/600 [00:01<00:00, 333.64it/s]
# 100%|██████████| 600/600 [00:01<00:00, 328.74it/s]
# 2021-09-30 00:48:59,595 - pytorch_modeler.py - INFO - epoch:69/100, tr_loss:9.246675, src_loss:9.534190, src_mean_auc:0.639967, tgt_loss:10.084234, tgt_mean_auc:0.605133,
#                AUC      pAUC
# Source_0  0.669100  0.581053
# Source_1  0.632500  0.502105
# Source_2  0.618300  0.557368
# Target_0  0.689500  0.548421
# Target_1  0.454800  0.482105
# Target_2  0.671100  0.572105
# mean      0.622550  0.540526
# h_mean    0.610246  0.538003
# 100%|██████████| 454/454 [00:11<00:00, 39.51it/s]
# 100%|██████████| 600/600 [00:01<00:00, 328.67it/s]
# 100%|██████████| 600/600 [00:01<00:00, 327.28it/s]
# 2021-09-30 00:49:27,391 - pytorch_modeler.py - INFO - epoch:70/100, tr_loss:9.245147, src_loss:9.536412, src_mean_auc:0.644233, tgt_loss:10.055660, tgt_mean_auc:0.589967,
#                AUC      pAUC
# Source_0  0.659200  0.576842
# Source_1  0.643800  0.504211
# Source_2  0.629700  0.551579
# Target_0  0.692800  0.542632
# Target_1  0.450500  0.480526
# Target_2  0.626600  0.566316
# mean      0.617100  0.537018
# h_mean    0.604996  0.534780
# 100%|██████████| 454/454 [00:12<00:00, 37.75it/s]
# 100%|██████████| 600/600 [00:01<00:00, 313.75it/s]
# 100%|██████████| 600/600 [00:01<00:00, 332.74it/s]
# 2021-09-30 00:49:52,934 - pytorch_modeler.py - INFO - epoch:71/100, tr_loss:9.242962, src_loss:9.508958, src_mean_auc:0.644467, tgt_loss:10.027382, tgt_mean_auc:0.605233,
#                AUC      pAUC
# Source_0  0.673700  0.580000
# Source_1  0.644200  0.503158
# Source_2  0.615500  0.545263
# Target_0  0.689200  0.545263
# Target_1  0.453600  0.483158
# Target_2  0.672900  0.572632
# mean      0.624850  0.538246
# h_mean    0.612058  0.535926
# 100%|██████████| 454/454 [00:11<00:00, 39.78it/s]
# 100%|██████████| 600/600 [00:01<00:00, 326.88it/s]
# 100%|██████████| 600/600 [00:01<00:00, 333.05it/s]
# 2021-09-30 00:50:20,812 - pytorch_modeler.py - INFO - epoch:72/100, tr_loss:9.243025, src_loss:9.492499, src_mean_auc:0.648300, tgt_loss:10.010632, tgt_mean_auc:0.591833,
#                AUC      pAUC
# Source_0  0.675500  0.577895
# Source_1  0.644400  0.505263
# Source_2  0.625000  0.545789
# Target_0  0.696000  0.546316
# Target_1  0.444700  0.482632
# Target_2  0.634800  0.560526
# mean      0.620067  0.536404
# h_mean    0.606489  0.534367
# 100%|██████████| 454/454 [00:11<00:00, 40.06it/s]
# 100%|██████████| 600/600 [00:01<00:00, 325.91it/s]
# 100%|██████████| 600/600 [00:01<00:00, 331.85it/s]
# 2021-09-30 00:50:49,161 - pytorch_modeler.py - INFO - epoch:73/100, tr_loss:9.240252, src_loss:9.495768, src_mean_auc:0.643300, tgt_loss:10.023209, tgt_mean_auc:0.591500,
#                AUC      pAUC
# Source_0  0.670400  0.583158
# Source_1  0.640000  0.503684
# Source_2  0.619500  0.554737
# Target_0  0.692100  0.547368
# Target_1  0.440700  0.482105
# Target_2  0.641700  0.562632
# mean      0.617400  0.538947
# h_mean    0.603579  0.536608
# 100%|██████████| 454/454 [00:11<00:00, 39.73it/s]
# 100%|██████████| 600/600 [00:01<00:00, 332.52it/s]
# 100%|██████████| 600/600 [00:01<00:00, 334.27it/s]
# 2021-09-30 00:51:15,995 - pytorch_modeler.py - INFO - epoch:74/100, tr_loss:9.237557, src_loss:9.501054, src_mean_auc:0.653067, tgt_loss:10.015917, tgt_mean_auc:0.600733,
#                AUC      pAUC
# Source_0  0.678400  0.581579
# Source_1  0.650200  0.504211
# Source_2  0.630600  0.551579
# Target_0  0.691200  0.548421
# Target_1  0.448900  0.481053
# Target_2  0.662100  0.574211
# mean      0.626900  0.540175
# h_mean    0.613333  0.537661
# 100%|██████████| 454/454 [00:11<00:00, 39.82it/s]
# 100%|██████████| 600/600 [00:01<00:00, 334.49it/s]
# 100%|██████████| 600/600 [00:01<00:00, 321.97it/s]
# 2021-09-30 00:51:43,167 - pytorch_modeler.py - INFO - epoch:75/100, tr_loss:9.235941, src_loss:9.482274, src_mean_auc:0.644200, tgt_loss:10.015864, tgt_mean_auc:0.594933,
#                AUC      pAUC
# Source_0  0.670700  0.577368
# Source_1  0.641800  0.504737
# Source_2  0.620100  0.548421
# Target_0  0.692800  0.549474
# Target_1  0.445300  0.482105
# Target_2  0.646700  0.574211
# mean      0.619567  0.539386
# h_mean    0.606235  0.537041
# 100%|██████████| 454/454 [00:11<00:00, 40.15it/s]
# 100%|██████████| 600/600 [00:01<00:00, 334.11it/s]
# 100%|██████████| 600/600 [00:01<00:00, 329.15it/s]
# 2021-09-30 00:52:11,440 - pytorch_modeler.py - INFO - epoch:76/100, tr_loss:9.235100, src_loss:9.510167, src_mean_auc:0.649000, tgt_loss:10.032142, tgt_mean_auc:0.594900,
#                AUC      pAUC
# Source_0  0.678100  0.576842
# Source_1  0.635500  0.502105
# Source_2  0.633400  0.547368
# Target_0  0.694500  0.544211
# Target_1  0.448400  0.481579
# Target_2  0.641800  0.571053
# mean      0.621950  0.537193
# h_mean    0.608815  0.534888
# 100%|██████████| 454/454 [00:11<00:00, 40.07it/s]
# 100%|██████████| 600/600 [00:01<00:00, 330.03it/s]
# 100%|██████████| 600/600 [00:01<00:00, 319.55it/s]
# 2021-09-30 00:52:41,185 - pytorch_modeler.py - INFO - epoch:77/100, tr_loss:9.233532, src_loss:9.480407, src_mean_auc:0.645433, tgt_loss:9.993957, tgt_mean_auc:0.604033,
#                AUC      pAUC
# Source_0  0.672100  0.577368
# Source_1  0.641500  0.504211
# Source_2  0.622700  0.548421
# Target_0  0.691100  0.549474
# Target_1  0.455500  0.483684
# Target_2  0.665500  0.584737
# mean      0.624733  0.541316
# h_mean    0.612394  0.538780
# 100%|██████████| 454/454 [00:11<00:00, 39.79it/s]
# 100%|██████████| 600/600 [00:01<00:00, 328.24it/s]
# 100%|██████████| 600/600 [00:01<00:00, 318.28it/s]
# 2021-09-30 00:53:09,561 - pytorch_modeler.py - INFO - epoch:78/100, tr_loss:9.231592, src_loss:9.490022, src_mean_auc:0.646767, tgt_loss:10.024084, tgt_mean_auc:0.597367,
#                AUC      pAUC
# Source_0  0.675100  0.576316
# Source_1  0.643000  0.503158
# Source_2  0.622200  0.551579
# Target_0  0.692800  0.544211
# Target_1  0.447600  0.483158
# Target_2  0.651700  0.561053
# mean      0.622067  0.536579
# h_mean    0.608786  0.534512
# 100%|██████████| 454/454 [00:11<00:00, 39.46it/s]
# 100%|██████████| 600/600 [00:02<00:00, 294.22it/s]
# 100%|██████████| 600/600 [00:01<00:00, 321.19it/s]
# 2021-09-30 00:53:34,773 - pytorch_modeler.py - INFO - epoch:79/100, tr_loss:9.228362, src_loss:9.488771, src_mean_auc:0.647367, tgt_loss:10.037113, tgt_mean_auc:0.604533,
#                AUC      pAUC
# Source_0  0.691900  0.584211
# Source_1  0.633400  0.504211
# Source_2  0.616800  0.545789
# Target_0  0.697400  0.548947
# Target_1  0.444100  0.482105
# Target_2  0.672100  0.567368
# mean      0.625950  0.538772
# h_mean    0.611069  0.536402
# 100%|██████████| 454/454 [00:11<00:00, 39.86it/s]
# 100%|██████████| 600/600 [00:01<00:00, 329.45it/s]
# 100%|██████████| 600/600 [00:01<00:00, 335.70it/s]
# 2021-09-30 00:54:02,508 - pytorch_modeler.py - INFO - epoch:80/100, tr_loss:9.228641, src_loss:9.487881, src_mean_auc:0.639400, tgt_loss:10.019325, tgt_mean_auc:0.601933,
#                AUC      pAUC
# Source_0  0.671900  0.583684
# Source_1  0.634400  0.504211
# Source_2  0.611900  0.552105
# Target_0  0.694600  0.549474
# Target_1  0.452200  0.484211
# Target_2  0.659000  0.577895
# mean      0.620667  0.541930
# h_mean    0.608063  0.539405
# 100%|██████████| 454/454 [00:11<00:00, 40.01it/s]
# 100%|██████████| 600/600 [00:01<00:00, 334.81it/s]
# 100%|██████████| 600/600 [00:01<00:00, 330.76it/s]
# 2021-09-30 00:54:27,319 - pytorch_modeler.py - INFO - epoch:81/100, tr_loss:9.227092, src_loss:9.470390, src_mean_auc:0.646633, tgt_loss:9.993792, tgt_mean_auc:0.594967,
#               AUC      pAUC
# Source_0  0.68050  0.575263
# Source_1  0.63370  0.501053
# Source_2  0.62570  0.546316
# Target_0  0.69600  0.547368
# Target_1  0.44790  0.482632
# Target_2  0.64100  0.572105
# mean      0.62080  0.537456
# h_mean    0.60758  0.535169
# 100%|██████████| 454/454 [00:11<00:00, 39.83it/s]
# 100%|██████████| 600/600 [00:01<00:00, 331.52it/s]
# 100%|██████████| 600/600 [00:01<00:00, 326.61it/s]
# 2021-09-30 00:54:54,725 - pytorch_modeler.py - INFO - epoch:82/100, tr_loss:9.225747, src_loss:9.489077, src_mean_auc:0.652567, tgt_loss:10.026180, tgt_mean_auc:0.599633,
#                AUC      pAUC
# Source_0  0.672300  0.578947
# Source_1  0.645800  0.501579
# Source_2  0.639600  0.550000
# Target_0  0.689600  0.543684
# Target_1  0.454500  0.482105
# Target_2  0.654800  0.578947
# mean      0.626100  0.539211
# h_mean    0.613692  0.536674
# 100%|██████████| 454/454 [00:11<00:00, 40.29it/s]
# 100%|██████████| 600/600 [00:01<00:00, 322.57it/s]
# 100%|██████████| 600/600 [00:01<00:00, 330.30it/s]
# 2021-09-30 00:55:23,124 - pytorch_modeler.py - INFO - epoch:83/100, tr_loss:9.224588, src_loss:9.502579, src_mean_auc:0.648967, tgt_loss:10.021275, tgt_mean_auc:0.601733,
#                AUC      pAUC
# Source_0  0.677700  0.577368
# Source_1  0.643900  0.503684
# Source_2  0.625300  0.552632
# Target_0  0.701000  0.542105
# Target_1  0.450600  0.483684
# Target_2  0.653600  0.565789
# mean      0.625350  0.537544
# h_mean    0.612018  0.535406
# 100%|██████████| 454/454 [00:12<00:00, 37.66it/s]
# 100%|██████████| 600/600 [00:01<00:00, 325.04it/s]
# 100%|██████████| 600/600 [00:01<00:00, 324.08it/s]
# 2021-09-30 00:55:48,287 - pytorch_modeler.py - INFO - epoch:84/100, tr_loss:9.224734, src_loss:9.482293, src_mean_auc:0.651667, tgt_loss:10.005749, tgt_mean_auc:0.605433,
#                AUC      pAUC
# Source_0  0.672100  0.573158
# Source_1  0.656300  0.503158
# Source_2  0.626600  0.537895
# Target_0  0.697000  0.542105
# Target_1  0.451700  0.483158
# Target_2  0.667600  0.577368
# mean      0.628550  0.536140
# h_mean    0.615135  0.533920
# 100%|██████████| 454/454 [00:11<00:00, 39.17it/s]
# 100%|██████████| 600/600 [00:01<00:00, 332.64it/s]
# 100%|██████████| 600/600 [00:01<00:00, 332.10it/s]
# 2021-09-30 00:56:17,724 - pytorch_modeler.py - INFO - epoch:85/100, tr_loss:9.220798, src_loss:9.478645, src_mean_auc:0.645533, tgt_loss:10.006842, tgt_mean_auc:0.593667,
#                AUC      pAUC
# Source_0  0.680700  0.576316
# Source_1  0.640200  0.503684
# Source_2  0.615700  0.543684
# Target_0  0.698500  0.542105
# Target_1  0.444300  0.483684
# Target_2  0.638200  0.563158
# mean      0.619600  0.535439
# h_mean    0.605783  0.533444
# 100%|██████████| 454/454 [00:11<00:00, 38.85it/s]
# 100%|██████████| 600/600 [00:01<00:00, 325.50it/s]
# 100%|██████████| 600/600 [00:01<00:00, 335.76it/s]
# 2021-09-30 00:56:43,631 - pytorch_modeler.py - INFO - epoch:86/100, tr_loss:9.220894, src_loss:9.520712, src_mean_auc:0.650500, tgt_loss:10.062627, tgt_mean_auc:0.600400,
#                AUC      pAUC
# Source_0  0.682200  0.581579
# Source_1  0.643100  0.501579
# Source_2  0.626200  0.550000
# Target_0  0.695800  0.541053
# Target_1  0.447200  0.483158
# Target_2  0.658200  0.578421
# mean      0.625450  0.539298
# h_mean    0.611598  0.536761
# 100%|██████████| 454/454 [00:11<00:00, 38.39it/s]
# 100%|██████████| 600/600 [00:01<00:00, 336.14it/s]
# 100%|██████████| 600/600 [00:01<00:00, 327.92it/s]
# 2021-09-30 00:57:11,830 - pytorch_modeler.py - INFO - epoch:87/100, tr_loss:9.218835, src_loss:9.499871, src_mean_auc:0.638133, tgt_loss:10.021639, tgt_mean_auc:0.601700,
#                AUC      pAUC
# Source_0  0.656500  0.577368
# Source_1  0.638600  0.502632
# Source_2  0.619300  0.552105
# Target_0  0.698800  0.548421
# Target_1  0.459300  0.483158
# Target_2  0.647000  0.571579
# mean      0.619917  0.539211
# h_mean    0.608660  0.536891
# 100%|██████████| 454/454 [00:11<00:00, 39.69it/s]
# 100%|██████████| 600/600 [00:01<00:00, 303.95it/s]
# 100%|██████████| 600/600 [00:01<00:00, 319.28it/s]
# 2021-09-30 00:57:35,224 - pytorch_modeler.py - INFO - epoch:88/100, tr_loss:9.218604, src_loss:9.466752, src_mean_auc:0.649933, tgt_loss:10.004277, tgt_mean_auc:0.607100,
#                AUC      pAUC
# Source_0  0.678700  0.575789
# Source_1  0.649100  0.503684
# Source_2  0.622000  0.549474
# Target_0  0.694700  0.540000
# Target_1  0.450000  0.482105
# Target_2  0.676600  0.593158
# mean      0.628517  0.540702
# h_mean    0.614667  0.537923
# 100%|██████████| 454/454 [00:11<00:00, 39.65it/s]
# 100%|██████████| 600/600 [00:01<00:00, 327.51it/s]
# 100%|██████████| 600/600 [00:01<00:00, 325.30it/s]
# 2021-09-30 00:58:04,303 - pytorch_modeler.py - INFO - epoch:89/100, tr_loss:9.217121, src_loss:9.534492, src_mean_auc:0.649833, tgt_loss:10.049799, tgt_mean_auc:0.587567,
#                AUC      pAUC
# Source_0  0.669300  0.583158
# Source_1  0.655900  0.505789
# Source_2  0.624300  0.554737
# Target_0  0.693800  0.548947
# Target_1  0.457300  0.483684
# Target_2  0.611600  0.553158
# mean      0.618700  0.538246
# h_mean    0.607063  0.536121
# 100%|██████████| 454/454 [00:11<00:00, 38.98it/s]
# 100%|██████████| 600/600 [00:01<00:00, 338.17it/s]
# 100%|██████████| 600/600 [00:01<00:00, 317.88it/s]
# 2021-09-30 00:58:34,067 - pytorch_modeler.py - INFO - epoch:90/100, tr_loss:9.214856, src_loss:9.452573, src_mean_auc:0.649900, tgt_loss:9.980816, tgt_mean_auc:0.603600,
#                AUC      pAUC
# Source_0  0.680800  0.574211
# Source_1  0.644300  0.504211
# Source_2  0.624600  0.545263
# Target_0  0.695900  0.542105
# Target_1  0.444000  0.483684
# Target_2  0.670900  0.578947
# mean      0.626750  0.538070
# h_mean    0.612137  0.535801
# 100%|██████████| 454/454 [00:13<00:00, 34.78it/s]
# 100%|██████████| 600/600 [00:01<00:00, 330.26it/s]
# 100%|██████████| 600/600 [00:01<00:00, 332.07it/s]
# 2021-09-30 00:59:03,770 - pytorch_modeler.py - INFO - epoch:91/100, tr_loss:9.215802, src_loss:9.488213, src_mean_auc:0.653600, tgt_loss:10.038516, tgt_mean_auc:0.604167,
#                AUC      pAUC
# Source_0  0.676000  0.580000
# Source_1  0.654500  0.503158
# Source_2  0.630300  0.546842
# Target_0  0.697000  0.547368
# Target_1  0.464400  0.484211
# Target_2  0.651100  0.577895
# mean      0.628883  0.539912
# h_mean    0.617435  0.537498
# 100%|██████████| 454/454 [00:11<00:00, 38.16it/s]
# 100%|██████████| 600/600 [00:02<00:00, 287.57it/s]
# 100%|██████████| 600/600 [00:02<00:00, 299.80it/s]
# 2021-09-30 00:59:33,480 - pytorch_modeler.py - INFO - epoch:92/100, tr_loss:9.212538, src_loss:9.469180, src_mean_auc:0.652733, tgt_loss:10.000118, tgt_mean_auc:0.602667,
#                AUC      pAUC
# Source_0  0.682100  0.578421
# Source_1  0.648500  0.504737
# Source_2  0.627600  0.548421
# Target_0  0.692400  0.547368
# Target_1  0.444900  0.483684
# Target_2  0.670700  0.591053
# mean      0.627700  0.542281
# h_mean    0.613222  0.539579
# 100%|██████████| 454/454 [00:11<00:00, 39.36it/s]
# 100%|██████████| 600/600 [00:01<00:00, 325.04it/s]
# 100%|██████████| 600/600 [00:01<00:00, 336.05it/s]
# 2021-09-30 01:00:00,634 - pytorch_modeler.py - INFO - epoch:93/100, tr_loss:9.212122, src_loss:9.444852, src_mean_auc:0.652167, tgt_loss:9.961747, tgt_mean_auc:0.605067,
#                AUC      pAUC
# Source_0  0.675000  0.577895
# Source_1  0.648900  0.505789
# Source_2  0.632600  0.549474
# Target_0  0.696400  0.543684
# Target_1  0.448700  0.484211
# Target_2  0.670100  0.584211
# mean      0.628617  0.540877
# h_mean    0.614738  0.538422
# 100%|██████████| 454/454 [00:11<00:00, 37.88it/s]
# 100%|██████████| 600/600 [00:01<00:00, 333.56it/s]
# 100%|██████████| 600/600 [00:01<00:00, 333.92it/s]
# 2021-09-30 01:00:32,157 - pytorch_modeler.py - INFO - epoch:94/100, tr_loss:9.209819, src_loss:9.469932, src_mean_auc:0.643033, tgt_loss:9.995390, tgt_mean_auc:0.605233,
#                AUC      pAUC
# Source_0  0.666200  0.579474
# Source_1  0.640600  0.502632
# Source_2  0.622300  0.554737
# Target_0  0.695000  0.543684
# Target_1  0.456500  0.484211
# Target_2  0.664200  0.574211
# mean      0.624133  0.539825
# h_mean    0.611993  0.537445
# 100%|██████████| 454/454 [00:11<00:00, 39.51it/s]
# 100%|██████████| 600/600 [00:01<00:00, 320.78it/s]
# 100%|██████████| 600/600 [00:01<00:00, 333.25it/s]
# 2021-09-30 01:00:58,081 - pytorch_modeler.py - INFO - epoch:95/100, tr_loss:9.208223, src_loss:9.496625, src_mean_auc:0.648433, tgt_loss:10.000574, tgt_mean_auc:0.595533,
#                AUC      pAUC
# Source_0  0.667400  0.580526
# Source_1  0.647900  0.503684
# Source_2  0.630000  0.554211
# Target_0  0.691400  0.547895
# Target_1  0.456600  0.483684
# Target_2  0.638600  0.570526
# mean      0.621983  0.540088
# h_mean    0.610285  0.537745
# 100%|██████████| 454/454 [00:12<00:00, 37.69it/s]
# 100%|██████████| 600/600 [00:01<00:00, 323.13it/s]
# 100%|██████████| 600/600 [00:01<00:00, 325.40it/s]
# 2021-09-30 01:01:29,056 - pytorch_modeler.py - INFO - epoch:96/100, tr_loss:9.207760, src_loss:9.476111, src_mean_auc:0.637467, tgt_loss:10.001290, tgt_mean_auc:0.603400,
#                AUC      pAUC
# Source_0  0.674500  0.581053
# Source_1  0.626900  0.504211
# Source_2  0.611000  0.553684
# Target_0  0.697500  0.547368
# Target_1  0.448000  0.482632
# Target_2  0.664700  0.565263
# mean      0.620433  0.539035
# h_mean    0.607001  0.536750
# 100%|██████████| 454/454 [00:11<00:00, 38.21it/s]
# 100%|██████████| 600/600 [00:01<00:00, 326.07it/s]
# 100%|██████████| 600/600 [00:01<00:00, 331.55it/s]
# 2021-09-30 01:01:57,324 - pytorch_modeler.py - INFO - epoch:97/100, tr_loss:9.207438, src_loss:9.458671, src_mean_auc:0.651967, tgt_loss:9.999097, tgt_mean_auc:0.605967,
#                AUC      pAUC
# Source_0  0.675200  0.577895
# Source_1  0.645300  0.504211
# Source_2  0.635400  0.547895
# Target_0  0.691900  0.542105
# Target_1  0.448500  0.483158
# Target_2  0.677500  0.597368
# mean      0.628967  0.542105
# h_mean    0.615039  0.539216
# 100%|██████████| 454/454 [00:11<00:00, 39.94it/s]
# 100%|██████████| 600/600 [00:01<00:00, 324.11it/s]
# 100%|██████████| 600/600 [00:01<00:00, 329.22it/s]
# 2021-09-30 01:02:23,155 - pytorch_modeler.py - INFO - epoch:98/100, tr_loss:9.207572, src_loss:9.448955, src_mean_auc:0.649933, tgt_loss:9.970996, tgt_mean_auc:0.598933,
#                AUC      pAUC
# Source_0  0.676000  0.578947
# Source_1  0.650900  0.504737
# Source_2  0.622900  0.550526
# Target_0  0.699900  0.549474
# Target_1  0.445600  0.483684
# Target_2  0.651300  0.569474
# mean      0.624433  0.539474
# h_mean    0.610417  0.537233
# 100%|██████████| 454/454 [00:11<00:00, 39.84it/s]
# 100%|██████████| 600/600 [00:01<00:00, 336.21it/s]
# 100%|██████████| 600/600 [00:01<00:00, 318.47it/s]
# 2021-09-30 01:02:50,080 - pytorch_modeler.py - INFO - epoch:99/100, tr_loss:9.206862, src_loss:9.449845, src_mean_auc:0.652100, tgt_loss:9.968356, tgt_mean_auc:0.599500,
#                AUC      pAUC
# Source_0  0.671200  0.578947
# Source_1  0.648900  0.504211
# Source_2  0.636200  0.547895
# Target_0  0.691600  0.540526
# Target_1  0.446400  0.484211
# Target_2  0.660500  0.574211
# mean      0.625800  0.538333
# h_mean    0.612067  0.536072
# 100%|██████████| 454/454 [00:11<00:00, 39.59it/s]
# 100%|██████████| 600/600 [00:01<00:00, 331.45it/s]
# 100%|██████████| 600/600 [00:01<00:00, 328.64it/s]
# 2021-09-30 01:03:17,971 - pytorch_modeler.py - INFO - epoch:100/100, tr_loss:9.204002, src_loss:9.457688, src_mean_auc:0.646600, tgt_loss:9.972115, tgt_mean_auc:0.608733,
#                AUC      pAUC
# Source_0  0.665900  0.575789
# Source_1  0.652200  0.503684
# Source_2  0.621700  0.553158
# Target_0  0.700900  0.547895
# Target_1  0.454000  0.483684
# Target_2  0.671300  0.584211
# mean      0.627667  0.541404
# h_mean    0.614595  0.538877
# 2021-09-30 01:03:24,334 - 00_train.py - INFO - SAVE SUCCESS : /media/hiroki/HDD1TB/research/DCASE_experiments/domain_adaptation/IDNN/baseline/models/fan_model.pkl
# 2021-09-30 01:03:24,336 - 00_train.py - INFO - TARGET MACHINE_TYPE: gearbox
# 2021-09-30 01:03:24,337 - 00_train.py - INFO - MAKE DATA_LOADER
#   0%|          | 1/6140 [00:00<19:16,  5.31it/s]
# elapsed time: 2804.462434053 [sec]
# 100%|██████████| 6140/6140 [02:01<00:00, 50.45it/s]
#  27%|██▋       | 205/762 [00:03<00:08, 62.34it/s]

# %%
#run(machine_types[0], dev_paths)
