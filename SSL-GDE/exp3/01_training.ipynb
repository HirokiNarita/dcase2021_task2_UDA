# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter
import timm

#from torchvision.models import wide_resnet50_2, resnet18
#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
import common as com
import pytorch_modeler as modeler
from pytorch_model import EfficientNet_b1 as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %%
# effnet1 = timm.create_model('efficientnet_b1', pretrained=True)
# # M7:block[5], M8:block[6], M9:conv_head
# effnet1

# %% [markdown]
# ## load config and set logger

# %%
log_folder = config['IO_OPTION']['OUTPUT_ROOT']+'/{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_folder, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(42)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
dev_dir = INPUT_ROOT + "/dev_data"
add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = os.listdir(dev_dir)
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'

TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
PRED_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/pred'
SCORE_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/score'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
os.makedirs(PRED_DIR, exist_ok=True)
os.makedirs(SCORE_DIR, exist_ok=True)

# copy config
# shutil.copy('./config.yaml', OUTPUT_ROOT)

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## make path list

# %% [markdown]
# - __train_paths__ ([dict]): Each Machine Type
#     - __ToyCar__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) :paths
#     - __ToyTrain__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) : paths
#     - ...

# %%
percent = 0.1

# %%
dev_paths = {}

for machine_type in machine_types:
    # dev train
    dev_train_paths = [f"{dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/train")]
    dev_train_paths = sorted(dev_train_paths)
    
    print(f'Machine {machine_type}', end=',')
    print(f'dev_train_size : {len(dev_train_paths)}', end=', ')
    dev_train_source_paths = [path for path in dev_train_paths if 'source' in path]
    print(f'source_size : {len(dev_train_source_paths)}', end=', ')
    dev_train_target_paths = [path for path in dev_train_paths if 'target' in path]
    print(f'target_size : {len(dev_train_target_paths)}', end=', ')
    # increse tgt
    num_increse_tgt = int(len(dev_train_source_paths) * percent)
    increse_dev_train_target_paths = dev_train_target_paths# * num_increse_tgt
    # concat
    dev_train_paths = dev_train_source_paths + increse_dev_train_target_paths
    
    # add_dev train
    add_dev_paths = [f"{add_dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{add_dev_dir}/{machine_type}/train")]
    add_dev_paths = sorted(add_dev_paths)
    print(f'adddev_train_size : {len(add_dev_paths)}', end=', ')
    add_dev_source_paths = [path for path in add_dev_paths if 'source' in path]
    print(f'source_size : {len(add_dev_source_paths)}', end=', ')
    add_dev_target_paths = [path for path in add_dev_paths if 'target' in path]
    print(f'target_size : {len(add_dev_target_paths)}')
    # increse tgt
    num_increse_tgt = int(len(add_dev_source_paths) * percent)
    increse_add_dev_target_paths = add_dev_target_paths# * num_increse_tgt
    # concat
    add_dev_paths = add_dev_source_paths + increse_add_dev_target_paths

    print('==============================================================')
    
    # dev_source valid
    dev_source_paths = [f"{dev_dir}/{machine_type}/source_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/source_test")]
    dev_source_paths = sorted(dev_source_paths)
    
    # dev_target valid
    dev_target_paths = [f"{dev_dir}/{machine_type}/target_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/target_test")]
    dev_target_paths = sorted(dev_target_paths)
    
    # bundle
    dev_paths[machine_type] = {}
    dev_paths[machine_type]['train'] = dev_train_paths + add_dev_paths
    dev_paths[machine_type]['valid_source'] = dev_source_paths
    dev_paths[machine_type]['valid_target'] = dev_target_paths
# Out:
# Machine pump,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine gearbox,dev_train_size : 3026, source_size : 3017, target_size : 9, adddev_train_size : 3114, source_size : 3105, target_size : 9
# ==============================================================
# Machine slider,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyCar,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine valve,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyTrain,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine fan,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================

# %%
machine_types
# Out:
# ['pump', 'gearbox', 'slider', 'ToyCar', 'valve', 'ToyTrain', 'fan']

# %%
#############################################################################
# run
#############################################################################
def run(machine_type, dev_paths):
    com.tic()
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dev_train_paths
    dataloaders_dict = modeler.make_dataloader(dev_paths, machine_type)
    # parameter setting
    logger.info('TRAINING')
    model = Model(n_out=36, n_classes=6)
    
    optimizer = torch.optim.Adam(model.parameters(),lr=1e-3)
    output_dict, model, pred_df, score_df = modeler.run_training(model, dataloaders_dict, writer, optimizer)
    
    # output
    feature_out_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
    model_out_path = f'{MODEL_DIR}/{machine_type}_model.pkl'
    pred_out_path = f'{PRED_DIR}/{machine_type}_pred.csv'
    score_out_path = f'{SCORE_DIR}/{machine_type}_pred.csv'
    # save
    pd.to_pickle(output_dict, feature_out_path)
    torch.save(model.state_dict(), model_out_path)
    pred_df.to_csv(pred_out_path)
    score_df.to_csv(score_out_path)
    logger.info(f'SAVE SUCCESS : {model_out_path}')
    
    com.toc()

# %%
#run(machine_types[0], dev_paths)

# %%
for machine_type in machine_types[0:]:
    run(machine_type, dev_paths)
# Out:
# 2021-11-01 10:11:16,644 - 00_train.py - INFO - TARGET MACHINE_TYPE: pump
# 2021-11-01 10:11:16,644 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-11-01 10:11:16,660 - 00_train.py - INFO - TRAINING
# use: cuda:0
# 100%|██████████| 48/48 [00:54<00:00,  1.14s/it]
# 100%|██████████| 600/600 [02:01<00:00,  4.95it/s]
# 100%|██████████| 600/600 [01:38<00:00,  6.09it/s]
# 2021-11-01 10:15:57,072 - pytorch_modeler.py - INFO - epoch:1/200, tr_loss:5.495108, src_loss:0.000000, src_mean_auc:0.532000, tgt_loss:0.000000, tgt_mean_auc:0.426167, mean_auc:0.479083,
#                AUC      pAUC
# Source_0  0.565800  0.543158
# Source_1  0.441600  0.497895
# Source_2  0.588600  0.504737
# Target_0  0.468000  0.478421
# Target_1  0.358100  0.481053
# Target_2  0.452400  0.491579
# mean      0.479083  0.499474
# h_mean    0.466181  0.498587
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:43<00:00,  1.09it/s]
# 2021-11-01 10:16:41,810 - pytorch_modeler.py - INFO - epoch:2/200, tr_loss:5.467796, src_loss:0.000000, src_mean_auc:0.532000, tgt_loss:0.000000, tgt_mean_auc:0.426167, mean_auc:0.479083,
#                AUC      pAUC
# Source_0  0.565800  0.543158
# Source_1  0.441600  0.497895
# Source_2  0.588600  0.504737
# Target_0  0.468000  0.478421
# Target_1  0.358100  0.481053
# Target_2  0.452400  0.491579
# mean      0.479083  0.499474
# h_mean    0.466181  0.498587
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:48<00:00,  1.01s/it]
# 2021-11-01 10:17:31,190 - pytorch_modeler.py - INFO - epoch:3/200, tr_loss:5.454546, src_loss:0.000000, src_mean_auc:0.532000, tgt_loss:0.000000, tgt_mean_auc:0.426167, mean_auc:0.479083,
#                AUC      pAUC
# Source_0  0.565800  0.543158
# Source_1  0.441600  0.497895
# Source_2  0.588600  0.504737
# Target_0  0.468000  0.478421
# Target_1  0.358100  0.481053
# Target_2  0.452400  0.491579
# mean      0.479083  0.499474
# h_mean    0.466181  0.498587
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:46<00:00,  1.03it/s]
# 2021-11-01 10:18:18,771 - pytorch_modeler.py - INFO - epoch:4/200, tr_loss:5.450144, src_loss:0.000000, src_mean_auc:0.532000, tgt_loss:0.000000, tgt_mean_auc:0.426167, mean_auc:0.479083,
#                AUC      pAUC
# Source_0  0.565800  0.543158
# Source_1  0.441600  0.497895
# Source_2  0.588600  0.504737
# Target_0  0.468000  0.478421
# Target_1  0.358100  0.481053
# Target_2  0.452400  0.491579
# mean      0.479083  0.499474
# h_mean    0.466181  0.498587
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:43<00:00,  1.10it/s]
# 2021-11-01 10:19:03,405 - pytorch_modeler.py - INFO - epoch:5/200, tr_loss:5.448943, src_loss:0.000000, src_mean_auc:0.532000, tgt_loss:0.000000, tgt_mean_auc:0.426167, mean_auc:0.479083,
#                AUC      pAUC
# Source_0  0.565800  0.543158
# Source_1  0.441600  0.497895
# Source_2  0.588600  0.504737
# Target_0  0.468000  0.478421
# Target_1  0.358100  0.481053
# Target_2  0.452400  0.491579
# mean      0.479083  0.499474
# h_mean    0.466181  0.498587
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:44<00:00,  1.07it/s]
# 2021-11-01 10:19:49,153 - pytorch_modeler.py - INFO - epoch:6/200, tr_loss:5.449720, src_loss:0.000000, src_mean_auc:0.532000, tgt_loss:0.000000, tgt_mean_auc:0.426167, mean_auc:0.479083,
#                AUC      pAUC
# Source_0  0.565800  0.543158
# Source_1  0.441600  0.497895
# Source_2  0.588600  0.504737
# Target_0  0.468000  0.478421
# Target_1  0.358100  0.481053
# Target_2  0.452400  0.491579
# mean      0.479083  0.499474
# h_mean    0.466181  0.498587
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:43<00:00,  1.10it/s]
# 2021-11-01 10:20:33,741 - pytorch_modeler.py - INFO - epoch:7/200, tr_loss:5.449544, src_loss:0.000000, src_mean_auc:0.532000, tgt_loss:0.000000, tgt_mean_auc:0.426167, mean_auc:0.479083,
#                AUC      pAUC
# Source_0  0.565800  0.543158
# Source_1  0.441600  0.497895
# Source_2  0.588600  0.504737
# Target_0  0.468000  0.478421
# Target_1  0.358100  0.481053
# Target_2  0.452400  0.491579
# mean      0.479083  0.499474
# h_mean    0.466181  0.498587
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:44<00:00,  1.09it/s]
# 2021-11-01 10:21:18,544 - pytorch_modeler.py - INFO - epoch:8/200, tr_loss:5.448386, src_loss:0.000000, src_mean_auc:0.532000, tgt_loss:0.000000, tgt_mean_auc:0.426167, mean_auc:0.479083,
#                AUC      pAUC
# Source_0  0.565800  0.543158
# Source_1  0.441600  0.497895
# Source_2  0.588600  0.504737
# Target_0  0.468000  0.478421
# Target_1  0.358100  0.481053
# Target_2  0.452400  0.491579
# mean      0.479083  0.499474
# h_mean    0.466181  0.498587
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:45<00:00,  1.05it/s]
# 2021-11-01 10:22:05,401 - pytorch_modeler.py - INFO - epoch:9/200, tr_loss:5.446744, src_loss:0.000000, src_mean_auc:0.532000, tgt_loss:0.000000, tgt_mean_auc:0.426167, mean_auc:0.479083,
#                AUC      pAUC
# Source_0  0.565800  0.543158
# Source_1  0.441600  0.497895
# Source_2  0.588600  0.504737
# Target_0  0.468000  0.478421
# Target_1  0.358100  0.481053
# Target_2  0.452400  0.491579
# mean      0.479083  0.499474
# h_mean    0.466181  0.498587
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:45<00:00,  1.05it/s]
# 100%|██████████| 600/600 [01:30<00:00,  6.65it/s]
# 100%|██████████| 600/600 [01:30<00:00,  6.65it/s]
# 2021-11-01 10:25:52,774 - pytorch_modeler.py - INFO - epoch:10/200, tr_loss:5.447385, src_loss:0.000000, src_mean_auc:0.457400, tgt_loss:0.000000, tgt_mean_auc:0.426367, mean_auc:0.441883,
#                AUC      pAUC
# Source_0  0.382600  0.477895
# Source_1  0.492600  0.502105
# Source_2  0.497000  0.517368
# Target_0  0.469500  0.478947
# Target_1  0.384900  0.480526
# Target_2  0.424700  0.485263
# mean      0.441883  0.490351
# h_mean    0.436731  0.489929
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:44<00:00,  1.09it/s]
# 2021-11-01 10:26:37,785 - pytorch_modeler.py - INFO - epoch:11/200, tr_loss:5.449008, src_loss:0.000000, src_mean_auc:0.457400, tgt_loss:0.000000, tgt_mean_auc:0.426367, mean_auc:0.441883,
#                AUC      pAUC
# Source_0  0.382600  0.477895
# Source_1  0.492600  0.502105
# Source_2  0.497000  0.517368
# Target_0  0.469500  0.478947
# Target_1  0.384900  0.480526
# Target_2  0.424700  0.485263
# mean      0.441883  0.490351
# h_mean    0.436731  0.489929
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:45<00:00,  1.05it/s]
# 2021-11-01 10:27:24,937 - pytorch_modeler.py - INFO - epoch:12/200, tr_loss:5.448049, src_loss:0.000000, src_mean_auc:0.457400, tgt_loss:0.000000, tgt_mean_auc:0.426367, mean_auc:0.441883,
#                AUC      pAUC
# Source_0  0.382600  0.477895
# Source_1  0.492600  0.502105
# Source_2  0.497000  0.517368
# Target_0  0.469500  0.478947
# Target_1  0.384900  0.480526
# Target_2  0.424700  0.485263
# mean      0.441883  0.490351
# h_mean    0.436731  0.489929
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:41<00:00,  1.16it/s]
# 2021-11-01 10:28:07,193 - pytorch_modeler.py - INFO - epoch:13/200, tr_loss:5.446367, src_loss:0.000000, src_mean_auc:0.457400, tgt_loss:0.000000, tgt_mean_auc:0.426367, mean_auc:0.441883,
#                AUC      pAUC
# Source_0  0.382600  0.477895
# Source_1  0.492600  0.502105
# Source_2  0.497000  0.517368
# Target_0  0.469500  0.478947
# Target_1  0.384900  0.480526
# Target_2  0.424700  0.485263
# mean      0.441883  0.490351
# h_mean    0.436731  0.489929
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:51<00:00,  1.07s/it]
# 2021-11-01 10:28:59,361 - pytorch_modeler.py - INFO - epoch:14/200, tr_loss:5.447725, src_loss:0.000000, src_mean_auc:0.457400, tgt_loss:0.000000, tgt_mean_auc:0.426367, mean_auc:0.441883,
#                AUC      pAUC
# Source_0  0.382600  0.477895
# Source_1  0.492600  0.502105
# Source_2  0.497000  0.517368
# Target_0  0.469500  0.478947
# Target_1  0.384900  0.480526
# Target_2  0.424700  0.485263
# mean      0.441883  0.490351
# h_mean    0.436731  0.489929
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:53<00:00,  1.12s/it]
# 2021-11-01 10:29:54,360 - pytorch_modeler.py - INFO - epoch:15/200, tr_loss:5.446086, src_loss:0.000000, src_mean_auc:0.457400, tgt_loss:0.000000, tgt_mean_auc:0.426367, mean_auc:0.441883,
#                AUC      pAUC
# Source_0  0.382600  0.477895
# Source_1  0.492600  0.502105
# Source_2  0.497000  0.517368
# Target_0  0.469500  0.478947
# Target_1  0.384900  0.480526
# Target_2  0.424700  0.485263
# mean      0.441883  0.490351
# h_mean    0.436731  0.489929
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:51<00:00,  1.07s/it]
# 2021-11-01 10:30:46,773 - pytorch_modeler.py - INFO - epoch:16/200, tr_loss:5.445446, src_loss:0.000000, src_mean_auc:0.457400, tgt_loss:0.000000, tgt_mean_auc:0.426367, mean_auc:0.441883,
#                AUC      pAUC
# Source_0  0.382600  0.477895
# Source_1  0.492600  0.502105
# Source_2  0.497000  0.517368
# Target_0  0.469500  0.478947
# Target_1  0.384900  0.480526
# Target_2  0.424700  0.485263
# mean      0.441883  0.490351
# h_mean    0.436731  0.489929
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:48<00:00,  1.01s/it]
# 2021-11-01 10:31:36,178 - pytorch_modeler.py - INFO - epoch:17/200, tr_loss:5.442450, src_loss:0.000000, src_mean_auc:0.457400, tgt_loss:0.000000, tgt_mean_auc:0.426367, mean_auc:0.441883,
#                AUC      pAUC
# Source_0  0.382600  0.477895
# Source_1  0.492600  0.502105
# Source_2  0.497000  0.517368
# Target_0  0.469500  0.478947
# Target_1  0.384900  0.480526
# Target_2  0.424700  0.485263
# mean      0.441883  0.490351
# h_mean    0.436731  0.489929
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:39<00:00,  1.21it/s]
# 2021-11-01 10:32:16,751 - pytorch_modeler.py - INFO - epoch:18/200, tr_loss:5.442282, src_loss:0.000000, src_mean_auc:0.457400, tgt_loss:0.000000, tgt_mean_auc:0.426367, mean_auc:0.441883,
#                AUC      pAUC
# Source_0  0.382600  0.477895
# Source_1  0.492600  0.502105
# Source_2  0.497000  0.517368
# Target_0  0.469500  0.478947
# Target_1  0.384900  0.480526
# Target_2  0.424700  0.485263
# mean      0.441883  0.490351
# h_mean    0.436731  0.489929
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:46<00:00,  1.04it/s]
# 2021-11-01 10:33:03,644 - pytorch_modeler.py - INFO - epoch:19/200, tr_loss:5.441097, src_loss:0.000000, src_mean_auc:0.457400, tgt_loss:0.000000, tgt_mean_auc:0.426367, mean_auc:0.441883,
#                AUC      pAUC
# Source_0  0.382600  0.477895
# Source_1  0.492600  0.502105
# Source_2  0.497000  0.517368
# Target_0  0.469500  0.478947
# Target_1  0.384900  0.480526
# Target_2  0.424700  0.485263
# mean      0.441883  0.490351
# h_mean    0.436731  0.489929
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:44<00:00,  1.07it/s]
# 100%|██████████| 600/600 [01:29<00:00,  6.70it/s]
# 100%|██████████| 600/600 [01:29<00:00,  6.67it/s]
# 2021-11-01 10:36:48,927 - pytorch_modeler.py - INFO - epoch:20/200, tr_loss:5.436555, src_loss:0.000000, src_mean_auc:0.580100, tgt_loss:0.000000, tgt_mean_auc:0.493633, mean_auc:0.536867,
#                AUC      pAUC
# Source_0  0.640400  0.531053
# Source_1  0.556800  0.505789
# Source_2  0.543100  0.502105
# Target_0  0.383400  0.475263
# Target_1  0.580800  0.568421
# Target_2  0.516700  0.492632
# mean      0.536867  0.512544
# h_mean    0.523371  0.510854
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:41<00:00,  1.15it/s]
# 2021-11-01 10:37:31,586 - pytorch_modeler.py - INFO - epoch:21/200, tr_loss:5.427795, src_loss:0.000000, src_mean_auc:0.580100, tgt_loss:0.000000, tgt_mean_auc:0.493633, mean_auc:0.536867,
#                AUC      pAUC
# Source_0  0.640400  0.531053
# Source_1  0.556800  0.505789
# Source_2  0.543100  0.502105
# Target_0  0.383400  0.475263
# Target_1  0.580800  0.568421
# Target_2  0.516700  0.492632
# mean      0.536867  0.512544
# h_mean    0.523371  0.510854
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:43<00:00,  1.11it/s]
# 2021-11-01 10:38:15,804 - pytorch_modeler.py - INFO - epoch:22/200, tr_loss:5.442750, src_loss:0.000000, src_mean_auc:0.580100, tgt_loss:0.000000, tgt_mean_auc:0.493633, mean_auc:0.536867,
#                AUC      pAUC
# Source_0  0.640400  0.531053
# Source_1  0.556800  0.505789
# Source_2  0.543100  0.502105
# Target_0  0.383400  0.475263
# Target_1  0.580800  0.568421
# Target_2  0.516700  0.492632
# mean      0.536867  0.512544
# h_mean    0.523371  0.510854
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:42<00:00,  1.13it/s]
# 2021-11-01 10:38:59,291 - pytorch_modeler.py - INFO - epoch:23/200, tr_loss:5.433052, src_loss:0.000000, src_mean_auc:0.580100, tgt_loss:0.000000, tgt_mean_auc:0.493633, mean_auc:0.536867,
#                AUC      pAUC
# Source_0  0.640400  0.531053
# Source_1  0.556800  0.505789
# Source_2  0.543100  0.502105
# Target_0  0.383400  0.475263
# Target_1  0.580800  0.568421
# Target_2  0.516700  0.492632
# mean      0.536867  0.512544
# h_mean    0.523371  0.510854
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:47<00:00,  1.01it/s]
# 2021-11-01 10:39:47,611 - pytorch_modeler.py - INFO - epoch:24/200, tr_loss:5.433192, src_loss:0.000000, src_mean_auc:0.580100, tgt_loss:0.000000, tgt_mean_auc:0.493633, mean_auc:0.536867,
#                AUC      pAUC
# Source_0  0.640400  0.531053
# Source_1  0.556800  0.505789
# Source_2  0.543100  0.502105
# Target_0  0.383400  0.475263
# Target_1  0.580800  0.568421
# Target_2  0.516700  0.492632
# mean      0.536867  0.512544
# h_mean    0.523371  0.510854
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:40<00:00,  1.19it/s]
# 2021-11-01 10:40:28,872 - pytorch_modeler.py - INFO - epoch:25/200, tr_loss:5.426070, src_loss:0.000000, src_mean_auc:0.580100, tgt_loss:0.000000, tgt_mean_auc:0.493633, mean_auc:0.536867,
#                AUC      pAUC
# Source_0  0.640400  0.531053
# Source_1  0.556800  0.505789
# Source_2  0.543100  0.502105
# Target_0  0.383400  0.475263
# Target_1  0.580800  0.568421
# Target_2  0.516700  0.492632
# mean      0.536867  0.512544
# h_mean    0.523371  0.510854
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:42<00:00,  1.13it/s]
# 2021-11-01 10:41:12,387 - pytorch_modeler.py - INFO - epoch:26/200, tr_loss:5.422262, src_loss:0.000000, src_mean_auc:0.580100, tgt_loss:0.000000, tgt_mean_auc:0.493633, mean_auc:0.536867,
#                AUC      pAUC
# Source_0  0.640400  0.531053
# Source_1  0.556800  0.505789
# Source_2  0.543100  0.502105
# Target_0  0.383400  0.475263
# Target_1  0.580800  0.568421
# Target_2  0.516700  0.492632
# mean      0.536867  0.512544
# h_mean    0.523371  0.510854
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:40<00:00,  1.18it/s]
# 2021-11-01 10:41:53,913 - pytorch_modeler.py - INFO - epoch:27/200, tr_loss:5.423111, src_loss:0.000000, src_mean_auc:0.580100, tgt_loss:0.000000, tgt_mean_auc:0.493633, mean_auc:0.536867,
#                AUC      pAUC
# Source_0  0.640400  0.531053
# Source_1  0.556800  0.505789
# Source_2  0.543100  0.502105
# Target_0  0.383400  0.475263
# Target_1  0.580800  0.568421
# Target_2  0.516700  0.492632
# mean      0.536867  0.512544
# h_mean    0.523371  0.510854
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:45<00:00,  1.05it/s]
# 2021-11-01 10:42:40,660 - pytorch_modeler.py - INFO - epoch:28/200, tr_loss:5.433728, src_loss:0.000000, src_mean_auc:0.580100, tgt_loss:0.000000, tgt_mean_auc:0.493633, mean_auc:0.536867,
#                AUC      pAUC
# Source_0  0.640400  0.531053
# Source_1  0.556800  0.505789
# Source_2  0.543100  0.502105
# Target_0  0.383400  0.475263
# Target_1  0.580800  0.568421
# Target_2  0.516700  0.492632
# mean      0.536867  0.512544
# h_mean    0.523371  0.510854
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:43<00:00,  1.11it/s]
# 2021-11-01 10:43:25,073 - pytorch_modeler.py - INFO - epoch:29/200, tr_loss:5.420406, src_loss:0.000000, src_mean_auc:0.580100, tgt_loss:0.000000, tgt_mean_auc:0.493633, mean_auc:0.536867,
#                AUC      pAUC
# Source_0  0.640400  0.531053
# Source_1  0.556800  0.505789
# Source_2  0.543100  0.502105
# Target_0  0.383400  0.475263
# Target_1  0.580800  0.568421
# Target_2  0.516700  0.492632
# mean      0.536867  0.512544
# h_mean    0.523371  0.510854
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:45<00:00,  1.05it/s]
# 100%|██████████| 600/600 [01:31<00:00,  6.56it/s]
# 100%|██████████| 600/600 [02:00<00:00,  4.98it/s]
# 2021-11-01 10:47:43,638 - pytorch_modeler.py - INFO - epoch:30/200, tr_loss:5.424960, src_loss:0.000000, src_mean_auc:0.574400, tgt_loss:0.000000, tgt_mean_auc:0.529767, mean_auc:0.552083,
#                AUC      pAUC
# Source_0  0.632400  0.498947
# Source_1  0.528300  0.538421
# Source_2  0.562500  0.522105
# Target_0  0.400600  0.482632
# Target_1  0.582200  0.503158
# Target_2  0.606500  0.513158
# mean      0.552083  0.509737
# h_mean    0.539830  0.509123
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:51<00:00,  1.07s/it]
# 2021-11-01 10:48:35,654 - pytorch_modeler.py - INFO - epoch:31/200, tr_loss:5.413359, src_loss:0.000000, src_mean_auc:0.574400, tgt_loss:0.000000, tgt_mean_auc:0.529767, mean_auc:0.552083,
#                AUC      pAUC
# Source_0  0.632400  0.498947
# Source_1  0.528300  0.538421
# Source_2  0.562500  0.522105
# Target_0  0.400600  0.482632
# Target_1  0.582200  0.503158
# Target_2  0.606500  0.513158
# mean      0.552083  0.509737
# h_mean    0.539830  0.509123
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# ...
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:45<00:00,  1.05it/s]
# 100%|██████████| 600/600 [01:29<00:00,  6.71it/s]
# 100%|██████████| 600/600 [01:30<00:00,  6.65it/s]
# 2021-11-01 10:58:26,512 - pytorch_modeler.py - INFO - epoch:40/200, tr_loss:5.405572, src_loss:0.000000, src_mean_auc:0.520167, tgt_loss:0.000000, tgt_mean_auc:0.482367, mean_auc:0.501267,
#                AUC      pAUC
# Source_0  0.544800  0.497368
# Source_1  0.456000  0.506316
# Source_2  0.559700  0.529474
# Target_0  0.511100  0.540526
# Target_1  0.442900  0.497368
# Target_2  0.493100  0.498947
# mean      0.501267  0.511667
# h_mean    0.497612  0.511110
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:41<00:00,  1.17it/s]
# 2021-11-01 10:59:08,564 - pytorch_modeler.py - INFO - epoch:41/200, tr_loss:5.410717, src_loss:0.000000, src_mean_auc:0.520167, tgt_loss:0.000000, tgt_mean_auc:0.482367, mean_auc:0.501267,
#                AUC      pAUC
# Source_0  0.544800  0.497368
# Source_1  0.456000  0.506316
# Source_2  0.559700  0.529474
# Target_0  0.511100  0.540526
# Target_1  0.442900  0.497368
# Target_2  0.493100  0.498947
# mean      0.501267  0.511667
# h_mean    0.497612  0.511110
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:43<00:00,  1.10it/s]
# 2021-11-01 10:59:53,300 - pytorch_modeler.py - INFO - epoch:42/200, tr_loss:5.412634, src_loss:0.000000, src_mean_auc:0.520167, tgt_loss:0.000000, tgt_mean_auc:0.482367, mean_auc:0.501267,
#                AUC      pAUC
# Source_0  0.544800  0.497368
# Source_1  0.456000  0.506316
# Source_2  0.559700  0.529474
# Target_0  0.511100  0.540526
# Target_1  0.442900  0.497368
# Target_2  0.493100  0.498947
# mean      0.501267  0.511667
# h_mean    0.497612  0.511110
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:43<00:00,  1.10it/s]
# 2021-11-01 11:00:37,635 - pytorch_modeler.py - INFO - epoch:43/200, tr_loss:5.396863, src_loss:0.000000, src_mean_auc:0.520167, tgt_loss:0.000000, tgt_mean_auc:0.482367, mean_auc:0.501267,
#                AUC      pAUC
# Source_0  0.544800  0.497368
# Source_1  0.456000  0.506316
# Source_2  0.559700  0.529474
# Target_0  0.511100  0.540526
# Target_1  0.442900  0.497368
# Target_2  0.493100  0.498947
# mean      0.501267  0.511667
# h_mean    0.497612  0.511110
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:43<00:00,  1.11it/s]
# 2021-11-01 11:01:21,781 - pytorch_modeler.py - INFO - epoch:44/200, tr_loss:5.378988, src_loss:0.000000, src_mean_auc:0.520167, tgt_loss:0.000000, tgt_mean_auc:0.482367, mean_auc:0.501267,
#                AUC      pAUC
# Source_0  0.544800  0.497368
# Source_1  0.456000  0.506316
# Source_2  0.559700  0.529474
# Target_0  0.511100  0.540526
# Target_1  0.442900  0.497368
# Target_2  0.493100  0.498947
# mean      0.501267  0.511667
# h_mean    0.497612  0.511110
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:42<00:00,  1.14it/s]
# 2021-11-01 11:02:04,930 - pytorch_modeler.py - INFO - epoch:45/200, tr_loss:5.390448, src_loss:0.000000, src_mean_auc:0.520167, tgt_loss:0.000000, tgt_mean_auc:0.482367, mean_auc:0.501267,
#                AUC      pAUC
# Source_0  0.544800  0.497368
# Source_1  0.456000  0.506316
# Source_2  0.559700  0.529474
# Target_0  0.511100  0.540526
# Target_1  0.442900  0.497368
# Target_2  0.493100  0.498947
# mean      0.501267  0.511667
# h_mean    0.497612  0.511110
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:39<00:00,  1.22it/s]
# 2021-11-01 11:02:45,189 - pytorch_modeler.py - INFO - epoch:46/200, tr_loss:5.394620, src_loss:0.000000, src_mean_auc:0.520167, tgt_loss:0.000000, tgt_mean_auc:0.482367, mean_auc:0.501267,
#                AUC      pAUC
# Source_0  0.544800  0.497368
# Source_1  0.456000  0.506316
# Source_2  0.559700  0.529474
# Target_0  0.511100  0.540526
# Target_1  0.442900  0.497368
# Target_2  0.493100  0.498947
# mean      0.501267  0.511667
# h_mean    0.497612  0.511110
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:45<00:00,  1.07it/s]
# 2021-11-01 11:03:31,494 - pytorch_modeler.py - INFO - epoch:47/200, tr_loss:5.397508, src_loss:0.000000, src_mean_auc:0.520167, tgt_loss:0.000000, tgt_mean_auc:0.482367, mean_auc:0.501267,
#                AUC      pAUC
# Source_0  0.544800  0.497368
# Source_1  0.456000  0.506316
# Source_2  0.559700  0.529474
# Target_0  0.511100  0.540526
# Target_1  0.442900  0.497368
# Target_2  0.493100  0.498947
# mean      0.501267  0.511667
# h_mean    0.497612  0.511110
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:53<00:00,  1.12s/it]
# 2021-11-01 11:04:26,030 - pytorch_modeler.py - INFO - epoch:48/200, tr_loss:5.373789, src_loss:0.000000, src_mean_auc:0.520167, tgt_loss:0.000000, tgt_mean_auc:0.482367, mean_auc:0.501267,
#                AUC      pAUC
# Source_0  0.544800  0.497368
# Source_1  0.456000  0.506316
# Source_2  0.559700  0.529474
# Target_0  0.511100  0.540526
# Target_1  0.442900  0.497368
# Target_2  0.493100  0.498947
# mean      0.501267  0.511667
# h_mean    0.497612  0.511110
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:53<00:00,  1.11s/it]
# 2021-11-01 11:05:20,785 - pytorch_modeler.py - INFO - epoch:49/200, tr_loss:5.397844, src_loss:0.000000, src_mean_auc:0.520167, tgt_loss:0.000000, tgt_mean_auc:0.482367, mean_auc:0.501267,
#                AUC      pAUC
# Source_0  0.544800  0.497368
# Source_1  0.456000  0.506316
# Source_2  0.559700  0.529474
# Target_0  0.511100  0.540526
# Target_1  0.442900  0.497368
# Target_2  0.493100  0.498947
# mean      0.501267  0.511667
# h_mean    0.497612  0.511110
#   0%|          | 0/48 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 48/48 [00:52<00:00,  1.10s/it]
#  70%|██████▉   | 419/600 [01:05<00:22,  7.92it/s]

# %%
#run(machine_types[0], dev_paths)

# %% [markdown]
# # run

# %% [raw]
# # debug
# import dcase_util
# import pandas as pd
#
# sample = pd.read_pickle('/media/hiroki/HDD1TB/research/DCASE_experiments/domain_adaptation/exp2/extraction_features/ToyCar_features.pkl')
# sample = sample['val_src']
#
# src_pred_df = dcase_util.make_pred_df(sample['wav_name'], sample['section_label'], sample['domain_label'], sample['label'], sample['label'])
#
# df1 = dcase_util.calc_dcase2021_task2_score(src_pred_df, prefix='Source')
# df2 = dcase_util.calc_dcase2021_task2_score(src_pred_df, prefix='Target')
# score = pd.concat([df1, df2])
# mean = pd.DataFrame([score.mean()], index=['mean'])
# hmean = scipy.stats.hmean(score, axis=0)
# hmean = pd.DataFrame([hmean], columns=['AUC', 'pAUC'], index=['h_mean'])
# score = score.append([mean, hmean])
