# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter
import timm

#from torchvision.models import wide_resnet50_2, resnet18
#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
import common as com
import pytorch_modeler as modeler
from pytorch_model import EfficientNet_b1 as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %%
# effnet1 = timm.create_model('efficientnet_b1', pretrained=True)
# # M7:block[5], M8:block[6], M9:conv_head
# effnet1

# %% [markdown]
# ## load config and set logger

# %%
log_folder = config['IO_OPTION']['OUTPUT_ROOT']+'/{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_folder, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(42)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
dev_dir = INPUT_ROOT + "/dev_data"
add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = os.listdir(dev_dir)
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'

TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
PRED_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/pred'
SCORE_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/score'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
os.makedirs(PRED_DIR, exist_ok=True)
os.makedirs(SCORE_DIR, exist_ok=True)

# copy config
# shutil.copy('./config.yaml', OUTPUT_ROOT)

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## make path list

# %% [markdown]
# - __train_paths__ ([dict]): Each Machine Type
#     - __ToyCar__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) :paths
#     - __ToyTrain__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) : paths
#     - ...

# %%
percent = 0.1

# %%
dev_paths = {}

for machine_type in machine_types:
    # dev train
    dev_train_paths = [f"{dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/train")]
    dev_train_paths = sorted(dev_train_paths)
    
    print(f'Machine {machine_type}', end=',')
    print(f'dev_train_size : {len(dev_train_paths)}', end=', ')
    dev_train_source_paths = [path for path in dev_train_paths if 'source' in path]
    print(f'source_size : {len(dev_train_source_paths)}', end=', ')
    dev_train_target_paths = [path for path in dev_train_paths if 'target' in path]
    print(f'target_size : {len(dev_train_target_paths)}', end=', ')
    # increse tgt
    num_increse_tgt = int(len(dev_train_source_paths) * percent)
    increse_dev_train_target_paths = dev_train_target_paths * num_increse_tgt
    # concat
    dev_train_paths = dev_train_source_paths + increse_dev_train_target_paths
    
    # add_dev train
    add_dev_paths = [f"{add_dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{add_dev_dir}/{machine_type}/train")]
    add_dev_paths = sorted(add_dev_paths)
    print(f'adddev_train_size : {len(add_dev_paths)}', end=', ')
    add_dev_source_paths = [path for path in add_dev_paths if 'source' in path]
    print(f'source_size : {len(add_dev_source_paths)}', end=', ')
    add_dev_target_paths = [path for path in add_dev_paths if 'target' in path]
    print(f'target_size : {len(add_dev_target_paths)}')
    # increse tgt
    num_increse_tgt = int(len(add_dev_source_paths) * percent)
    increse_add_dev_target_paths = add_dev_target_paths * num_increse_tgt
    # concat
    add_dev_paths = add_dev_source_paths + increse_add_dev_target_paths

    print('==============================================================')
    
    # dev_source valid
    dev_source_paths = [f"{dev_dir}/{machine_type}/source_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/source_test")]
    dev_source_paths = sorted(dev_source_paths)
    
    # dev_target valid
    dev_target_paths = [f"{dev_dir}/{machine_type}/target_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/target_test")]
    dev_target_paths = sorted(dev_target_paths)
    
    # bundle
    dev_paths[machine_type] = {}
    dev_paths[machine_type]['train'] = dev_train_paths + add_dev_paths
    dev_paths[machine_type]['valid_source'] = dev_source_paths
    dev_paths[machine_type]['valid_target'] = dev_target_paths
# Out:
# Machine pump,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine gearbox,dev_train_size : 3026, source_size : 3017, target_size : 9, adddev_train_size : 3114, source_size : 3105, target_size : 9
# ==============================================================
# Machine slider,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyCar,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine valve,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyTrain,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine fan,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================

# %%
machine_types
# Out:
# ['pump', 'gearbox', 'slider', 'ToyCar', 'valve', 'ToyTrain', 'fan']

# %%
#############################################################################
# run
#############################################################################
def run(machine_type, dev_paths):
    com.tic()
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dev_train_paths
    dataloaders_dict = modeler.make_dataloader(dev_paths, machine_type)
    # parameter setting
    logger.info('TRAINING')
    model = Model(n_out=36, n_classes=6)
    
    optimizer = torch.optim.Adam(model.parameters(),lr=1e-4)
    output_dict, model, pred_df, score_df = modeler.run_training(model, dataloaders_dict, writer, optimizer)
    
    # output
    feature_out_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
    model_out_path = f'{MODEL_DIR}/{machine_type}_model.pkl'
    pred_out_path = f'{PRED_DIR}/{machine_type}_pred.csv'
    score_out_path = f'{SCORE_DIR}/{machine_type}_pred.csv'
    # save
    pd.to_pickle(output_dict, feature_out_path)
    torch.save(model.state_dict(), model_out_path)
    pred_df.to_csv(pred_out_path)
    score_df.to_csv(score_out_path)
    logger.info(f'SAVE SUCCESS : {model_out_path}')
    
    com.toc()

# %%
#run(machine_types[0], dev_paths)

# %%
for machine_type in machine_types[5:]:
    run(machine_type, dev_paths)
# Out:
# 2021-10-30 08:28:09,479 - 00_train.py - INFO - TARGET MACHINE_TYPE: pump
# 2021-10-30 08:28:09,480 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-10-30 08:28:09,490 - 00_train.py - INFO - TRAINING
# use: cuda:0
# 100%|██████████| 45/45 [00:46<00:00,  1.03s/it]
# 100%|██████████| 600/600 [01:22<00:00,  7.30it/s]
# 100%|██████████| 600/600 [01:22<00:00,  7.27it/s]
# 2021-10-30 08:31:45,422 - pytorch_modeler.py - INFO - epoch:1/100, tr_loss:14.594258, src_loss:15.291936, src_mean_auc:0.548600, tgt_loss:13.934995, tgt_mean_auc:0.517333, mean_auc:0.532967,
#                AUC      pAUC
# Source_0  0.524300  0.498421
# Source_1  0.534400  0.528421
# Source_2  0.587100  0.532105
# Target_0  0.575700  0.523158
# Target_1  0.428100  0.485263
# Target_2  0.548200  0.500000
# mean      0.532967  0.511228
# h_mean    0.527291  0.510625
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:45<00:00,  1.01s/it]
# 2021-10-30 08:32:31,916 - pytorch_modeler.py - INFO - epoch:2/100, tr_loss:10.154581, src_loss:15.291936, src_mean_auc:0.548600, tgt_loss:13.934995, tgt_mean_auc:0.517333, mean_auc:0.532967,
#                AUC      pAUC
# Source_0  0.524300  0.498421
# Source_1  0.534400  0.528421
# Source_2  0.587100  0.532105
# Target_0  0.575700  0.523158
# Target_1  0.428100  0.485263
# Target_2  0.548200  0.500000
# mean      0.532967  0.511228
# h_mean    0.527291  0.510625
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:46<00:00,  1.04s/it]
# 2021-10-30 08:33:19,655 - pytorch_modeler.py - INFO - epoch:3/100, tr_loss:6.732169, src_loss:15.291936, src_mean_auc:0.548600, tgt_loss:13.934995, tgt_mean_auc:0.517333, mean_auc:0.532967,
#                AUC      pAUC
# Source_0  0.524300  0.498421
# Source_1  0.534400  0.528421
# Source_2  0.587100  0.532105
# Target_0  0.575700  0.523158
# Target_1  0.428100  0.485263
# Target_2  0.548200  0.500000
# mean      0.532967  0.511228
# h_mean    0.527291  0.510625
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:46<00:00,  1.03s/it]
# 2021-10-30 08:34:07,096 - pytorch_modeler.py - INFO - epoch:4/100, tr_loss:4.664590, src_loss:15.291936, src_mean_auc:0.548600, tgt_loss:13.934995, tgt_mean_auc:0.517333, mean_auc:0.532967,
#                AUC      pAUC
# Source_0  0.524300  0.498421
# Source_1  0.534400  0.528421
# Source_2  0.587100  0.532105
# Target_0  0.575700  0.523158
# Target_1  0.428100  0.485263
# Target_2  0.548200  0.500000
# mean      0.532967  0.511228
# h_mean    0.527291  0.510625
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:45<00:00,  1.01s/it]
# 2021-10-30 08:34:53,503 - pytorch_modeler.py - INFO - epoch:5/100, tr_loss:3.099139, src_loss:15.291936, src_mean_auc:0.548600, tgt_loss:13.934995, tgt_mean_auc:0.517333, mean_auc:0.532967,
#                AUC      pAUC
# Source_0  0.524300  0.498421
# Source_1  0.534400  0.528421
# Source_2  0.587100  0.532105
# Target_0  0.575700  0.523158
# Target_1  0.428100  0.485263
# Target_2  0.548200  0.500000
# mean      0.532967  0.511228
# h_mean    0.527291  0.510625
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:46<00:00,  1.02s/it]
# 2021-10-30 08:35:40,548 - pytorch_modeler.py - INFO - epoch:6/100, tr_loss:2.210545, src_loss:15.291936, src_mean_auc:0.548600, tgt_loss:13.934995, tgt_mean_auc:0.517333, mean_auc:0.532967,
#                AUC      pAUC
# Source_0  0.524300  0.498421
# Source_1  0.534400  0.528421
# Source_2  0.587100  0.532105
# Target_0  0.575700  0.523158
# Target_1  0.428100  0.485263
# Target_2  0.548200  0.500000
# mean      0.532967  0.511228
# h_mean    0.527291  0.510625
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:46<00:00,  1.03s/it]
# 2021-10-30 08:36:27,830 - pytorch_modeler.py - INFO - epoch:7/100, tr_loss:1.688926, src_loss:15.291936, src_mean_auc:0.548600, tgt_loss:13.934995, tgt_mean_auc:0.517333, mean_auc:0.532967,
#                AUC      pAUC
# Source_0  0.524300  0.498421
# Source_1  0.534400  0.528421
# Source_2  0.587100  0.532105
# Target_0  0.575700  0.523158
# Target_1  0.428100  0.485263
# Target_2  0.548200  0.500000
# mean      0.532967  0.511228
# h_mean    0.527291  0.510625
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:57<00:00,  1.27s/it]
# 2021-10-30 08:37:26,241 - pytorch_modeler.py - INFO - epoch:8/100, tr_loss:1.276318, src_loss:15.291936, src_mean_auc:0.548600, tgt_loss:13.934995, tgt_mean_auc:0.517333, mean_auc:0.532967,
#                AUC      pAUC
# Source_0  0.524300  0.498421
# Source_1  0.534400  0.528421
# Source_2  0.587100  0.532105
# Target_0  0.575700  0.523158
# Target_1  0.428100  0.485263
# Target_2  0.548200  0.500000
# mean      0.532967  0.511228
# h_mean    0.527291  0.510625
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:57<00:00,  1.29s/it]
# 2021-10-30 08:38:25,201 - pytorch_modeler.py - INFO - epoch:9/100, tr_loss:1.158723, src_loss:15.291936, src_mean_auc:0.548600, tgt_loss:13.934995, tgt_mean_auc:0.517333, mean_auc:0.532967,
#                AUC      pAUC
# Source_0  0.524300  0.498421
# Source_1  0.534400  0.528421
# Source_2  0.587100  0.532105
# Target_0  0.575700  0.523158
# Target_1  0.428100  0.485263
# Target_2  0.548200  0.500000
# mean      0.532967  0.511228
# h_mean    0.527291  0.510625
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:57<00:00,  1.28s/it]
# 100%|██████████| 600/600 [01:22<00:00,  7.26it/s]
# 100%|██████████| 600/600 [01:22<00:00,  7.26it/s]
# 2021-10-30 08:42:09,265 - pytorch_modeler.py - INFO - epoch:10/100, tr_loss:1.061034, src_loss:8.193481, src_mean_auc:0.731767, tgt_loss:5.480281, tgt_mean_auc:0.606567, mean_auc:0.669167,
#                AUC      pAUC
# Source_0  0.672600  0.535789
# Source_1  0.864500  0.725789
# Source_2  0.658200  0.560526
# Target_0  0.657000  0.549474
# Target_1  0.640400  0.558947
# Target_2  0.522300  0.504737
# mean      0.669167  0.572544
# h_mean    0.654950  0.565052
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:45<00:00,  1.01s/it]
# 2021-10-30 08:42:55,502 - pytorch_modeler.py - INFO - epoch:11/100, tr_loss:0.841179, src_loss:8.193481, src_mean_auc:0.731767, tgt_loss:5.480281, tgt_mean_auc:0.606567, mean_auc:0.669167,
#                AUC      pAUC
# Source_0  0.672600  0.535789
# Source_1  0.864500  0.725789
# Source_2  0.658200  0.560526
# Target_0  0.657000  0.549474
# Target_1  0.640400  0.558947
# Target_2  0.522300  0.504737
# mean      0.669167  0.572544
# h_mean    0.654950  0.565052
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:46<00:00,  1.02s/it]
# 2021-10-30 08:43:42,643 - pytorch_modeler.py - INFO - epoch:12/100, tr_loss:0.820494, src_loss:8.193481, src_mean_auc:0.731767, tgt_loss:5.480281, tgt_mean_auc:0.606567, mean_auc:0.669167,
#                AUC      pAUC
# Source_0  0.672600  0.535789
# Source_1  0.864500  0.725789
# Source_2  0.658200  0.560526
# Target_0  0.657000  0.549474
# Target_1  0.640400  0.558947
# Target_2  0.522300  0.504737
# mean      0.669167  0.572544
# h_mean    0.654950  0.565052
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:47<00:00,  1.06s/it]
# 2021-10-30 08:44:31,298 - pytorch_modeler.py - INFO - epoch:13/100, tr_loss:0.695012, src_loss:8.193481, src_mean_auc:0.731767, tgt_loss:5.480281, tgt_mean_auc:0.606567, mean_auc:0.669167,
#                AUC      pAUC
# Source_0  0.672600  0.535789
# Source_1  0.864500  0.725789
# Source_2  0.658200  0.560526
# Target_0  0.657000  0.549474
# Target_1  0.640400  0.558947
# Target_2  0.522300  0.504737
# mean      0.669167  0.572544
# h_mean    0.654950  0.565052
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:46<00:00,  1.04s/it]
# 2021-10-30 08:45:19,249 - pytorch_modeler.py - INFO - epoch:14/100, tr_loss:0.590459, src_loss:8.193481, src_mean_auc:0.731767, tgt_loss:5.480281, tgt_mean_auc:0.606567, mean_auc:0.669167,
#                AUC      pAUC
# Source_0  0.672600  0.535789
# Source_1  0.864500  0.725789
# Source_2  0.658200  0.560526
# Target_0  0.657000  0.549474
# Target_1  0.640400  0.558947
# Target_2  0.522300  0.504737
# mean      0.669167  0.572544
# h_mean    0.654950  0.565052
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:46<00:00,  1.02s/it]
# 2021-10-30 08:46:06,317 - pytorch_modeler.py - INFO - epoch:15/100, tr_loss:0.648430, src_loss:8.193481, src_mean_auc:0.731767, tgt_loss:5.480281, tgt_mean_auc:0.606567, mean_auc:0.669167,
#                AUC      pAUC
# Source_0  0.672600  0.535789
# Source_1  0.864500  0.725789
# Source_2  0.658200  0.560526
# Target_0  0.657000  0.549474
# Target_1  0.640400  0.558947
# Target_2  0.522300  0.504737
# mean      0.669167  0.572544
# h_mean    0.654950  0.565052
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:48<00:00,  1.08s/it]
# 2021-10-30 08:46:55,824 - pytorch_modeler.py - INFO - epoch:16/100, tr_loss:0.631848, src_loss:8.193481, src_mean_auc:0.731767, tgt_loss:5.480281, tgt_mean_auc:0.606567, mean_auc:0.669167,
#                AUC      pAUC
# Source_0  0.672600  0.535789
# Source_1  0.864500  0.725789
# Source_2  0.658200  0.560526
# Target_0  0.657000  0.549474
# Target_1  0.640400  0.558947
# Target_2  0.522300  0.504737
# mean      0.669167  0.572544
# h_mean    0.654950  0.565052
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:42<00:00,  1.06it/s]
# 2021-10-30 08:47:39,189 - pytorch_modeler.py - INFO - epoch:17/100, tr_loss:0.539639, src_loss:8.193481, src_mean_auc:0.731767, tgt_loss:5.480281, tgt_mean_auc:0.606567, mean_auc:0.669167,
#                AUC      pAUC
# Source_0  0.672600  0.535789
# Source_1  0.864500  0.725789
# Source_2  0.658200  0.560526
# Target_0  0.657000  0.549474
# Target_1  0.640400  0.558947
# Target_2  0.522300  0.504737
# mean      0.669167  0.572544
# h_mean    0.654950  0.565052
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:47<00:00,  1.07s/it]
# 2021-10-30 08:48:28,141 - pytorch_modeler.py - INFO - epoch:18/100, tr_loss:0.460028, src_loss:8.193481, src_mean_auc:0.731767, tgt_loss:5.480281, tgt_mean_auc:0.606567, mean_auc:0.669167,
#                AUC      pAUC
# Source_0  0.672600  0.535789
# Source_1  0.864500  0.725789
# Source_2  0.658200  0.560526
# Target_0  0.657000  0.549474
# Target_1  0.640400  0.558947
# Target_2  0.522300  0.504737
# mean      0.669167  0.572544
# h_mean    0.654950  0.565052
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:58<00:00,  1.29s/it]
# 2021-10-30 08:49:27,199 - pytorch_modeler.py - INFO - epoch:19/100, tr_loss:0.425863, src_loss:8.193481, src_mean_auc:0.731767, tgt_loss:5.480281, tgt_mean_auc:0.606567, mean_auc:0.669167,
#                AUC      pAUC
# Source_0  0.672600  0.535789
# Source_1  0.864500  0.725789
# Source_2  0.658200  0.560526
# Target_0  0.657000  0.549474
# Target_1  0.640400  0.558947
# Target_2  0.522300  0.504737
# mean      0.669167  0.572544
# h_mean    0.654950  0.565052
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:57<00:00,  1.29s/it]
# 100%|██████████| 600/600 [01:36<00:00,  6.22it/s]
# 100%|██████████| 600/600 [01:22<00:00,  7.30it/s]
# 2021-10-30 08:53:24,951 - pytorch_modeler.py - INFO - epoch:20/100, tr_loss:0.460633, src_loss:8.235209, src_mean_auc:0.750000, tgt_loss:5.297642, tgt_mean_auc:0.625867, mean_auc:0.687933,
#                AUC      pAUC
# Source_0  0.712700  0.576842
# Source_1  0.855500  0.712632
# Source_2  0.681800  0.558421
# Target_0  0.641500  0.542105
# Target_1  0.663700  0.570000
# Target_2  0.572400  0.510000
# mean      0.687933  0.578333
# h_mean    0.677866  0.572114
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:44<00:00,  1.00it/s]
# 2021-10-30 08:54:10,843 - pytorch_modeler.py - INFO - epoch:21/100, tr_loss:0.435397, src_loss:8.235209, src_mean_auc:0.750000, tgt_loss:5.297642, tgt_mean_auc:0.625867, mean_auc:0.687933,
#                AUC      pAUC
# Source_0  0.712700  0.576842
# Source_1  0.855500  0.712632
# Source_2  0.681800  0.558421
# Target_0  0.641500  0.542105
# Target_1  0.663700  0.570000
# Target_2  0.572400  0.510000
# mean      0.687933  0.578333
# h_mean    0.677866  0.572114
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:45<00:00,  1.02s/it]
# 2021-10-30 08:54:57,585 - pytorch_modeler.py - INFO - epoch:22/100, tr_loss:0.445157, src_loss:8.235209, src_mean_auc:0.750000, tgt_loss:5.297642, tgt_mean_auc:0.625867, mean_auc:0.687933,
#                AUC      pAUC
# Source_0  0.712700  0.576842
# Source_1  0.855500  0.712632
# Source_2  0.681800  0.558421
# Target_0  0.641500  0.542105
# Target_1  0.663700  0.570000
# Target_2  0.572400  0.510000
# mean      0.687933  0.578333
# h_mean    0.677866  0.572114
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:50<00:00,  1.11s/it]
# 2021-10-30 08:55:48,758 - pytorch_modeler.py - INFO - epoch:23/100, tr_loss:0.525409, src_loss:8.235209, src_mean_auc:0.750000, tgt_loss:5.297642, tgt_mean_auc:0.625867, mean_auc:0.687933,
#                AUC      pAUC
# Source_0  0.712700  0.576842
# Source_1  0.855500  0.712632
# Source_2  0.681800  0.558421
# Target_0  0.641500  0.542105
# Target_1  0.663700  0.570000
# Target_2  0.572400  0.510000
# mean      0.687933  0.578333
# h_mean    0.677866  0.572114
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:58<00:00,  1.29s/it]
# 2021-10-30 08:56:48,005 - pytorch_modeler.py - INFO - epoch:24/100, tr_loss:0.432155, src_loss:8.235209, src_mean_auc:0.750000, tgt_loss:5.297642, tgt_mean_auc:0.625867, mean_auc:0.687933,
#                AUC      pAUC
# Source_0  0.712700  0.576842
# Source_1  0.855500  0.712632
# Source_2  0.681800  0.558421
# Target_0  0.641500  0.542105
# Target_1  0.663700  0.570000
# Target_2  0.572400  0.510000
# mean      0.687933  0.578333
# h_mean    0.677866  0.572114
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:58<00:00,  1.29s/it]
# 2021-10-30 08:57:47,318 - pytorch_modeler.py - INFO - epoch:25/100, tr_loss:0.410798, src_loss:8.235209, src_mean_auc:0.750000, tgt_loss:5.297642, tgt_mean_auc:0.625867, mean_auc:0.687933,
#                AUC      pAUC
# Source_0  0.712700  0.576842
# Source_1  0.855500  0.712632
# Source_2  0.681800  0.558421
# Target_0  0.641500  0.542105
# Target_1  0.663700  0.570000
# Target_2  0.572400  0.510000
# mean      0.687933  0.578333
# h_mean    0.677866  0.572114
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-30 08:58:38,920 - pytorch_modeler.py - INFO - epoch:26/100, tr_loss:0.305717, src_loss:8.235209, src_mean_auc:0.750000, tgt_loss:5.297642, tgt_mean_auc:0.625867, mean_auc:0.687933,
#                AUC      pAUC
# Source_0  0.712700  0.576842
# Source_1  0.855500  0.712632
# Source_2  0.681800  0.558421
# Target_0  0.641500  0.542105
# Target_1  0.663700  0.570000
# Target_2  0.572400  0.510000
# mean      0.687933  0.578333
# h_mean    0.677866  0.572114
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:46<00:00,  1.03s/it]
# 2021-10-30 08:59:26,393 - pytorch_modeler.py - INFO - epoch:27/100, tr_loss:0.306897, src_loss:8.235209, src_mean_auc:0.750000, tgt_loss:5.297642, tgt_mean_auc:0.625867, mean_auc:0.687933,
#                AUC      pAUC
# Source_0  0.712700  0.576842
# Source_1  0.855500  0.712632
# Source_2  0.681800  0.558421
# Target_0  0.641500  0.542105
# Target_1  0.663700  0.570000
# Target_2  0.572400  0.510000
# mean      0.687933  0.578333
# h_mean    0.677866  0.572114
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:44<00:00,  1.01it/s]
# 2021-10-30 09:00:11,879 - pytorch_modeler.py - INFO - epoch:28/100, tr_loss:0.307441, src_loss:8.235209, src_mean_auc:0.750000, tgt_loss:5.297642, tgt_mean_auc:0.625867, mean_auc:0.687933,
#                AUC      pAUC
# Source_0  0.712700  0.576842
# Source_1  0.855500  0.712632
# Source_2  0.681800  0.558421
# Target_0  0.641500  0.542105
# Target_1  0.663700  0.570000
# Target_2  0.572400  0.510000
# mean      0.687933  0.578333
# h_mean    0.677866  0.572114
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:47<00:00,  1.06s/it]
# 2021-10-30 09:01:00,556 - pytorch_modeler.py - INFO - epoch:29/100, tr_loss:0.310197, src_loss:8.235209, src_mean_auc:0.750000, tgt_loss:5.297642, tgt_mean_auc:0.625867, mean_auc:0.687933,
#                AUC      pAUC
# Source_0  0.712700  0.576842
# Source_1  0.855500  0.712632
# Source_2  0.681800  0.558421
# Target_0  0.641500  0.542105
# Target_1  0.663700  0.570000
# Target_2  0.572400  0.510000
# mean      0.687933  0.578333
# h_mean    0.677866  0.572114
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:48<00:00,  1.07s/it]
# 100%|██████████| 600/600 [01:36<00:00,  6.21it/s]
# 100%|██████████| 600/600 [02:00<00:00,  4.97it/s]
# 2021-10-30 09:05:27,084 - pytorch_modeler.py - INFO - epoch:30/100, tr_loss:0.341305, src_loss:8.001029, src_mean_auc:0.771767, tgt_loss:4.939412, tgt_mean_auc:0.649800, mean_auc:0.710783,
#                AUC      pAUC
# Source_0  0.764800  0.608421
# Source_1  0.864100  0.724211
# Source_2  0.686400  0.553684
# Target_0  0.716300  0.571579
# Target_1  0.665100  0.566842
# Target_2  0.568000  0.505789
# mean      0.710783  0.588421
# h_mean    0.699151  0.581322
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:55<00:00,  1.24s/it]
# 2021-10-30 09:06:24,017 - pytorch_modeler.py - INFO - epoch:31/100, tr_loss:0.266885, src_loss:8.001029, src_mean_auc:0.771767, tgt_loss:4.939412, tgt_mean_auc:0.649800, mean_auc:0.710783,
#                AUC      pAUC
# Source_0  0.764800  0.608421
# Source_1  0.864100  0.724211
# Source_2  0.686400  0.553684
# Target_0  0.716300  0.571579
# Target_1  0.665100  0.566842
# Target_2  0.568000  0.505789
# mean      0.710783  0.588421
# h_mean    0.699151  0.581322
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# ...
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:46<00:00,  1.04s/it]
# 100%|██████████| 600/600 [01:22<00:00,  7.27it/s]
# 100%|██████████| 600/600 [01:22<00:00,  7.29it/s]
# 2021-10-30 09:16:58,550 - pytorch_modeler.py - INFO - epoch:40/100, tr_loss:0.159427, src_loss:7.624511, src_mean_auc:0.762133, tgt_loss:4.452223, tgt_mean_auc:0.634700, mean_auc:0.698417,
#                AUC      pAUC
# Source_0  0.744700  0.632632
# Source_1  0.855400  0.714737
# Source_2  0.686300  0.563684
# Target_0  0.678200  0.552105
# Target_1  0.651800  0.560526
# Target_2  0.574100  0.504737
# mean      0.698417  0.588070
# h_mean    0.688112  0.580811
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:47<00:00,  1.05s/it]
# 2021-10-30 09:17:46,904 - pytorch_modeler.py - INFO - epoch:41/100, tr_loss:0.195022, src_loss:7.624511, src_mean_auc:0.762133, tgt_loss:4.452223, tgt_mean_auc:0.634700, mean_auc:0.698417,
#                AUC      pAUC
# Source_0  0.744700  0.632632
# Source_1  0.855400  0.714737
# Source_2  0.686300  0.563684
# Target_0  0.678200  0.552105
# Target_1  0.651800  0.560526
# Target_2  0.574100  0.504737
# mean      0.698417  0.588070
# h_mean    0.688112  0.580811
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:48<00:00,  1.09s/it]
# 2021-10-30 09:18:36,941 - pytorch_modeler.py - INFO - epoch:42/100, tr_loss:0.197387, src_loss:7.624511, src_mean_auc:0.762133, tgt_loss:4.452223, tgt_mean_auc:0.634700, mean_auc:0.698417,
#                AUC      pAUC
# Source_0  0.744700  0.632632
# Source_1  0.855400  0.714737
# Source_2  0.686300  0.563684
# Target_0  0.678200  0.552105
# Target_1  0.651800  0.560526
# Target_2  0.574100  0.504737
# mean      0.698417  0.588070
# h_mean    0.688112  0.580811
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:57<00:00,  1.29s/it]
# 2021-10-30 09:19:35,926 - pytorch_modeler.py - INFO - epoch:43/100, tr_loss:0.156040, src_loss:7.624511, src_mean_auc:0.762133, tgt_loss:4.452223, tgt_mean_auc:0.634700, mean_auc:0.698417,
#                AUC      pAUC
# Source_0  0.744700  0.632632
# Source_1  0.855400  0.714737
# Source_2  0.686300  0.563684
# Target_0  0.678200  0.552105
# Target_1  0.651800  0.560526
# Target_2  0.574100  0.504737
# mean      0.698417  0.588070
# h_mean    0.688112  0.580811
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:58<00:00,  1.29s/it]
# 2021-10-30 09:20:35,068 - pytorch_modeler.py - INFO - epoch:44/100, tr_loss:0.195898, src_loss:7.624511, src_mean_auc:0.762133, tgt_loss:4.452223, tgt_mean_auc:0.634700, mean_auc:0.698417,
#                AUC      pAUC
# Source_0  0.744700  0.632632
# Source_1  0.855400  0.714737
# Source_2  0.686300  0.563684
# Target_0  0.678200  0.552105
# Target_1  0.651800  0.560526
# Target_2  0.574100  0.504737
# mean      0.698417  0.588070
# h_mean    0.688112  0.580811
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:53<00:00,  1.19s/it]
# 2021-10-30 09:21:29,516 - pytorch_modeler.py - INFO - epoch:45/100, tr_loss:0.197610, src_loss:7.624511, src_mean_auc:0.762133, tgt_loss:4.452223, tgt_mean_auc:0.634700, mean_auc:0.698417,
#                AUC      pAUC
# Source_0  0.744700  0.632632
# Source_1  0.855400  0.714737
# Source_2  0.686300  0.563684
# Target_0  0.678200  0.552105
# Target_1  0.651800  0.560526
# Target_2  0.574100  0.504737
# mean      0.698417  0.588070
# h_mean    0.688112  0.580811
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:45<00:00,  1.02s/it]
# 2021-10-30 09:22:16,323 - pytorch_modeler.py - INFO - epoch:46/100, tr_loss:0.187882, src_loss:7.624511, src_mean_auc:0.762133, tgt_loss:4.452223, tgt_mean_auc:0.634700, mean_auc:0.698417,
#                AUC      pAUC
# Source_0  0.744700  0.632632
# Source_1  0.855400  0.714737
# Source_2  0.686300  0.563684
# Target_0  0.678200  0.552105
# Target_1  0.651800  0.560526
# Target_2  0.574100  0.504737
# mean      0.698417  0.588070
# h_mean    0.688112  0.580811
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:47<00:00,  1.06s/it]
# 2021-10-30 09:23:04,979 - pytorch_modeler.py - INFO - epoch:47/100, tr_loss:0.173022, src_loss:7.624511, src_mean_auc:0.762133, tgt_loss:4.452223, tgt_mean_auc:0.634700, mean_auc:0.698417,
#                AUC      pAUC
# Source_0  0.744700  0.632632
# Source_1  0.855400  0.714737
# Source_2  0.686300  0.563684
# Target_0  0.678200  0.552105
# Target_1  0.651800  0.560526
# Target_2  0.574100  0.504737
# mean      0.698417  0.588070
# h_mean    0.688112  0.580811
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:49<00:00,  1.09s/it]
# 2021-10-30 09:23:55,219 - pytorch_modeler.py - INFO - epoch:48/100, tr_loss:0.158022, src_loss:7.624511, src_mean_auc:0.762133, tgt_loss:4.452223, tgt_mean_auc:0.634700, mean_auc:0.698417,
#                AUC      pAUC
# Source_0  0.744700  0.632632
# Source_1  0.855400  0.714737
# Source_2  0.686300  0.563684
# Target_0  0.678200  0.552105
# Target_1  0.651800  0.560526
# Target_2  0.574100  0.504737
# mean      0.698417  0.588070
# h_mean    0.688112  0.580811
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:45<00:00,  1.01s/it]
# 2021-10-30 09:24:41,599 - pytorch_modeler.py - INFO - epoch:49/100, tr_loss:0.156654, src_loss:7.624511, src_mean_auc:0.762133, tgt_loss:4.452223, tgt_mean_auc:0.634700, mean_auc:0.698417,
#                AUC      pAUC
# Source_0  0.744700  0.632632
# Source_1  0.855400  0.714737
# Source_2  0.686300  0.563684
# Target_0  0.678200  0.552105
# Target_1  0.651800  0.560526
# Target_2  0.574100  0.504737
# mean      0.698417  0.588070
# h_mean    0.688112  0.580811
#   0%|          | 0/45 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py:208: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py:78: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information.
#   if p.grad is not None:
# 100%|██████████| 45/45 [00:47<00:00,  1.06s/it]
# 100%|██████████| 600/600 [02:00<00:00,  4.99it/s]
#  57%|█████▋    | 342/600 [00:55<00:27,  9.45it/s]

# %%
#run(machine_types[0], dev_paths)

# %% [markdown]
# # run

# %% [raw]
# # debug
# import dcase_util
# import pandas as pd
#
# sample = pd.read_pickle('/media/hiroki/HDD1TB/research/DCASE_experiments/domain_adaptation/exp2/extraction_features/ToyCar_features.pkl')
# sample = sample['val_src']
#
# src_pred_df = dcase_util.make_pred_df(sample['wav_name'], sample['section_label'], sample['domain_label'], sample['label'], sample['label'])
#
# df1 = dcase_util.calc_dcase2021_task2_score(src_pred_df, prefix='Source')
# df2 = dcase_util.calc_dcase2021_task2_score(src_pred_df, prefix='Target')
# score = pd.concat([df1, df2])
# mean = pd.DataFrame([score.mean()], index=['mean'])
# hmean = scipy.stats.hmean(score, axis=0)
# hmean = pd.DataFrame([hmean], columns=['AUC', 'pAUC'], index=['h_mean'])
# score = score.append([mean, hmean])
