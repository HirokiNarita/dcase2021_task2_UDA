# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# <ipython-input-1-1499ab5789c7>:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(f)

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter
import timm
import torch_optimizer
#from torchvision.models import wide_resnet50_2, resnet18
#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
import common as com
import pytorch_modeler as modeler
from pytorch_model import ResNet38 as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %% [markdown]
# ## load config and set logger

# %%
log_folder = config['IO_OPTION']['OUTPUT_ROOT']+'/{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_folder, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(42)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
dev_dir = INPUT_ROOT + "/dev_data"
add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = os.listdir(dev_dir)
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'
TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
# copy config
shutil.copy('./config.yaml', OUTPUT_ROOT)
# Out:
# '/media/hiroki/HDD1TB/research/DCASE_experiments/domain_adaptation/exp3/config.yaml'

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## make path list

# %% [markdown]
# - __train_paths__ ([dict]): Each Machine Type
#     - __ToyCar__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) :paths
#     - __ToyTrain__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) : paths
#     - ...

# %%
dev_paths = {}

for machine_type in machine_types:
    # dev train
    dev_train_paths = [f"{dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/train")]
    dev_train_paths = sorted(dev_train_paths)
    
    print(f'Machine {machine_type}', end=',')
    print(f'dev_train_size : {len(dev_train_paths)}', end=', ')
    dev_train_source_paths = [path for path in dev_train_paths if 'source' in path]
    print(f'source_size : {len(dev_train_source_paths)}', end=', ')
    dev_train_target_paths = [path for path in dev_train_paths if 'target' in path]
    print(f'target_size : {len(dev_train_target_paths)}', end=', ')
    # source mode
    dev_train_paths = dev_train_source_paths + dev_train_target_paths
    
    # add_dev train
    add_dev_paths = [f"{add_dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{add_dev_dir}/{machine_type}/train")]
    add_dev_paths = sorted(add_dev_paths)
    print(f'adddev_train_size : {len(dev_train_paths)}', end=', ')
    add_dev_source_paths = [path for path in add_dev_paths if 'source' in path]
    print(f'source_size : {len(add_dev_source_paths)}', end=', ')
    add_dev_target_paths = [path for path in add_dev_paths if 'target' in path]
    print(f'target_size : {len(add_dev_target_paths)}')
    # source mode
    add_dev_paths = add_dev_source_paths + add_dev_target_paths
    print('==============================================================')
    
    # dev_source valid
    dev_source_paths = [f"{dev_dir}/{machine_type}/source_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/source_test")]
    dev_source_paths = sorted(dev_source_paths)
    
    # dev_target valid
    dev_target_paths = [f"{dev_dir}/{machine_type}/target_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/target_test")]
    dev_target_paths = sorted(dev_target_paths)
    
    # bundle
    dev_paths[machine_type] = {}
    dev_paths[machine_type]['train'] = dev_train_paths + add_dev_paths
    dev_paths[machine_type]['valid_source'] = dev_source_paths
    dev_paths[machine_type]['valid_target'] = dev_target_paths
# Out:
# Machine fan,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine gearbox,dev_train_size : 3026, source_size : 3017, target_size : 9, adddev_train_size : 3026, source_size : 3105, target_size : 9
# ==============================================================
# Machine pump,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine slider,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyCar,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyTrain,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine valve,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================

# %%
machine_types
# Out:
# ['fan', 'gearbox', 'pump', 'slider', 'ToyCar', 'ToyTrain', 'valve']

# %%
#############################################################################
# run
#############################################################################
def run(machine_type, dev_paths):
    com.tic()
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dev_train_paths
    dataloaders_dict = modeler.make_dataloader(dev_paths, machine_type)
    # parameter setting
    logger.info('TRAINING')
    model = Model(sample_rate=config['param']['sample_rate'],
                  window_size=config['param']['window_size'],
                  hop_size=config['param']['hop_size'],
                  mel_bins=config['param']['mel_bins'],
                  fmin=config['param']['fmin'],
                  fmax=config['param']['fmax'],
                  classes_num=6)
    pretrained_dict = torch.load(config['IO_OPTION']['PREMODEL_ROOT'])
    model.load_state_dict(pretrained_dict['model'], strict=False)
    optimizer = torch_optimizer.RAdam(model.parameters())
    output_dicts, model = modeler.run_training(model, dataloaders_dict, writer, optimizer)
    
    feature_out_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
    model_out_path = f'{MODEL_DIR}/{machine_type}_model.pkl'
    pd.to_pickle(output_dicts, feature_out_path)
    torch.save(model.state_dict(), model_out_path)
    logger.info(f'SAVE SUCCESS : {model_out_path}')
    
    com.toc()

# %% [markdown]
# # run

# %%
for machine_type in machine_types[6:]:
    run(machine_type, dev_paths)
# Out:
# 2021-09-17 23:40:33,391 - 00_train.py - INFO - TARGET MACHINE_TYPE: fan
# 2021-09-17 23:40:33,392 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-09-17 23:40:33,393 - 00_train.py - INFO - TRAINING
#   0%|          | 0/48 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 48/48 [02:17<00:00,  2.87s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.23it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# 2021-09-17 23:42:57,458 - pytorch_modeler.py - INFO - epoch:1/50, tr_loss:88.254273, src_loss:8.832669, src_acc:0.303333, tgt_loss:8.909448, tgt_acc:0.260000,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.37it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 2021-09-17 23:45:19,276 - pytorch_modeler.py - INFO - epoch:2/50, tr_loss:82.185745, src_loss:6.769127, src_acc:0.496667, tgt_loss:7.129643, tgt_acc:0.470000,
# 100%|██████████| 48/48 [02:17<00:00,  2.86s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.39it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.40it/s]
# 2021-09-17 23:47:38,791 - pytorch_modeler.py - INFO - epoch:3/50, tr_loss:63.039005, src_loss:5.398846, src_acc:0.576667, tgt_loss:5.801771, tgt_acc:0.511667,
# 100%|██████████| 48/48 [02:17<00:00,  2.86s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.42it/s]
# 2021-09-17 23:49:58,269 - pytorch_modeler.py - INFO - epoch:4/50, tr_loss:45.458613, src_loss:6.939033, src_acc:0.703333, tgt_loss:11.464368, tgt_acc:0.525000,
# 100%|██████████| 48/48 [02:17<00:00,  2.86s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.47it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.36it/s]
# 2021-09-17 23:52:17,744 - pytorch_modeler.py - INFO - epoch:5/50, tr_loss:31.717931, src_loss:5.613701, src_acc:0.768333, tgt_loss:22.648845, tgt_acc:0.480000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.47it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.32it/s]
# 2021-09-17 23:54:36,737 - pytorch_modeler.py - INFO - epoch:6/50, tr_loss:21.221107, src_loss:4.560501, src_acc:0.836667, tgt_loss:12.802782, tgt_acc:0.600000,
# 100%|██████████| 48/48 [02:17<00:00,  2.86s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.30it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.24it/s]
# 2021-09-17 23:56:56,273 - pytorch_modeler.py - INFO - epoch:7/50, tr_loss:18.252563, src_loss:4.274143, src_acc:0.805000, tgt_loss:9.867571, tgt_acc:0.505000,
# 100%|██████████| 48/48 [02:22<00:00,  2.97s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.08it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.01it/s]
# 2021-09-17 23:59:21,491 - pytorch_modeler.py - INFO - epoch:8/50, tr_loss:11.054090, src_loss:5.717820, src_acc:0.848333, tgt_loss:9.583111, tgt_acc:0.586667,
# 100%|██████████| 48/48 [02:18<00:00,  2.88s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.21it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.21it/s]
# 2021-09-18 00:01:42,026 - pytorch_modeler.py - INFO - epoch:9/50, tr_loss:8.673733, src_loss:7.359647, src_acc:0.796667, tgt_loss:10.557475, tgt_acc:0.545000,
# 100%|██████████| 48/48 [02:17<00:00,  2.86s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.18it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.15it/s]
# 2021-09-18 00:04:01,819 - pytorch_modeler.py - INFO - epoch:10/50, tr_loss:19.126860, src_loss:7.571981, src_acc:0.801667, tgt_loss:9.770312, tgt_acc:0.583333,
# 100%|██████████| 48/48 [02:20<00:00,  2.92s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.35it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.12it/s]
# 2021-09-18 00:06:24,282 - pytorch_modeler.py - INFO - epoch:11/50, tr_loss:11.971623, src_loss:4.862247, src_acc:0.833333, tgt_loss:7.074227, tgt_acc:0.646667,
# 100%|██████████| 48/48 [02:18<00:00,  2.90s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.40it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 2021-09-18 00:08:45,621 - pytorch_modeler.py - INFO - epoch:12/50, tr_loss:10.917276, src_loss:5.847051, src_acc:0.831667, tgt_loss:7.831518, tgt_acc:0.618333,
# 100%|██████████| 48/48 [02:18<00:00,  2.88s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.40it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.21it/s]
# 2021-09-18 00:11:06,090 - pytorch_modeler.py - INFO - epoch:13/50, tr_loss:19.937082, src_loss:5.409553, src_acc:0.848333, tgt_loss:5.988880, tgt_acc:0.676667,
# 100%|██████████| 48/48 [02:17<00:00,  2.87s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.48it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.35it/s]
# 2021-09-18 00:13:26,084 - pytorch_modeler.py - INFO - epoch:14/50, tr_loss:22.495675, src_loss:5.911216, src_acc:0.818333, tgt_loss:7.510935, tgt_acc:0.620000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.30it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.28it/s]
# 2021-09-18 00:15:45,252 - pytorch_modeler.py - INFO - epoch:15/50, tr_loss:21.737720, src_loss:5.233764, src_acc:0.850000, tgt_loss:7.126883, tgt_acc:0.661667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.45it/s]
# 2021-09-18 00:18:04,370 - pytorch_modeler.py - INFO - epoch:16/50, tr_loss:23.163109, src_loss:4.650958, src_acc:0.815000, tgt_loss:7.848585, tgt_acc:0.625000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.49it/s]
# 2021-09-18 00:20:23,454 - pytorch_modeler.py - INFO - epoch:17/50, tr_loss:36.304384, src_loss:5.836304, src_acc:0.830000, tgt_loss:7.412889, tgt_acc:0.675000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.33it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.35it/s]
# 2021-09-18 00:22:42,569 - pytorch_modeler.py - INFO - epoch:18/50, tr_loss:21.869677, src_loss:5.406939, src_acc:0.845000, tgt_loss:4.202523, tgt_acc:0.780000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.30it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.46it/s]
# 2021-09-18 00:25:01,691 - pytorch_modeler.py - INFO - epoch:19/50, tr_loss:11.660646, src_loss:4.023162, src_acc:0.853333, tgt_loss:9.506958, tgt_acc:0.626667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.44it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 2021-09-18 00:27:20,796 - pytorch_modeler.py - INFO - epoch:20/50, tr_loss:52.843471, src_loss:3.976500, src_acc:0.843333, tgt_loss:5.116991, tgt_acc:0.728333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.37it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.23it/s]
# 2021-09-18 00:29:39,993 - pytorch_modeler.py - INFO - epoch:21/50, tr_loss:25.983682, src_loss:4.187416, src_acc:0.845000, tgt_loss:5.561346, tgt_acc:0.726667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.44it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.48it/s]
# 2021-09-18 00:31:59,073 - pytorch_modeler.py - INFO - epoch:22/50, tr_loss:10.727516, src_loss:4.218169, src_acc:0.850000, tgt_loss:4.532543, tgt_acc:0.745000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.36it/s]
# 2021-09-18 00:34:18,224 - pytorch_modeler.py - INFO - epoch:23/50, tr_loss:12.230804, src_loss:4.355025, src_acc:0.863333, tgt_loss:3.702844, tgt_acc:0.806667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.28it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.30it/s]
# 2021-09-18 00:36:37,423 - pytorch_modeler.py - INFO - epoch:24/50, tr_loss:27.210136, src_loss:4.725984, src_acc:0.841667, tgt_loss:4.450525, tgt_acc:0.765000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.32it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.47it/s]
# 2021-09-18 00:38:56,513 - pytorch_modeler.py - INFO - epoch:25/50, tr_loss:40.059798, src_loss:3.798880, src_acc:0.858333, tgt_loss:4.408490, tgt_acc:0.785000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.32it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.47it/s]
# 2021-09-18 00:41:15,582 - pytorch_modeler.py - INFO - epoch:26/50, tr_loss:29.284790, src_loss:4.364756, src_acc:0.860000, tgt_loss:5.569581, tgt_acc:0.733333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.45it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.33it/s]
# 2021-09-18 00:43:34,645 - pytorch_modeler.py - INFO - epoch:27/50, tr_loss:13.349734, src_loss:4.985127, src_acc:0.855000, tgt_loss:5.002911, tgt_acc:0.755000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.22it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.30it/s]
# 2021-09-18 00:45:53,828 - pytorch_modeler.py - INFO - epoch:28/50, tr_loss:27.652160, src_loss:7.674735, src_acc:0.836667, tgt_loss:9.321491, tgt_acc:0.675000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.33it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.33it/s]
# 2021-09-18 00:48:12,895 - pytorch_modeler.py - INFO - epoch:29/50, tr_loss:18.405332, src_loss:5.276027, src_acc:0.841667, tgt_loss:6.464354, tgt_acc:0.683333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.30it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.50it/s]
# 2021-09-18 00:50:31,961 - pytorch_modeler.py - INFO - epoch:30/50, tr_loss:40.106003, src_loss:5.685843, src_acc:0.831667, tgt_loss:7.223002, tgt_acc:0.695000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.46it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.37it/s]
# 2021-09-18 00:52:50,915 - pytorch_modeler.py - INFO - epoch:31/50, tr_loss:17.022608, src_loss:6.184090, src_acc:0.831667, tgt_loss:7.941930, tgt_acc:0.650000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.49it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.33it/s]
# 2021-09-18 00:55:09,867 - pytorch_modeler.py - INFO - epoch:32/50, tr_loss:20.745412, src_loss:5.473350, src_acc:0.855000, tgt_loss:5.784183, tgt_acc:0.750000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.17it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.09it/s]
# 2021-09-18 00:57:29,016 - pytorch_modeler.py - INFO - epoch:33/50, tr_loss:23.019816, src_loss:4.994304, src_acc:0.863333, tgt_loss:4.910056, tgt_acc:0.755000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.26it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.45it/s]
# 2021-09-18 00:59:48,146 - pytorch_modeler.py - INFO - epoch:34/50, tr_loss:29.170855, src_loss:6.235957, src_acc:0.868333, tgt_loss:4.168206, tgt_acc:0.808333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.44it/s]
# 2021-09-18 01:02:07,144 - pytorch_modeler.py - INFO - epoch:35/50, tr_loss:39.043804, src_loss:7.898515, src_acc:0.835000, tgt_loss:5.237437, tgt_acc:0.741667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.32it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.48it/s]
# 2021-09-18 01:04:26,135 - pytorch_modeler.py - INFO - epoch:36/50, tr_loss:44.694538, src_loss:9.308529, src_acc:0.786667, tgt_loss:9.138247, tgt_acc:0.601667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.34it/s]
# 2021-09-18 01:06:45,199 - pytorch_modeler.py - INFO - epoch:37/50, tr_loss:80.771242, src_loss:4.658952, src_acc:0.698333, tgt_loss:7.768428, tgt_acc:0.505000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.35it/s]
# 2021-09-18 01:09:04,230 - pytorch_modeler.py - INFO - epoch:38/50, tr_loss:89.820318, src_loss:3.781463, src_acc:0.785000, tgt_loss:4.830681, tgt_acc:0.708333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.42it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.46it/s]
# 2021-09-18 01:11:23,167 - pytorch_modeler.py - INFO - epoch:39/50, tr_loss:80.258076, src_loss:25.497420, src_acc:0.776667, tgt_loss:4.611791, tgt_acc:0.711667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.31it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.44it/s]
# 2021-09-18 01:13:42,260 - pytorch_modeler.py - INFO - epoch:40/50, tr_loss:73.613384, src_loss:3.770414, src_acc:0.798333, tgt_loss:4.256200, tgt_acc:0.731667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.47it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.51it/s]
# 2021-09-18 01:16:01,149 - pytorch_modeler.py - INFO - epoch:41/50, tr_loss:67.193973, src_loss:4.359927, src_acc:0.745000, tgt_loss:5.475525, tgt_acc:0.656667,
# 100%|██████████| 48/48 [02:16<00:00,  2.84s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.48it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.41it/s]
# 2021-09-18 01:18:19,881 - pytorch_modeler.py - INFO - epoch:42/50, tr_loss:56.264807, src_loss:4.005222, src_acc:0.788333, tgt_loss:5.054357, tgt_acc:0.680000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.45it/s]
# 2021-09-18 01:20:38,893 - pytorch_modeler.py - INFO - epoch:43/50, tr_loss:41.836475, src_loss:3.647289, src_acc:0.825000, tgt_loss:3.730934, tgt_acc:0.761667,
# 100%|██████████| 48/48 [02:16<00:00,  2.84s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.45it/s]
# 2021-09-18 01:22:57,668 - pytorch_modeler.py - INFO - epoch:44/50, tr_loss:47.951047, src_loss:4.105591, src_acc:0.815000, tgt_loss:3.993018, tgt_acc:0.763333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.49it/s]
# 2021-09-18 01:25:16,608 - pytorch_modeler.py - INFO - epoch:45/50, tr_loss:19.233316, src_loss:4.554743, src_acc:0.845000, tgt_loss:4.561453, tgt_acc:0.765000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.46it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.30it/s]
# 2021-09-18 01:27:35,635 - pytorch_modeler.py - INFO - epoch:46/50, tr_loss:46.424072, src_loss:4.529300, src_acc:0.843333, tgt_loss:4.142690, tgt_acc:0.783333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.44it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.46it/s]
# 2021-09-18 01:29:54,590 - pytorch_modeler.py - INFO - epoch:47/50, tr_loss:29.390792, src_loss:3.819180, src_acc:0.836667, tgt_loss:4.587791, tgt_acc:0.750000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.46it/s]
# 2021-09-18 01:32:13,615 - pytorch_modeler.py - INFO - epoch:48/50, tr_loss:93.176577, src_loss:6.096150, src_acc:0.820000, tgt_loss:6.839041, tgt_acc:0.715000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.44it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.31it/s]
# 2021-09-18 01:34:32,574 - pytorch_modeler.py - INFO - epoch:49/50, tr_loss:27.064282, src_loss:3.902665, src_acc:0.851667, tgt_loss:4.599067, tgt_acc:0.763333,
# 100%|██████████| 48/48 [02:16<00:00,  2.84s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.45it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.44it/s]
# 2021-09-18 01:36:51,291 - pytorch_modeler.py - INFO - epoch:50/50, tr_loss:36.439098, src_loss:4.079605, src_acc:0.846667, tgt_loss:5.280497, tgt_acc:0.760000,
# 2021-09-18 01:36:52,833 - 00_train.py - INFO - SAVE SUCCESS : /media/hiroki/HDD1TB/research/DCASE_experiments/domain_adaptation/exp3/models/fan_model.pkl
# 2021-09-18 01:36:52,835 - 00_train.py - INFO - TARGET MACHINE_TYPE: gearbox
# 2021-09-18 01:36:52,835 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-09-18 01:36:52,836 - 00_train.py - INFO - TRAINING
# elapsed time: 6980.291739225 [sec]
#   0%|          | 0/48 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 48/48 [02:22<00:00,  2.98s/it]
# 100%|██████████| 6/6 [00:08<00:00,  1.48s/it]
# 100%|██████████| 6/6 [00:08<00:00,  1.34s/it]
# 2021-09-18 01:39:33,883 - pytorch_modeler.py - INFO - epoch:1/50, tr_loss:86.488104, src_loss:10.800702, src_acc:0.056430, tgt_loss:10.768758, tgt_acc:0.075969,
# 100%|██████████| 48/48 [02:19<00:00,  2.90s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.44it/s]
# 100%|██████████| 6/6 [00:01<00:00,  5.02it/s]
# 2021-09-18 01:41:55,791 - pytorch_modeler.py - INFO - epoch:2/50, tr_loss:77.872019, src_loss:9.454329, src_acc:0.322835, tgt_loss:9.687645, tgt_acc:0.288372,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.42it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.93it/s]
# 2021-09-18 01:44:17,857 - pytorch_modeler.py - INFO - epoch:3/50, tr_loss:55.169042, src_loss:7.522640, src_acc:0.393701, tgt_loss:8.227231, tgt_acc:0.368992,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.37it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.92it/s]
# 2021-09-18 01:46:40,049 - pytorch_modeler.py - INFO - epoch:4/50, tr_loss:40.204860, src_loss:7.913542, src_acc:0.412073, tgt_loss:8.852760, tgt_acc:0.423256,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.44it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.94it/s]
# 2021-09-18 01:49:02,147 - pytorch_modeler.py - INFO - epoch:5/50, tr_loss:32.843191, src_loss:6.766580, src_acc:0.497375, tgt_loss:8.015309, tgt_acc:0.500775,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.46it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.88it/s]
# 2021-09-18 01:51:24,228 - pytorch_modeler.py - INFO - epoch:6/50, tr_loss:27.752725, src_loss:6.602532, src_acc:0.541995, tgt_loss:8.584998, tgt_acc:0.483721,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.46it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.94it/s]
# 2021-09-18 01:53:46,344 - pytorch_modeler.py - INFO - epoch:7/50, tr_loss:25.519906, src_loss:6.704842, src_acc:0.586614, tgt_loss:8.502893, tgt_acc:0.576744,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.36it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.87it/s]
# 2021-09-18 01:56:08,476 - pytorch_modeler.py - INFO - epoch:8/50, tr_loss:22.940392, src_loss:5.791821, src_acc:0.629921, tgt_loss:7.792799, tgt_acc:0.598450,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.42it/s]
# 100%|██████████| 6/6 [00:01<00:00,  5.00it/s]
# 2021-09-18 01:58:30,565 - pytorch_modeler.py - INFO - epoch:9/50, tr_loss:20.384339, src_loss:6.279844, src_acc:0.641732, tgt_loss:8.060106, tgt_acc:0.615504,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.32it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.93it/s]
# 2021-09-18 02:00:52,761 - pytorch_modeler.py - INFO - epoch:10/50, tr_loss:19.370131, src_loss:6.493825, src_acc:0.652231, tgt_loss:7.642676, tgt_acc:0.629457,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.36it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.92it/s]
# 2021-09-18 02:03:14,878 - pytorch_modeler.py - INFO - epoch:11/50, tr_loss:17.199984, src_loss:5.738899, src_acc:0.665354, tgt_loss:6.899904, tgt_acc:0.626357,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.47it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.98it/s]
# 2021-09-18 02:05:36,992 - pytorch_modeler.py - INFO - epoch:12/50, tr_loss:16.842852, src_loss:5.728118, src_acc:0.670604, tgt_loss:8.045425, tgt_acc:0.624806,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.35it/s]
# 100%|██████████| 6/6 [00:01<00:00,  5.05it/s]
# 2021-09-18 02:07:59,060 - pytorch_modeler.py - INFO - epoch:13/50, tr_loss:15.403066, src_loss:6.665996, src_acc:0.686352, tgt_loss:9.334124, tgt_acc:0.600000,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.42it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.89it/s]
# 2021-09-18 02:10:21,183 - pytorch_modeler.py - INFO - epoch:14/50, tr_loss:14.455881, src_loss:6.441797, src_acc:0.677165, tgt_loss:10.336992, tgt_acc:0.613953,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.46it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.92it/s]
# 2021-09-18 02:12:43,287 - pytorch_modeler.py - INFO - epoch:15/50, tr_loss:13.640412, src_loss:6.057328, src_acc:0.678478, tgt_loss:9.486275, tgt_acc:0.568992,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.43it/s]
# 100%|██████████| 6/6 [00:01<00:00,  5.04it/s]
# 2021-09-18 02:15:05,375 - pytorch_modeler.py - INFO - epoch:16/50, tr_loss:12.471224, src_loss:6.804745, src_acc:0.669291, tgt_loss:9.581678, tgt_acc:0.634109,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.33it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.84it/s]
# 2021-09-18 02:17:27,532 - pytorch_modeler.py - INFO - epoch:17/50, tr_loss:12.098600, src_loss:5.932610, src_acc:0.704724, tgt_loss:9.659365, tgt_acc:0.618605,
# 100%|██████████| 48/48 [02:19<00:00,  2.90s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.43it/s]
# 100%|██████████| 6/6 [00:01<00:00,  5.04it/s]
# 2021-09-18 02:19:49,459 - pytorch_modeler.py - INFO - epoch:18/50, tr_loss:11.145170, src_loss:7.914499, src_acc:0.650919, tgt_loss:10.365664, tgt_acc:0.589147,
# 100%|██████████| 48/48 [02:19<00:00,  2.90s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.33it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.89it/s]
# 2021-09-18 02:22:11,353 - pytorch_modeler.py - INFO - epoch:19/50, tr_loss:11.232398, src_loss:7.665531, src_acc:0.652231, tgt_loss:11.652791, tgt_acc:0.539535,
# 100%|██████████| 48/48 [02:19<00:00,  2.90s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.43it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.90it/s]
# 2021-09-18 02:24:33,252 - pytorch_modeler.py - INFO - epoch:20/50, tr_loss:10.047994, src_loss:8.101093, src_acc:0.686352, tgt_loss:11.951609, tgt_acc:0.634109,
# 100%|██████████| 48/48 [02:19<00:00,  2.90s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.41it/s]
# 100%|██████████| 6/6 [00:01<00:00,  5.03it/s]
# 2021-09-18 02:26:55,286 - pytorch_modeler.py - INFO - epoch:21/50, tr_loss:9.679620, src_loss:8.448431, src_acc:0.649606, tgt_loss:10.535960, tgt_acc:0.624806,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.44it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.88it/s]
# 2021-09-18 02:29:17,399 - pytorch_modeler.py - INFO - epoch:22/50, tr_loss:9.006908, src_loss:7.735771, src_acc:0.666667, tgt_loss:10.820434, tgt_acc:0.603101,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.36it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.94it/s]
# 2021-09-18 02:31:39,598 - pytorch_modeler.py - INFO - epoch:23/50, tr_loss:8.617983, src_loss:7.400167, src_acc:0.696850, tgt_loss:11.775138, tgt_acc:0.589147,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.43it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.90it/s]
# 2021-09-18 02:34:01,756 - pytorch_modeler.py - INFO - epoch:24/50, tr_loss:8.912884, src_loss:8.125902, src_acc:0.675853, tgt_loss:11.797945, tgt_acc:0.604651,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.44it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.93it/s]
# 2021-09-18 02:36:23,820 - pytorch_modeler.py - INFO - epoch:25/50, tr_loss:8.597221, src_loss:8.697881, src_acc:0.661417, tgt_loss:13.074478, tgt_acc:0.595349,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.45it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.89it/s]
# 2021-09-18 02:38:45,980 - pytorch_modeler.py - INFO - epoch:26/50, tr_loss:7.611731, src_loss:8.333291, src_acc:0.700787, tgt_loss:13.851252, tgt_acc:0.631008,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.35it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.85it/s]
# 2021-09-18 02:41:08,150 - pytorch_modeler.py - INFO - epoch:27/50, tr_loss:7.370777, src_loss:7.933084, src_acc:0.699475, tgt_loss:12.790210, tgt_acc:0.610853,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.26it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.65it/s]
# 2021-09-18 02:43:30,402 - pytorch_modeler.py - INFO - epoch:28/50, tr_loss:6.825159, src_loss:7.140119, src_acc:0.716535, tgt_loss:12.128461, tgt_acc:0.654264,
# 100%|██████████| 48/48 [02:19<00:00,  2.90s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.35it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.87it/s]
# 2021-09-18 02:45:52,293 - pytorch_modeler.py - INFO - epoch:29/50, tr_loss:7.788030, src_loss:7.078046, src_acc:0.703412, tgt_loss:10.178274, tgt_acc:0.641860,
# 100%|██████████| 48/48 [02:19<00:00,  2.90s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.33it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.91it/s]
# 2021-09-18 02:48:14,183 - pytorch_modeler.py - INFO - epoch:30/50, tr_loss:6.602551, src_loss:8.379183, src_acc:0.681102, tgt_loss:13.905180, tgt_acc:0.600000,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.45it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.85it/s]
# 2021-09-18 02:50:36,329 - pytorch_modeler.py - INFO - epoch:31/50, tr_loss:6.495883, src_loss:7.009809, src_acc:0.685039, tgt_loss:11.798770, tgt_acc:0.655814,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.30it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.93it/s]
# 2021-09-18 02:52:58,548 - pytorch_modeler.py - INFO - epoch:32/50, tr_loss:6.247497, src_loss:8.800609, src_acc:0.707349, tgt_loss:12.663437, tgt_acc:0.632558,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.42it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.93it/s]
# 2021-09-18 02:55:20,676 - pytorch_modeler.py - INFO - epoch:33/50, tr_loss:5.756908, src_loss:9.043637, src_acc:0.683727, tgt_loss:14.878096, tgt_acc:0.582946,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.37it/s]
# 100%|██████████| 6/6 [00:01<00:00,  5.04it/s]
# 2021-09-18 02:57:42,798 - pytorch_modeler.py - INFO - epoch:34/50, tr_loss:5.433274, src_loss:8.457630, src_acc:0.670604, tgt_loss:14.151958, tgt_acc:0.626357,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.35it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.92it/s]
# 2021-09-18 03:00:04,915 - pytorch_modeler.py - INFO - epoch:35/50, tr_loss:5.004894, src_loss:8.579285, src_acc:0.682415, tgt_loss:13.215992, tgt_acc:0.598450,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.46it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.93it/s]
# 2021-09-18 03:02:27,054 - pytorch_modeler.py - INFO - epoch:36/50, tr_loss:5.240523, src_loss:8.632563, src_acc:0.682415, tgt_loss:15.333577, tgt_acc:0.606202,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.45it/s]
# 100%|██████████| 6/6 [00:01<00:00,  5.02it/s]
# 2021-09-18 03:04:49,175 - pytorch_modeler.py - INFO - epoch:37/50, tr_loss:5.584643, src_loss:7.926825, src_acc:0.702100, tgt_loss:12.526929, tgt_acc:0.663566,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.43it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.88it/s]
# 2021-09-18 03:07:11,352 - pytorch_modeler.py - INFO - epoch:38/50, tr_loss:4.459008, src_loss:8.974246, src_acc:0.679790, tgt_loss:12.267472, tgt_acc:0.603101,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.46it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.91it/s]
# 2021-09-18 03:09:33,469 - pytorch_modeler.py - INFO - epoch:39/50, tr_loss:5.070651, src_loss:9.071025, src_acc:0.691601, tgt_loss:12.805749, tgt_acc:0.635659,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.35it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.91it/s]
# 2021-09-18 03:11:55,575 - pytorch_modeler.py - INFO - epoch:40/50, tr_loss:3.958614, src_loss:10.060405, src_acc:0.666667, tgt_loss:14.277130, tgt_acc:0.596899,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.32it/s]
# 100%|██████████| 6/6 [00:01<00:00,  5.04it/s]
# 2021-09-18 03:14:17,688 - pytorch_modeler.py - INFO - epoch:41/50, tr_loss:4.561472, src_loss:9.533700, src_acc:0.678478, tgt_loss:12.463952, tgt_acc:0.626357,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.37it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.88it/s]
# 2021-09-18 03:16:39,823 - pytorch_modeler.py - INFO - epoch:42/50, tr_loss:4.421385, src_loss:8.898445, src_acc:0.691601, tgt_loss:13.909656, tgt_acc:0.598450,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.35it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.94it/s]
# 2021-09-18 03:19:01,915 - pytorch_modeler.py - INFO - epoch:43/50, tr_loss:4.262949, src_loss:8.202772, src_acc:0.669291, tgt_loss:10.683740, tgt_acc:0.634109,
# 100%|██████████| 48/48 [02:19<00:00,  2.90s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.35it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.99it/s]
# 2021-09-18 03:21:23,969 - pytorch_modeler.py - INFO - epoch:44/50, tr_loss:4.687548, src_loss:7.427848, src_acc:0.711286, tgt_loss:14.467482, tgt_acc:0.596899,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.47it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.90it/s]
# 2021-09-18 03:23:46,067 - pytorch_modeler.py - INFO - epoch:45/50, tr_loss:4.123418, src_loss:11.165967, src_acc:0.658793, tgt_loss:15.946392, tgt_acc:0.561240,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.45it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.86it/s]
# 2021-09-18 03:26:08,168 - pytorch_modeler.py - INFO - epoch:46/50, tr_loss:4.029696, src_loss:9.914946, src_acc:0.674541, tgt_loss:15.967584, tgt_acc:0.582946,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.31it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.86it/s]
# 2021-09-18 03:28:30,302 - pytorch_modeler.py - INFO - epoch:47/50, tr_loss:3.743422, src_loss:8.303520, src_acc:0.685039, tgt_loss:12.049605, tgt_acc:0.632558,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.43it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.91it/s]
# 2021-09-18 03:30:52,452 - pytorch_modeler.py - INFO - epoch:48/50, tr_loss:3.662472, src_loss:10.495673, src_acc:0.656168, tgt_loss:13.597157, tgt_acc:0.582946,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.42it/s]
# 100%|██████████| 6/6 [00:01<00:00,  5.04it/s]
# 2021-09-18 03:33:14,525 - pytorch_modeler.py - INFO - epoch:49/50, tr_loss:3.969184, src_loss:7.882774, src_acc:0.709974, tgt_loss:12.211467, tgt_acc:0.624806,
# 100%|██████████| 48/48 [02:19<00:00,  2.91s/it]
# 100%|██████████| 6/6 [00:01<00:00,  4.35it/s]
# 100%|██████████| 6/6 [00:01<00:00,  4.90it/s]
# 2021-09-18 03:35:36,762 - pytorch_modeler.py - INFO - epoch:50/50, tr_loss:3.413563, src_loss:9.678233, src_acc:0.707349, tgt_loss:15.082176, tgt_acc:0.615504,
# 2021-09-18 03:35:38,262 - 00_train.py - INFO - SAVE SUCCESS : /media/hiroki/HDD1TB/research/DCASE_experiments/domain_adaptation/exp3/models/gearbox_model.pkl
# 2021-09-18 03:35:38,272 - 00_train.py - INFO - TARGET MACHINE_TYPE: pump
# 2021-09-18 03:35:38,272 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-09-18 03:35:38,273 - 00_train.py - INFO - TRAINING
# elapsed time: 7125.428194046 [sec]
#   0%|          | 0/48 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 48/48 [02:19<00:00,  2.90s/it]
# 100%|██████████| 5/5 [00:05<00:00,  1.08s/it]
# 100%|██████████| 5/5 [00:05<00:00,  1.13s/it]
# 2021-09-18 03:38:10,053 - pytorch_modeler.py - INFO - epoch:1/50, tr_loss:86.773689, src_loss:8.770084, src_acc:0.355000, tgt_loss:8.619602, tgt_acc:0.438333,
# 100%|██████████| 48/48 [02:16<00:00,  2.84s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.44it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.33it/s]
# 2021-09-18 03:40:28,815 - pytorch_modeler.py - INFO - epoch:2/50, tr_loss:78.441695, src_loss:6.536617, src_acc:0.506667, tgt_loss:5.669913, tgt_acc:0.543333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.40it/s]
# 2021-09-18 03:42:47,932 - pytorch_modeler.py - INFO - epoch:3/50, tr_loss:55.077343, src_loss:5.204718, src_acc:0.578333, tgt_loss:4.081244, tgt_acc:0.650000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.32it/s]
# 2021-09-18 03:45:07,092 - pytorch_modeler.py - INFO - epoch:4/50, tr_loss:39.652535, src_loss:4.513948, src_acc:0.573333, tgt_loss:3.804837, tgt_acc:0.643333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.28it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# 2021-09-18 03:47:26,282 - pytorch_modeler.py - INFO - epoch:5/50, tr_loss:23.815364, src_loss:4.778906, src_acc:0.663333, tgt_loss:3.275819, tgt_acc:0.760000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.38it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.38it/s]
# 2021-09-18 03:49:45,385 - pytorch_modeler.py - INFO - epoch:6/50, tr_loss:20.745923, src_loss:4.258598, src_acc:0.686667, tgt_loss:2.754201, tgt_acc:0.776667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.39it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.30it/s]
# 2021-09-18 03:52:04,298 - pytorch_modeler.py - INFO - epoch:7/50, tr_loss:17.512667, src_loss:3.926088, src_acc:0.715000, tgt_loss:2.572853, tgt_acc:0.801667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.41it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.44it/s]
# 2021-09-18 03:54:23,390 - pytorch_modeler.py - INFO - epoch:8/50, tr_loss:16.013577, src_loss:4.265073, src_acc:0.708333, tgt_loss:2.785215, tgt_acc:0.776667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.40it/s]
# 2021-09-18 03:56:42,540 - pytorch_modeler.py - INFO - epoch:9/50, tr_loss:15.809757, src_loss:3.762310, src_acc:0.708333, tgt_loss:2.484244, tgt_acc:0.818333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.41it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# 2021-09-18 03:59:01,645 - pytorch_modeler.py - INFO - epoch:10/50, tr_loss:24.696147, src_loss:4.310377, src_acc:0.716667, tgt_loss:2.786600, tgt_acc:0.788333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.39it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.35it/s]
# 2021-09-18 04:01:20,753 - pytorch_modeler.py - INFO - epoch:11/50, tr_loss:17.216479, src_loss:3.783728, src_acc:0.741667, tgt_loss:2.116429, tgt_acc:0.836667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.25it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# 2021-09-18 04:03:39,864 - pytorch_modeler.py - INFO - epoch:12/50, tr_loss:26.866318, src_loss:3.474867, src_acc:0.760000, tgt_loss:2.836117, tgt_acc:0.785000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 2021-09-18 04:05:59,036 - pytorch_modeler.py - INFO - epoch:13/50, tr_loss:20.027283, src_loss:4.065662, src_acc:0.733333, tgt_loss:2.748403, tgt_acc:0.783333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.32it/s]
# 2021-09-18 04:08:18,174 - pytorch_modeler.py - INFO - epoch:14/50, tr_loss:15.931495, src_loss:4.317988, src_acc:0.715000, tgt_loss:2.902345, tgt_acc:0.783333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.32it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.31it/s]
# 2021-09-18 04:10:37,305 - pytorch_modeler.py - INFO - epoch:15/50, tr_loss:15.623546, src_loss:4.274637, src_acc:0.738333, tgt_loss:2.451838, tgt_acc:0.815000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.39it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.41it/s]
# 2021-09-18 04:12:56,390 - pytorch_modeler.py - INFO - epoch:16/50, tr_loss:17.851448, src_loss:4.172761, src_acc:0.733333, tgt_loss:2.569399, tgt_acc:0.820000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.40it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.42it/s]
# 2021-09-18 04:15:15,504 - pytorch_modeler.py - INFO - epoch:17/50, tr_loss:26.225715, src_loss:3.730419, src_acc:0.753333, tgt_loss:2.683465, tgt_acc:0.815000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.40it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.32it/s]
# 2021-09-18 04:17:34,580 - pytorch_modeler.py - INFO - epoch:18/50, tr_loss:20.629270, src_loss:4.040432, src_acc:0.781667, tgt_loss:2.576979, tgt_acc:0.823333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.39it/s]
# 2021-09-18 04:19:53,699 - pytorch_modeler.py - INFO - epoch:19/50, tr_loss:15.892190, src_loss:4.273110, src_acc:0.736667, tgt_loss:2.996482, tgt_acc:0.778333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# 2021-09-18 04:22:12,820 - pytorch_modeler.py - INFO - epoch:20/50, tr_loss:12.946755, src_loss:3.536434, src_acc:0.771667, tgt_loss:2.142740, tgt_acc:0.840000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.24it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.33it/s]
# 2021-09-18 04:24:31,989 - pytorch_modeler.py - INFO - epoch:21/50, tr_loss:14.535272, src_loss:4.212347, src_acc:0.745000, tgt_loss:2.648989, tgt_acc:0.805000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.28it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.31it/s]
# 2021-09-18 04:26:51,153 - pytorch_modeler.py - INFO - epoch:22/50, tr_loss:32.833959, src_loss:4.799122, src_acc:0.753333, tgt_loss:2.564774, tgt_acc:0.820000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.31it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.42it/s]
# 2021-09-18 04:29:10,201 - pytorch_modeler.py - INFO - epoch:23/50, tr_loss:35.187734, src_loss:5.371041, src_acc:0.760000, tgt_loss:2.918999, tgt_acc:0.795000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.07it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.14it/s]
# 2021-09-18 04:31:29,405 - pytorch_modeler.py - INFO - epoch:24/50, tr_loss:31.066150, src_loss:4.690894, src_acc:0.780000, tgt_loss:2.578117, tgt_acc:0.821667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.44it/s]
# 2021-09-18 04:33:48,547 - pytorch_modeler.py - INFO - epoch:25/50, tr_loss:42.147637, src_loss:4.897420, src_acc:0.783333, tgt_loss:2.478275, tgt_acc:0.853333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.26it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# 2021-09-18 04:36:07,655 - pytorch_modeler.py - INFO - epoch:26/50, tr_loss:28.796651, src_loss:4.258429, src_acc:0.770000, tgt_loss:2.561911, tgt_acc:0.826667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.30it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 2021-09-18 04:38:26,814 - pytorch_modeler.py - INFO - epoch:27/50, tr_loss:22.260243, src_loss:4.751613, src_acc:0.750000, tgt_loss:3.138819, tgt_acc:0.818333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.41it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.30it/s]
# 2021-09-18 04:40:45,864 - pytorch_modeler.py - INFO - epoch:28/50, tr_loss:29.528058, src_loss:4.325257, src_acc:0.743333, tgt_loss:2.400890, tgt_acc:0.845000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.41it/s]
# 2021-09-18 04:43:04,926 - pytorch_modeler.py - INFO - epoch:29/50, tr_loss:16.397660, src_loss:4.111893, src_acc:0.760000, tgt_loss:2.343340, tgt_acc:0.846667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.44it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.42it/s]
# 2021-09-18 04:45:23,962 - pytorch_modeler.py - INFO - epoch:30/50, tr_loss:26.736130, src_loss:4.710249, src_acc:0.763333, tgt_loss:3.282582, tgt_acc:0.816667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.41it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.45it/s]
# 2021-09-18 04:47:42,986 - pytorch_modeler.py - INFO - epoch:31/50, tr_loss:13.987089, src_loss:5.124682, src_acc:0.763333, tgt_loss:3.120289, tgt_acc:0.815000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.28it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.42it/s]
# 2021-09-18 04:50:02,059 - pytorch_modeler.py - INFO - epoch:32/50, tr_loss:27.242705, src_loss:5.377075, src_acc:0.756667, tgt_loss:3.094162, tgt_acc:0.796667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.36it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.38it/s]
# 2021-09-18 04:52:21,124 - pytorch_modeler.py - INFO - epoch:33/50, tr_loss:35.006193, src_loss:4.734605, src_acc:0.746667, tgt_loss:2.248619, tgt_acc:0.853333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.30it/s]
# 2021-09-18 04:54:40,218 - pytorch_modeler.py - INFO - epoch:34/50, tr_loss:13.138991, src_loss:4.495403, src_acc:0.768333, tgt_loss:2.275513, tgt_acc:0.850000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.39it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.44it/s]
# 2021-09-18 04:56:59,280 - pytorch_modeler.py - INFO - epoch:35/50, tr_loss:11.708862, src_loss:4.555404, src_acc:0.766667, tgt_loss:2.527212, tgt_acc:0.846667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.28it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.32it/s]
# 2021-09-18 04:59:18,396 - pytorch_modeler.py - INFO - epoch:36/50, tr_loss:37.730363, src_loss:4.730656, src_acc:0.768333, tgt_loss:2.123569, tgt_acc:0.868333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.39it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.42it/s]
# 2021-09-18 05:01:37,514 - pytorch_modeler.py - INFO - epoch:37/50, tr_loss:46.328338, src_loss:5.129353, src_acc:0.745000, tgt_loss:3.683088, tgt_acc:0.793333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.39it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# 2021-09-18 05:03:56,604 - pytorch_modeler.py - INFO - epoch:38/50, tr_loss:18.726786, src_loss:4.499141, src_acc:0.743333, tgt_loss:2.816484, tgt_acc:0.823333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.42it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.39it/s]
# 2021-09-18 05:06:15,680 - pytorch_modeler.py - INFO - epoch:39/50, tr_loss:28.596671, src_loss:4.274098, src_acc:0.765000, tgt_loss:2.267851, tgt_acc:0.846667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.42it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.42it/s]
# 2021-09-18 05:08:34,702 - pytorch_modeler.py - INFO - epoch:40/50, tr_loss:25.145571, src_loss:3.764008, src_acc:0.736667, tgt_loss:2.830563, tgt_acc:0.796667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.38it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# 2021-09-18 05:10:53,714 - pytorch_modeler.py - INFO - epoch:41/50, tr_loss:33.109765, src_loss:4.963780, src_acc:0.726667, tgt_loss:2.678224, tgt_acc:0.801667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.39it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.40it/s]
# 2021-09-18 05:13:12,802 - pytorch_modeler.py - INFO - epoch:42/50, tr_loss:72.834952, src_loss:3.998023, src_acc:0.776667, tgt_loss:2.244462, tgt_acc:0.846667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.25it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.30it/s]
# 2021-09-18 05:15:32,033 - pytorch_modeler.py - INFO - epoch:43/50, tr_loss:28.351018, src_loss:3.709302, src_acc:0.705000, tgt_loss:2.314772, tgt_acc:0.813333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.23it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.23it/s]
# 2021-09-18 05:17:51,244 - pytorch_modeler.py - INFO - epoch:44/50, tr_loss:33.735575, src_loss:3.499998, src_acc:0.766667, tgt_loss:2.029157, tgt_acc:0.845000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.40it/s]
# 2021-09-18 05:20:10,382 - pytorch_modeler.py - INFO - epoch:45/50, tr_loss:12.645601, src_loss:3.551642, src_acc:0.755000, tgt_loss:2.302115, tgt_acc:0.826667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.26it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 2021-09-18 05:22:29,473 - pytorch_modeler.py - INFO - epoch:46/50, tr_loss:65.017245, src_loss:4.143171, src_acc:0.788333, tgt_loss:1.957103, tgt_acc:0.860000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# 2021-09-18 05:24:48,561 - pytorch_modeler.py - INFO - epoch:47/50, tr_loss:93.529023, src_loss:3.807186, src_acc:0.765000, tgt_loss:2.014819, tgt_acc:0.866667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.38it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 2021-09-18 05:27:07,641 - pytorch_modeler.py - INFO - epoch:48/50, tr_loss:38.780072, src_loss:3.565471, src_acc:0.780000, tgt_loss:2.020795, tgt_acc:0.855000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.38it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.42it/s]
# 2021-09-18 05:29:26,693 - pytorch_modeler.py - INFO - epoch:49/50, tr_loss:30.919262, src_loss:3.725325, src_acc:0.786667, tgt_loss:2.225611, tgt_acc:0.850000,
# 100%|██████████| 48/48 [02:16<00:00,  2.84s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.20it/s]
# 2021-09-18 05:31:45,626 - pytorch_modeler.py - INFO - epoch:50/50, tr_loss:11.690576, src_loss:3.905457, src_acc:0.771667, tgt_loss:2.414949, tgt_acc:0.820000,
# 2021-09-18 05:31:47,172 - 00_train.py - INFO - SAVE SUCCESS : /media/hiroki/HDD1TB/research/DCASE_experiments/domain_adaptation/exp3/models/pump_model.pkl
# 2021-09-18 05:31:47,181 - 00_train.py - INFO - TARGET MACHINE_TYPE: slider
# 2021-09-18 05:31:47,181 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-09-18 05:31:47,182 - 00_train.py - INFO - TRAINING
# elapsed time: 6968.903542042 [sec]
#   0%|          | 0/48 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 48/48 [02:20<00:00,  2.93s/it]
# 100%|██████████| 5/5 [00:06<00:00,  1.38s/it]
# 100%|██████████| 5/5 [00:06<00:00,  1.37s/it]
# 2021-09-18 05:34:23,029 - pytorch_modeler.py - INFO - epoch:1/50, tr_loss:85.256889, src_loss:8.430247, src_acc:0.504902, tgt_loss:8.648326, tgt_acc:0.372093,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.24it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.41it/s]
# 2021-09-18 05:36:41,962 - pytorch_modeler.py - INFO - epoch:2/50, tr_loss:67.813676, src_loss:4.688539, src_acc:0.563725, tgt_loss:8.118054, tgt_acc:0.410299,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.20it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.32it/s]
# 2021-09-18 05:39:01,202 - pytorch_modeler.py - INFO - epoch:3/50, tr_loss:26.426298, src_loss:2.445566, src_acc:0.803922, tgt_loss:10.097817, tgt_acc:0.508306,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.21it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.30it/s]
# 2021-09-18 05:41:20,479 - pytorch_modeler.py - INFO - epoch:4/50, tr_loss:13.281400, src_loss:1.910628, src_acc:0.859477, tgt_loss:10.827204, tgt_acc:0.543189,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.19it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.44it/s]
# ...
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.26it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 2021-09-18 07:53:44,560 - pytorch_modeler.py - INFO - epoch:11/50, tr_loss:13.860083, src_loss:2.970327, src_acc:0.755000, tgt_loss:2.050569, tgt_acc:0.868333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.38it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 2021-09-18 07:56:03,804 - pytorch_modeler.py - INFO - epoch:12/50, tr_loss:11.038860, src_loss:3.320036, src_acc:0.750000, tgt_loss:1.759461, tgt_acc:0.891667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.40it/s]
# 2021-09-18 07:58:22,930 - pytorch_modeler.py - INFO - epoch:13/50, tr_loss:24.435669, src_loss:2.763811, src_acc:0.796667, tgt_loss:1.749203, tgt_acc:0.856667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.28it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.30it/s]
# 2021-09-18 08:00:42,084 - pytorch_modeler.py - INFO - epoch:14/50, tr_loss:10.553227, src_loss:3.366517, src_acc:0.728333, tgt_loss:1.770990, tgt_acc:0.881667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.28it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 2021-09-18 08:03:01,278 - pytorch_modeler.py - INFO - epoch:15/50, tr_loss:11.923574, src_loss:3.844230, src_acc:0.750000, tgt_loss:1.485219, tgt_acc:0.915000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.24it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.28it/s]
# 2021-09-18 08:05:20,470 - pytorch_modeler.py - INFO - epoch:16/50, tr_loss:11.063591, src_loss:2.545889, src_acc:0.815000, tgt_loss:1.457136, tgt_acc:0.911667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.40it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.30it/s]
# 2021-09-18 08:07:39,592 - pytorch_modeler.py - INFO - epoch:17/50, tr_loss:9.444588, src_loss:2.837110, src_acc:0.800000, tgt_loss:1.543214, tgt_acc:0.871667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.40it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 2021-09-18 08:09:58,709 - pytorch_modeler.py - INFO - epoch:18/50, tr_loss:12.729277, src_loss:3.481451, src_acc:0.801667, tgt_loss:1.264321, tgt_acc:0.921667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.42it/s]
# 2021-09-18 08:12:17,858 - pytorch_modeler.py - INFO - epoch:19/50, tr_loss:10.399473, src_loss:4.741861, src_acc:0.753333, tgt_loss:2.101423, tgt_acc:0.856667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.41it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# 2021-09-18 08:14:36,907 - pytorch_modeler.py - INFO - epoch:20/50, tr_loss:22.377622, src_loss:2.852778, src_acc:0.798333, tgt_loss:1.827896, tgt_acc:0.810000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.38it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.28it/s]
# 2021-09-18 08:16:56,120 - pytorch_modeler.py - INFO - epoch:21/50, tr_loss:16.124641, src_loss:2.204755, src_acc:0.818333, tgt_loss:1.958635, tgt_acc:0.795000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.40it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 2021-09-18 08:19:15,216 - pytorch_modeler.py - INFO - epoch:22/50, tr_loss:31.082698, src_loss:2.469980, src_acc:0.831667, tgt_loss:2.547957, tgt_acc:0.766667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.30it/s]
# 2021-09-18 08:21:34,409 - pytorch_modeler.py - INFO - epoch:23/50, tr_loss:27.645463, src_loss:3.438550, src_acc:0.790000, tgt_loss:1.981255, tgt_acc:0.830000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.38it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.41it/s]
# 2021-09-18 08:23:53,482 - pytorch_modeler.py - INFO - epoch:24/50, tr_loss:30.089816, src_loss:4.948987, src_acc:0.731667, tgt_loss:2.655130, tgt_acc:0.788333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.37it/s]
# 2021-09-18 08:26:12,669 - pytorch_modeler.py - INFO - epoch:25/50, tr_loss:34.791466, src_loss:3.500982, src_acc:0.793333, tgt_loss:3.135580, tgt_acc:0.761667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.42it/s]
# 2021-09-18 08:28:31,826 - pytorch_modeler.py - INFO - epoch:26/50, tr_loss:15.571276, src_loss:4.799721, src_acc:0.760000, tgt_loss:2.511712, tgt_acc:0.781667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.40it/s]
# 2021-09-18 08:30:50,923 - pytorch_modeler.py - INFO - epoch:27/50, tr_loss:13.531616, src_loss:3.913444, src_acc:0.788333, tgt_loss:1.725796, tgt_acc:0.851667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.28it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.38it/s]
# 2021-09-18 08:33:10,069 - pytorch_modeler.py - INFO - epoch:28/50, tr_loss:28.474826, src_loss:6.121178, src_acc:0.701667, tgt_loss:3.357915, tgt_acc:0.740000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.32it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.23it/s]
# 2021-09-18 08:35:29,236 - pytorch_modeler.py - INFO - epoch:29/50, tr_loss:36.599724, src_loss:2.555061, src_acc:0.793333, tgt_loss:3.318623, tgt_acc:0.726667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.15it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.42it/s]
# 2021-09-18 08:37:48,430 - pytorch_modeler.py - INFO - epoch:30/50, tr_loss:43.376594, src_loss:3.028869, src_acc:0.761667, tgt_loss:3.676717, tgt_acc:0.725000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.26it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.31it/s]
# 2021-09-18 08:40:07,634 - pytorch_modeler.py - INFO - epoch:31/50, tr_loss:14.895391, src_loss:2.923585, src_acc:0.798333, tgt_loss:2.864411, tgt_acc:0.771667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.23it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.39it/s]
# 2021-09-18 08:42:26,766 - pytorch_modeler.py - INFO - epoch:32/50, tr_loss:13.287681, src_loss:3.847418, src_acc:0.750000, tgt_loss:2.524220, tgt_acc:0.801667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.22it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.39it/s]
# 2021-09-18 08:44:45,922 - pytorch_modeler.py - INFO - epoch:33/50, tr_loss:14.409133, src_loss:3.593229, src_acc:0.803333, tgt_loss:2.574861, tgt_acc:0.780000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.39it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.26it/s]
# 2021-09-18 08:47:05,016 - pytorch_modeler.py - INFO - epoch:34/50, tr_loss:17.177947, src_loss:4.032606, src_acc:0.775000, tgt_loss:2.464167, tgt_acc:0.791667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.31it/s]
# 2021-09-18 08:49:24,151 - pytorch_modeler.py - INFO - epoch:35/50, tr_loss:10.833728, src_loss:4.606596, src_acc:0.778333, tgt_loss:2.301956, tgt_acc:0.798333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.37it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.42it/s]
# 2021-09-18 08:51:43,251 - pytorch_modeler.py - INFO - epoch:36/50, tr_loss:15.998341, src_loss:3.179024, src_acc:0.806667, tgt_loss:3.109084, tgt_acc:0.746667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.37it/s]
# 2021-09-18 08:54:02,362 - pytorch_modeler.py - INFO - epoch:37/50, tr_loss:14.670987, src_loss:4.325764, src_acc:0.791667, tgt_loss:2.292276, tgt_acc:0.796667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.26it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# 2021-09-18 08:56:21,442 - pytorch_modeler.py - INFO - epoch:38/50, tr_loss:37.251902, src_loss:3.797871, src_acc:0.828333, tgt_loss:2.503051, tgt_acc:0.781667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.42it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.31it/s]
# 2021-09-18 08:58:40,552 - pytorch_modeler.py - INFO - epoch:39/50, tr_loss:11.971186, src_loss:4.281530, src_acc:0.785000, tgt_loss:1.930732, tgt_acc:0.850000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.26it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# 2021-09-18 09:00:59,812 - pytorch_modeler.py - INFO - epoch:40/50, tr_loss:11.742138, src_loss:4.586178, src_acc:0.778333, tgt_loss:2.603378, tgt_acc:0.776667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.40it/s]
# 2021-09-18 09:03:18,932 - pytorch_modeler.py - INFO - epoch:41/50, tr_loss:30.549316, src_loss:4.431973, src_acc:0.773333, tgt_loss:2.051758, tgt_acc:0.831667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.35it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.28it/s]
# 2021-09-18 09:05:38,073 - pytorch_modeler.py - INFO - epoch:42/50, tr_loss:41.399186, src_loss:3.907185, src_acc:0.800000, tgt_loss:1.816233, tgt_acc:0.820000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.31it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.31it/s]
# 2021-09-18 09:07:57,195 - pytorch_modeler.py - INFO - epoch:43/50, tr_loss:27.342274, src_loss:5.809412, src_acc:0.748333, tgt_loss:2.327548, tgt_acc:0.791667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.41it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.40it/s]
# 2021-09-18 09:10:16,293 - pytorch_modeler.py - INFO - epoch:44/50, tr_loss:23.275356, src_loss:4.896498, src_acc:0.753333, tgt_loss:2.032487, tgt_acc:0.825000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.38it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.30it/s]
# 2021-09-18 09:12:35,442 - pytorch_modeler.py - INFO - epoch:45/50, tr_loss:16.343023, src_loss:4.078874, src_acc:0.790000, tgt_loss:1.677055, tgt_acc:0.845000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.33it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.41it/s]
# 2021-09-18 09:14:54,553 - pytorch_modeler.py - INFO - epoch:46/50, tr_loss:12.819195, src_loss:4.566943, src_acc:0.770000, tgt_loss:2.223655, tgt_acc:0.801667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.24it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.31it/s]
# 2021-09-18 09:17:13,688 - pytorch_modeler.py - INFO - epoch:47/50, tr_loss:27.636955, src_loss:4.849232, src_acc:0.771667, tgt_loss:1.930620, tgt_acc:0.848333,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.26it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.42it/s]
# 2021-09-18 09:19:32,806 - pytorch_modeler.py - INFO - epoch:48/50, tr_loss:23.813093, src_loss:4.651484, src_acc:0.736667, tgt_loss:2.156049, tgt_acc:0.840000,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.42it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.32it/s]
# 2021-09-18 09:21:51,941 - pytorch_modeler.py - INFO - epoch:49/50, tr_loss:22.948155, src_loss:4.615006, src_acc:0.763333, tgt_loss:1.624197, tgt_acc:0.906667,
# 100%|██████████| 48/48 [02:16<00:00,  2.85s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.36it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.29it/s]
# 2021-09-18 09:24:11,108 - pytorch_modeler.py - INFO - epoch:50/50, tr_loss:22.047676, src_loss:6.711508, src_acc:0.741667, tgt_loss:1.538569, tgt_acc:0.916667,
# 2021-09-18 09:24:12,726 - 00_train.py - INFO - SAVE SUCCESS : /media/hiroki/HDD1TB/research/DCASE_experiments/domain_adaptation/exp3/models/ToyCar_model.pkl
# 2021-09-18 09:24:12,737 - 00_train.py - INFO - TARGET MACHINE_TYPE: ToyTrain
# 2021-09-18 09:24:12,738 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-09-18 09:24:12,739 - 00_train.py - INFO - TRAINING
# elapsed time: 6971.751324415 [sec]
#   0%|          | 0/48 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 48/48 [02:18<00:00,  2.89s/it]
# 100%|██████████| 5/5 [00:04<00:00,  1.23it/s]
# 100%|██████████| 5/5 [00:04<00:00,  1.09it/s]
# 2021-09-18 09:26:41,575 - pytorch_modeler.py - INFO - epoch:1/50, tr_loss:nan, src_loss:nan, src_acc:0.333333, tgt_loss:nan, tgt_acc:0.333333,
# 100%|██████████| 48/48 [02:15<00:00,  2.82s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.42it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.45it/s]
# 2021-09-18 09:28:59,207 - pytorch_modeler.py - INFO - epoch:2/50, tr_loss:nan, src_loss:nan, src_acc:0.333333, tgt_loss:nan, tgt_acc:0.333333,
# 100%|██████████| 48/48 [02:15<00:00,  2.82s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.39it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.27it/s]
# 2021-09-18 09:31:17,052 - pytorch_modeler.py - INFO - epoch:3/50, tr_loss:nan, src_loss:nan, src_acc:0.333333, tgt_loss:nan, tgt_acc:0.333333,
# 100%|██████████| 48/48 [02:15<00:00,  2.82s/it]
# 100%|██████████| 5/5 [00:01<00:00,  4.41it/s]
# 100%|██████████| 5/5 [00:01<00:00,  4.28it/s]
# 2021-09-18 09:33:34,946 - pytorch_modeler.py - INFO - epoch:4/50, tr_loss:nan, src_loss:nan, src_acc:0.333333, tgt_loss:nan, tgt_acc:0.333333,
#  50%|█████     | 24/48 [01:14<01:14,  3.10s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-1e044a84fb95> in <module>
#       1 for machine_type in machine_types[0:]:
# ----> 2     run(machine_type, dev_paths)
#
# <ipython-input-10-fffcc0f1be77> in run(machine_type, dev_paths)
#      24     model.load_state_dict(pretrained_dict['model'], strict=False)
#      25     optimizer = torch_optimizer.RAdam(model.parameters())
# ---> 26     output_dicts, model = modeler.run_training(model, dataloaders_dict, writer, optimizer)
#      27
#      28     feature_out_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
#
# ~/research/DCASE_experiments/dcase2021/domain_adaptation/exp3/pytorch_modeler.py in run_training(model, dataloaders_dict, writer, optimizer)
#     278     n_epochs = config['param']['num_epochs']
#     279     for epoch in range(n_epochs):
# --> 280         output_tr = train_fn(
#     281             data_loader=dataloaders_dict['train'],
#     282             model=model,
#
# ~/research/DCASE_experiments/dcase2021/domain_adaptation/exp3/pytorch_modeler.py in train_fn(data_loader, model, optimizer, criterion, scaler, device)
#     202             loss = criterion(pred, section_label)
#     203             pred = F.softmax(pred, dim=1)
# --> 204         scaler.scale(loss).backward()
#     205         scaler.step(optimizer)
#     206         scaler.update()
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     243                 create_graph=create_graph,
#     244                 inputs=inputs)
# --> 245         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     246
#     247     def register_hook(self, hook):
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     143         retain_graph = create_graph
#     144
# --> 145     Variable._execution_engine.run_backward(
#     146         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     147         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
feature_out_path = f'{OUT_FEATURE_DIR}/{machine_types[0]}_features.pkl'
tst = pd.read_pickle(feature_out_path)

# %%
tst['val_tgt']

# %%
plt.figure(figsize=(10,10))
plt.imshow(tst['val_src']['feature'].astype(float), aspect='auto')

# %%
tst['val_src']['feature'].shape

# %%
plt.figure(figsize=(10,10))
plt.imshow(tst['val_tgt']['feature'].astype(float), aspect='auto')
