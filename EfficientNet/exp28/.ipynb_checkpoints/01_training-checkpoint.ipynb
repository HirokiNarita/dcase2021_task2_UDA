# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter
import timm

#from torchvision.models import wide_resnet50_2, resnet18
#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
import common as com
import pytorch_modeler as modeler
from pytorch_model import EfficientNet_b1 as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %%
# effnet1 = timm.create_model('efficientnet_b1', pretrained=True)
# # M7:block[5], M8:block[6], M9:conv_head
# effnet1

# %% [markdown]
# ## load config and set logger

# %%
log_folder = config['IO_OPTION']['OUTPUT_ROOT']+'/{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_folder, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(42)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
dev_dir = INPUT_ROOT + "/dev_data"
add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = os.listdir(dev_dir)
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'

TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
PRED_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/pred'
SCORE_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/score'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
os.makedirs(PRED_DIR, exist_ok=True)
os.makedirs(SCORE_DIR, exist_ok=True)

# copy config
# shutil.copy('./config.yaml', OUTPUT_ROOT)

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## make path list

# %% [markdown]
# - __train_paths__ ([dict]): Each Machine Type
#     - __ToyCar__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) :paths
#     - __ToyTrain__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) : paths
#     - ...

# %%
percent = 0.1

# %%
dev_paths = {}

for machine_type in machine_types:
    # dev train
    dev_train_paths = [f"{dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/train")]
    dev_train_paths = sorted(dev_train_paths)
    
    print(f'Machine {machine_type}', end=',')
    print(f'dev_train_size : {len(dev_train_paths)}', end=', ')
    dev_train_source_paths = [path for path in dev_train_paths if 'source' in path]
    print(f'source_size : {len(dev_train_source_paths)}', end=', ')
    dev_train_target_paths = [path for path in dev_train_paths if 'target' in path]
    print(f'target_size : {len(dev_train_target_paths)}', end=', ')
    # increse tgt
    num_increse_tgt = int(len(dev_train_source_paths) * percent)
    increse_dev_train_target_paths = dev_train_target_paths * num_increse_tgt
    # concat
    dev_train_paths = dev_train_source_paths + increse_dev_train_target_paths
    
    # add_dev train
    add_dev_paths = [f"{add_dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{add_dev_dir}/{machine_type}/train")]
    add_dev_paths = sorted(add_dev_paths)
    print(f'adddev_train_size : {len(add_dev_paths)}', end=', ')
    add_dev_source_paths = [path for path in add_dev_paths if 'source' in path]
    print(f'source_size : {len(add_dev_source_paths)}', end=', ')
    add_dev_target_paths = [path for path in add_dev_paths if 'target' in path]
    print(f'target_size : {len(add_dev_target_paths)}')
    # increse tgt
    num_increse_tgt = int(len(add_dev_source_paths) * percent)
    increse_add_dev_target_paths = add_dev_target_paths * num_increse_tgt
    # concat
    add_dev_paths = add_dev_source_paths + increse_add_dev_target_paths

    print('==============================================================')
    
    # dev_source valid
    dev_source_paths = [f"{dev_dir}/{machine_type}/source_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/source_test")]
    dev_source_paths = sorted(dev_source_paths)
    
    # dev_target valid
    dev_target_paths = [f"{dev_dir}/{machine_type}/target_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/target_test")]
    dev_target_paths = sorted(dev_target_paths)
    
    # bundle
    dev_paths[machine_type] = {}
    dev_paths[machine_type]['train'] = dev_train_paths + add_dev_paths
    dev_paths[machine_type]['valid_source'] = dev_source_paths
    dev_paths[machine_type]['valid_target'] = dev_target_paths
# Out:
# Machine pump,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine gearbox,dev_train_size : 3026, source_size : 3017, target_size : 9, adddev_train_size : 3114, source_size : 3105, target_size : 9
# ==============================================================
# Machine slider,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyCar,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine valve,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyTrain,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine fan,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================

# %%
machine_types
# Out:
# ['pump', 'gearbox', 'slider', 'ToyCar', 'valve', 'ToyTrain', 'fan']

# %%
#############################################################################
# run
#############################################################################
def run(machine_type, dev_paths):
    com.tic()
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dev_train_paths
    dataloaders_dict = modeler.make_dataloader(dev_paths, machine_type)
    # parameter setting
    logger.info('TRAINING')
    model = Model(n_out=36, n_centers=6)
    
    optimizer = torch.optim.Adam(model.parameters(),lr=1e-4)
    output_dict, model, pred_df, score_df = modeler.run_training(model, dataloaders_dict, writer, optimizer)
    
    # output
    feature_out_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
    model_out_path = f'{MODEL_DIR}/{machine_type}_model.pkl'
    pred_out_path = f'{PRED_DIR}/{machine_type}_pred.csv'
    score_out_path = f'{SCORE_DIR}/{machine_type}_pred.csv'
    # save
    pd.to_pickle(output_dict, feature_out_path)
    torch.save(model.state_dict(), model_out_path)
    pred_df.to_csv(pred_out_path)
    score_df.to_csv(score_out_path)
    logger.info(f'SAVE SUCCESS : {model_out_path}')
    
    com.toc()

# %%
#run(machine_types[0], dev_paths)

# %%
for machine_type in machine_types[5:]:
    run(machine_type, dev_paths)
# Out:
# 2021-10-27 08:04:08,653 - 00_train.py - INFO - TARGET MACHINE_TYPE: ToyTrain
# 2021-10-27 08:04:08,653 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-10-27 08:04:08,658 - 00_train.py - INFO - TRAINING
# use: cuda:0
# 100%|██████████| 45/45 [00:46<00:00,  1.04s/it]
# 100%|██████████| 600/600 [01:21<00:00,  7.36it/s]
# 100%|██████████| 600/600 [01:21<00:00,  7.35it/s]
# 2021-10-27 08:07:42,001 - pytorch_modeler.py - INFO - epoch:1/100, tr_loss:1.258446, src_loss:1.511840, src_mean_auc:0.496833, tgt_loss:0.857418, tgt_mean_auc:0.523633, mean_auc:0.510233,
#                AUC      pAUC
# Source_0  0.494400  0.473684
# Source_1  0.469100  0.478421
# Source_2  0.527000  0.523684
# Target_0  0.572100  0.538947
# Target_1  0.503300  0.486842
# Target_2  0.495500  0.570000
# mean      0.510233  0.511930
# h_mean    0.508262  0.509564
# 100%|██████████| 45/45 [00:46<00:00,  1.04s/it]
# 2021-10-27 08:08:28,931 - pytorch_modeler.py - INFO - epoch:2/100, tr_loss:0.523243, src_loss:1.511840, src_mean_auc:0.496833, tgt_loss:0.857418, tgt_mean_auc:0.523633, mean_auc:0.510233,
#                AUC      pAUC
# Source_0  0.494400  0.473684
# Source_1  0.469100  0.478421
# Source_2  0.527000  0.523684
# Target_0  0.572100  0.538947
# Target_1  0.503300  0.486842
# Target_2  0.495500  0.570000
# mean      0.510233  0.511930
# h_mean    0.508262  0.509564
# 100%|██████████| 45/45 [00:46<00:00,  1.04s/it]
# 2021-10-27 08:09:15,766 - pytorch_modeler.py - INFO - epoch:3/100, tr_loss:0.336709, src_loss:1.511840, src_mean_auc:0.496833, tgt_loss:0.857418, tgt_mean_auc:0.523633, mean_auc:0.510233,
#                AUC      pAUC
# Source_0  0.494400  0.473684
# Source_1  0.469100  0.478421
# Source_2  0.527000  0.523684
# Target_0  0.572100  0.538947
# Target_1  0.503300  0.486842
# Target_2  0.495500  0.570000
# mean      0.510233  0.511930
# h_mean    0.508262  0.509564
# 100%|██████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-27 08:10:06,075 - pytorch_modeler.py - INFO - epoch:4/100, tr_loss:0.279296, src_loss:1.511840, src_mean_auc:0.496833, tgt_loss:0.857418, tgt_mean_auc:0.523633, mean_auc:0.510233,
#                AUC      pAUC
# Source_0  0.494400  0.473684
# Source_1  0.469100  0.478421
# Source_2  0.527000  0.523684
# Target_0  0.572100  0.538947
# Target_1  0.503300  0.486842
# Target_2  0.495500  0.570000
# mean      0.510233  0.511930
# h_mean    0.508262  0.509564
# 100%|██████████| 45/45 [01:00<00:00,  1.34s/it]
# 2021-10-27 08:11:06,533 - pytorch_modeler.py - INFO - epoch:5/100, tr_loss:0.238819, src_loss:1.511840, src_mean_auc:0.496833, tgt_loss:0.857418, tgt_mean_auc:0.523633, mean_auc:0.510233,
#                AUC      pAUC
# Source_0  0.494400  0.473684
# Source_1  0.469100  0.478421
# Source_2  0.527000  0.523684
# Target_0  0.572100  0.538947
# Target_1  0.503300  0.486842
# Target_2  0.495500  0.570000
# mean      0.510233  0.511930
# h_mean    0.508262  0.509564
# 100%|██████████| 45/45 [00:59<00:00,  1.33s/it]
# 2021-10-27 08:12:06,549 - pytorch_modeler.py - INFO - epoch:6/100, tr_loss:0.216082, src_loss:1.511840, src_mean_auc:0.496833, tgt_loss:0.857418, tgt_mean_auc:0.523633, mean_auc:0.510233,
#                AUC      pAUC
# Source_0  0.494400  0.473684
# Source_1  0.469100  0.478421
# Source_2  0.527000  0.523684
# Target_0  0.572100  0.538947
# Target_1  0.503300  0.486842
# Target_2  0.495500  0.570000
# mean      0.510233  0.511930
# h_mean    0.508262  0.509564
# 100%|██████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-27 08:12:57,157 - pytorch_modeler.py - INFO - epoch:7/100, tr_loss:0.196995, src_loss:1.511840, src_mean_auc:0.496833, tgt_loss:0.857418, tgt_mean_auc:0.523633, mean_auc:0.510233,
#                AUC      pAUC
# Source_0  0.494400  0.473684
# Source_1  0.469100  0.478421
# Source_2  0.527000  0.523684
# Target_0  0.572100  0.538947
# Target_1  0.503300  0.486842
# Target_2  0.495500  0.570000
# mean      0.510233  0.511930
# h_mean    0.508262  0.509564
# 100%|██████████| 45/45 [00:44<00:00,  1.02it/s]
# 2021-10-27 08:13:41,279 - pytorch_modeler.py - INFO - epoch:8/100, tr_loss:0.178270, src_loss:1.511840, src_mean_auc:0.496833, tgt_loss:0.857418, tgt_mean_auc:0.523633, mean_auc:0.510233,
#                AUC      pAUC
# Source_0  0.494400  0.473684
# Source_1  0.469100  0.478421
# Source_2  0.527000  0.523684
# Target_0  0.572100  0.538947
# Target_1  0.503300  0.486842
# Target_2  0.495500  0.570000
# mean      0.510233  0.511930
# h_mean    0.508262  0.509564
# 100%|██████████| 45/45 [00:43<00:00,  1.04it/s]
# 2021-10-27 08:14:24,641 - pytorch_modeler.py - INFO - epoch:9/100, tr_loss:0.158064, src_loss:1.511840, src_mean_auc:0.496833, tgt_loss:0.857418, tgt_mean_auc:0.523633, mean_auc:0.510233,
#                AUC      pAUC
# Source_0  0.494400  0.473684
# Source_1  0.469100  0.478421
# Source_2  0.527000  0.523684
# Target_0  0.572100  0.538947
# Target_1  0.503300  0.486842
# Target_2  0.495500  0.570000
# mean      0.510233  0.511930
# h_mean    0.508262  0.509564
# 100%|██████████| 45/45 [00:43<00:00,  1.04it/s]
# 100%|██████████| 600/600 [01:01<00:00,  9.68it/s]
# 100%|██████████| 600/600 [01:06<00:00,  9.05it/s]
# 2021-10-27 08:17:16,275 - pytorch_modeler.py - INFO - epoch:10/100, tr_loss:0.153403, src_loss:0.105853, src_mean_auc:0.582567, tgt_loss:0.133028, tgt_mean_auc:0.549567, mean_auc:0.566067,
#                AUC      pAUC
# Source_0  0.369600  0.473684
# Source_1  0.663000  0.545263
# Source_2  0.715100  0.477895
# Target_0  0.607500  0.527895
# Target_1  0.469400  0.480526
# Target_2  0.571800  0.578421
# mean      0.566067  0.513947
# h_mean    0.538713  0.510994
# 100%|██████████| 45/45 [00:57<00:00,  1.28s/it]
# 2021-10-27 08:18:13,884 - pytorch_modeler.py - INFO - epoch:11/100, tr_loss:0.133148, src_loss:0.105853, src_mean_auc:0.582567, tgt_loss:0.133028, tgt_mean_auc:0.549567, mean_auc:0.566067,
#                AUC      pAUC
# Source_0  0.369600  0.473684
# Source_1  0.663000  0.545263
# Source_2  0.715100  0.477895
# Target_0  0.607500  0.527895
# Target_1  0.469400  0.480526
# Target_2  0.571800  0.578421
# mean      0.566067  0.513947
# h_mean    0.538713  0.510994
# 100%|██████████| 45/45 [00:57<00:00,  1.28s/it]
# 2021-10-27 08:19:11,384 - pytorch_modeler.py - INFO - epoch:12/100, tr_loss:0.131196, src_loss:0.105853, src_mean_auc:0.582567, tgt_loss:0.133028, tgt_mean_auc:0.549567, mean_auc:0.566067,
#                AUC      pAUC
# Source_0  0.369600  0.473684
# Source_1  0.663000  0.545263
# Source_2  0.715100  0.477895
# Target_0  0.607500  0.527895
# Target_1  0.469400  0.480526
# Target_2  0.571800  0.578421
# mean      0.566067  0.513947
# h_mean    0.538713  0.510994
# 100%|██████████| 45/45 [00:57<00:00,  1.27s/it]
# 2021-10-27 08:20:08,690 - pytorch_modeler.py - INFO - epoch:13/100, tr_loss:0.116788, src_loss:0.105853, src_mean_auc:0.582567, tgt_loss:0.133028, tgt_mean_auc:0.549567, mean_auc:0.566067,
#                AUC      pAUC
# Source_0  0.369600  0.473684
# Source_1  0.663000  0.545263
# Source_2  0.715100  0.477895
# Target_0  0.607500  0.527895
# Target_1  0.469400  0.480526
# Target_2  0.571800  0.578421
# mean      0.566067  0.513947
# h_mean    0.538713  0.510994
# 100%|██████████| 45/45 [00:46<00:00,  1.03s/it]
# 2021-10-27 08:20:55,088 - pytorch_modeler.py - INFO - epoch:14/100, tr_loss:0.104816, src_loss:0.105853, src_mean_auc:0.582567, tgt_loss:0.133028, tgt_mean_auc:0.549567, mean_auc:0.566067,
#                AUC      pAUC
# Source_0  0.369600  0.473684
# Source_1  0.663000  0.545263
# Source_2  0.715100  0.477895
# Target_0  0.607500  0.527895
# Target_1  0.469400  0.480526
# Target_2  0.571800  0.578421
# mean      0.566067  0.513947
# h_mean    0.538713  0.510994
# 100%|██████████| 45/45 [00:45<00:00,  1.01s/it]
# 2021-10-27 08:21:40,607 - pytorch_modeler.py - INFO - epoch:15/100, tr_loss:0.099704, src_loss:0.105853, src_mean_auc:0.582567, tgt_loss:0.133028, tgt_mean_auc:0.549567, mean_auc:0.566067,
#                AUC      pAUC
# Source_0  0.369600  0.473684
# Source_1  0.663000  0.545263
# Source_2  0.715100  0.477895
# Target_0  0.607500  0.527895
# Target_1  0.469400  0.480526
# Target_2  0.571800  0.578421
# mean      0.566067  0.513947
# h_mean    0.538713  0.510994
# 100%|██████████| 45/45 [00:44<00:00,  1.02it/s]
# 2021-10-27 08:22:24,955 - pytorch_modeler.py - INFO - epoch:16/100, tr_loss:0.095978, src_loss:0.105853, src_mean_auc:0.582567, tgt_loss:0.133028, tgt_mean_auc:0.549567, mean_auc:0.566067,
#                AUC      pAUC
# Source_0  0.369600  0.473684
# Source_1  0.663000  0.545263
# Source_2  0.715100  0.477895
# Target_0  0.607500  0.527895
# Target_1  0.469400  0.480526
# Target_2  0.571800  0.578421
# mean      0.566067  0.513947
# h_mean    0.538713  0.510994
# 100%|██████████| 45/45 [00:44<00:00,  1.00it/s]
# 2021-10-27 08:23:09,774 - pytorch_modeler.py - INFO - epoch:17/100, tr_loss:0.090334, src_loss:0.105853, src_mean_auc:0.582567, tgt_loss:0.133028, tgt_mean_auc:0.549567, mean_auc:0.566067,
#                AUC      pAUC
# Source_0  0.369600  0.473684
# Source_1  0.663000  0.545263
# Source_2  0.715100  0.477895
# Target_0  0.607500  0.527895
# Target_1  0.469400  0.480526
# Target_2  0.571800  0.578421
# mean      0.566067  0.513947
# h_mean    0.538713  0.510994
# 100%|██████████| 45/45 [00:44<00:00,  1.01it/s]
# 2021-10-27 08:23:54,166 - pytorch_modeler.py - INFO - epoch:18/100, tr_loss:0.087720, src_loss:0.105853, src_mean_auc:0.582567, tgt_loss:0.133028, tgt_mean_auc:0.549567, mean_auc:0.566067,
#                AUC      pAUC
# Source_0  0.369600  0.473684
# Source_1  0.663000  0.545263
# Source_2  0.715100  0.477895
# Target_0  0.607500  0.527895
# Target_1  0.469400  0.480526
# Target_2  0.571800  0.578421
# mean      0.566067  0.513947
# h_mean    0.538713  0.510994
# 100%|██████████| 45/45 [00:44<00:00,  1.01it/s]
# 2021-10-27 08:24:38,720 - pytorch_modeler.py - INFO - epoch:19/100, tr_loss:0.081492, src_loss:0.105853, src_mean_auc:0.582567, tgt_loss:0.133028, tgt_mean_auc:0.549567, mean_auc:0.566067,
#                AUC      pAUC
# Source_0  0.369600  0.473684
# Source_1  0.663000  0.545263
# Source_2  0.715100  0.477895
# Target_0  0.607500  0.527895
# Target_1  0.469400  0.480526
# Target_2  0.571800  0.578421
# mean      0.566067  0.513947
# h_mean    0.538713  0.510994
# 100%|██████████| 45/45 [00:45<00:00,  1.01s/it]
# 100%|██████████| 600/600 [01:21<00:00,  7.38it/s]
# 100%|██████████| 600/600 [01:40<00:00,  5.97it/s]
# 2021-10-27 08:28:25,976 - pytorch_modeler.py - INFO - epoch:20/100, tr_loss:0.072732, src_loss:0.068831, src_mean_auc:0.575733, tgt_loss:0.120368, tgt_mean_auc:0.512700, mean_auc:0.544217,
#                AUC      pAUC
# Source_0  0.253600  0.478421
# Source_1  0.713700  0.548947
# Source_2  0.759900  0.476842
# Target_0  0.509100  0.516842
# Target_1  0.461700  0.478421
# Target_2  0.567300  0.580000
# mean      0.544217  0.513246
# h_mean    0.477965  0.510283
# 100%|██████████| 45/45 [00:59<00:00,  1.32s/it]
# 2021-10-27 08:29:25,582 - pytorch_modeler.py - INFO - epoch:21/100, tr_loss:0.069763, src_loss:0.068831, src_mean_auc:0.575733, tgt_loss:0.120368, tgt_mean_auc:0.512700, mean_auc:0.544217,
#                AUC      pAUC
# Source_0  0.253600  0.478421
# Source_1  0.713700  0.548947
# Source_2  0.759900  0.476842
# Target_0  0.509100  0.516842
# Target_1  0.461700  0.478421
# Target_2  0.567300  0.580000
# mean      0.544217  0.513246
# h_mean    0.477965  0.510283
# 100%|██████████| 45/45 [00:58<00:00,  1.30s/it]
# 2021-10-27 08:30:24,192 - pytorch_modeler.py - INFO - epoch:22/100, tr_loss:0.063703, src_loss:0.068831, src_mean_auc:0.575733, tgt_loss:0.120368, tgt_mean_auc:0.512700, mean_auc:0.544217,
#                AUC      pAUC
# Source_0  0.253600  0.478421
# Source_1  0.713700  0.548947
# Source_2  0.759900  0.476842
# Target_0  0.509100  0.516842
# Target_1  0.461700  0.478421
# Target_2  0.567300  0.580000
# mean      0.544217  0.513246
# h_mean    0.477965  0.510283
# 100%|██████████| 45/45 [00:45<00:00,  1.01s/it]
# 2021-10-27 08:31:09,872 - pytorch_modeler.py - INFO - epoch:23/100, tr_loss:0.066929, src_loss:0.068831, src_mean_auc:0.575733, tgt_loss:0.120368, tgt_mean_auc:0.512700, mean_auc:0.544217,
#                AUC      pAUC
# Source_0  0.253600  0.478421
# Source_1  0.713700  0.548947
# Source_2  0.759900  0.476842
# Target_0  0.509100  0.516842
# Target_1  0.461700  0.478421
# Target_2  0.567300  0.580000
# mean      0.544217  0.513246
# h_mean    0.477965  0.510283
# 100%|██████████| 45/45 [00:45<00:00,  1.02s/it]
# 2021-10-27 08:31:55,651 - pytorch_modeler.py - INFO - epoch:24/100, tr_loss:0.058996, src_loss:0.068831, src_mean_auc:0.575733, tgt_loss:0.120368, tgt_mean_auc:0.512700, mean_auc:0.544217,
#                AUC      pAUC
# Source_0  0.253600  0.478421
# Source_1  0.713700  0.548947
# Source_2  0.759900  0.476842
# Target_0  0.509100  0.516842
# Target_1  0.461700  0.478421
# Target_2  0.567300  0.580000
# mean      0.544217  0.513246
# h_mean    0.477965  0.510283
# 100%|██████████| 45/45 [00:45<00:00,  1.01s/it]
# 2021-10-27 08:32:41,280 - pytorch_modeler.py - INFO - epoch:25/100, tr_loss:0.061643, src_loss:0.068831, src_mean_auc:0.575733, tgt_loss:0.120368, tgt_mean_auc:0.512700, mean_auc:0.544217,
#                AUC      pAUC
# Source_0  0.253600  0.478421
# Source_1  0.713700  0.548947
# Source_2  0.759900  0.476842
# Target_0  0.509100  0.516842
# Target_1  0.461700  0.478421
# Target_2  0.567300  0.580000
# mean      0.544217  0.513246
# h_mean    0.477965  0.510283
# 100%|██████████| 45/45 [00:44<00:00,  1.01it/s]
# 2021-10-27 08:33:25,998 - pytorch_modeler.py - INFO - epoch:26/100, tr_loss:0.058305, src_loss:0.068831, src_mean_auc:0.575733, tgt_loss:0.120368, tgt_mean_auc:0.512700, mean_auc:0.544217,
#                AUC      pAUC
# Source_0  0.253600  0.478421
# Source_1  0.713700  0.548947
# Source_2  0.759900  0.476842
# Target_0  0.509100  0.516842
# Target_1  0.461700  0.478421
# Target_2  0.567300  0.580000
# mean      0.544217  0.513246
# h_mean    0.477965  0.510283
# 100%|██████████| 45/45 [00:45<00:00,  1.01s/it]
# 2021-10-27 08:34:11,383 - pytorch_modeler.py - INFO - epoch:27/100, tr_loss:0.053321, src_loss:0.068831, src_mean_auc:0.575733, tgt_loss:0.120368, tgt_mean_auc:0.512700, mean_auc:0.544217,
#                AUC      pAUC
# Source_0  0.253600  0.478421
# Source_1  0.713700  0.548947
# Source_2  0.759900  0.476842
# Target_0  0.509100  0.516842
# Target_1  0.461700  0.478421
# Target_2  0.567300  0.580000
# mean      0.544217  0.513246
# h_mean    0.477965  0.510283
# 100%|██████████| 45/45 [00:46<00:00,  1.03s/it]
# 2021-10-27 08:34:57,657 - pytorch_modeler.py - INFO - epoch:28/100, tr_loss:0.053783, src_loss:0.068831, src_mean_auc:0.575733, tgt_loss:0.120368, tgt_mean_auc:0.512700, mean_auc:0.544217,
#                AUC      pAUC
# Source_0  0.253600  0.478421
# Source_1  0.713700  0.548947
# Source_2  0.759900  0.476842
# Target_0  0.509100  0.516842
# Target_1  0.461700  0.478421
# Target_2  0.567300  0.580000
# mean      0.544217  0.513246
# h_mean    0.477965  0.510283
# 100%|██████████| 45/45 [00:45<00:00,  1.02s/it]
# 2021-10-27 08:35:43,456 - pytorch_modeler.py - INFO - epoch:29/100, tr_loss:0.052089, src_loss:0.068831, src_mean_auc:0.575733, tgt_loss:0.120368, tgt_mean_auc:0.512700, mean_auc:0.544217,
#                AUC      pAUC
# Source_0  0.253600  0.478421
# Source_1  0.713700  0.548947
# Source_2  0.759900  0.476842
# Target_0  0.509100  0.516842
# Target_1  0.461700  0.478421
# Target_2  0.567300  0.580000
# mean      0.544217  0.513246
# h_mean    0.477965  0.510283
# 100%|██████████| 45/45 [00:45<00:00,  1.01s/it]
# 100%|██████████| 600/600 [01:21<00:00,  7.38it/s]
# 100%|██████████| 600/600 [01:42<00:00,  5.87it/s]
# 2021-10-27 08:39:32,435 - pytorch_modeler.py - INFO - epoch:30/100, tr_loss:0.050126, src_loss:0.075705, src_mean_auc:0.584267, tgt_loss:0.110941, tgt_mean_auc:0.517733, mean_auc:0.551000,
#               AUC      pAUC
# Source_0  0.27050  0.478421
# Source_1  0.71650  0.568421
# Source_2  0.76580  0.475263
# Target_0  0.48840  0.526316
# Target_1  0.49270  0.486316
# Target_2  0.57210  0.571053
# mean      0.55100  0.517632
# h_mean    0.49086  0.514536
# 100%|██████████| 45/45 [01:00<00:00,  1.34s/it]
# 2021-10-27 08:40:32,672 - pytorch_modeler.py - INFO - epoch:31/100, tr_loss:0.047984, src_loss:0.075705, src_mean_auc:0.584267, tgt_loss:0.110941, tgt_mean_auc:0.517733, mean_auc:0.551000,
#               AUC      pAUC
# Source_0  0.27050  0.478421
# Source_1  0.71650  0.568421
# Source_2  0.76580  0.475263
# Target_0  0.48840  0.526316
# Target_1  0.49270  0.486316
# Target_2  0.57210  0.571053
# mean      0.55100  0.517632
# h_mean    0.49086  0.514536
# 100%|██████████| 45/45 [00:59<00:00,  1.31s/it]
# 2021-10-27 08:41:31,809 - pytorch_modeler.py - INFO - epoch:32/100, tr_loss:0.051914, src_loss:0.075705, src_mean_auc:0.584267, tgt_loss:0.110941, tgt_mean_auc:0.517733, mean_auc:0.551000,
#               AUC      pAUC
# Source_0  0.27050  0.478421
# Source_1  0.71650  0.568421
# Source_2  0.76580  0.475263
# Target_0  0.48840  0.526316
# Target_1  0.49270  0.486316
# Target_2  0.57210  0.571053
# mean      0.55100  0.517632
# h_mean    0.49086  0.514536
# 100%|██████████| 45/45 [00:45<00:00,  1.00s/it]
# 2021-10-27 08:42:17,069 - pytorch_modeler.py - INFO - epoch:33/100, tr_loss:0.045985, src_loss:0.075705, src_mean_auc:0.584267, tgt_loss:0.110941, tgt_mean_auc:0.517733, mean_auc:0.551000,
#               AUC      pAUC
# Source_0  0.27050  0.478421
# Source_1  0.71650  0.568421
# Source_2  0.76580  0.475263
# Target_0  0.48840  0.526316
# Target_1  0.49270  0.486316
# Target_2  0.57210  0.571053
# mean      0.55100  0.517632
# h_mean    0.49086  0.514536
# 100%|██████████| 45/45 [00:45<00:00,  1.01s/it]
# 2021-10-27 08:43:02,603 - pytorch_modeler.py - INFO - epoch:34/100, tr_loss:0.043730, src_loss:0.075705, src_mean_auc:0.584267, tgt_loss:0.110941, tgt_mean_auc:0.517733, mean_auc:0.551000,
#               AUC      pAUC
# Source_0  0.27050  0.478421
# Source_1  0.71650  0.568421
# Source_2  0.76580  0.475263
# Target_0  0.48840  0.526316
# Target_1  0.49270  0.486316
# Target_2  0.57210  0.571053
# mean      0.55100  0.517632
# h_mean    0.49086  0.514536
# 100%|██████████| 45/45 [00:45<00:00,  1.02s/it]
# 2021-10-27 08:43:48,474 - pytorch_modeler.py - INFO - epoch:35/100, tr_loss:0.042170, src_loss:0.075705, src_mean_auc:0.584267, tgt_loss:0.110941, tgt_mean_auc:0.517733, mean_auc:0.551000,
#               AUC      pAUC
# Source_0  0.27050  0.478421
# Source_1  0.71650  0.568421
# Source_2  0.76580  0.475263
# Target_0  0.48840  0.526316
# Target_1  0.49270  0.486316
# Target_2  0.57210  0.571053
# mean      0.55100  0.517632
# h_mean    0.49086  0.514536
# 100%|██████████| 45/45 [00:45<00:00,  1.02s/it]
# 2021-10-27 08:44:34,434 - pytorch_modeler.py - INFO - epoch:36/100, tr_loss:0.043890, src_loss:0.075705, src_mean_auc:0.584267, tgt_loss:0.110941, tgt_mean_auc:0.517733, mean_auc:0.551000,
#               AUC      pAUC
# Source_0  0.27050  0.478421
# Source_1  0.71650  0.568421
# Source_2  0.76580  0.475263
# Target_0  0.48840  0.526316
# Target_1  0.49270  0.486316
# Target_2  0.57210  0.571053
# mean      0.55100  0.517632
# h_mean    0.49086  0.514536
# 100%|██████████| 45/45 [00:46<00:00,  1.03s/it]
# 2021-10-27 08:45:20,625 - pytorch_modeler.py - INFO - epoch:37/100, tr_loss:0.040696, src_loss:0.075705, src_mean_auc:0.584267, tgt_loss:0.110941, tgt_mean_auc:0.517733, mean_auc:0.551000,
#               AUC      pAUC
# Source_0  0.27050  0.478421
# Source_1  0.71650  0.568421
# Source_2  0.76580  0.475263
# Target_0  0.48840  0.526316
# Target_1  0.49270  0.486316
# Target_2  0.57210  0.571053
# mean      0.55100  0.517632
# h_mean    0.49086  0.514536
# 100%|██████████| 45/45 [00:45<00:00,  1.01s/it]
# 2021-10-27 08:46:06,225 - pytorch_modeler.py - INFO - epoch:38/100, tr_loss:0.041408, src_loss:0.075705, src_mean_auc:0.584267, tgt_loss:0.110941, tgt_mean_auc:0.517733, mean_auc:0.551000,
#               AUC      pAUC
# Source_0  0.27050  0.478421
# Source_1  0.71650  0.568421
# Source_2  0.76580  0.475263
# Target_0  0.48840  0.526316
# Target_1  0.49270  0.486316
# Target_2  0.57210  0.571053
# mean      0.55100  0.517632
# h_mean    0.49086  0.514536
# 100%|██████████| 45/45 [00:45<00:00,  1.01s/it]
# 2021-10-27 08:46:51,826 - pytorch_modeler.py - INFO - epoch:39/100, tr_loss:0.039600, src_loss:0.075705, src_mean_auc:0.584267, tgt_loss:0.110941, tgt_mean_auc:0.517733, mean_auc:0.551000,
#               AUC      pAUC
# Source_0  0.27050  0.478421
# Source_1  0.71650  0.568421
# Source_2  0.76580  0.475263
# Target_0  0.48840  0.526316
# Target_1  0.49270  0.486316
# Target_2  0.57210  0.571053
# mean      0.55100  0.517632
# h_mean    0.49086  0.514536
# 100%|██████████| 45/45 [00:44<00:00,  1.01it/s]
# 100%|██████████| 600/600 [01:21<00:00,  7.40it/s]
# 100%|██████████| 600/600 [01:41<00:00,  5.91it/s]
# 2021-10-27 08:50:39,229 - pytorch_modeler.py - INFO - epoch:40/100, tr_loss:0.042303, src_loss:0.082747, src_mean_auc:0.592900, tgt_loss:0.122111, tgt_mean_auc:0.509400, mean_auc:0.551150,
#                AUC      pAUC
# Source_0  0.275400  0.477895
# Source_1  0.730300  0.564211
# Source_2  0.773000  0.490526
# Target_0  0.512500  0.524211
# Target_1  0.475000  0.483684
# Target_2  0.540700  0.570000
# mean      0.551150  0.518421
# h_mean    0.491804  0.515774
# 100%|██████████| 45/45 [01:00<00:00,  1.34s/it]
# 2021-10-27 08:51:39,680 - pytorch_modeler.py - INFO - epoch:41/100, tr_loss:0.037790, src_loss:0.082747, src_mean_auc:0.592900, tgt_loss:0.122111, tgt_mean_auc:0.509400, mean_auc:0.551150,
#                AUC      pAUC
# Source_0  0.275400  0.477895
# Source_1  0.730300  0.564211
# Source_2  0.773000  0.490526
# Target_0  0.512500  0.524211
# Target_1  0.475000  0.483684
# Target_2  0.540700  0.570000
# mean      0.551150  0.518421
# h_mean    0.491804  0.515774
# 100%|██████████| 45/45 [00:57<00:00,  1.29s/it]
# 2021-10-27 08:52:37,559 - pytorch_modeler.py - INFO - epoch:42/100, tr_loss:0.038521, src_loss:0.082747, src_mean_auc:0.592900, tgt_loss:0.122111, tgt_mean_auc:0.509400, mean_auc:0.551150,
#                AUC      pAUC
# Source_0  0.275400  0.477895
# Source_1  0.730300  0.564211
# Source_2  0.773000  0.490526
# Target_0  0.512500  0.524211
# Target_1  0.475000  0.483684
# Target_2  0.540700  0.570000
# mean      0.551150  0.518421
# h_mean    0.491804  0.515774
# 100%|██████████| 45/45 [00:43<00:00,  1.03it/s]
# 2021-10-27 08:53:21,333 - pytorch_modeler.py - INFO - epoch:43/100, tr_loss:0.037759, src_loss:0.082747, src_mean_auc:0.592900, tgt_loss:0.122111, tgt_mean_auc:0.509400, mean_auc:0.551150,
#                AUC      pAUC
# Source_0  0.275400  0.477895
# Source_1  0.730300  0.564211
# Source_2  0.773000  0.490526
# Target_0  0.512500  0.524211
# Target_1  0.475000  0.483684
# Target_2  0.540700  0.570000
# mean      0.551150  0.518421
# h_mean    0.491804  0.515774
# 100%|██████████| 45/45 [00:44<00:00,  1.01it/s]
# 2021-10-27 08:55:34,729 - pytorch_modeler.py - INFO - epoch:46/100, tr_loss:0.036375, src_loss:0.082747, src_mean_auc:0.592900, tgt_loss:0.122111, tgt_mean_auc:0.509400, mean_auc:0.551150,
#                AUC      pAUC
# Source_0  0.275400  0.477895
# Source_1  0.730300  0.564211
# Source_2  0.773000  0.490526
# Target_0  0.512500  0.524211
# Target_1  0.475000  0.483684
# Target_2  0.540700  0.570000
# mean      0.551150  0.518421
# h_mean    0.491804  0.515774
# 100%|██████████| 45/45 [00:43<00:00,  1.03it/s]
# 2021-10-27 08:56:18,296 - pytorch_modeler.py - INFO - epoch:47/100, tr_loss:0.033186, src_loss:0.082747, src_mean_auc:0.592900, tgt_loss:0.122111, tgt_mean_auc:0.509400, mean_auc:0.551150,
#                AUC      pAUC
# Source_0  0.275400  0.477895
# Source_1  0.730300  0.564211
# Source_2  0.773000  0.490526
# Target_0  0.512500  0.524211
# Target_1  0.475000  0.483684
# Target_2  0.540700  0.570000
# mean      0.551150  0.518421
# h_mean    0.491804  0.515774
# 100%|██████████| 45/45 [00:44<00:00,  1.02it/s]
# 2021-10-27 08:57:02,450 - pytorch_modeler.py - INFO - epoch:48/100, tr_loss:0.037342, src_loss:0.082747, src_mean_auc:0.592900, tgt_loss:0.122111, tgt_mean_auc:0.509400, mean_auc:0.551150,
#                AUC      pAUC
# Source_0  0.275400  0.477895
# Source_1  0.730300  0.564211
# Source_2  0.773000  0.490526
# Target_0  0.512500  0.524211
# Target_1  0.475000  0.483684
# Target_2  0.540700  0.570000
# mean      0.551150  0.518421
# h_mean    0.491804  0.515774
# 100%|██████████| 45/45 [00:44<00:00,  1.02it/s]
# 2021-10-27 08:57:46,495 - pytorch_modeler.py - INFO - epoch:49/100, tr_loss:0.030912, src_loss:0.082747, src_mean_auc:0.592900, tgt_loss:0.122111, tgt_mean_auc:0.509400, mean_auc:0.551150,
#                AUC      pAUC
# Source_0  0.275400  0.477895
# Source_1  0.730300  0.564211
# Source_2  0.773000  0.490526
# Target_0  0.512500  0.524211
# Target_1  0.475000  0.483684
# Target_2  0.540700  0.570000
# mean      0.551150  0.518421
# h_mean    0.491804  0.515774
# 100%|██████████| 45/45 [00:48<00:00,  1.08s/it]
# 100%|██████████| 600/600 [01:21<00:00,  7.38it/s]
# 100%|██████████| 600/600 [01:41<00:00,  5.93it/s]
# 2021-10-27 09:01:37,537 - pytorch_modeler.py - INFO - epoch:50/100, tr_loss:0.030364, src_loss:0.071251, src_mean_auc:0.607433, tgt_loss:0.121625, tgt_mean_auc:0.519233, mean_auc:0.563333,
#                AUC      pAUC
# Source_0  0.258100  0.480000
# Source_1  0.749700  0.598421
# Source_2  0.814500  0.473684
# Target_0  0.523200  0.528421
# Target_1  0.481500  0.482105
# Target_2  0.553000  0.578421
# mean      0.563333  0.523509
# h_mean    0.490494  0.518985
# 100%|██████████| 45/45 [01:00<00:00,  1.34s/it]
# 2021-10-27 09:02:37,764 - pytorch_modeler.py - INFO - epoch:51/100, tr_loss:0.030209, src_loss:0.071251, src_mean_auc:0.607433, tgt_loss:0.121625, tgt_mean_auc:0.519233, mean_auc:0.563333,
#                AUC      pAUC
# Source_0  0.258100  0.480000
# Source_1  0.749700  0.598421
# Source_2  0.814500  0.473684
# Target_0  0.523200  0.528421
# Target_1  0.481500  0.482105
# Target_2  0.553000  0.578421
# mean      0.563333  0.523509
# h_mean    0.490494  0.518985
# 100%|██████████| 45/45 [00:58<00:00,  1.29s/it]
# 2021-10-27 09:03:35,929 - pytorch_modeler.py - INFO - epoch:52/100, tr_loss:0.030045, src_loss:0.071251, src_mean_auc:0.607433, tgt_loss:0.121625, tgt_mean_auc:0.519233, mean_auc:0.563333,
#                AUC      pAUC
# Source_0  0.258100  0.480000
# Source_1  0.749700  0.598421
# Source_2  0.814500  0.473684
# Target_0  0.523200  0.528421
# Target_1  0.481500  0.482105
# Target_2  0.553000  0.578421
# mean      0.563333  0.523509
# h_mean    0.490494  0.518985
# 100%|██████████| 45/45 [00:45<00:00,  1.00s/it]
# 2021-10-27 09:04:21,157 - pytorch_modeler.py - INFO - epoch:53/100, tr_loss:0.028824, src_loss:0.071251, src_mean_auc:0.607433, tgt_loss:0.121625, tgt_mean_auc:0.519233, mean_auc:0.563333,
#                AUC      pAUC
# Source_0  0.258100  0.480000
# Source_1  0.749700  0.598421
# Source_2  0.814500  0.473684
# Target_0  0.523200  0.528421
# Target_1  0.481500  0.482105
# Target_2  0.553000  0.578421
# mean      0.563333  0.523509
# h_mean    0.490494  0.518985
# 100%|██████████| 45/45 [00:44<00:00,  1.01it/s]
# 2021-10-27 09:05:05,639 - pytorch_modeler.py - INFO - epoch:54/100, tr_loss:0.027834, src_loss:0.071251, src_mean_auc:0.607433, tgt_loss:0.121625, tgt_mean_auc:0.519233, mean_auc:0.563333,
#                AUC      pAUC
# Source_0  0.258100  0.480000
# Source_1  0.749700  0.598421
# Source_2  0.814500  0.473684
# Target_0  0.523200  0.528421
# Target_1  0.481500  0.482105
# Target_2  0.553000  0.578421
# mean      0.563333  0.523509
# h_mean    0.490494  0.518985
# 100%|██████████| 45/45 [00:45<00:00,  1.02s/it]
# 2021-10-27 09:05:51,655 - pytorch_modeler.py - INFO - epoch:55/100, tr_loss:0.028892, src_loss:0.071251, src_mean_auc:0.607433, tgt_loss:0.121625, tgt_mean_auc:0.519233, mean_auc:0.563333,
#                AUC      pAUC
# Source_0  0.258100  0.480000
# Source_1  0.749700  0.598421
# Source_2  0.814500  0.473684
# Target_0  0.523200  0.528421
# Target_1  0.481500  0.482105
# Target_2  0.553000  0.578421
# mean      0.563333  0.523509
# h_mean    0.490494  0.518985
# 100%|██████████| 45/45 [00:45<00:00,  1.02s/it]
# 2021-10-27 09:06:37,676 - pytorch_modeler.py - INFO - epoch:56/100, tr_loss:0.026201, src_loss:0.071251, src_mean_auc:0.607433, tgt_loss:0.121625, tgt_mean_auc:0.519233, mean_auc:0.563333,
#                AUC      pAUC
# Source_0  0.258100  0.480000
# Source_1  0.749700  0.598421
# Source_2  0.814500  0.473684
# Target_0  0.523200  0.528421
# Target_1  0.481500  0.482105
# Target_2  0.553000  0.578421
# mean      0.563333  0.523509
# h_mean    0.490494  0.518985
# 100%|██████████| 45/45 [00:45<00:00,  1.01s/it]
# 2021-10-27 09:07:23,083 - pytorch_modeler.py - INFO - epoch:57/100, tr_loss:0.031460, src_loss:0.071251, src_mean_auc:0.607433, tgt_loss:0.121625, tgt_mean_auc:0.519233, mean_auc:0.563333,
#                AUC      pAUC
# Source_0  0.258100  0.480000
# Source_1  0.749700  0.598421
# Source_2  0.814500  0.473684
# Target_0  0.523200  0.528421
# Target_1  0.481500  0.482105
# Target_2  0.553000  0.578421
# mean      0.563333  0.523509
# h_mean    0.490494  0.518985
# 100%|██████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-27 09:08:12,522 - pytorch_modeler.py - INFO - epoch:58/100, tr_loss:0.028164, src_loss:0.071251, src_mean_auc:0.607433, tgt_loss:0.121625, tgt_mean_auc:0.519233, mean_auc:0.563333,
#                AUC      pAUC
# Source_0  0.258100  0.480000
# Source_1  0.749700  0.598421
# Source_2  0.814500  0.473684
# Target_0  0.523200  0.528421
# Target_1  0.481500  0.482105
# Target_2  0.553000  0.578421
# mean      0.563333  0.523509
# h_mean    0.490494  0.518985
# 100%|██████████| 45/45 [00:44<00:00,  1.00it/s]
# 2021-10-27 09:08:57,439 - pytorch_modeler.py - INFO - epoch:59/100, tr_loss:0.026301, src_loss:0.071251, src_mean_auc:0.607433, tgt_loss:0.121625, tgt_mean_auc:0.519233, mean_auc:0.563333,
#                AUC      pAUC
# Source_0  0.258100  0.480000
# Source_1  0.749700  0.598421
# Source_2  0.814500  0.473684
# Target_0  0.523200  0.528421
# Target_1  0.481500  0.482105
# Target_2  0.553000  0.578421
# mean      0.563333  0.523509
# h_mean    0.490494  0.518985
# 100%|██████████| 45/45 [00:44<00:00,  1.00it/s]
# 100%|██████████| 600/600 [01:20<00:00,  7.41it/s]
# 100%|██████████| 600/600 [01:41<00:00,  5.91it/s]
# 2021-10-27 09:12:44,869 - pytorch_modeler.py - INFO - epoch:60/100, tr_loss:0.028303, src_loss:0.048502, src_mean_auc:0.592633, tgt_loss:0.119515, tgt_mean_auc:0.515400, mean_auc:0.554017,
#                AUC      pAUC
# Source_0  0.228100  0.478421
# Source_1  0.750800  0.573158
# Source_2  0.799000  0.473684
# Target_0  0.511200  0.529474
# Target_1  0.485500  0.486842
# Target_2  0.549500  0.576316
# mean      0.554017  0.519649
# h_mean    0.468630  0.516177
# 100%|██████████| 45/45 [01:00<00:00,  1.34s/it]
# 2021-10-27 09:13:45,341 - pytorch_modeler.py - INFO - epoch:61/100, tr_loss:0.027150, src_loss:0.048502, src_mean_auc:0.592633, tgt_loss:0.119515, tgt_mean_auc:0.515400, mean_auc:0.554017,
#                AUC      pAUC
# Source_0  0.228100  0.478421
# Source_1  0.750800  0.573158
# Source_2  0.799000  0.473684
# Target_0  0.511200  0.529474
# Target_1  0.485500  0.486842
# Target_2  0.549500  0.576316
# mean      0.554017  0.519649
# h_mean    0.468630  0.516177
# 100%|██████████| 45/45 [00:59<00:00,  1.32s/it]
# 2021-10-27 09:14:44,780 - pytorch_modeler.py - INFO - epoch:62/100, tr_loss:0.026711, src_loss:0.048502, src_mean_auc:0.592633, tgt_loss:0.119515, tgt_mean_auc:0.515400, mean_auc:0.554017,
#                AUC      pAUC
# Source_0  0.228100  0.478421
# Source_1  0.750800  0.573158
# Source_2  0.799000  0.473684
# Target_0  0.511200  0.529474
# Target_1  0.485500  0.486842
# Target_2  0.549500  0.576316
# mean      0.554017  0.519649
# h_mean    0.468630  0.516177
#  82%|████████▏ | 37/45 [00:36<00:07,  1.01it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 100%|██████████| 600/600 [01:57<00:00,  5.09it/s]
# 100%|██████████| 600/600 [01:16<00:00,  7.85it/s]
# 2021-10-27 10:11:06,389 - pytorch_modeler.py - INFO - epoch:10/100, tr_loss:0.152006, src_loss:1.251159, src_mean_auc:0.702633, tgt_loss:1.119075, tgt_mean_auc:0.644433, mean_auc:0.673533,
#                AUC      pAUC
# Source_0  0.511900  0.492632
# Source_1  0.791400  0.694737
# Source_2  0.804600  0.749474
# Target_0  0.667000  0.535789
# Target_1  0.654800  0.519474
# Target_2  0.611500  0.524737
# mean      0.673533  0.586140
# h_mean    0.657772  0.571389
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-27 10:11:41,620 - pytorch_modeler.py - INFO - epoch:11/100, tr_loss:0.131909, src_loss:1.251159, src_mean_auc:0.702633, tgt_loss:1.119075, tgt_mean_auc:0.644433, mean_auc:0.673533,
#                AUC      pAUC
# Source_0  0.511900  0.492632
# Source_1  0.791400  0.694737
# Source_2  0.804600  0.749474
# Target_0  0.667000  0.535789
# Target_1  0.654800  0.519474
# Target_2  0.611500  0.524737
# mean      0.673533  0.586140
# h_mean    0.657772  0.571389
# 100%|██████████| 45/45 [00:34<00:00,  1.29it/s]
# 2021-10-27 10:12:16,636 - pytorch_modeler.py - INFO - epoch:12/100, tr_loss:0.120638, src_loss:1.251159, src_mean_auc:0.702633, tgt_loss:1.119075, tgt_mean_auc:0.644433, mean_auc:0.673533,
#                AUC      pAUC
# Source_0  0.511900  0.492632
# Source_1  0.791400  0.694737
# Source_2  0.804600  0.749474
# Target_0  0.667000  0.535789
# Target_1  0.654800  0.519474
# Target_2  0.611500  0.524737
# mean      0.673533  0.586140
# h_mean    0.657772  0.571389
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-27 10:12:51,754 - pytorch_modeler.py - INFO - epoch:13/100, tr_loss:0.105022, src_loss:1.251159, src_mean_auc:0.702633, tgt_loss:1.119075, tgt_mean_auc:0.644433, mean_auc:0.673533,
#                AUC      pAUC
# Source_0  0.511900  0.492632
# Source_1  0.791400  0.694737
# Source_2  0.804600  0.749474
# Target_0  0.667000  0.535789
# Target_1  0.654800  0.519474
# Target_2  0.611500  0.524737
# mean      0.673533  0.586140
# h_mean    0.657772  0.571389
# 100%|██████████| 45/45 [00:34<00:00,  1.29it/s]
# 2021-10-27 10:13:26,635 - pytorch_modeler.py - INFO - epoch:14/100, tr_loss:0.100722, src_loss:1.251159, src_mean_auc:0.702633, tgt_loss:1.119075, tgt_mean_auc:0.644433, mean_auc:0.673533,
#                AUC      pAUC
# Source_0  0.511900  0.492632
# Source_1  0.791400  0.694737
# Source_2  0.804600  0.749474
# Target_0  0.667000  0.535789
# Target_1  0.654800  0.519474
# Target_2  0.611500  0.524737
# mean      0.673533  0.586140
# h_mean    0.657772  0.571389
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-27 10:14:01,320 - pytorch_modeler.py - INFO - epoch:15/100, tr_loss:0.091278, src_loss:1.251159, src_mean_auc:0.702633, tgt_loss:1.119075, tgt_mean_auc:0.644433, mean_auc:0.673533,
#                AUC      pAUC
# Source_0  0.511900  0.492632
# Source_1  0.791400  0.694737
# Source_2  0.804600  0.749474
# Target_0  0.667000  0.535789
# Target_1  0.654800  0.519474
# Target_2  0.611500  0.524737
# mean      0.673533  0.586140
# h_mean    0.657772  0.571389
# 100%|██████████| 45/45 [00:34<00:00,  1.29it/s]
# 2021-10-27 10:14:36,277 - pytorch_modeler.py - INFO - epoch:16/100, tr_loss:0.083163, src_loss:1.251159, src_mean_auc:0.702633, tgt_loss:1.119075, tgt_mean_auc:0.644433, mean_auc:0.673533,
#                AUC      pAUC
# Source_0  0.511900  0.492632
# Source_1  0.791400  0.694737
# Source_2  0.804600  0.749474
# Target_0  0.667000  0.535789
# Target_1  0.654800  0.519474
# Target_2  0.611500  0.524737
# mean      0.673533  0.586140
# h_mean    0.657772  0.571389
# 100%|██████████| 45/45 [00:34<00:00,  1.31it/s]
# 2021-10-27 10:15:10,717 - pytorch_modeler.py - INFO - epoch:17/100, tr_loss:0.078216, src_loss:1.251159, src_mean_auc:0.702633, tgt_loss:1.119075, tgt_mean_auc:0.644433, mean_auc:0.673533,
#                AUC      pAUC
# Source_0  0.511900  0.492632
# Source_1  0.791400  0.694737
# Source_2  0.804600  0.749474
# Target_0  0.667000  0.535789
# Target_1  0.654800  0.519474
# Target_2  0.611500  0.524737
# mean      0.673533  0.586140
# h_mean    0.657772  0.571389
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-27 10:15:45,388 - pytorch_modeler.py - INFO - epoch:18/100, tr_loss:0.072806, src_loss:1.251159, src_mean_auc:0.702633, tgt_loss:1.119075, tgt_mean_auc:0.644433, mean_auc:0.673533,
#                AUC      pAUC
# Source_0  0.511900  0.492632
# Source_1  0.791400  0.694737
# Source_2  0.804600  0.749474
# Target_0  0.667000  0.535789
# Target_1  0.654800  0.519474
# Target_2  0.611500  0.524737
# mean      0.673533  0.586140
# h_mean    0.657772  0.571389
# 100%|██████████| 45/45 [00:34<00:00,  1.31it/s]
# 2021-10-27 10:16:19,851 - pytorch_modeler.py - INFO - epoch:19/100, tr_loss:0.064767, src_loss:1.251159, src_mean_auc:0.702633, tgt_loss:1.119075, tgt_mean_auc:0.644433, mean_auc:0.673533,
#                AUC      pAUC
# Source_0  0.511900  0.492632
# Source_1  0.791400  0.694737
# Source_2  0.804600  0.749474
# Target_0  0.667000  0.535789
# Target_1  0.654800  0.519474
# Target_2  0.611500  0.524737
# mean      0.673533  0.586140
# h_mean    0.657772  0.571389
# 100%|██████████| 45/45 [00:34<00:00,  1.29it/s]
# 100%|██████████| 600/600 [00:56<00:00, 10.56it/s]
# 100%|██████████| 600/600 [00:57<00:00, 10.47it/s]
# 2021-10-27 10:18:48,771 - pytorch_modeler.py - INFO - epoch:20/100, tr_loss:0.058667, src_loss:1.225134, src_mean_auc:0.704500, tgt_loss:1.091750, tgt_mean_auc:0.645500, mean_auc:0.675000,
#               AUC      pAUC
# Source_0  0.51350  0.495263
# Source_1  0.79180  0.710000
# Source_2  0.80820  0.745789
# Target_0  0.64360  0.536316
# Target_1  0.66640  0.541579
# Target_2  0.62650  0.533684
# mean      0.67500  0.593772
# h_mean    0.65947  0.579529
# 100%|██████████| 45/45 [00:34<00:00,  1.29it/s]
# 2021-10-27 10:19:23,708 - pytorch_modeler.py - INFO - epoch:21/100, tr_loss:0.058220, src_loss:1.225134, src_mean_auc:0.704500, tgt_loss:1.091750, tgt_mean_auc:0.645500, mean_auc:0.675000,
#               AUC      pAUC
# Source_0  0.51350  0.495263
# Source_1  0.79180  0.710000
# Source_2  0.80820  0.745789
# Target_0  0.64360  0.536316
# Target_1  0.66640  0.541579
# Target_2  0.62650  0.533684
# mean      0.67500  0.593772
# h_mean    0.65947  0.579529
# 100%|██████████| 45/45 [00:34<00:00,  1.29it/s]
# 2021-10-27 10:19:58,641 - pytorch_modeler.py - INFO - epoch:22/100, tr_loss:0.051530, src_loss:1.225134, src_mean_auc:0.704500, tgt_loss:1.091750, tgt_mean_auc:0.645500, mean_auc:0.675000,
#               AUC      pAUC
# Source_0  0.51350  0.495263
# Source_1  0.79180  0.710000
# Source_2  0.80820  0.745789
# Target_0  0.64360  0.536316
# Target_1  0.66640  0.541579
# Target_2  0.62650  0.533684
# mean      0.67500  0.593772
# h_mean    0.65947  0.579529
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-27 10:20:33,293 - pytorch_modeler.py - INFO - epoch:23/100, tr_loss:0.047894, src_loss:1.225134, src_mean_auc:0.704500, tgt_loss:1.091750, tgt_mean_auc:0.645500, mean_auc:0.675000,
#               AUC      pAUC
# Source_0  0.51350  0.495263
# Source_1  0.79180  0.710000
# Source_2  0.80820  0.745789
# Target_0  0.64360  0.536316
# Target_1  0.66640  0.541579
# Target_2  0.62650  0.533684
# mean      0.67500  0.593772
# h_mean    0.65947  0.579529
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-27 10:21:07,909 - pytorch_modeler.py - INFO - epoch:24/100, tr_loss:0.046485, src_loss:1.225134, src_mean_auc:0.704500, tgt_loss:1.091750, tgt_mean_auc:0.645500, mean_auc:0.675000,
#               AUC      pAUC
# Source_0  0.51350  0.495263
# Source_1  0.79180  0.710000
# Source_2  0.80820  0.745789
# Target_0  0.64360  0.536316
# Target_1  0.66640  0.541579
# Target_2  0.62650  0.533684
# mean      0.67500  0.593772
# h_mean    0.65947  0.579529
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-27 10:21:42,574 - pytorch_modeler.py - INFO - epoch:25/100, tr_loss:0.042897, src_loss:1.225134, src_mean_auc:0.704500, tgt_loss:1.091750, tgt_mean_auc:0.645500, mean_auc:0.675000,
#               AUC      pAUC
# Source_0  0.51350  0.495263
# Source_1  0.79180  0.710000
# Source_2  0.80820  0.745789
# Target_0  0.64360  0.536316
# Target_1  0.66640  0.541579
# Target_2  0.62650  0.533684
# mean      0.67500  0.593772
# h_mean    0.65947  0.579529
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-27 10:22:17,204 - pytorch_modeler.py - INFO - epoch:26/100, tr_loss:0.038685, src_loss:1.225134, src_mean_auc:0.704500, tgt_loss:1.091750, tgt_mean_auc:0.645500, mean_auc:0.675000,
#               AUC      pAUC
# Source_0  0.51350  0.495263
# Source_1  0.79180  0.710000
# Source_2  0.80820  0.745789
# Target_0  0.64360  0.536316
# Target_1  0.66640  0.541579
# Target_2  0.62650  0.533684
# mean      0.67500  0.593772
# h_mean    0.65947  0.579529
# 100%|██████████| 45/45 [00:34<00:00,  1.29it/s]
# 2021-10-27 10:22:52,156 - pytorch_modeler.py - INFO - epoch:27/100, tr_loss:0.041928, src_loss:1.225134, src_mean_auc:0.704500, tgt_loss:1.091750, tgt_mean_auc:0.645500, mean_auc:0.675000,
#               AUC      pAUC
# Source_0  0.51350  0.495263
# Source_1  0.79180  0.710000
# Source_2  0.80820  0.745789
# Target_0  0.64360  0.536316
# Target_1  0.66640  0.541579
# Target_2  0.62650  0.533684
# mean      0.67500  0.593772
# h_mean    0.65947  0.579529
# 100%|██████████| 45/45 [00:34<00:00,  1.29it/s]
# 2021-10-27 10:23:27,172 - pytorch_modeler.py - INFO - epoch:28/100, tr_loss:0.033996, src_loss:1.225134, src_mean_auc:0.704500, tgt_loss:1.091750, tgt_mean_auc:0.645500, mean_auc:0.675000,
#               AUC      pAUC
# Source_0  0.51350  0.495263
# Source_1  0.79180  0.710000
# Source_2  0.80820  0.745789
# Target_0  0.64360  0.536316
# Target_1  0.66640  0.541579
# Target_2  0.62650  0.533684
# mean      0.67500  0.593772
# h_mean    0.65947  0.579529
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-27 10:24:01,784 - pytorch_modeler.py - INFO - epoch:29/100, tr_loss:0.028862, src_loss:1.225134, src_mean_auc:0.704500, tgt_loss:1.091750, tgt_mean_auc:0.645500, mean_auc:0.675000,
#               AUC      pAUC
# Source_0  0.51350  0.495263
# Source_1  0.79180  0.710000
# Source_2  0.80820  0.745789
# Target_0  0.64360  0.536316
# Target_1  0.66640  0.541579
# Target_2  0.62650  0.533684
# mean      0.67500  0.593772
# h_mean    0.65947  0.579529
# 100%|██████████| 45/45 [00:34<00:00,  1.29it/s]
# 100%|██████████| 600/600 [00:56<00:00, 10.58it/s]
# 100%|██████████| 600/600 [00:57<00:00, 10.46it/s]
# 2021-10-27 10:26:30,647 - pytorch_modeler.py - INFO - epoch:30/100, tr_loss:0.028363, src_loss:1.329102, src_mean_auc:0.719900, tgt_loss:1.370304, tgt_mean_auc:0.647067, mean_auc:0.683483,
#                AUC      pAUC
# Source_0  0.524400  0.511053
# Source_1  0.816600  0.743684
# Source_2  0.818700  0.753684
# Target_0  0.647700  0.551579
# Target_1  0.672000  0.545263
# Target_2  0.621500  0.526842
# mean      0.683483  0.605351
# h_mean    0.667111  0.589781
# 100%|██████████| 45/45 [00:34<00:00,  1.29it/s]
# 2021-10-27 10:27:05,653 - pytorch_modeler.py - INFO - epoch:31/100, tr_loss:0.030099, src_loss:1.329102, src_mean_auc:0.719900, tgt_loss:1.370304, tgt_mean_auc:0.647067, mean_auc:0.683483,
#                AUC      pAUC
# Source_0  0.524400  0.511053
# Source_1  0.816600  0.743684
# Source_2  0.818700  0.753684
# Target_0  0.647700  0.551579
# Target_1  0.672000  0.545263
# Target_2  0.621500  0.526842
# mean      0.683483  0.605351
# h_mean    0.667111  0.589781
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-27 10:27:40,933 - pytorch_modeler.py - INFO - epoch:32/100, tr_loss:0.025991, src_loss:1.329102, src_mean_auc:0.719900, tgt_loss:1.370304, tgt_mean_auc:0.647067, mean_auc:0.683483,
#                AUC      pAUC
# Source_0  0.524400  0.511053
# Source_1  0.816600  0.743684
# Source_2  0.818700  0.753684
# Target_0  0.647700  0.551579
# Target_1  0.672000  0.545263
# Target_2  0.621500  0.526842
# mean      0.683483  0.605351
# h_mean    0.667111  0.589781
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-27 10:28:16,110 - pytorch_modeler.py - INFO - epoch:33/100, tr_loss:0.025362, src_loss:1.329102, src_mean_auc:0.719900, tgt_loss:1.370304, tgt_mean_auc:0.647067, mean_auc:0.683483,
#                AUC      pAUC
# Source_0  0.524400  0.511053
# Source_1  0.816600  0.743684
# Source_2  0.818700  0.753684
# Target_0  0.647700  0.551579
# Target_1  0.672000  0.545263
# Target_2  0.621500  0.526842
# mean      0.683483  0.605351
# h_mean    0.667111  0.589781
# 100%|██████████| 45/45 [00:34<00:00,  1.29it/s]
# 2021-10-27 10:28:51,034 - pytorch_modeler.py - INFO - epoch:34/100, tr_loss:0.025722, src_loss:1.329102, src_mean_auc:0.719900, tgt_loss:1.370304, tgt_mean_auc:0.647067, mean_auc:0.683483,
#                AUC      pAUC
# Source_0  0.524400  0.511053
# Source_1  0.816600  0.743684
# Source_2  0.818700  0.753684
# Target_0  0.647700  0.551579
# Target_1  0.672000  0.545263
# Target_2  0.621500  0.526842
# mean      0.683483  0.605351
# h_mean    0.667111  0.589781
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-27 10:29:25,712 - pytorch_modeler.py - INFO - epoch:35/100, tr_loss:0.019364, src_loss:1.329102, src_mean_auc:0.719900, tgt_loss:1.370304, tgt_mean_auc:0.647067, mean_auc:0.683483,
#                AUC      pAUC
# Source_0  0.524400  0.511053
# Source_1  0.816600  0.743684
# Source_2  0.818700  0.753684
# Target_0  0.647700  0.551579
# Target_1  0.672000  0.545263
# Target_2  0.621500  0.526842
# mean      0.683483  0.605351
# h_mean    0.667111  0.589781
# 100%|██████████| 45/45 [00:34<00:00,  1.29it/s]
# 2021-10-27 10:30:00,543 - pytorch_modeler.py - INFO - epoch:36/100, tr_loss:0.023115, src_loss:1.329102, src_mean_auc:0.719900, tgt_loss:1.370304, tgt_mean_auc:0.647067, mean_auc:0.683483,
#                AUC      pAUC
# Source_0  0.524400  0.511053
# Source_1  0.816600  0.743684
# Source_2  0.818700  0.753684
# Target_0  0.647700  0.551579
# Target_1  0.672000  0.545263
# Target_2  0.621500  0.526842
# mean      0.683483  0.605351
# h_mean    0.667111  0.589781
#  29%|██▉       | 13/45 [00:10<00:24,  1.31it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#run(machine_types[0], dev_paths)

# %% [markdown]
# # run

# %% [raw]
# # debug
# import dcase_util
# import pandas as pd
#
# sample = pd.read_pickle('/media/hiroki/HDD1TB/research/DCASE_experiments/domain_adaptation/exp2/extraction_features/ToyCar_features.pkl')
# sample = sample['val_src']
#
# src_pred_df = dcase_util.make_pred_df(sample['wav_name'], sample['section_label'], sample['domain_label'], sample['label'], sample['label'])
#
# df1 = dcase_util.calc_dcase2021_task2_score(src_pred_df, prefix='Source')
# df2 = dcase_util.calc_dcase2021_task2_score(src_pred_df, prefix='Target')
# score = pd.concat([df1, df2])
# mean = pd.DataFrame([score.mean()], index=['mean'])
# hmean = scipy.stats.hmean(score, axis=0)
# hmean = pd.DataFrame([hmean], columns=['AUC', 'pAUC'], index=['h_mean'])
# score = score.append([mean, hmean])
