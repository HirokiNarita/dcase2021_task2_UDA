# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter
import timm

#from torchvision.models import wide_resnet50_2, resnet18
#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
import common as com
import pytorch_modeler as modeler
from pytorch_model import EfficientNet_b1 as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %%
# effnet1 = timm.create_model('efficientnet_b1', pretrained=True)
# # M7:block[5], M8:block[6], M9:conv_head
# effnet1

# %% [markdown]
# ## load config and set logger

# %%
log_folder = config['IO_OPTION']['OUTPUT_ROOT']+'/{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_folder, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(42)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
dev_dir = INPUT_ROOT + "/dev_data"
add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = os.listdir(dev_dir)
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'

TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
PRED_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/pred'
SCORE_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/score'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
os.makedirs(PRED_DIR, exist_ok=True)
os.makedirs(SCORE_DIR, exist_ok=True)

# copy config
# shutil.copy('./config.yaml', OUTPUT_ROOT)

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## make path list

# %% [markdown]
# - __train_paths__ ([dict]): Each Machine Type
#     - __ToyCar__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) :paths
#     - __ToyTrain__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) : paths
#     - ...

# %%
percent = 0.1

# %%
dev_paths = {}

for machine_type in machine_types:
    # dev train
    dev_train_paths = [f"{dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/train")]
    dev_train_paths = sorted(dev_train_paths)
    
    print(f'Machine {machine_type}', end=',')
    print(f'dev_train_size : {len(dev_train_paths)}', end=', ')
    dev_train_source_paths = [path for path in dev_train_paths if 'source' in path]
    print(f'source_size : {len(dev_train_source_paths)}', end=', ')
    dev_train_target_paths = [path for path in dev_train_paths if 'target' in path]
    print(f'target_size : {len(dev_train_target_paths)}', end=', ')
    # increse tgt
    num_increse_tgt = int(len(dev_train_source_paths) * percent)
    increse_dev_train_target_paths = dev_train_target_paths * num_increse_tgt
    # concat
    dev_train_paths = dev_train_source_paths + increse_dev_train_target_paths
    
    # add_dev train
    add_dev_paths = [f"{add_dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{add_dev_dir}/{machine_type}/train")]
    add_dev_paths = sorted(add_dev_paths)
    print(f'adddev_train_size : {len(add_dev_paths)}', end=', ')
    add_dev_source_paths = [path for path in add_dev_paths if 'source' in path]
    print(f'source_size : {len(add_dev_source_paths)}', end=', ')
    add_dev_target_paths = [path for path in add_dev_paths if 'target' in path]
    print(f'target_size : {len(add_dev_target_paths)}')
    # increse tgt
    num_increse_tgt = int(len(add_dev_source_paths) * percent)
    increse_add_dev_target_paths = add_dev_target_paths * num_increse_tgt
    # concat
    add_dev_paths = add_dev_source_paths + increse_add_dev_target_paths

    print('==============================================================')
    
    # dev_source valid
    dev_source_paths = [f"{dev_dir}/{machine_type}/source_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/source_test")]
    dev_source_paths = sorted(dev_source_paths)
    
    # dev_target valid
    dev_target_paths = [f"{dev_dir}/{machine_type}/target_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/target_test")]
    dev_target_paths = sorted(dev_target_paths)
    
    # bundle
    dev_paths[machine_type] = {}
    dev_paths[machine_type]['train'] = dev_train_paths + add_dev_paths
    dev_paths[machine_type]['valid_source'] = dev_source_paths
    dev_paths[machine_type]['valid_target'] = dev_target_paths
# Out:
# Machine pump,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine gearbox,dev_train_size : 3026, source_size : 3017, target_size : 9, adddev_train_size : 3114, source_size : 3105, target_size : 9
# ==============================================================
# Machine slider,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyCar,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine valve,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyTrain,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine fan,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================

# %%
machine_types
# Out:
# ['pump', 'gearbox', 'slider', 'ToyCar', 'valve', 'ToyTrain', 'fan']

# %%
#############################################################################
# run
#############################################################################
def run(machine_type, dev_paths):
    com.tic()
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dev_train_paths
    dataloaders_dict = modeler.make_dataloader(dev_paths, machine_type)
    # parameter setting
    logger.info('TRAINING')
    model = Model(n_out=36, n_centers=6)
    
    optimizer = torch.optim.Adam(model.parameters(),lr=1e-4)
    output_dict, model, pred_df, score_df = modeler.run_training(model, dataloaders_dict, writer, optimizer)
    
    # output
    feature_out_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
    model_out_path = f'{MODEL_DIR}/{machine_type}_model.pkl'
    pred_out_path = f'{PRED_DIR}/{machine_type}_pred.csv'
    score_out_path = f'{SCORE_DIR}/{machine_type}_pred.csv'
    # save
    pd.to_pickle(output_dict, feature_out_path)
    torch.save(model.state_dict(), model_out_path)
    pred_df.to_csv(pred_out_path)
    score_df.to_csv(score_out_path)
    logger.info(f'SAVE SUCCESS : {model_out_path}')
    
    com.toc()

# %%
#run(machine_types[0], dev_paths)

# %%
for machine_type in machine_types[5:]:
    run(machine_type, dev_paths)
# Out:
# 2021-10-28 04:33:24,182 - 00_train.py - INFO - TARGET MACHINE_TYPE: pump
# 2021-10-28 04:33:24,183 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-10-28 04:33:24,188 - 00_train.py - INFO - TRAINING
# use: cuda:0
# 100%|██████████| 45/45 [02:18<00:00,  3.08s/it]
# 100%|██████████| 600/600 [00:59<00:00, 10.14it/s]
# 100%|██████████| 600/600 [00:59<00:00, 10.01it/s]
# 2021-10-28 04:37:44,845 - pytorch_modeler.py - INFO - epoch:1/100, tr_loss:0.510696, src_loss:0.677956, src_mean_auc:0.648833, tgt_loss:0.598441, tgt_mean_auc:0.576900, mean_auc:0.612867,
#                AUC      pAUC
# Source_0  0.665000  0.638421
# Source_1  0.672200  0.586316
# Source_2  0.609300  0.517895
# Target_0  0.649600  0.564737
# Target_1  0.524400  0.500000
# Target_2  0.556700  0.533158
# mean      0.612867  0.556754
# h_mean    0.607577  0.553037
# 100%|██████████| 45/45 [00:36<00:00,  1.24it/s]
# 2021-10-28 04:38:21,233 - pytorch_modeler.py - INFO - epoch:2/100, tr_loss:0.251658, src_loss:0.677956, src_mean_auc:0.648833, tgt_loss:0.598441, tgt_mean_auc:0.576900, mean_auc:0.612867,
#                AUC      pAUC
# Source_0  0.665000  0.638421
# Source_1  0.672200  0.586316
# Source_2  0.609300  0.517895
# Target_0  0.649600  0.564737
# Target_1  0.524400  0.500000
# Target_2  0.556700  0.533158
# mean      0.612867  0.556754
# h_mean    0.607577  0.553037
# 100%|██████████| 45/45 [00:36<00:00,  1.25it/s]
# 2021-10-28 04:38:57,366 - pytorch_modeler.py - INFO - epoch:3/100, tr_loss:0.155138, src_loss:0.677956, src_mean_auc:0.648833, tgt_loss:0.598441, tgt_mean_auc:0.576900, mean_auc:0.612867,
#                AUC      pAUC
# Source_0  0.665000  0.638421
# Source_1  0.672200  0.586316
# Source_2  0.609300  0.517895
# Target_0  0.649600  0.564737
# Target_1  0.524400  0.500000
# Target_2  0.556700  0.533158
# mean      0.612867  0.556754
# h_mean    0.607577  0.553037
# 100%|██████████| 45/45 [00:36<00:00,  1.25it/s]
# 2021-10-28 04:39:33,399 - pytorch_modeler.py - INFO - epoch:4/100, tr_loss:0.117951, src_loss:0.677956, src_mean_auc:0.648833, tgt_loss:0.598441, tgt_mean_auc:0.576900, mean_auc:0.612867,
#                AUC      pAUC
# Source_0  0.665000  0.638421
# Source_1  0.672200  0.586316
# Source_2  0.609300  0.517895
# Target_0  0.649600  0.564737
# Target_1  0.524400  0.500000
# Target_2  0.556700  0.533158
# mean      0.612867  0.556754
# h_mean    0.607577  0.553037
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-28 04:40:09,378 - pytorch_modeler.py - INFO - epoch:5/100, tr_loss:0.098121, src_loss:0.677956, src_mean_auc:0.648833, tgt_loss:0.598441, tgt_mean_auc:0.576900, mean_auc:0.612867,
#                AUC      pAUC
# Source_0  0.665000  0.638421
# Source_1  0.672200  0.586316
# Source_2  0.609300  0.517895
# Target_0  0.649600  0.564737
# Target_1  0.524400  0.500000
# Target_2  0.556700  0.533158
# mean      0.612867  0.556754
# h_mean    0.607577  0.553037
# 100%|██████████| 45/45 [00:36<00:00,  1.25it/s]
# 2021-10-28 04:40:45,478 - pytorch_modeler.py - INFO - epoch:6/100, tr_loss:0.084570, src_loss:0.677956, src_mean_auc:0.648833, tgt_loss:0.598441, tgt_mean_auc:0.576900, mean_auc:0.612867,
#                AUC      pAUC
# Source_0  0.665000  0.638421
# Source_1  0.672200  0.586316
# Source_2  0.609300  0.517895
# Target_0  0.649600  0.564737
# Target_1  0.524400  0.500000
# Target_2  0.556700  0.533158
# mean      0.612867  0.556754
# h_mean    0.607577  0.553037
# 100%|██████████| 45/45 [00:36<00:00,  1.25it/s]
# 2021-10-28 04:41:21,581 - pytorch_modeler.py - INFO - epoch:7/100, tr_loss:0.071531, src_loss:0.677956, src_mean_auc:0.648833, tgt_loss:0.598441, tgt_mean_auc:0.576900, mean_auc:0.612867,
#                AUC      pAUC
# Source_0  0.665000  0.638421
# Source_1  0.672200  0.586316
# Source_2  0.609300  0.517895
# Target_0  0.649600  0.564737
# Target_1  0.524400  0.500000
# Target_2  0.556700  0.533158
# mean      0.612867  0.556754
# h_mean    0.607577  0.553037
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-28 04:41:57,583 - pytorch_modeler.py - INFO - epoch:8/100, tr_loss:0.063843, src_loss:0.677956, src_mean_auc:0.648833, tgt_loss:0.598441, tgt_mean_auc:0.576900, mean_auc:0.612867,
#                AUC      pAUC
# Source_0  0.665000  0.638421
# Source_1  0.672200  0.586316
# Source_2  0.609300  0.517895
# Target_0  0.649600  0.564737
# Target_1  0.524400  0.500000
# Target_2  0.556700  0.533158
# mean      0.612867  0.556754
# h_mean    0.607577  0.553037
# 100%|██████████| 45/45 [00:36<00:00,  1.25it/s]
# 2021-10-28 04:42:33,615 - pytorch_modeler.py - INFO - epoch:9/100, tr_loss:0.058283, src_loss:0.677956, src_mean_auc:0.648833, tgt_loss:0.598441, tgt_mean_auc:0.576900, mean_auc:0.612867,
#                AUC      pAUC
# Source_0  0.665000  0.638421
# Source_1  0.672200  0.586316
# Source_2  0.609300  0.517895
# Target_0  0.649600  0.564737
# Target_1  0.524400  0.500000
# Target_2  0.556700  0.533158
# mean      0.612867  0.556754
# h_mean    0.607577  0.553037
# 100%|██████████| 45/45 [00:36<00:00,  1.25it/s]
# 100%|██████████| 600/600 [00:57<00:00, 10.43it/s]
# 100%|██████████| 600/600 [00:57<00:00, 10.41it/s]
# 2021-10-28 04:45:04,909 - pytorch_modeler.py - INFO - epoch:10/100, tr_loss:0.054054, src_loss:0.405861, src_mean_auc:0.774067, tgt_loss:0.320471, tgt_mean_auc:0.692133, mean_auc:0.733100,
#                AUC      pAUC
# Source_0  0.761900  0.625263
# Source_1  0.893900  0.690000
# Source_2  0.666400  0.577895
# Target_0  0.793600  0.700000
# Target_1  0.751700  0.630000
# Target_2  0.531100  0.510526
# mean      0.733100  0.622281
# h_mean    0.713854  0.615154
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-28 04:45:40,904 - pytorch_modeler.py - INFO - epoch:11/100, tr_loss:0.051398, src_loss:0.405861, src_mean_auc:0.774067, tgt_loss:0.320471, tgt_mean_auc:0.692133, mean_auc:0.733100,
#                AUC      pAUC
# Source_0  0.761900  0.625263
# Source_1  0.893900  0.690000
# Source_2  0.666400  0.577895
# Target_0  0.793600  0.700000
# Target_1  0.751700  0.630000
# Target_2  0.531100  0.510526
# mean      0.733100  0.622281
# h_mean    0.713854  0.615154
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-28 04:46:16,916 - pytorch_modeler.py - INFO - epoch:12/100, tr_loss:0.047333, src_loss:0.405861, src_mean_auc:0.774067, tgt_loss:0.320471, tgt_mean_auc:0.692133, mean_auc:0.733100,
#                AUC      pAUC
# Source_0  0.761900  0.625263
# Source_1  0.893900  0.690000
# Source_2  0.666400  0.577895
# Target_0  0.793600  0.700000
# Target_1  0.751700  0.630000
# Target_2  0.531100  0.510526
# mean      0.733100  0.622281
# h_mean    0.713854  0.615154
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-28 04:46:52,919 - pytorch_modeler.py - INFO - epoch:13/100, tr_loss:0.046484, src_loss:0.405861, src_mean_auc:0.774067, tgt_loss:0.320471, tgt_mean_auc:0.692133, mean_auc:0.733100,
#                AUC      pAUC
# Source_0  0.761900  0.625263
# Source_1  0.893900  0.690000
# Source_2  0.666400  0.577895
# Target_0  0.793600  0.700000
# Target_1  0.751700  0.630000
# Target_2  0.531100  0.510526
# mean      0.733100  0.622281
# h_mean    0.713854  0.615154
# 100%|██████████| 45/45 [00:36<00:00,  1.25it/s]
# 2021-10-28 04:47:29,015 - pytorch_modeler.py - INFO - epoch:14/100, tr_loss:0.042808, src_loss:0.405861, src_mean_auc:0.774067, tgt_loss:0.320471, tgt_mean_auc:0.692133, mean_auc:0.733100,
#                AUC      pAUC
# Source_0  0.761900  0.625263
# Source_1  0.893900  0.690000
# Source_2  0.666400  0.577895
# Target_0  0.793600  0.700000
# Target_1  0.751700  0.630000
# Target_2  0.531100  0.510526
# mean      0.733100  0.622281
# h_mean    0.713854  0.615154
# 100%|██████████| 45/45 [00:36<00:00,  1.25it/s]
# 2021-10-28 04:48:05,074 - pytorch_modeler.py - INFO - epoch:15/100, tr_loss:0.039618, src_loss:0.405861, src_mean_auc:0.774067, tgt_loss:0.320471, tgt_mean_auc:0.692133, mean_auc:0.733100,
#                AUC      pAUC
# Source_0  0.761900  0.625263
# Source_1  0.893900  0.690000
# Source_2  0.666400  0.577895
# Target_0  0.793600  0.700000
# Target_1  0.751700  0.630000
# Target_2  0.531100  0.510526
# mean      0.733100  0.622281
# h_mean    0.713854  0.615154
# 100%|██████████| 45/45 [00:36<00:00,  1.25it/s]
# 2021-10-28 04:48:41,144 - pytorch_modeler.py - INFO - epoch:16/100, tr_loss:0.039908, src_loss:0.405861, src_mean_auc:0.774067, tgt_loss:0.320471, tgt_mean_auc:0.692133, mean_auc:0.733100,
#                AUC      pAUC
# Source_0  0.761900  0.625263
# Source_1  0.893900  0.690000
# Source_2  0.666400  0.577895
# Target_0  0.793600  0.700000
# Target_1  0.751700  0.630000
# Target_2  0.531100  0.510526
# mean      0.733100  0.622281
# h_mean    0.713854  0.615154
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-28 04:49:17,021 - pytorch_modeler.py - INFO - epoch:17/100, tr_loss:0.033921, src_loss:0.405861, src_mean_auc:0.774067, tgt_loss:0.320471, tgt_mean_auc:0.692133, mean_auc:0.733100,
#                AUC      pAUC
# Source_0  0.761900  0.625263
# Source_1  0.893900  0.690000
# Source_2  0.666400  0.577895
# Target_0  0.793600  0.700000
# Target_1  0.751700  0.630000
# Target_2  0.531100  0.510526
# mean      0.733100  0.622281
# h_mean    0.713854  0.615154
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-28 04:49:52,845 - pytorch_modeler.py - INFO - epoch:18/100, tr_loss:0.037023, src_loss:0.405861, src_mean_auc:0.774067, tgt_loss:0.320471, tgt_mean_auc:0.692133, mean_auc:0.733100,
#                AUC      pAUC
# Source_0  0.761900  0.625263
# Source_1  0.893900  0.690000
# Source_2  0.666400  0.577895
# Target_0  0.793600  0.700000
# Target_1  0.751700  0.630000
# Target_2  0.531100  0.510526
# mean      0.733100  0.622281
# h_mean    0.713854  0.615154
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-28 04:50:28,551 - pytorch_modeler.py - INFO - epoch:19/100, tr_loss:0.034130, src_loss:0.405861, src_mean_auc:0.774067, tgt_loss:0.320471, tgt_mean_auc:0.692133, mean_auc:0.733100,
#                AUC      pAUC
# Source_0  0.761900  0.625263
# Source_1  0.893900  0.690000
# Source_2  0.666400  0.577895
# Target_0  0.793600  0.700000
# Target_1  0.751700  0.630000
# Target_2  0.531100  0.510526
# mean      0.733100  0.622281
# h_mean    0.713854  0.615154
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 100%|██████████| 600/600 [00:56<00:00, 10.54it/s]
# 100%|██████████| 600/600 [00:57<00:00, 10.41it/s]
# 2021-10-28 04:52:58,817 - pytorch_modeler.py - INFO - epoch:20/100, tr_loss:0.033962, src_loss:0.367223, src_mean_auc:0.774733, tgt_loss:0.293065, tgt_mean_auc:0.702533, mean_auc:0.738633,
#                AUC      pAUC
# Source_0  0.767000  0.621053
# Source_1  0.894700  0.725263
# Source_2  0.662500  0.548947
# Target_0  0.798900  0.678421
# Target_1  0.738200  0.656316
# Target_2  0.570500  0.518947
# mean      0.738633  0.624825
# h_mean    0.723753  0.616314
# 100%|██████████| 45/45 [00:36<00:00,  1.25it/s]
# 2021-10-28 04:53:34,916 - pytorch_modeler.py - INFO - epoch:21/100, tr_loss:0.030763, src_loss:0.367223, src_mean_auc:0.774733, tgt_loss:0.293065, tgt_mean_auc:0.702533, mean_auc:0.738633,
#                AUC      pAUC
# Source_0  0.767000  0.621053
# Source_1  0.894700  0.725263
# Source_2  0.662500  0.548947
# Target_0  0.798900  0.678421
# Target_1  0.738200  0.656316
# Target_2  0.570500  0.518947
# mean      0.738633  0.624825
# h_mean    0.723753  0.616314
# 100%|██████████| 45/45 [00:36<00:00,  1.23it/s]
# 2021-10-28 04:54:11,476 - pytorch_modeler.py - INFO - epoch:22/100, tr_loss:0.029865, src_loss:0.367223, src_mean_auc:0.774733, tgt_loss:0.293065, tgt_mean_auc:0.702533, mean_auc:0.738633,
#                AUC      pAUC
# Source_0  0.767000  0.621053
# Source_1  0.894700  0.725263
# Source_2  0.662500  0.548947
# Target_0  0.798900  0.678421
# Target_1  0.738200  0.656316
# Target_2  0.570500  0.518947
# mean      0.738633  0.624825
# h_mean    0.723753  0.616314
# 100%|██████████| 45/45 [00:36<00:00,  1.24it/s]
# 2021-10-28 04:54:47,747 - pytorch_modeler.py - INFO - epoch:23/100, tr_loss:0.029245, src_loss:0.367223, src_mean_auc:0.774733, tgt_loss:0.293065, tgt_mean_auc:0.702533, mean_auc:0.738633,
#                AUC      pAUC
# Source_0  0.767000  0.621053
# Source_1  0.894700  0.725263
# Source_2  0.662500  0.548947
# Target_0  0.798900  0.678421
# Target_1  0.738200  0.656316
# Target_2  0.570500  0.518947
# mean      0.738633  0.624825
# h_mean    0.723753  0.616314
# 100%|██████████| 45/45 [00:36<00:00,  1.24it/s]
# 2021-10-28 04:55:24,170 - pytorch_modeler.py - INFO - epoch:24/100, tr_loss:0.028892, src_loss:0.367223, src_mean_auc:0.774733, tgt_loss:0.293065, tgt_mean_auc:0.702533, mean_auc:0.738633,
#                AUC      pAUC
# Source_0  0.767000  0.621053
# Source_1  0.894700  0.725263
# Source_2  0.662500  0.548947
# Target_0  0.798900  0.678421
# Target_1  0.738200  0.656316
# Target_2  0.570500  0.518947
# mean      0.738633  0.624825
# h_mean    0.723753  0.616314
# 100%|██████████| 45/45 [00:36<00:00,  1.24it/s]
# 2021-10-28 04:56:00,374 - pytorch_modeler.py - INFO - epoch:25/100, tr_loss:0.026460, src_loss:0.367223, src_mean_auc:0.774733, tgt_loss:0.293065, tgt_mean_auc:0.702533, mean_auc:0.738633,
#                AUC      pAUC
# Source_0  0.767000  0.621053
# Source_1  0.894700  0.725263
# Source_2  0.662500  0.548947
# Target_0  0.798900  0.678421
# Target_1  0.738200  0.656316
# Target_2  0.570500  0.518947
# mean      0.738633  0.624825
# h_mean    0.723753  0.616314
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-28 04:56:36,370 - pytorch_modeler.py - INFO - epoch:26/100, tr_loss:0.025219, src_loss:0.367223, src_mean_auc:0.774733, tgt_loss:0.293065, tgt_mean_auc:0.702533, mean_auc:0.738633,
#                AUC      pAUC
# Source_0  0.767000  0.621053
# Source_1  0.894700  0.725263
# Source_2  0.662500  0.548947
# Target_0  0.798900  0.678421
# Target_1  0.738200  0.656316
# Target_2  0.570500  0.518947
# mean      0.738633  0.624825
# h_mean    0.723753  0.616314
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-28 04:57:12,369 - pytorch_modeler.py - INFO - epoch:27/100, tr_loss:0.025970, src_loss:0.367223, src_mean_auc:0.774733, tgt_loss:0.293065, tgt_mean_auc:0.702533, mean_auc:0.738633,
#                AUC      pAUC
# Source_0  0.767000  0.621053
# Source_1  0.894700  0.725263
# Source_2  0.662500  0.548947
# Target_0  0.798900  0.678421
# Target_1  0.738200  0.656316
# Target_2  0.570500  0.518947
# mean      0.738633  0.624825
# h_mean    0.723753  0.616314
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-28 04:57:48,202 - pytorch_modeler.py - INFO - epoch:28/100, tr_loss:0.023007, src_loss:0.367223, src_mean_auc:0.774733, tgt_loss:0.293065, tgt_mean_auc:0.702533, mean_auc:0.738633,
#                AUC      pAUC
# Source_0  0.767000  0.621053
# Source_1  0.894700  0.725263
# Source_2  0.662500  0.548947
# Target_0  0.798900  0.678421
# Target_1  0.738200  0.656316
# Target_2  0.570500  0.518947
# mean      0.738633  0.624825
# h_mean    0.723753  0.616314
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-28 04:58:24,007 - pytorch_modeler.py - INFO - epoch:29/100, tr_loss:0.023110, src_loss:0.367223, src_mean_auc:0.774733, tgt_loss:0.293065, tgt_mean_auc:0.702533, mean_auc:0.738633,
#                AUC      pAUC
# Source_0  0.767000  0.621053
# Source_1  0.894700  0.725263
# Source_2  0.662500  0.548947
# Target_0  0.798900  0.678421
# Target_1  0.738200  0.656316
# Target_2  0.570500  0.518947
# mean      0.738633  0.624825
# h_mean    0.723753  0.616314
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 100%|██████████| 600/600 [00:58<00:00, 10.28it/s]
# 100%|██████████| 600/600 [00:58<00:00, 10.34it/s]
# 2021-10-28 05:00:56,243 - pytorch_modeler.py - INFO - epoch:30/100, tr_loss:0.022792, src_loss:0.353667, src_mean_auc:0.799967, tgt_loss:0.287471, tgt_mean_auc:0.732000, mean_auc:0.765983,
#                AUC      pAUC
# Source_0  0.803300  0.658947
# Source_1  0.908200  0.733684
# Source_2  0.688400  0.552632
# Target_0  0.829400  0.722105
# Target_1  0.766700  0.674211
# Target_2  0.599900  0.525789
# mean      0.765983  0.644561
# h_mean    0.752303  0.634247
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-28 05:01:31,842 - pytorch_modeler.py - INFO - epoch:31/100, tr_loss:0.020857, src_loss:0.353667, src_mean_auc:0.799967, tgt_loss:0.287471, tgt_mean_auc:0.732000, mean_auc:0.765983,
#                AUC      pAUC
# Source_0  0.803300  0.658947
# Source_1  0.908200  0.733684
# Source_2  0.688400  0.552632
# Target_0  0.829400  0.722105
# Target_1  0.766700  0.674211
# Target_2  0.599900  0.525789
# mean      0.765983  0.644561
# h_mean    0.752303  0.634247
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-28 05:02:07,347 - pytorch_modeler.py - INFO - epoch:32/100, tr_loss:0.021092, src_loss:0.353667, src_mean_auc:0.799967, tgt_loss:0.287471, tgt_mean_auc:0.732000, mean_auc:0.765983,
#                AUC      pAUC
# Source_0  0.803300  0.658947
# Source_1  0.908200  0.733684
# Source_2  0.688400  0.552632
# Target_0  0.829400  0.722105
# Target_1  0.766700  0.674211
# Target_2  0.599900  0.525789
# mean      0.765983  0.644561
# h_mean    0.752303  0.634247
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-28 05:02:42,751 - pytorch_modeler.py - INFO - epoch:33/100, tr_loss:0.019650, src_loss:0.353667, src_mean_auc:0.799967, tgt_loss:0.287471, tgt_mean_auc:0.732000, mean_auc:0.765983,
#                AUC      pAUC
# Source_0  0.803300  0.658947
# Source_1  0.908200  0.733684
# Source_2  0.688400  0.552632
# Target_0  0.829400  0.722105
# Target_1  0.766700  0.674211
# Target_2  0.599900  0.525789
# mean      0.765983  0.644561
# h_mean    0.752303  0.634247
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-28 05:03:18,186 - pytorch_modeler.py - INFO - epoch:34/100, tr_loss:0.020859, src_loss:0.353667, src_mean_auc:0.799967, tgt_loss:0.287471, tgt_mean_auc:0.732000, mean_auc:0.765983,
#                AUC      pAUC
# Source_0  0.803300  0.658947
# Source_1  0.908200  0.733684
# Source_2  0.688400  0.552632
# Target_0  0.829400  0.722105
# Target_1  0.766700  0.674211
# Target_2  0.599900  0.525789
# mean      0.765983  0.644561
# h_mean    0.752303  0.634247
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-28 05:03:53,490 - pytorch_modeler.py - INFO - epoch:35/100, tr_loss:0.018539, src_loss:0.353667, src_mean_auc:0.799967, tgt_loss:0.287471, tgt_mean_auc:0.732000, mean_auc:0.765983,
#                AUC      pAUC
# Source_0  0.803300  0.658947
# Source_1  0.908200  0.733684
# Source_2  0.688400  0.552632
# Target_0  0.829400  0.722105
# Target_1  0.766700  0.674211
# Target_2  0.599900  0.525789
# mean      0.765983  0.644561
# h_mean    0.752303  0.634247
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-28 05:04:28,913 - pytorch_modeler.py - INFO - epoch:36/100, tr_loss:0.020075, src_loss:0.353667, src_mean_auc:0.799967, tgt_loss:0.287471, tgt_mean_auc:0.732000, mean_auc:0.765983,
#                AUC      pAUC
# Source_0  0.803300  0.658947
# Source_1  0.908200  0.733684
# Source_2  0.688400  0.552632
# Target_0  0.829400  0.722105
# Target_1  0.766700  0.674211
# Target_2  0.599900  0.525789
# mean      0.765983  0.644561
# h_mean    0.752303  0.634247
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-28 05:05:04,347 - pytorch_modeler.py - INFO - epoch:37/100, tr_loss:0.017628, src_loss:0.353667, src_mean_auc:0.799967, tgt_loss:0.287471, tgt_mean_auc:0.732000, mean_auc:0.765983,
#                AUC      pAUC
# Source_0  0.803300  0.658947
# Source_1  0.908200  0.733684
# Source_2  0.688400  0.552632
# Target_0  0.829400  0.722105
# Target_1  0.766700  0.674211
# Target_2  0.599900  0.525789
# mean      0.765983  0.644561
# h_mean    0.752303  0.634247
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-28 05:05:39,600 - pytorch_modeler.py - INFO - epoch:38/100, tr_loss:0.015810, src_loss:0.353667, src_mean_auc:0.799967, tgt_loss:0.287471, tgt_mean_auc:0.732000, mean_auc:0.765983,
#                AUC      pAUC
# Source_0  0.803300  0.658947
# Source_1  0.908200  0.733684
# Source_2  0.688400  0.552632
# Target_0  0.829400  0.722105
# Target_1  0.766700  0.674211
# Target_2  0.599900  0.525789
# mean      0.765983  0.644561
# h_mean    0.752303  0.634247
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-28 05:06:14,904 - pytorch_modeler.py - INFO - epoch:39/100, tr_loss:0.016219, src_loss:0.353667, src_mean_auc:0.799967, tgt_loss:0.287471, tgt_mean_auc:0.732000, mean_auc:0.765983,
#                AUC      pAUC
# Source_0  0.803300  0.658947
# Source_1  0.908200  0.733684
# Source_2  0.688400  0.552632
# Target_0  0.829400  0.722105
# Target_1  0.766700  0.674211
# Target_2  0.599900  0.525789
# mean      0.765983  0.644561
# h_mean    0.752303  0.634247
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 100%|██████████| 600/600 [00:58<00:00, 10.32it/s]
# 100%|██████████| 600/600 [00:58<00:00, 10.32it/s]
# 2021-10-28 05:08:46,587 - pytorch_modeler.py - INFO - epoch:40/100, tr_loss:0.017943, src_loss:0.344687, src_mean_auc:0.782967, tgt_loss:0.318753, tgt_mean_auc:0.713300, mean_auc:0.748133,
#                AUC      pAUC
# Source_0  0.790000  0.644737
# Source_1  0.890600  0.730526
# Source_2  0.668300  0.533158
# Target_0  0.813700  0.692632
# Target_1  0.734300  0.681053
# Target_2  0.591900  0.528421
# mean      0.748133  0.635088
# h_mean    0.734820  0.624998
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-28 05:09:21,977 - pytorch_modeler.py - INFO - epoch:41/100, tr_loss:0.016131, src_loss:0.344687, src_mean_auc:0.782967, tgt_loss:0.318753, tgt_mean_auc:0.713300, mean_auc:0.748133,
#                AUC      pAUC
# Source_0  0.790000  0.644737
# Source_1  0.890600  0.730526
# Source_2  0.668300  0.533158
# Target_0  0.813700  0.692632
# Target_1  0.734300  0.681053
# Target_2  0.591900  0.528421
# mean      0.748133  0.635088
# h_mean    0.734820  0.624998
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-28 05:09:57,625 - pytorch_modeler.py - INFO - epoch:42/100, tr_loss:0.016101, src_loss:0.344687, src_mean_auc:0.782967, tgt_loss:0.318753, tgt_mean_auc:0.713300, mean_auc:0.748133,
#                AUC      pAUC
# Source_0  0.790000  0.644737
# Source_1  0.890600  0.730526
# Source_2  0.668300  0.533158
# Target_0  0.813700  0.692632
# Target_1  0.734300  0.681053
# Target_2  0.591900  0.528421
# mean      0.748133  0.635088
# h_mean    0.734820  0.624998
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-28 05:10:32,932 - pytorch_modeler.py - INFO - epoch:43/100, tr_loss:0.015737, src_loss:0.344687, src_mean_auc:0.782967, tgt_loss:0.318753, tgt_mean_auc:0.713300, mean_auc:0.748133,
#                AUC      pAUC
# Source_0  0.790000  0.644737
# Source_1  0.890600  0.730526
# Source_2  0.668300  0.533158
# Target_0  0.813700  0.692632
# Target_1  0.734300  0.681053
# Target_2  0.591900  0.528421
# mean      0.748133  0.635088
# h_mean    0.734820  0.624998
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-28 05:11:08,205 - pytorch_modeler.py - INFO - epoch:44/100, tr_loss:0.013794, src_loss:0.344687, src_mean_auc:0.782967, tgt_loss:0.318753, tgt_mean_auc:0.713300, mean_auc:0.748133,
#                AUC      pAUC
# Source_0  0.790000  0.644737
# Source_1  0.890600  0.730526
# Source_2  0.668300  0.533158
# Target_0  0.813700  0.692632
# Target_1  0.734300  0.681053
# Target_2  0.591900  0.528421
# mean      0.748133  0.635088
# h_mean    0.734820  0.624998
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-28 05:11:43,462 - pytorch_modeler.py - INFO - epoch:45/100, tr_loss:0.014311, src_loss:0.344687, src_mean_auc:0.782967, tgt_loss:0.318753, tgt_mean_auc:0.713300, mean_auc:0.748133,
#                AUC      pAUC
# Source_0  0.790000  0.644737
# Source_1  0.890600  0.730526
# Source_2  0.668300  0.533158
# Target_0  0.813700  0.692632
# Target_1  0.734300  0.681053
# Target_2  0.591900  0.528421
# mean      0.748133  0.635088
# h_mean    0.734820  0.624998
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-28 05:12:18,872 - pytorch_modeler.py - INFO - epoch:46/100, tr_loss:0.016055, src_loss:0.344687, src_mean_auc:0.782967, tgt_loss:0.318753, tgt_mean_auc:0.713300, mean_auc:0.748133,
#                AUC      pAUC
# Source_0  0.790000  0.644737
# Source_1  0.890600  0.730526
# Source_2  0.668300  0.533158
# Target_0  0.813700  0.692632
# Target_1  0.734300  0.681053
# Target_2  0.591900  0.528421
# mean      0.748133  0.635088
# h_mean    0.734820  0.624998
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-28 05:12:54,163 - pytorch_modeler.py - INFO - epoch:47/100, tr_loss:0.016916, src_loss:0.344687, src_mean_auc:0.782967, tgt_loss:0.318753, tgt_mean_auc:0.713300, mean_auc:0.748133,
#                AUC      pAUC
# Source_0  0.790000  0.644737
# Source_1  0.890600  0.730526
# Source_2  0.668300  0.533158
# Target_0  0.813700  0.692632
# Target_1  0.734300  0.681053
# Target_2  0.591900  0.528421
# mean      0.748133  0.635088
# h_mean    0.734820  0.624998
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-28 05:13:29,580 - pytorch_modeler.py - INFO - epoch:48/100, tr_loss:0.013061, src_loss:0.344687, src_mean_auc:0.782967, tgt_loss:0.318753, tgt_mean_auc:0.713300, mean_auc:0.748133,
#                AUC      pAUC
# Source_0  0.790000  0.644737
# Source_1  0.890600  0.730526
# Source_2  0.668300  0.533158
# Target_0  0.813700  0.692632
# Target_1  0.734300  0.681053
# Target_2  0.591900  0.528421
# mean      0.748133  0.635088
# h_mean    0.734820  0.624998
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-28 05:14:05,065 - pytorch_modeler.py - INFO - epoch:49/100, tr_loss:0.013001, src_loss:0.344687, src_mean_auc:0.782967, tgt_loss:0.318753, tgt_mean_auc:0.713300, mean_auc:0.748133,
#                AUC      pAUC
# Source_0  0.790000  0.644737
# Source_1  0.890600  0.730526
# Source_2  0.668300  0.533158
# Target_0  0.813700  0.692632
# Target_1  0.734300  0.681053
# Target_2  0.591900  0.528421
# mean      0.748133  0.635088
# h_mean    0.734820  0.624998
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 100%|██████████| 600/600 [00:58<00:00, 10.31it/s]
# 100%|██████████| 600/600 [00:58<00:00, 10.33it/s]
# 2021-10-28 05:16:36,722 - pytorch_modeler.py - INFO - epoch:50/100, tr_loss:0.012776, src_loss:0.322595, src_mean_auc:0.786200, tgt_loss:0.276696, tgt_mean_auc:0.729533, mean_auc:0.757867,
#                AUC      pAUC
# Source_0  0.763400  0.647895
# Source_1  0.909100  0.776842
# Source_2  0.686100  0.546316
# Target_0  0.806600  0.721579
# Target_1  0.758800  0.687368
# Target_2  0.623200  0.527895
# mean      0.757867  0.651316
# h_mean    0.747226  0.638559
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-28 05:17:12,289 - pytorch_modeler.py - INFO - epoch:51/100, tr_loss:0.012969, src_loss:0.322595, src_mean_auc:0.786200, tgt_loss:0.276696, tgt_mean_auc:0.729533, mean_auc:0.757867,
#                AUC      pAUC
# Source_0  0.763400  0.647895
# Source_1  0.909100  0.776842
# Source_2  0.686100  0.546316
# Target_0  0.806600  0.721579
# Target_1  0.758800  0.687368
# Target_2  0.623200  0.527895
# mean      0.757867  0.651316
# h_mean    0.747226  0.638559
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-28 05:17:48,160 - pytorch_modeler.py - INFO - epoch:52/100, tr_loss:0.013222, src_loss:0.322595, src_mean_auc:0.786200, tgt_loss:0.276696, tgt_mean_auc:0.729533, mean_auc:0.757867,
#                AUC      pAUC
# Source_0  0.763400  0.647895
# Source_1  0.909100  0.776842
# Source_2  0.686100  0.546316
# Target_0  0.806600  0.721579
# Target_1  0.758800  0.687368
# Target_2  0.623200  0.527895
# mean      0.757867  0.651316
# h_mean    0.747226  0.638559
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-28 05:18:23,759 - pytorch_modeler.py - INFO - epoch:53/100, tr_loss:0.011773, src_loss:0.322595, src_mean_auc:0.786200, tgt_loss:0.276696, tgt_mean_auc:0.729533, mean_auc:0.757867,
#                AUC      pAUC
# Source_0  0.763400  0.647895
# Source_1  0.909100  0.776842
# Source_2  0.686100  0.546316
# Target_0  0.806600  0.721579
# Target_1  0.758800  0.687368
# Target_2  0.623200  0.527895
# mean      0.757867  0.651316
# h_mean    0.747226  0.638559
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-28 05:18:59,213 - pytorch_modeler.py - INFO - epoch:54/100, tr_loss:0.011554, src_loss:0.322595, src_mean_auc:0.786200, tgt_loss:0.276696, tgt_mean_auc:0.729533, mean_auc:0.757867,
#                AUC      pAUC
# Source_0  0.763400  0.647895
# Source_1  0.909100  0.776842
# Source_2  0.686100  0.546316
# Target_0  0.806600  0.721579
# Target_1  0.758800  0.687368
# Target_2  0.623200  0.527895
# mean      0.757867  0.651316
# h_mean    0.747226  0.638559
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-28 05:19:34,477 - pytorch_modeler.py - INFO - epoch:55/100, tr_loss:0.012317, src_loss:0.322595, src_mean_auc:0.786200, tgt_loss:0.276696, tgt_mean_auc:0.729533, mean_auc:0.757867,
#                AUC      pAUC
# Source_0  0.763400  0.647895
# Source_1  0.909100  0.776842
# Source_2  0.686100  0.546316
# Target_0  0.806600  0.721579
# Target_1  0.758800  0.687368
# Target_2  0.623200  0.527895
# mean      0.757867  0.651316
# h_mean    0.747226  0.638559
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-28 05:20:09,967 - pytorch_modeler.py - INFO - epoch:56/100, tr_loss:0.012475, src_loss:0.322595, src_mean_auc:0.786200, tgt_loss:0.276696, tgt_mean_auc:0.729533, mean_auc:0.757867,
#                AUC      pAUC
# Source_0  0.763400  0.647895
# Source_1  0.909100  0.776842
# Source_2  0.686100  0.546316
# Target_0  0.806600  0.721579
# Target_1  0.758800  0.687368
# Target_2  0.623200  0.527895
# mean      0.757867  0.651316
# h_mean    0.747226  0.638559
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-28 05:20:45,400 - pytorch_modeler.py - INFO - epoch:57/100, tr_loss:0.011769, src_loss:0.322595, src_mean_auc:0.786200, tgt_loss:0.276696, tgt_mean_auc:0.729533, mean_auc:0.757867,
#                AUC      pAUC
# Source_0  0.763400  0.647895
# Source_1  0.909100  0.776842
# Source_2  0.686100  0.546316
# Target_0  0.806600  0.721579
# Target_1  0.758800  0.687368
# Target_2  0.623200  0.527895
# mean      0.757867  0.651316
# h_mean    0.747226  0.638559
#  84%|████████▍ | 38/45 [00:30<00:05,  1.24it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5046/1835963252.py in <module>
#       1 for machine_type in machine_types:
# ----> 2     run(machine_type, dev_paths)
#
# /tmp/ipykernel_5046/1914341529.py in run(machine_type, dev_paths)
#      17
#      18     optimizer = torch.optim.Adam(model.parameters(),lr=1e-4)
# ---> 19     output_dict, model, pred_df, score_df = modeler.run_training(model, dataloaders_dict, writer, optimizer)
#      20
#      21     # output
#
# /media/code-disk/dcase2021_task2_UDA/EfficientNet/exp32/pytorch_modeler.py in run_training(model, dataloaders_dict, writer, optimizer)
#     272             optimizer=optimizer,
#     273             epoch=epoch,
# --> 274             device=device,
#     275             )
#     276         if epoch == n_epochs:
#
# /media/code-disk/dcase2021_task2_UDA/EfficientNet/exp32/pytorch_modeler.py in train_fn(data_loader, model, optimizer, epoch, device)
#     169         #feature, section_label = mixup(feature, section_label)
#     170         # effnet forward
# --> 171         loss, _ = model.forward(feature, section_label)
#     172         # hook
#     173         #deep_feat = torch.cat(tmp_deep_feat, dim=1)
#
# /media/code-disk/dcase2021_task2_UDA/EfficientNet/exp32/pytorch_model.py in forward(self, x, section_label)
#     128
#     129         # effnet
# --> 130         embedding = self.effnet(x)
#     131         #x = self.adacos(embedding, section_label)
#     132         #classifier_loss = self.effnet_loss(x, section_label)
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /media/code-disk/dcase2021_task2_UDA/EfficientNet/exp32/pytorch_model.py in effnet_forward(self, x)
#     107
#     108     def effnet_forward(self, x):
# --> 109         x = self.effnet.forward_features(x)
#     110         x = self.effnet.global_pool(x)
#     111         if self.effnet.drop_rate > 0.:
#
# /opt/conda/lib/python3.7/site-packages/timm/models/efficientnet.py in forward_features(self, x)
#     469         x = self.act1(x)
#     470         x = self.blocks(x)
# --> 471         x = self.conv_head(x)
#     472         x = self.bn2(x)
#     473         x = self.act2(x)
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     441
#     442     def forward(self, input: Tensor) -> Tensor:
# --> 443         return self._conv_forward(input, self.weight, self.bias)
#     444
#     445 class Conv3d(_ConvNd):
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     438                             _pair(0), self.dilation, self.groups)
#     439         return F.conv2d(input, weight, bias, self.stride,
# --> 440                         self.padding, self.dilation, self.groups)
#     441
#     442     def forward(self, input: Tensor) -> Tensor:
#
# KeyboardInterrupt:

# %%
#run(machine_types[0], dev_paths)

# %% [markdown]
# # run

# %% [raw]
# # debug
# import dcase_util
# import pandas as pd
#
# sample = pd.read_pickle('/media/hiroki/HDD1TB/research/DCASE_experiments/domain_adaptation/exp2/extraction_features/ToyCar_features.pkl')
# sample = sample['val_src']
#
# src_pred_df = dcase_util.make_pred_df(sample['wav_name'], sample['section_label'], sample['domain_label'], sample['label'], sample['label'])
#
# df1 = dcase_util.calc_dcase2021_task2_score(src_pred_df, prefix='Source')
# df2 = dcase_util.calc_dcase2021_task2_score(src_pred_df, prefix='Target')
# score = pd.concat([df1, df2])
# mean = pd.DataFrame([score.mean()], index=['mean'])
# hmean = scipy.stats.hmean(score, axis=0)
# hmean = pd.DataFrame([hmean], columns=['AUC', 'pAUC'], index=['h_mean'])
# score = score.append([mean, hmean])
