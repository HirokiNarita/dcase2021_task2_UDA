# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter
import timm

#from torchvision.models import wide_resnet50_2, resnet18
#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
import common as com
import pytorch_modeler as modeler
from pytorch_model import EfficientNet_b1 as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %%
# effnet1 = timm.create_model('efficientnet_b1', pretrained=True)
# # M7:block[5], M8:block[6], M9:conv_head
# effnet1

# %% [markdown]
# ## load config and set logger

# %%
log_folder = config['IO_OPTION']['OUTPUT_ROOT']+'/{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_folder, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(42)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
dev_dir = INPUT_ROOT + "/dev_data"
add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = os.listdir(dev_dir)
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'

TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
PRED_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/pred'
SCORE_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/score'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
os.makedirs(PRED_DIR, exist_ok=True)
os.makedirs(SCORE_DIR, exist_ok=True)

# copy config
# shutil.copy('./config.yaml', OUTPUT_ROOT)

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## make path list

# %% [markdown]
# - __train_paths__ ([dict]): Each Machine Type
#     - __ToyCar__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) :paths
#     - __ToyTrain__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) : paths
#     - ...

# %%
percent = 0.1

# %%
dev_paths = {}

for machine_type in machine_types:
    # dev train
    dev_train_paths = [f"{dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/train")]
    dev_train_paths = sorted(dev_train_paths)
    
    print(f'Machine {machine_type}', end=',')
    print(f'dev_train_size : {len(dev_train_paths)}', end=', ')
    dev_train_source_paths = [path for path in dev_train_paths if 'source' in path]
    print(f'source_size : {len(dev_train_source_paths)}', end=', ')
    dev_train_target_paths = [path for path in dev_train_paths if 'target' in path]
    print(f'target_size : {len(dev_train_target_paths)}', end=', ')
    # increse tgt
    num_increse_tgt = int(len(dev_train_source_paths) * percent)
    increse_dev_train_target_paths = dev_train_target_paths * num_increse_tgt
    # concat
    dev_train_paths = dev_train_source_paths + increse_dev_train_target_paths
    
    # add_dev train
    add_dev_paths = [f"{add_dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{add_dev_dir}/{machine_type}/train")]
    add_dev_paths = sorted(add_dev_paths)
    print(f'adddev_train_size : {len(add_dev_paths)}', end=', ')
    add_dev_source_paths = [path for path in add_dev_paths if 'source' in path]
    print(f'source_size : {len(add_dev_source_paths)}', end=', ')
    add_dev_target_paths = [path for path in add_dev_paths if 'target' in path]
    print(f'target_size : {len(add_dev_target_paths)}')
    # increse tgt
    num_increse_tgt = int(len(add_dev_source_paths) * percent)
    increse_add_dev_target_paths = add_dev_target_paths * num_increse_tgt
    # concat
    add_dev_paths = add_dev_source_paths + increse_add_dev_target_paths

    print('==============================================================')
    
    # dev_source valid
    dev_source_paths = [f"{dev_dir}/{machine_type}/source_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/source_test")]
    dev_source_paths = sorted(dev_source_paths)
    
    # dev_target valid
    dev_target_paths = [f"{dev_dir}/{machine_type}/target_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/target_test")]
    dev_target_paths = sorted(dev_target_paths)
    
    # bundle
    dev_paths[machine_type] = {}
    dev_paths[machine_type]['train'] = dev_train_paths + add_dev_paths
    dev_paths[machine_type]['valid_source'] = dev_source_paths
    dev_paths[machine_type]['valid_target'] = dev_target_paths
# Out:
# Machine pump,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine gearbox,dev_train_size : 3026, source_size : 3017, target_size : 9, adddev_train_size : 3114, source_size : 3105, target_size : 9
# ==============================================================
# Machine slider,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyCar,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine valve,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyTrain,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine fan,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================

# %%
machine_types
# Out:
# ['pump', 'gearbox', 'slider', 'ToyCar', 'valve', 'ToyTrain', 'fan']

# %%
#############################################################################
# run
#############################################################################
def run(machine_type, dev_paths):
    com.tic()
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dev_train_paths
    dataloaders_dict = modeler.make_dataloader(dev_paths, machine_type)
    # parameter setting
    logger.info('TRAINING')
    model = Model(n_out=36, n_centers=6)
    
    optimizer = torch.optim.Adam(model.parameters(),lr=1e-3)
    output_dict, model, pred_df, score_df = modeler.run_training(model, dataloaders_dict, writer, optimizer)
    
    # output
    feature_out_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
    model_out_path = f'{MODEL_DIR}/{machine_type}_model.pkl'
    pred_out_path = f'{PRED_DIR}/{machine_type}_pred.csv'
    score_out_path = f'{SCORE_DIR}/{machine_type}_pred.csv'
    # save
    pd.to_pickle(output_dict, feature_out_path)
    torch.save(model.state_dict(), model_out_path)
    pred_df.to_csv(pred_out_path)
    score_df.to_csv(score_out_path)
    logger.info(f'SAVE SUCCESS : {model_out_path}')
    
    com.toc()

# %%
#run(machine_types[0], dev_paths)

# %%
for machine_type in machine_types[4:]:
    run(machine_type, dev_paths)
# Out:
# 2021-10-21 04:31:15,187 - 00_train.py - INFO - TARGET MACHINE_TYPE: pump
# 2021-10-21 04:31:15,188 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-10-21 04:31:15,605 - 00_train.py - INFO - TRAINING
# use: cuda:0
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [05:13<00:00,  6.96s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [01:15<00:00,  7.97it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [01:14<00:00,  8.04it/s]
# 2021-10-21 04:39:36,480 - pytorch_modeler.py - INFO - epoch:1/100, tr_loss:17.501669, src_loss:7.866264, src_mean_auc:0.597000, tgt_loss:7.069182, tgt_mean_auc:0.533733, mean_auc:0.565367,
#                AUC      pAUC
# Source_0  0.654000  0.645263
# Source_1  0.623200  0.527368
# Source_2  0.513800  0.507368
# Target_0  0.576400  0.517895
# Target_1  0.531600  0.488947
# Target_2  0.493200  0.521579
# mean      0.565367  0.534737
# h_mean    0.559516  0.530491
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 04:40:27,037 - pytorch_modeler.py - INFO - epoch:2/100, tr_loss:12.314290, src_loss:7.866264, src_mean_auc:0.597000, tgt_loss:7.069182, tgt_mean_auc:0.533733, mean_auc:0.565367,
#                AUC      pAUC
# Source_0  0.654000  0.645263
# Source_1  0.623200  0.527368
# Source_2  0.513800  0.507368
# Target_0  0.576400  0.517895
# Target_1  0.531600  0.488947
# Target_2  0.493200  0.521579
# mean      0.565367  0.534737
# h_mean    0.559516  0.530491
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 04:41:17,565 - pytorch_modeler.py - INFO - epoch:3/100, tr_loss:9.804527, src_loss:7.866264, src_mean_auc:0.597000, tgt_loss:7.069182, tgt_mean_auc:0.533733, mean_auc:0.565367,
#                AUC      pAUC
# Source_0  0.654000  0.645263
# Source_1  0.623200  0.527368
# Source_2  0.513800  0.507368
# Target_0  0.576400  0.517895
# Target_1  0.531600  0.488947
# Target_2  0.493200  0.521579
# mean      0.565367  0.534737
# h_mean    0.559516  0.530491
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 04:42:08,151 - pytorch_modeler.py - INFO - epoch:4/100, tr_loss:8.329494, src_loss:7.866264, src_mean_auc:0.597000, tgt_loss:7.069182, tgt_mean_auc:0.533733, mean_auc:0.565367,
#                AUC      pAUC
# Source_0  0.654000  0.645263
# Source_1  0.623200  0.527368
# Source_2  0.513800  0.507368
# Target_0  0.576400  0.517895
# Target_1  0.531600  0.488947
# Target_2  0.493200  0.521579
# mean      0.565367  0.534737
# h_mean    0.559516  0.530491
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 04:42:58,806 - pytorch_modeler.py - INFO - epoch:5/100, tr_loss:7.028562, src_loss:7.866264, src_mean_auc:0.597000, tgt_loss:7.069182, tgt_mean_auc:0.533733, mean_auc:0.565367,
#                AUC      pAUC
# Source_0  0.654000  0.645263
# Source_1  0.623200  0.527368
# Source_2  0.513800  0.507368
# Target_0  0.576400  0.517895
# Target_1  0.531600  0.488947
# Target_2  0.493200  0.521579
# mean      0.565367  0.534737
# h_mean    0.559516  0.530491
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:51<00:00,  1.13s/it]
# 2021-10-21 04:43:49,876 - pytorch_modeler.py - INFO - epoch:6/100, tr_loss:6.017684, src_loss:7.866264, src_mean_auc:0.597000, tgt_loss:7.069182, tgt_mean_auc:0.533733, mean_auc:0.565367,
#                AUC      pAUC
# Source_0  0.654000  0.645263
# Source_1  0.623200  0.527368
# Source_2  0.513800  0.507368
# Target_0  0.576400  0.517895
# Target_1  0.531600  0.488947
# Target_2  0.493200  0.521579
# mean      0.565367  0.534737
# h_mean    0.559516  0.530491
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 04:44:40,307 - pytorch_modeler.py - INFO - epoch:7/100, tr_loss:5.246809, src_loss:7.866264, src_mean_auc:0.597000, tgt_loss:7.069182, tgt_mean_auc:0.533733, mean_auc:0.565367,
#                AUC      pAUC
# Source_0  0.654000  0.645263
# Source_1  0.623200  0.527368
# Source_2  0.513800  0.507368
# Target_0  0.576400  0.517895
# Target_1  0.531600  0.488947
# Target_2  0.493200  0.521579
# mean      0.565367  0.534737
# h_mean    0.559516  0.530491
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 04:45:30,773 - pytorch_modeler.py - INFO - epoch:8/100, tr_loss:4.720823, src_loss:7.866264, src_mean_auc:0.597000, tgt_loss:7.069182, tgt_mean_auc:0.533733, mean_auc:0.565367,
#                AUC      pAUC
# Source_0  0.654000  0.645263
# Source_1  0.623200  0.527368
# Source_2  0.513800  0.507368
# Target_0  0.576400  0.517895
# Target_1  0.531600  0.488947
# Target_2  0.493200  0.521579
# mean      0.565367  0.534737
# h_mean    0.559516  0.530491
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 04:46:21,340 - pytorch_modeler.py - INFO - epoch:9/100, tr_loss:4.287502, src_loss:7.866264, src_mean_auc:0.597000, tgt_loss:7.069182, tgt_mean_auc:0.533733, mean_auc:0.565367,
#                AUC      pAUC
# Source_0  0.654000  0.645263
# Source_1  0.623200  0.527368
# Source_2  0.513800  0.507368
# Target_0  0.576400  0.517895
# Target_1  0.531600  0.488947
# Target_2  0.493200  0.521579
# mean      0.565367  0.534737
# h_mean    0.559516  0.530491
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.13s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [01:07<00:00,  8.94it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [01:06<00:00,  8.99it/s]
# 2021-10-21 04:49:25,942 - pytorch_modeler.py - INFO - epoch:10/100, tr_loss:3.993318, src_loss:6.834456, src_mean_auc:0.802967, tgt_loss:5.718914, tgt_mean_auc:0.684633, mean_auc:0.743800,
#                AUC      pAUC
# Source_0  0.765000  0.693684
# Source_1  0.943800  0.852632
# Source_2  0.700100  0.611053
# Target_0  0.779700  0.609474
# Target_1  0.694400  0.673684
# Target_2  0.579800  0.545263
# mean      0.743800  0.664298
# h_mean    0.727937  0.651462
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 04:50:16,387 - pytorch_modeler.py - INFO - epoch:11/100, tr_loss:4.061291, src_loss:6.834456, src_mean_auc:0.802967, tgt_loss:5.718914, tgt_mean_auc:0.684633, mean_auc:0.743800,
#                AUC      pAUC
# Source_0  0.765000  0.693684
# Source_1  0.943800  0.852632
# Source_2  0.700100  0.611053
# Target_0  0.779700  0.609474
# Target_1  0.694400  0.673684
# Target_2  0.579800  0.545263
# mean      0.743800  0.664298
# h_mean    0.727937  0.651462
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 04:51:06,769 - pytorch_modeler.py - INFO - epoch:12/100, tr_loss:3.687500, src_loss:6.834456, src_mean_auc:0.802967, tgt_loss:5.718914, tgt_mean_auc:0.684633, mean_auc:0.743800,
#                AUC      pAUC
# Source_0  0.765000  0.693684
# Source_1  0.943800  0.852632
# Source_2  0.700100  0.611053
# Target_0  0.779700  0.609474
# Target_1  0.694400  0.673684
# Target_2  0.579800  0.545263
# mean      0.743800  0.664298
# h_mean    0.727937  0.651462
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 04:51:57,198 - pytorch_modeler.py - INFO - epoch:13/100, tr_loss:3.423516, src_loss:6.834456, src_mean_auc:0.802967, tgt_loss:5.718914, tgt_mean_auc:0.684633, mean_auc:0.743800,
#                AUC      pAUC
# Source_0  0.765000  0.693684
# Source_1  0.943800  0.852632
# Source_2  0.700100  0.611053
# Target_0  0.779700  0.609474
# Target_1  0.694400  0.673684
# Target_2  0.579800  0.545263
# mean      0.743800  0.664298
# h_mean    0.727937  0.651462
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 04:52:47,630 - pytorch_modeler.py - INFO - epoch:14/100, tr_loss:3.172506, src_loss:6.834456, src_mean_auc:0.802967, tgt_loss:5.718914, tgt_mean_auc:0.684633, mean_auc:0.743800,
#                AUC      pAUC
# Source_0  0.765000  0.693684
# Source_1  0.943800  0.852632
# Source_2  0.700100  0.611053
# Target_0  0.779700  0.609474
# Target_1  0.694400  0.673684
# Target_2  0.579800  0.545263
# mean      0.743800  0.664298
# h_mean    0.727937  0.651462
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 04:53:38,205 - pytorch_modeler.py - INFO - epoch:15/100, tr_loss:3.026704, src_loss:6.834456, src_mean_auc:0.802967, tgt_loss:5.718914, tgt_mean_auc:0.684633, mean_auc:0.743800,
#                AUC      pAUC
# Source_0  0.765000  0.693684
# Source_1  0.943800  0.852632
# Source_2  0.700100  0.611053
# Target_0  0.779700  0.609474
# Target_1  0.694400  0.673684
# Target_2  0.579800  0.545263
# mean      0.743800  0.664298
# h_mean    0.727937  0.651462
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 04:54:28,424 - pytorch_modeler.py - INFO - epoch:16/100, tr_loss:2.881941, src_loss:6.834456, src_mean_auc:0.802967, tgt_loss:5.718914, tgt_mean_auc:0.684633, mean_auc:0.743800,
#                AUC      pAUC
# Source_0  0.765000  0.693684
# Source_1  0.943800  0.852632
# Source_2  0.700100  0.611053
# Target_0  0.779700  0.609474
# Target_1  0.694400  0.673684
# Target_2  0.579800  0.545263
# mean      0.743800  0.664298
# h_mean    0.727937  0.651462
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 04:55:18,998 - pytorch_modeler.py - INFO - epoch:17/100, tr_loss:2.718202, src_loss:6.834456, src_mean_auc:0.802967, tgt_loss:5.718914, tgt_mean_auc:0.684633, mean_auc:0.743800,
#                AUC      pAUC
# Source_0  0.765000  0.693684
# Source_1  0.943800  0.852632
# Source_2  0.700100  0.611053
# Target_0  0.779700  0.609474
# Target_1  0.694400  0.673684
# Target_2  0.579800  0.545263
# mean      0.743800  0.664298
# h_mean    0.727937  0.651462
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 04:56:09,428 - pytorch_modeler.py - INFO - epoch:18/100, tr_loss:2.612883, src_loss:6.834456, src_mean_auc:0.802967, tgt_loss:5.718914, tgt_mean_auc:0.684633, mean_auc:0.743800,
#                AUC      pAUC
# Source_0  0.765000  0.693684
# Source_1  0.943800  0.852632
# Source_2  0.700100  0.611053
# Target_0  0.779700  0.609474
# Target_1  0.694400  0.673684
# Target_2  0.579800  0.545263
# mean      0.743800  0.664298
# h_mean    0.727937  0.651462
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 04:56:59,801 - pytorch_modeler.py - INFO - epoch:19/100, tr_loss:2.610221, src_loss:6.834456, src_mean_auc:0.802967, tgt_loss:5.718914, tgt_mean_auc:0.684633, mean_auc:0.743800,
#                AUC      pAUC
# Source_0  0.765000  0.693684
# Source_1  0.943800  0.852632
# Source_2  0.700100  0.611053
# Target_0  0.779700  0.609474
# Target_1  0.694400  0.673684
# Target_2  0.579800  0.545263
# mean      0.743800  0.664298
# h_mean    0.727937  0.651462
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [01:06<00:00,  8.97it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [01:06<00:00,  9.01it/s]
# 2021-10-21 05:00:03,602 - pytorch_modeler.py - INFO - epoch:20/100, tr_loss:2.455868, src_loss:6.185760, src_mean_auc:0.808433, tgt_loss:4.913176, tgt_mean_auc:0.745333, mean_auc:0.776883,
#                AUC      pAUC
# Source_0  0.768200  0.603158
# Source_1  0.964200  0.860000
# Source_2  0.692900  0.553158
# Target_0  0.759200  0.660000
# Target_1  0.870700  0.730000
# Target_2  0.606100  0.550000
# mean      0.776883  0.659386
# h_mean    0.759719  0.642968
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 05:00:53,902 - pytorch_modeler.py - INFO - epoch:21/100, tr_loss:2.384168, src_loss:6.185760, src_mean_auc:0.808433, tgt_loss:4.913176, tgt_mean_auc:0.745333, mean_auc:0.776883,
#                AUC      pAUC
# Source_0  0.768200  0.603158
# Source_1  0.964200  0.860000
# Source_2  0.692900  0.553158
# Target_0  0.759200  0.660000
# Target_1  0.870700  0.730000
# Target_2  0.606100  0.550000
# mean      0.776883  0.659386
# h_mean    0.759719  0.642968
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 05:01:44,537 - pytorch_modeler.py - INFO - epoch:22/100, tr_loss:2.287342, src_loss:6.185760, src_mean_auc:0.808433, tgt_loss:4.913176, tgt_mean_auc:0.745333, mean_auc:0.776883,
#                AUC      pAUC
# Source_0  0.768200  0.603158
# Source_1  0.964200  0.860000
# Source_2  0.692900  0.553158
# Target_0  0.759200  0.660000
# Target_1  0.870700  0.730000
# Target_2  0.606100  0.550000
# mean      0.776883  0.659386
# h_mean    0.759719  0.642968
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.13s/it]
# 2021-10-21 05:02:35,347 - pytorch_modeler.py - INFO - epoch:23/100, tr_loss:2.213718, src_loss:6.185760, src_mean_auc:0.808433, tgt_loss:4.913176, tgt_mean_auc:0.745333, mean_auc:0.776883,
#                AUC      pAUC
# Source_0  0.768200  0.603158
# Source_1  0.964200  0.860000
# Source_2  0.692900  0.553158
# Target_0  0.759200  0.660000
# Target_1  0.870700  0.730000
# Target_2  0.606100  0.550000
# mean      0.776883  0.659386
# h_mean    0.759719  0.642968
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 05:03:25,756 - pytorch_modeler.py - INFO - epoch:24/100, tr_loss:2.209577, src_loss:6.185760, src_mean_auc:0.808433, tgt_loss:4.913176, tgt_mean_auc:0.745333, mean_auc:0.776883,
#                AUC      pAUC
# Source_0  0.768200  0.603158
# Source_1  0.964200  0.860000
# Source_2  0.692900  0.553158
# Target_0  0.759200  0.660000
# Target_1  0.870700  0.730000
# Target_2  0.606100  0.550000
# mean      0.776883  0.659386
# h_mean    0.759719  0.642968
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.11s/it]
# 2021-10-21 05:04:15,814 - pytorch_modeler.py - INFO - epoch:25/100, tr_loss:2.093183, src_loss:6.185760, src_mean_auc:0.808433, tgt_loss:4.913176, tgt_mean_auc:0.745333, mean_auc:0.776883,
#                AUC      pAUC
# Source_0  0.768200  0.603158
# Source_1  0.964200  0.860000
# Source_2  0.692900  0.553158
# Target_0  0.759200  0.660000
# Target_1  0.870700  0.730000
# Target_2  0.606100  0.550000
# mean      0.776883  0.659386
# h_mean    0.759719  0.642968
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.11s/it]
# 2021-10-21 05:05:06,000 - pytorch_modeler.py - INFO - epoch:26/100, tr_loss:2.133802, src_loss:6.185760, src_mean_auc:0.808433, tgt_loss:4.913176, tgt_mean_auc:0.745333, mean_auc:0.776883,
#                AUC      pAUC
# Source_0  0.768200  0.603158
# Source_1  0.964200  0.860000
# Source_2  0.692900  0.553158
# Target_0  0.759200  0.660000
# Target_1  0.870700  0.730000
# Target_2  0.606100  0.550000
# mean      0.776883  0.659386
# h_mean    0.759719  0.642968
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:05:55,554 - pytorch_modeler.py - INFO - epoch:27/100, tr_loss:2.026892, src_loss:6.185760, src_mean_auc:0.808433, tgt_loss:4.913176, tgt_mean_auc:0.745333, mean_auc:0.776883,
#                AUC      pAUC
# Source_0  0.768200  0.603158
# Source_1  0.964200  0.860000
# Source_2  0.692900  0.553158
# Target_0  0.759200  0.660000
# Target_1  0.870700  0.730000
# Target_2  0.606100  0.550000
# mean      0.776883  0.659386
# h_mean    0.759719  0.642968
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 05:06:45,428 - pytorch_modeler.py - INFO - epoch:28/100, tr_loss:1.990267, src_loss:6.185760, src_mean_auc:0.808433, tgt_loss:4.913176, tgt_mean_auc:0.745333, mean_auc:0.776883,
#                AUC      pAUC
# Source_0  0.768200  0.603158
# Source_1  0.964200  0.860000
# Source_2  0.692900  0.553158
# Target_0  0.759200  0.660000
# Target_1  0.870700  0.730000
# Target_2  0.606100  0.550000
# mean      0.776883  0.659386
# h_mean    0.759719  0.642968
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 05:07:35,352 - pytorch_modeler.py - INFO - epoch:29/100, tr_loss:1.899381, src_loss:6.185760, src_mean_auc:0.808433, tgt_loss:4.913176, tgt_mean_auc:0.745333, mean_auc:0.776883,
#                AUC      pAUC
# Source_0  0.768200  0.603158
# Source_1  0.964200  0.860000
# Source_2  0.692900  0.553158
# Target_0  0.759200  0.660000
# Target_1  0.870700  0.730000
# Target_2  0.606100  0.550000
# mean      0.776883  0.659386
# h_mean    0.759719  0.642968
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [01:06<00:00,  8.99it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [01:06<00:00,  9.04it/s]
# 2021-10-21 05:10:38,247 - pytorch_modeler.py - INFO - epoch:30/100, tr_loss:1.868961, src_loss:5.525629, src_mean_auc:0.807800, tgt_loss:4.330279, tgt_mean_auc:0.599467, mean_auc:0.703633,
#                AUC      pAUC
# Source_0  0.752500  0.604737
# Source_1  0.934000  0.895263
# Source_2  0.736900  0.572105
# Target_0  0.633400  0.569474
# Target_1  0.570500  0.666842
# Target_2  0.594500  0.540000
# mean      0.703633  0.641404
# h_mean    0.684126  0.623312
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:11:27,863 - pytorch_modeler.py - INFO - epoch:31/100, tr_loss:1.880247, src_loss:5.525629, src_mean_auc:0.807800, tgt_loss:4.330279, tgt_mean_auc:0.599467, mean_auc:0.703633,
#                AUC      pAUC
# Source_0  0.752500  0.604737
# Source_1  0.934000  0.895263
# Source_2  0.736900  0.572105
# Target_0  0.633400  0.569474
# Target_1  0.570500  0.666842
# Target_2  0.594500  0.540000
# mean      0.703633  0.641404
# h_mean    0.684126  0.623312
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 05:12:17,662 - pytorch_modeler.py - INFO - epoch:32/100, tr_loss:1.808871, src_loss:5.525629, src_mean_auc:0.807800, tgt_loss:4.330279, tgt_mean_auc:0.599467, mean_auc:0.703633,
#                AUC      pAUC
# Source_0  0.752500  0.604737
# Source_1  0.934000  0.895263
# Source_2  0.736900  0.572105
# Target_0  0.633400  0.569474
# Target_1  0.570500  0.666842
# Target_2  0.594500  0.540000
# mean      0.703633  0.641404
# h_mean    0.684126  0.623312
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:13:07,293 - pytorch_modeler.py - INFO - epoch:33/100, tr_loss:1.799851, src_loss:5.525629, src_mean_auc:0.807800, tgt_loss:4.330279, tgt_mean_auc:0.599467, mean_auc:0.703633,
#                AUC      pAUC
# Source_0  0.752500  0.604737
# Source_1  0.934000  0.895263
# Source_2  0.736900  0.572105
# Target_0  0.633400  0.569474
# Target_1  0.570500  0.666842
# Target_2  0.594500  0.540000
# mean      0.703633  0.641404
# h_mean    0.684126  0.623312
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 05:13:57,151 - pytorch_modeler.py - INFO - epoch:34/100, tr_loss:1.801784, src_loss:5.525629, src_mean_auc:0.807800, tgt_loss:4.330279, tgt_mean_auc:0.599467, mean_auc:0.703633,
#                AUC      pAUC
# Source_0  0.752500  0.604737
# Source_1  0.934000  0.895263
# Source_2  0.736900  0.572105
# Target_0  0.633400  0.569474
# Target_1  0.570500  0.666842
# Target_2  0.594500  0.540000
# mean      0.703633  0.641404
# h_mean    0.684126  0.623312
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 05:14:46,998 - pytorch_modeler.py - INFO - epoch:35/100, tr_loss:1.775189, src_loss:5.525629, src_mean_auc:0.807800, tgt_loss:4.330279, tgt_mean_auc:0.599467, mean_auc:0.703633,
#                AUC      pAUC
# Source_0  0.752500  0.604737
# Source_1  0.934000  0.895263
# Source_2  0.736900  0.572105
# Target_0  0.633400  0.569474
# Target_1  0.570500  0.666842
# Target_2  0.594500  0.540000
# mean      0.703633  0.641404
# h_mean    0.684126  0.623312
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:15:36,746 - pytorch_modeler.py - INFO - epoch:36/100, tr_loss:1.710078, src_loss:5.525629, src_mean_auc:0.807800, tgt_loss:4.330279, tgt_mean_auc:0.599467, mean_auc:0.703633,
#                AUC      pAUC
# Source_0  0.752500  0.604737
# Source_1  0.934000  0.895263
# Source_2  0.736900  0.572105
# Target_0  0.633400  0.569474
# Target_1  0.570500  0.666842
# Target_2  0.594500  0.540000
# mean      0.703633  0.641404
# h_mean    0.684126  0.623312
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 05:16:26,666 - pytorch_modeler.py - INFO - epoch:37/100, tr_loss:1.674403, src_loss:5.525629, src_mean_auc:0.807800, tgt_loss:4.330279, tgt_mean_auc:0.599467, mean_auc:0.703633,
#                AUC      pAUC
# Source_0  0.752500  0.604737
# Source_1  0.934000  0.895263
# Source_2  0.736900  0.572105
# Target_0  0.633400  0.569474
# Target_1  0.570500  0.666842
# Target_2  0.594500  0.540000
# mean      0.703633  0.641404
# h_mean    0.684126  0.623312
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 05:17:16,460 - pytorch_modeler.py - INFO - epoch:38/100, tr_loss:1.634143, src_loss:5.525629, src_mean_auc:0.807800, tgt_loss:4.330279, tgt_mean_auc:0.599467, mean_auc:0.703633,
#                AUC      pAUC
# Source_0  0.752500  0.604737
# Source_1  0.934000  0.895263
# Source_2  0.736900  0.572105
# Target_0  0.633400  0.569474
# Target_1  0.570500  0.666842
# Target_2  0.594500  0.540000
# mean      0.703633  0.641404
# h_mean    0.684126  0.623312
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:18:05,896 - pytorch_modeler.py - INFO - epoch:39/100, tr_loss:1.664902, src_loss:5.525629, src_mean_auc:0.807800, tgt_loss:4.330279, tgt_mean_auc:0.599467, mean_auc:0.703633,
#                AUC      pAUC
# Source_0  0.752500  0.604737
# Source_1  0.934000  0.895263
# Source_2  0.736900  0.572105
# Target_0  0.633400  0.569474
# Target_1  0.570500  0.666842
# Target_2  0.594500  0.540000
# mean      0.703633  0.641404
# h_mean    0.684126  0.623312
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [01:06<00:00,  9.01it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [01:06<00:00,  9.01it/s]
# 2021-10-21 05:21:08,821 - pytorch_modeler.py - INFO - epoch:40/100, tr_loss:1.624506, src_loss:4.882755, src_mean_auc:0.829667, tgt_loss:3.456560, tgt_mean_auc:0.624133, mean_auc:0.726900,
#                AUC      pAUC
# Source_0  0.767400  0.622105
# Source_1  0.982300  0.935263
# Source_2  0.739300  0.545263
# Target_0  0.701300  0.582632
# Target_1  0.560800  0.677368
# Target_2  0.610300  0.538421
# mean      0.726900  0.650175
# h_mean    0.704111  0.627577
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:21:58,456 - pytorch_modeler.py - INFO - epoch:41/100, tr_loss:1.611740, src_loss:4.882755, src_mean_auc:0.829667, tgt_loss:3.456560, tgt_mean_auc:0.624133, mean_auc:0.726900,
#                AUC      pAUC
# Source_0  0.767400  0.622105
# Source_1  0.982300  0.935263
# Source_2  0.739300  0.545263
# Target_0  0.701300  0.582632
# Target_1  0.560800  0.677368
# Target_2  0.610300  0.538421
# mean      0.726900  0.650175
# h_mean    0.704111  0.627577
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:22:47,885 - pytorch_modeler.py - INFO - epoch:42/100, tr_loss:1.536120, src_loss:4.882755, src_mean_auc:0.829667, tgt_loss:3.456560, tgt_mean_auc:0.624133, mean_auc:0.726900,
#                AUC      pAUC
# Source_0  0.767400  0.622105
# Source_1  0.982300  0.935263
# Source_2  0.739300  0.545263
# Target_0  0.701300  0.582632
# Target_1  0.560800  0.677368
# Target_2  0.610300  0.538421
# mean      0.726900  0.650175
# h_mean    0.704111  0.627577
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.11s/it]
# 2021-10-21 05:23:38,015 - pytorch_modeler.py - INFO - epoch:43/100, tr_loss:1.523270, src_loss:4.882755, src_mean_auc:0.829667, tgt_loss:3.456560, tgt_mean_auc:0.624133, mean_auc:0.726900,
#                AUC      pAUC
# Source_0  0.767400  0.622105
# Source_1  0.982300  0.935263
# Source_2  0.739300  0.545263
# Target_0  0.701300  0.582632
# Target_1  0.560800  0.677368
# Target_2  0.610300  0.538421
# mean      0.726900  0.650175
# h_mean    0.704111  0.627577
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 05:24:28,014 - pytorch_modeler.py - INFO - epoch:44/100, tr_loss:1.537407, src_loss:4.882755, src_mean_auc:0.829667, tgt_loss:3.456560, tgt_mean_auc:0.624133, mean_auc:0.726900,
#                AUC      pAUC
# Source_0  0.767400  0.622105
# Source_1  0.982300  0.935263
# Source_2  0.739300  0.545263
# Target_0  0.701300  0.582632
# Target_1  0.560800  0.677368
# Target_2  0.610300  0.538421
# mean      0.726900  0.650175
# h_mean    0.704111  0.627577
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 05:25:17,899 - pytorch_modeler.py - INFO - epoch:45/100, tr_loss:1.530519, src_loss:4.882755, src_mean_auc:0.829667, tgt_loss:3.456560, tgt_mean_auc:0.624133, mean_auc:0.726900,
#                AUC      pAUC
# Source_0  0.767400  0.622105
# Source_1  0.982300  0.935263
# Source_2  0.739300  0.545263
# Target_0  0.701300  0.582632
# Target_1  0.560800  0.677368
# Target_2  0.610300  0.538421
# mean      0.726900  0.650175
# h_mean    0.704111  0.627577
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:26:07,619 - pytorch_modeler.py - INFO - epoch:46/100, tr_loss:1.521456, src_loss:4.882755, src_mean_auc:0.829667, tgt_loss:3.456560, tgt_mean_auc:0.624133, mean_auc:0.726900,
#                AUC      pAUC
# Source_0  0.767400  0.622105
# Source_1  0.982300  0.935263
# Source_2  0.739300  0.545263
# Target_0  0.701300  0.582632
# Target_1  0.560800  0.677368
# Target_2  0.610300  0.538421
# mean      0.726900  0.650175
# h_mean    0.704111  0.627577
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:26:57,068 - pytorch_modeler.py - INFO - epoch:47/100, tr_loss:1.501300, src_loss:4.882755, src_mean_auc:0.829667, tgt_loss:3.456560, tgt_mean_auc:0.624133, mean_auc:0.726900,
#                AUC      pAUC
# Source_0  0.767400  0.622105
# Source_1  0.982300  0.935263
# Source_2  0.739300  0.545263
# Target_0  0.701300  0.582632
# Target_1  0.560800  0.677368
# Target_2  0.610300  0.538421
# mean      0.726900  0.650175
# h_mean    0.704111  0.627577
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 05:27:46,869 - pytorch_modeler.py - INFO - epoch:48/100, tr_loss:1.419818, src_loss:4.882755, src_mean_auc:0.829667, tgt_loss:3.456560, tgt_mean_auc:0.624133, mean_auc:0.726900,
#                AUC      pAUC
# Source_0  0.767400  0.622105
# Source_1  0.982300  0.935263
# Source_2  0.739300  0.545263
# Target_0  0.701300  0.582632
# Target_1  0.560800  0.677368
# Target_2  0.610300  0.538421
# mean      0.726900  0.650175
# h_mean    0.704111  0.627577
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 05:28:36,788 - pytorch_modeler.py - INFO - epoch:49/100, tr_loss:1.461339, src_loss:4.882755, src_mean_auc:0.829667, tgt_loss:3.456560, tgt_mean_auc:0.624133, mean_auc:0.726900,
#                AUC      pAUC
# Source_0  0.767400  0.622105
# Source_1  0.982300  0.935263
# Source_2  0.739300  0.545263
# Target_0  0.701300  0.582632
# Target_1  0.560800  0.677368
# Target_2  0.610300  0.538421
# mean      0.726900  0.650175
# h_mean    0.704111  0.627577
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [01:06<00:00,  8.99it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [01:06<00:00,  9.00it/s]
# 2021-10-21 05:31:39,960 - pytorch_modeler.py - INFO - epoch:50/100, tr_loss:1.474880, src_loss:5.192551, src_mean_auc:0.810700, tgt_loss:3.665795, tgt_mean_auc:0.619767, mean_auc:0.715233,
#                AUC      pAUC
# Source_0  0.753300  0.647895
# Source_1  0.973900  0.894211
# Source_2  0.704900  0.540526
# Target_0  0.677600  0.628421
# Target_1  0.581100  0.694737
# Target_2  0.600600  0.544211
# mean      0.715233  0.658333
# h_mean    0.694878  0.639657
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.09s/it]
# 2021-10-21 05:32:29,227 - pytorch_modeler.py - INFO - epoch:51/100, tr_loss:1.402040, src_loss:5.192551, src_mean_auc:0.810700, tgt_loss:3.665795, tgt_mean_auc:0.619767, mean_auc:0.715233,
#                AUC      pAUC
# Source_0  0.753300  0.647895
# Source_1  0.973900  0.894211
# Source_2  0.704900  0.540526
# Target_0  0.677600  0.628421
# Target_1  0.581100  0.694737
# Target_2  0.600600  0.544211
# mean      0.715233  0.658333
# h_mean    0.694878  0.639657
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:33:18,545 - pytorch_modeler.py - INFO - epoch:52/100, tr_loss:1.435063, src_loss:5.192551, src_mean_auc:0.810700, tgt_loss:3.665795, tgt_mean_auc:0.619767, mean_auc:0.715233,
#                AUC      pAUC
# Source_0  0.753300  0.647895
# Source_1  0.973900  0.894211
# Source_2  0.704900  0.540526
# Target_0  0.677600  0.628421
# Target_1  0.581100  0.694737
# Target_2  0.600600  0.544211
# mean      0.715233  0.658333
# h_mean    0.694878  0.639657
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:34:08,078 - pytorch_modeler.py - INFO - epoch:53/100, tr_loss:1.411353, src_loss:5.192551, src_mean_auc:0.810700, tgt_loss:3.665795, tgt_mean_auc:0.619767, mean_auc:0.715233,
#                AUC      pAUC
# Source_0  0.753300  0.647895
# Source_1  0.973900  0.894211
# Source_2  0.704900  0.540526
# Target_0  0.677600  0.628421
# Target_1  0.581100  0.694737
# Target_2  0.600600  0.544211
# mean      0.715233  0.658333
# h_mean    0.694878  0.639657
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:34:57,820 - pytorch_modeler.py - INFO - epoch:54/100, tr_loss:1.382909, src_loss:5.192551, src_mean_auc:0.810700, tgt_loss:3.665795, tgt_mean_auc:0.619767, mean_auc:0.715233,
#                AUC      pAUC
# Source_0  0.753300  0.647895
# Source_1  0.973900  0.894211
# Source_2  0.704900  0.540526
# Target_0  0.677600  0.628421
# Target_1  0.581100  0.694737
# Target_2  0.600600  0.544211
# mean      0.715233  0.658333
# h_mean    0.694878  0.639657
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:35:47,228 - pytorch_modeler.py - INFO - epoch:55/100, tr_loss:1.345572, src_loss:5.192551, src_mean_auc:0.810700, tgt_loss:3.665795, tgt_mean_auc:0.619767, mean_auc:0.715233,
#                AUC      pAUC
# Source_0  0.753300  0.647895
# Source_1  0.973900  0.894211
# Source_2  0.704900  0.540526
# Target_0  0.677600  0.628421
# Target_1  0.581100  0.694737
# Target_2  0.600600  0.544211
# mean      0.715233  0.658333
# h_mean    0.694878  0.639657
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:36:36,765 - pytorch_modeler.py - INFO - epoch:56/100, tr_loss:1.421541, src_loss:5.192551, src_mean_auc:0.810700, tgt_loss:3.665795, tgt_mean_auc:0.619767, mean_auc:0.715233,
#                AUC      pAUC
# Source_0  0.753300  0.647895
# Source_1  0.973900  0.894211
# Source_2  0.704900  0.540526
# Target_0  0.677600  0.628421
# Target_1  0.581100  0.694737
# Target_2  0.600600  0.544211
# mean      0.715233  0.658333
# h_mean    0.694878  0.639657
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 05:37:26,776 - pytorch_modeler.py - INFO - epoch:57/100, tr_loss:1.414385, src_loss:5.192551, src_mean_auc:0.810700, tgt_loss:3.665795, tgt_mean_auc:0.619767, mean_auc:0.715233,
#                AUC      pAUC
# Source_0  0.753300  0.647895
# Source_1  0.973900  0.894211
# Source_2  0.704900  0.540526
# Target_0  0.677600  0.628421
# Target_1  0.581100  0.694737
# Target_2  0.600600  0.544211
# mean      0.715233  0.658333
# h_mean    0.694878  0.639657
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.11s/it]
# 2021-10-21 05:38:16,875 - pytorch_modeler.py - INFO - epoch:58/100, tr_loss:1.390074, src_loss:5.192551, src_mean_auc:0.810700, tgt_loss:3.665795, tgt_mean_auc:0.619767, mean_auc:0.715233,
#                AUC      pAUC
# Source_0  0.753300  0.647895
# Source_1  0.973900  0.894211
# Source_2  0.704900  0.540526
# Target_0  0.677600  0.628421
# Target_1  0.581100  0.694737
# Target_2  0.600600  0.544211
# mean      0.715233  0.658333
# h_mean    0.694878  0.639657
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 05:39:06,734 - pytorch_modeler.py - INFO - epoch:59/100, tr_loss:1.342484, src_loss:5.192551, src_mean_auc:0.810700, tgt_loss:3.665795, tgt_mean_auc:0.619767, mean_auc:0.715233,
#                AUC      pAUC
# Source_0  0.753300  0.647895
# Source_1  0.973900  0.894211
# Source_2  0.704900  0.540526
# Target_0  0.677600  0.628421
# Target_1  0.581100  0.694737
# Target_2  0.600600  0.544211
# mean      0.715233  0.658333
# h_mean    0.694878  0.639657
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [01:06<00:00,  9.01it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [01:06<00:00,  9.01it/s]
# 2021-10-21 05:42:09,611 - pytorch_modeler.py - INFO - epoch:60/100, tr_loss:1.354948, src_loss:4.732939, src_mean_auc:0.803367, tgt_loss:3.049560, tgt_mean_auc:0.648333, mean_auc:0.725850,
#                AUC      pAUC
# Source_0  0.707200  0.615263
# Source_1  0.977900  0.916842
# Source_2  0.725000  0.556842
# Target_0  0.671300  0.633684
# Target_1  0.664300  0.732105
# Target_2  0.609400  0.550526
# mean      0.725850  0.667544
# h_mean    0.709901  0.647088
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:50<00:00,  1.12s/it]
# 2021-10-21 05:43:00,196 - pytorch_modeler.py - INFO - epoch:61/100, tr_loss:1.362972, src_loss:4.732939, src_mean_auc:0.803367, tgt_loss:3.049560, tgt_mean_auc:0.648333, mean_auc:0.725850,
#                AUC      pAUC
# Source_0  0.707200  0.615263
# Source_1  0.977900  0.916842
# Source_2  0.725000  0.556842
# Target_0  0.671300  0.633684
# Target_1  0.664300  0.732105
# Target_2  0.609400  0.550526
# mean      0.725850  0.667544
# h_mean    0.709901  0.647088
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:43:49,809 - pytorch_modeler.py - INFO - epoch:62/100, tr_loss:1.316520, src_loss:4.732939, src_mean_auc:0.803367, tgt_loss:3.049560, tgt_mean_auc:0.648333, mean_auc:0.725850,
#                AUC      pAUC
# Source_0  0.707200  0.615263
# Source_1  0.977900  0.916842
# Source_2  0.725000  0.556842
# Target_0  0.671300  0.633684
# Target_1  0.664300  0.732105
# Target_2  0.609400  0.550526
# mean      0.725850  0.667544
# h_mean    0.709901  0.647088
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 05:44:39,636 - pytorch_modeler.py - INFO - epoch:63/100, tr_loss:1.329507, src_loss:4.732939, src_mean_auc:0.803367, tgt_loss:3.049560, tgt_mean_auc:0.648333, mean_auc:0.725850,
#                AUC      pAUC
# Source_0  0.707200  0.615263
# Source_1  0.977900  0.916842
# Source_2  0.725000  0.556842
# Target_0  0.671300  0.633684
# Target_1  0.664300  0.732105
# Target_2  0.609400  0.550526
# mean      0.725850  0.667544
# h_mean    0.709901  0.647088
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:45:29,345 - pytorch_modeler.py - INFO - epoch:64/100, tr_loss:1.290545, src_loss:4.732939, src_mean_auc:0.803367, tgt_loss:3.049560, tgt_mean_auc:0.648333, mean_auc:0.725850,
#                AUC      pAUC
# Source_0  0.707200  0.615263
# Source_1  0.977900  0.916842
# Source_2  0.725000  0.556842
# Target_0  0.671300  0.633684
# Target_1  0.664300  0.732105
# Target_2  0.609400  0.550526
# mean      0.725850  0.667544
# h_mean    0.709901  0.647088
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:46:18,797 - pytorch_modeler.py - INFO - epoch:65/100, tr_loss:1.293285, src_loss:4.732939, src_mean_auc:0.803367, tgt_loss:3.049560, tgt_mean_auc:0.648333, mean_auc:0.725850,
#                AUC      pAUC
# Source_0  0.707200  0.615263
# Source_1  0.977900  0.916842
# Source_2  0.725000  0.556842
# Target_0  0.671300  0.633684
# Target_1  0.664300  0.732105
# Target_2  0.609400  0.550526
# mean      0.725850  0.667544
# h_mean    0.709901  0.647088
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 05:47:08,586 - pytorch_modeler.py - INFO - epoch:66/100, tr_loss:1.312498, src_loss:4.732939, src_mean_auc:0.803367, tgt_loss:3.049560, tgt_mean_auc:0.648333, mean_auc:0.725850,
#                AUC      pAUC
# Source_0  0.707200  0.615263
# Source_1  0.977900  0.916842
# Source_2  0.725000  0.556842
# Target_0  0.671300  0.633684
# Target_1  0.664300  0.732105
# Target_2  0.609400  0.550526
# mean      0.725850  0.667544
# h_mean    0.709901  0.647088
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 05:47:58,470 - pytorch_modeler.py - INFO - epoch:67/100, tr_loss:1.310984, src_loss:4.732939, src_mean_auc:0.803367, tgt_loss:3.049560, tgt_mean_auc:0.648333, mean_auc:0.725850,
#                AUC      pAUC
# Source_0  0.707200  0.615263
# Source_1  0.977900  0.916842
# Source_2  0.725000  0.556842
# Target_0  0.671300  0.633684
# Target_1  0.664300  0.732105
# Target_2  0.609400  0.550526
# mean      0.725850  0.667544
# h_mean    0.709901  0.647088
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:48:47,993 - pytorch_modeler.py - INFO - epoch:68/100, tr_loss:1.251217, src_loss:4.732939, src_mean_auc:0.803367, tgt_loss:3.049560, tgt_mean_auc:0.648333, mean_auc:0.725850,
#                AUC      pAUC
# Source_0  0.707200  0.615263
# Source_1  0.977900  0.916842
# Source_2  0.725000  0.556842
# Target_0  0.671300  0.633684
# Target_1  0.664300  0.732105
# Target_2  0.609400  0.550526
# mean      0.725850  0.667544
# h_mean    0.709901  0.647088
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:49:37,536 - pytorch_modeler.py - INFO - epoch:69/100, tr_loss:1.276111, src_loss:4.732939, src_mean_auc:0.803367, tgt_loss:3.049560, tgt_mean_auc:0.648333, mean_auc:0.725850,
#                AUC      pAUC
# Source_0  0.707200  0.615263
# Source_1  0.977900  0.916842
# Source_2  0.725000  0.556842
# Target_0  0.671300  0.633684
# Target_1  0.664300  0.732105
# Target_2  0.609400  0.550526
# mean      0.725850  0.667544
# h_mean    0.709901  0.647088
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [01:06<00:00,  9.00it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [01:06<00:00,  9.01it/s]
# 2021-10-21 05:52:40,442 - pytorch_modeler.py - INFO - epoch:70/100, tr_loss:1.220446, src_loss:4.620478, src_mean_auc:0.793067, tgt_loss:3.348653, tgt_mean_auc:0.648333, mean_auc:0.720700,
#                AUC      pAUC
# Source_0  0.712500  0.553158
# Source_1  0.995200  0.978421
# Source_2  0.671500  0.575789
# Target_0  0.669900  0.541053
# Target_1  0.704200  0.772632
# Target_2  0.570900  0.548947
# mean      0.720700  0.661667
# h_mean    0.700774  0.629538
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:53:29,860 - pytorch_modeler.py - INFO - epoch:71/100, tr_loss:1.246110, src_loss:4.620478, src_mean_auc:0.793067, tgt_loss:3.348653, tgt_mean_auc:0.648333, mean_auc:0.720700,
#                AUC      pAUC
# Source_0  0.712500  0.553158
# Source_1  0.995200  0.978421
# Source_2  0.671500  0.575789
# Target_0  0.669900  0.541053
# Target_1  0.704200  0.772632
# Target_2  0.570900  0.548947
# mean      0.720700  0.661667
# h_mean    0.700774  0.629538
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 05:54:19,818 - pytorch_modeler.py - INFO - epoch:72/100, tr_loss:1.254798, src_loss:4.620478, src_mean_auc:0.793067, tgt_loss:3.348653, tgt_mean_auc:0.648333, mean_auc:0.720700,
#                AUC      pAUC
# Source_0  0.712500  0.553158
# Source_1  0.995200  0.978421
# Source_2  0.671500  0.575789
# Target_0  0.669900  0.541053
# Target_1  0.704200  0.772632
# Target_2  0.570900  0.548947
# mean      0.720700  0.661667
# h_mean    0.700774  0.629538
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:55:09,410 - pytorch_modeler.py - INFO - epoch:73/100, tr_loss:1.281451, src_loss:4.620478, src_mean_auc:0.793067, tgt_loss:3.348653, tgt_mean_auc:0.648333, mean_auc:0.720700,
#                AUC      pAUC
# Source_0  0.712500  0.553158
# Source_1  0.995200  0.978421
# Source_2  0.671500  0.575789
# Target_0  0.669900  0.541053
# Target_1  0.704200  0.772632
# Target_2  0.570900  0.548947
# mean      0.720700  0.661667
# h_mean    0.700774  0.629538
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:55:59,006 - pytorch_modeler.py - INFO - epoch:74/100, tr_loss:1.241408, src_loss:4.620478, src_mean_auc:0.793067, tgt_loss:3.348653, tgt_mean_auc:0.648333, mean_auc:0.720700,
#                AUC      pAUC
# Source_0  0.712500  0.553158
# Source_1  0.995200  0.978421
# Source_2  0.671500  0.575789
# Target_0  0.669900  0.541053
# Target_1  0.704200  0.772632
# Target_2  0.570900  0.548947
# mean      0.720700  0.661667
# h_mean    0.700774  0.629538
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:56:48,750 - pytorch_modeler.py - INFO - epoch:75/100, tr_loss:1.222263, src_loss:4.620478, src_mean_auc:0.793067, tgt_loss:3.348653, tgt_mean_auc:0.648333, mean_auc:0.720700,
#                AUC      pAUC
# Source_0  0.712500  0.553158
# Source_1  0.995200  0.978421
# Source_2  0.671500  0.575789
# Target_0  0.669900  0.541053
# Target_1  0.704200  0.772632
# Target_2  0.570900  0.548947
# mean      0.720700  0.661667
# h_mean    0.700774  0.629538
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 05:57:38,514 - pytorch_modeler.py - INFO - epoch:76/100, tr_loss:1.223543, src_loss:4.620478, src_mean_auc:0.793067, tgt_loss:3.348653, tgt_mean_auc:0.648333, mean_auc:0.720700,
#                AUC      pAUC
# Source_0  0.712500  0.553158
# Source_1  0.995200  0.978421
# Source_2  0.671500  0.575789
# Target_0  0.669900  0.541053
# Target_1  0.704200  0.772632
# Target_2  0.570900  0.548947
# mean      0.720700  0.661667
# h_mean    0.700774  0.629538
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 05:58:28,084 - pytorch_modeler.py - INFO - epoch:77/100, tr_loss:1.244843, src_loss:4.620478, src_mean_auc:0.793067, tgt_loss:3.348653, tgt_mean_auc:0.648333, mean_auc:0.720700,
#                AUC      pAUC
# Source_0  0.712500  0.553158
# Source_1  0.995200  0.978421
# Source_2  0.671500  0.575789
# Target_0  0.669900  0.541053
# Target_1  0.704200  0.772632
# Target_2  0.570900  0.548947
# mean      0.720700  0.661667
# h_mean    0.700774  0.629538
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 05:59:17,942 - pytorch_modeler.py - INFO - epoch:78/100, tr_loss:1.219249, src_loss:4.620478, src_mean_auc:0.793067, tgt_loss:3.348653, tgt_mean_auc:0.648333, mean_auc:0.720700,
#                AUC      pAUC
# Source_0  0.712500  0.553158
# Source_1  0.995200  0.978421
# Source_2  0.671500  0.575789
# Target_0  0.669900  0.541053
# Target_1  0.704200  0.772632
# Target_2  0.570900  0.548947
# mean      0.720700  0.661667
# h_mean    0.700774  0.629538
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 2021-10-21 06:00:07,617 - pytorch_modeler.py - INFO - epoch:79/100, tr_loss:1.171266, src_loss:4.620478, src_mean_auc:0.793067, tgt_loss:3.348653, tgt_mean_auc:0.648333, mean_auc:0.720700,
#                AUC      pAUC
# Source_0  0.712500  0.553158
# Source_1  0.995200  0.978421
# Source_2  0.671500  0.575789
# Target_0  0.669900  0.541053
# Target_1  0.704200  0.772632
# Target_2  0.570900  0.548947
# mean      0.720700  0.661667
# h_mean    0.700774  0.629538
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.10s/it]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [01:06<00:00,  9.00it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [01:06<00:00,  9.01it/s]
# 2021-10-21 06:03:10,636 - pytorch_modeler.py - INFO - epoch:80/100, tr_loss:1.171175, src_loss:4.855036, src_mean_auc:0.811600, tgt_loss:3.635020, tgt_mean_auc:0.657367, mean_auc:0.734483,
#                AUC      pAUC
# Source_0  0.763100  0.647895
# Source_1  0.946000  0.910526
# Source_2  0.725700  0.557895
# Target_0  0.716000  0.593684
# Target_1  0.633300  0.653684
# Target_2  0.622800  0.555789
# mean      0.734483  0.653246
# h_mean    0.720562  0.635081
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 06:04:00,480 - pytorch_modeler.py - INFO - epoch:81/100, tr_loss:1.163116, src_loss:4.855036, src_mean_auc:0.811600, tgt_loss:3.635020, tgt_mean_auc:0.657367, mean_auc:0.734483,
#                AUC      pAUC
# Source_0  0.763100  0.647895
# Source_1  0.946000  0.910526
# Source_2  0.725700  0.557895
# Target_0  0.716000  0.593684
# Target_1  0.633300  0.653684
# Target_2  0.622800  0.555789
# mean      0.734483  0.653246
# h_mean    0.720562  0.635081
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 45/45 [00:49<00:00,  1.11s/it]
# 2021-10-21 06:04:50,472 - pytorch_modeler.py - INFO - epoch:82/100, tr_loss:1.217583, src_loss:4.855036, src_mean_auc:0.811600, tgt_loss:3.635020, tgt_mean_auc:0.657367, mean_auc:0.734483,
#                AUC      pAUC
# Source_0  0.763100  0.647895
# Source_1  0.946000  0.910526
# Source_2  0.725700  0.557895
# Target_0  0.716000  0.593684
# Target_1  0.633300  0.653684
# Target_2  0.622800  0.555789
# mean      0.734483  0.653246
# h_mean    0.720562  0.635081
#  76%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                    | 34/45 [00:37<00:12,  1.13s/it]

# %%
#run(machine_types[0], dev_paths)

# %% [markdown]
# # run

# %% [raw]
# # debug
# import dcase_util
# import pandas as pd
#
# sample = pd.read_pickle('/media/hiroki/HDD1TB/research/DCASE_experiments/domain_adaptation/exp2/extraction_features/ToyCar_features.pkl')
# sample = sample['val_src']
#
# src_pred_df = dcase_util.make_pred_df(sample['wav_name'], sample['section_label'], sample['domain_label'], sample['label'], sample['label'])
#
# df1 = dcase_util.calc_dcase2021_task2_score(src_pred_df, prefix='Source')
# df2 = dcase_util.calc_dcase2021_task2_score(src_pred_df, prefix='Target')
# score = pd.concat([df1, df2])
# mean = pd.DataFrame([score.mean()], index=['mean'])
# hmean = scipy.stats.hmean(score, axis=0)
# hmean = pd.DataFrame([hmean], columns=['AUC', 'pAUC'], index=['h_mean'])
# score = score.append([mean, hmean])
