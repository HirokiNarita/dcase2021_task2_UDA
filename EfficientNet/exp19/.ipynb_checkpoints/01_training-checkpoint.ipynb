# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter
import timm

#from torchvision.models import wide_resnet50_2, resnet18
#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
import common as com
import pytorch_modeler as modeler
from pytorch_model import EfficientNet_b1 as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %%
# effnet1 = timm.create_model('efficientnet_b1', pretrained=True)
# # M7:block[5], M8:block[6], M9:conv_head
# effnet1

# %% [markdown]
# ## load config and set logger

# %%
log_folder = config['IO_OPTION']['OUTPUT_ROOT']+'/{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_folder, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(42)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
dev_dir = INPUT_ROOT + "/dev_data"
add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = os.listdir(dev_dir)
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'

TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
PRED_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/pred'
SCORE_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/score'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
os.makedirs(PRED_DIR, exist_ok=True)
os.makedirs(SCORE_DIR, exist_ok=True)

# copy config
# shutil.copy('./config.yaml', OUTPUT_ROOT)

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## make path list

# %% [markdown]
# - __train_paths__ ([dict]): Each Machine Type
#     - __ToyCar__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) :paths
#     - __ToyTrain__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) : paths
#     - ...

# %%
percent = 0.1

# %%
dev_paths = {}

for machine_type in machine_types:
    # dev train
    dev_train_paths = [f"{dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/train")]
    dev_train_paths = sorted(dev_train_paths)
    
    print(f'Machine {machine_type}', end=',')
    print(f'dev_train_size : {len(dev_train_paths)}', end=', ')
    dev_train_source_paths = [path for path in dev_train_paths if 'source' in path]
    print(f'source_size : {len(dev_train_source_paths)}', end=', ')
    dev_train_target_paths = [path for path in dev_train_paths if 'target' in path]
    print(f'target_size : {len(dev_train_target_paths)}', end=', ')
    # increse tgt
    num_increse_tgt = int(len(dev_train_source_paths) * percent)
    increse_dev_train_target_paths = dev_train_target_paths * num_increse_tgt
    # concat
    dev_train_paths = dev_train_source_paths + increse_dev_train_target_paths
    
    # add_dev train
    add_dev_paths = [f"{add_dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{add_dev_dir}/{machine_type}/train")]
    add_dev_paths = sorted(add_dev_paths)
    print(f'adddev_train_size : {len(add_dev_paths)}', end=', ')
    add_dev_source_paths = [path for path in add_dev_paths if 'source' in path]
    print(f'source_size : {len(add_dev_source_paths)}', end=', ')
    add_dev_target_paths = [path for path in add_dev_paths if 'target' in path]
    print(f'target_size : {len(add_dev_target_paths)}')
    # increse tgt
    num_increse_tgt = int(len(add_dev_source_paths) * percent)
    increse_add_dev_target_paths = add_dev_target_paths * num_increse_tgt
    # concat
    add_dev_paths = add_dev_source_paths + increse_add_dev_target_paths

    print('==============================================================')
    
    # dev_source valid
    dev_source_paths = [f"{dev_dir}/{machine_type}/source_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/source_test")]
    dev_source_paths = sorted(dev_source_paths)
    
    # dev_target valid
    dev_target_paths = [f"{dev_dir}/{machine_type}/target_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/target_test")]
    dev_target_paths = sorted(dev_target_paths)
    
    # bundle
    dev_paths[machine_type] = {}
    dev_paths[machine_type]['train'] = dev_train_paths + add_dev_paths
    dev_paths[machine_type]['valid_source'] = dev_source_paths
    dev_paths[machine_type]['valid_target'] = dev_target_paths
# Out:
# Machine pump,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine gearbox,dev_train_size : 3026, source_size : 3017, target_size : 9, adddev_train_size : 3114, source_size : 3105, target_size : 9
# ==============================================================
# Machine slider,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyCar,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine valve,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine ToyTrain,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================
# Machine fan,dev_train_size : 3009, source_size : 3000, target_size : 9, adddev_train_size : 3009, source_size : 3000, target_size : 9
# ==============================================================

# %%
machine_types
# Out:
# ['pump', 'gearbox', 'slider', 'ToyCar', 'valve', 'ToyTrain', 'fan']

# %%
#############################################################################
# run
#############################################################################
def run(machine_type, dev_paths):
    com.tic()
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dev_train_paths
    dataloaders_dict = modeler.make_dataloader(dev_paths, machine_type)
    # parameter setting
    logger.info('TRAINING')
    model = Model(n_out=36, n_centers=6)
    
    optimizer = torch.optim.Adam(model.parameters(),lr=1e-6)
    output_dict, model, pred_df, score_df = modeler.run_training(model, dataloaders_dict, writer, optimizer)
    
    # output
    feature_out_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
    model_out_path = f'{MODEL_DIR}/{machine_type}_model.pkl'
    pred_out_path = f'{PRED_DIR}/{machine_type}_pred.csv'
    score_out_path = f'{SCORE_DIR}/{machine_type}_pred.csv'
    # save
    pd.to_pickle(output_dict, feature_out_path)
    torch.save(model.state_dict(), model_out_path)
    pred_df.to_csv(pred_out_path)
    score_df.to_csv(score_out_path)
    logger.info(f'SAVE SUCCESS : {model_out_path}')
    
    com.toc()

# %%
#run(machine_types[0], dev_paths)

# %%
for machine_type in machine_types:
    run(machine_type, dev_paths)
# Out:
# 2021-10-23 10:53:42,830 - 00_train.py - INFO - TARGET MACHINE_TYPE: pump
# 2021-10-23 10:53:42,831 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-10-23 10:53:42,835 - 00_train.py - INFO - TRAINING
# use: cuda:0
# 100%|██████████| 45/45 [04:12<00:00,  5.61s/it]
# 100%|██████████| 600/600 [00:59<00:00, 10.05it/s]
# 100%|██████████| 600/600 [01:01<00:00,  9.73it/s]
# 2021-10-23 10:59:59,559 - pytorch_modeler.py - INFO - epoch:1/100, tr_loss:0.756839, src_loss:1.298645, src_mean_auc:0.386567, tgt_loss:0.936039, tgt_mean_auc:0.469333, mean_auc:0.427950,
#                AUC      pAUC
# Source_0  0.432200  0.487368
# Source_1  0.260100  0.473684
# Source_2  0.467400  0.490000
# Target_0  0.535100  0.505789
# Target_1  0.362700  0.477368
# Target_2  0.510200  0.498421
# mean      0.427950  0.488772
# h_mean    0.403122  0.488519
# 100%|██████████| 45/45 [00:36<00:00,  1.24it/s]
# 2021-10-23 11:00:35,813 - pytorch_modeler.py - INFO - epoch:2/100, tr_loss:0.344659, src_loss:1.298645, src_mean_auc:0.386567, tgt_loss:0.936039, tgt_mean_auc:0.469333, mean_auc:0.427950,
#                AUC      pAUC
# Source_0  0.432200  0.487368
# Source_1  0.260100  0.473684
# Source_2  0.467400  0.490000
# Target_0  0.535100  0.505789
# Target_1  0.362700  0.477368
# Target_2  0.510200  0.498421
# mean      0.427950  0.488772
# h_mean    0.403122  0.488519
# 100%|██████████| 45/45 [00:36<00:00,  1.24it/s]
# 2021-10-23 11:01:12,232 - pytorch_modeler.py - INFO - epoch:3/100, tr_loss:0.253942, src_loss:1.298645, src_mean_auc:0.386567, tgt_loss:0.936039, tgt_mean_auc:0.469333, mean_auc:0.427950,
#                AUC      pAUC
# Source_0  0.432200  0.487368
# Source_1  0.260100  0.473684
# Source_2  0.467400  0.490000
# Target_0  0.535100  0.505789
# Target_1  0.362700  0.477368
# Target_2  0.510200  0.498421
# mean      0.427950  0.488772
# h_mean    0.403122  0.488519
# 100%|██████████| 45/45 [00:36<00:00,  1.24it/s]
# 2021-10-23 11:01:48,417 - pytorch_modeler.py - INFO - epoch:4/100, tr_loss:0.217245, src_loss:1.298645, src_mean_auc:0.386567, tgt_loss:0.936039, tgt_mean_auc:0.469333, mean_auc:0.427950,
#                AUC      pAUC
# Source_0  0.432200  0.487368
# Source_1  0.260100  0.473684
# Source_2  0.467400  0.490000
# Target_0  0.535100  0.505789
# Target_1  0.362700  0.477368
# Target_2  0.510200  0.498421
# mean      0.427950  0.488772
# h_mean    0.403122  0.488519
# 100%|██████████| 45/45 [00:36<00:00,  1.25it/s]
# 2021-10-23 11:02:24,493 - pytorch_modeler.py - INFO - epoch:5/100, tr_loss:0.187284, src_loss:1.298645, src_mean_auc:0.386567, tgt_loss:0.936039, tgt_mean_auc:0.469333, mean_auc:0.427950,
#                AUC      pAUC
# Source_0  0.432200  0.487368
# Source_1  0.260100  0.473684
# Source_2  0.467400  0.490000
# Target_0  0.535100  0.505789
# Target_1  0.362700  0.477368
# Target_2  0.510200  0.498421
# mean      0.427950  0.488772
# h_mean    0.403122  0.488519
# 100%|██████████| 45/45 [00:36<00:00,  1.24it/s]
# 2021-10-23 11:03:00,827 - pytorch_modeler.py - INFO - epoch:6/100, tr_loss:0.183183, src_loss:1.298645, src_mean_auc:0.386567, tgt_loss:0.936039, tgt_mean_auc:0.469333, mean_auc:0.427950,
#                AUC      pAUC
# Source_0  0.432200  0.487368
# Source_1  0.260100  0.473684
# Source_2  0.467400  0.490000
# Target_0  0.535100  0.505789
# Target_1  0.362700  0.477368
# Target_2  0.510200  0.498421
# mean      0.427950  0.488772
# h_mean    0.403122  0.488519
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-23 11:03:36,813 - pytorch_modeler.py - INFO - epoch:7/100, tr_loss:0.166288, src_loss:1.298645, src_mean_auc:0.386567, tgt_loss:0.936039, tgt_mean_auc:0.469333, mean_auc:0.427950,
#                AUC      pAUC
# Source_0  0.432200  0.487368
# Source_1  0.260100  0.473684
# Source_2  0.467400  0.490000
# Target_0  0.535100  0.505789
# Target_1  0.362700  0.477368
# Target_2  0.510200  0.498421
# mean      0.427950  0.488772
# h_mean    0.403122  0.488519
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-23 11:04:12,349 - pytorch_modeler.py - INFO - epoch:8/100, tr_loss:0.141536, src_loss:1.298645, src_mean_auc:0.386567, tgt_loss:0.936039, tgt_mean_auc:0.469333, mean_auc:0.427950,
#                AUC      pAUC
# Source_0  0.432200  0.487368
# Source_1  0.260100  0.473684
# Source_2  0.467400  0.490000
# Target_0  0.535100  0.505789
# Target_1  0.362700  0.477368
# Target_2  0.510200  0.498421
# mean      0.427950  0.488772
# h_mean    0.403122  0.488519
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-23 11:04:48,333 - pytorch_modeler.py - INFO - epoch:9/100, tr_loss:0.130160, src_loss:1.298645, src_mean_auc:0.386567, tgt_loss:0.936039, tgt_mean_auc:0.469333, mean_auc:0.427950,
#                AUC      pAUC
# Source_0  0.432200  0.487368
# Source_1  0.260100  0.473684
# Source_2  0.467400  0.490000
# Target_0  0.535100  0.505789
# Target_1  0.362700  0.477368
# Target_2  0.510200  0.498421
# mean      0.427950  0.488772
# h_mean    0.403122  0.488519
# 100%|██████████| 45/45 [00:36<00:00,  1.24it/s]
# 100%|██████████| 600/600 [00:57<00:00, 10.39it/s]
# 100%|██████████| 600/600 [00:58<00:00, 10.24it/s]
# 2021-10-23 11:07:20,902 - pytorch_modeler.py - INFO - epoch:10/100, tr_loss:0.122501, src_loss:0.870578, src_mean_auc:0.743567, tgt_loss:0.498396, tgt_mean_auc:0.624733, mean_auc:0.684150,
#                AUC      pAUC
# Source_0  0.773600  0.646842
# Source_1  0.836900  0.753684
# Source_2  0.620200  0.563158
# Target_0  0.726300  0.646316
# Target_1  0.627400  0.598421
# Target_2  0.520500  0.512105
# mean      0.684150  0.620088
# h_mean    0.667269  0.611029
# 100%|██████████| 45/45 [00:36<00:00,  1.23it/s]
# 2021-10-23 11:07:57,371 - pytorch_modeler.py - INFO - epoch:11/100, tr_loss:0.115402, src_loss:0.870578, src_mean_auc:0.743567, tgt_loss:0.498396, tgt_mean_auc:0.624733, mean_auc:0.684150,
#                AUC      pAUC
# Source_0  0.773600  0.646842
# Source_1  0.836900  0.753684
# Source_2  0.620200  0.563158
# Target_0  0.726300  0.646316
# Target_1  0.627400  0.598421
# Target_2  0.520500  0.512105
# mean      0.684150  0.620088
# h_mean    0.667269  0.611029
# 100%|██████████| 45/45 [00:36<00:00,  1.25it/s]
# 2021-10-23 11:08:33,477 - pytorch_modeler.py - INFO - epoch:12/100, tr_loss:0.106986, src_loss:0.870578, src_mean_auc:0.743567, tgt_loss:0.498396, tgt_mean_auc:0.624733, mean_auc:0.684150,
#                AUC      pAUC
# Source_0  0.773600  0.646842
# Source_1  0.836900  0.753684
# Source_2  0.620200  0.563158
# Target_0  0.726300  0.646316
# Target_1  0.627400  0.598421
# Target_2  0.520500  0.512105
# mean      0.684150  0.620088
# h_mean    0.667269  0.611029
# 100%|██████████| 45/45 [00:36<00:00,  1.25it/s]
# 2021-10-23 11:09:09,572 - pytorch_modeler.py - INFO - epoch:13/100, tr_loss:0.100254, src_loss:0.870578, src_mean_auc:0.743567, tgt_loss:0.498396, tgt_mean_auc:0.624733, mean_auc:0.684150,
#                AUC      pAUC
# Source_0  0.773600  0.646842
# Source_1  0.836900  0.753684
# Source_2  0.620200  0.563158
# Target_0  0.726300  0.646316
# Target_1  0.627400  0.598421
# Target_2  0.520500  0.512105
# mean      0.684150  0.620088
# h_mean    0.667269  0.611029
# 100%|██████████| 45/45 [00:36<00:00,  1.24it/s]
# 2021-10-23 11:09:45,788 - pytorch_modeler.py - INFO - epoch:14/100, tr_loss:0.099499, src_loss:0.870578, src_mean_auc:0.743567, tgt_loss:0.498396, tgt_mean_auc:0.624733, mean_auc:0.684150,
#                AUC      pAUC
# Source_0  0.773600  0.646842
# Source_1  0.836900  0.753684
# Source_2  0.620200  0.563158
# Target_0  0.726300  0.646316
# Target_1  0.627400  0.598421
# Target_2  0.520500  0.512105
# mean      0.684150  0.620088
# h_mean    0.667269  0.611029
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-23 11:10:21,675 - pytorch_modeler.py - INFO - epoch:15/100, tr_loss:0.092943, src_loss:0.870578, src_mean_auc:0.743567, tgt_loss:0.498396, tgt_mean_auc:0.624733, mean_auc:0.684150,
#                AUC      pAUC
# Source_0  0.773600  0.646842
# Source_1  0.836900  0.753684
# Source_2  0.620200  0.563158
# Target_0  0.726300  0.646316
# Target_1  0.627400  0.598421
# Target_2  0.520500  0.512105
# mean      0.684150  0.620088
# h_mean    0.667269  0.611029
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-23 11:10:57,615 - pytorch_modeler.py - INFO - epoch:16/100, tr_loss:0.084270, src_loss:0.870578, src_mean_auc:0.743567, tgt_loss:0.498396, tgt_mean_auc:0.624733, mean_auc:0.684150,
#                AUC      pAUC
# Source_0  0.773600  0.646842
# Source_1  0.836900  0.753684
# Source_2  0.620200  0.563158
# Target_0  0.726300  0.646316
# Target_1  0.627400  0.598421
# Target_2  0.520500  0.512105
# mean      0.684150  0.620088
# h_mean    0.667269  0.611029
# 100%|██████████| 45/45 [00:36<00:00,  1.24it/s]
# 2021-10-23 11:11:33,877 - pytorch_modeler.py - INFO - epoch:17/100, tr_loss:0.080340, src_loss:0.870578, src_mean_auc:0.743567, tgt_loss:0.498396, tgt_mean_auc:0.624733, mean_auc:0.684150,
#                AUC      pAUC
# Source_0  0.773600  0.646842
# Source_1  0.836900  0.753684
# Source_2  0.620200  0.563158
# Target_0  0.726300  0.646316
# Target_1  0.627400  0.598421
# Target_2  0.520500  0.512105
# mean      0.684150  0.620088
# h_mean    0.667269  0.611029
# 100%|██████████| 45/45 [00:36<00:00,  1.25it/s]
# 2021-10-23 11:12:09,936 - pytorch_modeler.py - INFO - epoch:18/100, tr_loss:0.071852, src_loss:0.870578, src_mean_auc:0.743567, tgt_loss:0.498396, tgt_mean_auc:0.624733, mean_auc:0.684150,
#                AUC      pAUC
# Source_0  0.773600  0.646842
# Source_1  0.836900  0.753684
# Source_2  0.620200  0.563158
# Target_0  0.726300  0.646316
# Target_1  0.627400  0.598421
# Target_2  0.520500  0.512105
# mean      0.684150  0.620088
# h_mean    0.667269  0.611029
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-23 11:12:45,875 - pytorch_modeler.py - INFO - epoch:19/100, tr_loss:0.070748, src_loss:0.870578, src_mean_auc:0.743567, tgt_loss:0.498396, tgt_mean_auc:0.624733, mean_auc:0.684150,
#                AUC      pAUC
# Source_0  0.773600  0.646842
# Source_1  0.836900  0.753684
# Source_2  0.620200  0.563158
# Target_0  0.726300  0.646316
# Target_1  0.627400  0.598421
# Target_2  0.520500  0.512105
# mean      0.684150  0.620088
# h_mean    0.667269  0.611029
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 100%|██████████| 600/600 [00:57<00:00, 10.46it/s]
# 100%|██████████| 600/600 [00:58<00:00, 10.25it/s]
# 2021-10-23 11:15:17,577 - pytorch_modeler.py - INFO - epoch:20/100, tr_loss:0.078886, src_loss:0.722394, src_mean_auc:0.774933, tgt_loss:0.503619, tgt_mean_auc:0.684200, mean_auc:0.729567,
#                AUC      pAUC
# Source_0  0.730700  0.580526
# Source_1  0.886100  0.765789
# Source_2  0.708000  0.546316
# Target_0  0.757200  0.626316
# Target_1  0.725300  0.640000
# Target_2  0.570100  0.549474
# mean      0.729567  0.618070
# h_mean    0.717446  0.609885
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-23 11:15:53,505 - pytorch_modeler.py - INFO - epoch:21/100, tr_loss:0.068801, src_loss:0.722394, src_mean_auc:0.774933, tgt_loss:0.503619, tgt_mean_auc:0.684200, mean_auc:0.729567,
#                AUC      pAUC
# Source_0  0.730700  0.580526
# Source_1  0.886100  0.765789
# Source_2  0.708000  0.546316
# Target_0  0.757200  0.626316
# Target_1  0.725300  0.640000
# Target_2  0.570100  0.549474
# mean      0.729567  0.618070
# h_mean    0.717446  0.609885
# 100%|██████████| 45/45 [00:36<00:00,  1.24it/s]
# 2021-10-23 11:16:29,844 - pytorch_modeler.py - INFO - epoch:22/100, tr_loss:0.063641, src_loss:0.722394, src_mean_auc:0.774933, tgt_loss:0.503619, tgt_mean_auc:0.684200, mean_auc:0.729567,
#                AUC      pAUC
# Source_0  0.730700  0.580526
# Source_1  0.886100  0.765789
# Source_2  0.708000  0.546316
# Target_0  0.757200  0.626316
# Target_1  0.725300  0.640000
# Target_2  0.570100  0.549474
# mean      0.729567  0.618070
# h_mean    0.717446  0.609885
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-23 11:17:05,754 - pytorch_modeler.py - INFO - epoch:23/100, tr_loss:0.056378, src_loss:0.722394, src_mean_auc:0.774933, tgt_loss:0.503619, tgt_mean_auc:0.684200, mean_auc:0.729567,
#                AUC      pAUC
# Source_0  0.730700  0.580526
# Source_1  0.886100  0.765789
# Source_2  0.708000  0.546316
# Target_0  0.757200  0.626316
# Target_1  0.725300  0.640000
# Target_2  0.570100  0.549474
# mean      0.729567  0.618070
# h_mean    0.717446  0.609885
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-23 11:17:41,771 - pytorch_modeler.py - INFO - epoch:24/100, tr_loss:0.055203, src_loss:0.722394, src_mean_auc:0.774933, tgt_loss:0.503619, tgt_mean_auc:0.684200, mean_auc:0.729567,
#                AUC      pAUC
# Source_0  0.730700  0.580526
# Source_1  0.886100  0.765789
# Source_2  0.708000  0.546316
# Target_0  0.757200  0.626316
# Target_1  0.725300  0.640000
# Target_2  0.570100  0.549474
# mean      0.729567  0.618070
# h_mean    0.717446  0.609885
# 100%|██████████| 45/45 [00:36<00:00,  1.24it/s]
# 2021-10-23 11:18:17,959 - pytorch_modeler.py - INFO - epoch:25/100, tr_loss:0.055834, src_loss:0.722394, src_mean_auc:0.774933, tgt_loss:0.503619, tgt_mean_auc:0.684200, mean_auc:0.729567,
#                AUC      pAUC
# Source_0  0.730700  0.580526
# Source_1  0.886100  0.765789
# Source_2  0.708000  0.546316
# Target_0  0.757200  0.626316
# Target_1  0.725300  0.640000
# Target_2  0.570100  0.549474
# mean      0.729567  0.618070
# h_mean    0.717446  0.609885
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-23 11:18:53,971 - pytorch_modeler.py - INFO - epoch:26/100, tr_loss:0.049551, src_loss:0.722394, src_mean_auc:0.774933, tgt_loss:0.503619, tgt_mean_auc:0.684200, mean_auc:0.729567,
#                AUC      pAUC
# Source_0  0.730700  0.580526
# Source_1  0.886100  0.765789
# Source_2  0.708000  0.546316
# Target_0  0.757200  0.626316
# Target_1  0.725300  0.640000
# Target_2  0.570100  0.549474
# mean      0.729567  0.618070
# h_mean    0.717446  0.609885
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-23 11:19:29,998 - pytorch_modeler.py - INFO - epoch:27/100, tr_loss:0.057098, src_loss:0.722394, src_mean_auc:0.774933, tgt_loss:0.503619, tgt_mean_auc:0.684200, mean_auc:0.729567,
#                AUC      pAUC
# Source_0  0.730700  0.580526
# Source_1  0.886100  0.765789
# Source_2  0.708000  0.546316
# Target_0  0.757200  0.626316
# Target_1  0.725300  0.640000
# Target_2  0.570100  0.549474
# mean      0.729567  0.618070
# h_mean    0.717446  0.609885
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-23 11:20:05,632 - pytorch_modeler.py - INFO - epoch:28/100, tr_loss:0.051113, src_loss:0.722394, src_mean_auc:0.774933, tgt_loss:0.503619, tgt_mean_auc:0.684200, mean_auc:0.729567,
#                AUC      pAUC
# Source_0  0.730700  0.580526
# Source_1  0.886100  0.765789
# Source_2  0.708000  0.546316
# Target_0  0.757200  0.626316
# Target_1  0.725300  0.640000
# Target_2  0.570100  0.549474
# mean      0.729567  0.618070
# h_mean    0.717446  0.609885
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-23 11:20:41,378 - pytorch_modeler.py - INFO - epoch:29/100, tr_loss:0.050626, src_loss:0.722394, src_mean_auc:0.774933, tgt_loss:0.503619, tgt_mean_auc:0.684200, mean_auc:0.729567,
#                AUC      pAUC
# Source_0  0.730700  0.580526
# Source_1  0.886100  0.765789
# Source_2  0.708000  0.546316
# Target_0  0.757200  0.626316
# Target_1  0.725300  0.640000
# Target_2  0.570100  0.549474
# mean      0.729567  0.618070
# h_mean    0.717446  0.609885
# 100%|██████████| 45/45 [00:36<00:00,  1.24it/s]
# 100%|██████████| 600/600 [00:57<00:00, 10.35it/s]
# 100%|██████████| 45/45 [00:36<00:00,  1.22it/s]s]
# 2021-10-23 11:24:26,615 - pytorch_modeler.py - INFO - epoch:32/100, tr_loss:0.044720, src_loss:0.816722, src_mean_auc:0.825900, tgt_loss:0.477993, tgt_mean_auc:0.679133, mean_auc:0.752517,
#                AUC      pAUC
# Source_0  0.798500  0.650000
# Source_1  0.947200  0.841053
# Source_2  0.732000  0.580526
# Target_0  0.722700  0.558947
# Target_1  0.755400  0.637368
# Target_2  0.559300  0.530526
# mean      0.752517  0.633070
# h_mean    0.734424  0.619005
# 100%|██████████| 45/45 [00:36<00:00,  1.24it/s]
# 2021-10-23 11:25:02,941 - pytorch_modeler.py - INFO - epoch:33/100, tr_loss:0.045199, src_loss:0.816722, src_mean_auc:0.825900, tgt_loss:0.477993, tgt_mean_auc:0.679133, mean_auc:0.752517,
#                AUC      pAUC
# Source_0  0.798500  0.650000
# Source_1  0.947200  0.841053
# Source_2  0.732000  0.580526
# Target_0  0.722700  0.558947
# Target_1  0.755400  0.637368
# Target_2  0.559300  0.530526
# mean      0.752517  0.633070
# h_mean    0.734424  0.619005
# 100%|██████████| 45/45 [00:36<00:00,  1.24it/s]
# 2021-10-23 11:25:39,173 - pytorch_modeler.py - INFO - epoch:34/100, tr_loss:0.038052, src_loss:0.816722, src_mean_auc:0.825900, tgt_loss:0.477993, tgt_mean_auc:0.679133, mean_auc:0.752517,
#                AUC      pAUC
# Source_0  0.798500  0.650000
# Source_1  0.947200  0.841053
# Source_2  0.732000  0.580526
# Target_0  0.722700  0.558947
# Target_1  0.755400  0.637368
# Target_2  0.559300  0.530526
# mean      0.752517  0.633070
# h_mean    0.734424  0.619005
# 100%|██████████| 45/45 [00:36<00:00,  1.24it/s]
# 2021-10-23 11:26:15,547 - pytorch_modeler.py - INFO - epoch:35/100, tr_loss:0.033468, src_loss:0.816722, src_mean_auc:0.825900, tgt_loss:0.477993, tgt_mean_auc:0.679133, mean_auc:0.752517,
#                AUC      pAUC
# Source_0  0.798500  0.650000
# Source_1  0.947200  0.841053
# Source_2  0.732000  0.580526
# Target_0  0.722700  0.558947
# Target_1  0.755400  0.637368
# Target_2  0.559300  0.530526
# mean      0.752517  0.633070
# h_mean    0.734424  0.619005
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-23 11:26:51,479 - pytorch_modeler.py - INFO - epoch:36/100, tr_loss:0.035687, src_loss:0.816722, src_mean_auc:0.825900, tgt_loss:0.477993, tgt_mean_auc:0.679133, mean_auc:0.752517,
#                AUC      pAUC
# Source_0  0.798500  0.650000
# Source_1  0.947200  0.841053
# Source_2  0.732000  0.580526
# Target_0  0.722700  0.558947
# Target_1  0.755400  0.637368
# Target_2  0.559300  0.530526
# mean      0.752517  0.633070
# h_mean    0.734424  0.619005
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-23 11:27:27,460 - pytorch_modeler.py - INFO - epoch:37/100, tr_loss:0.042667, src_loss:0.816722, src_mean_auc:0.825900, tgt_loss:0.477993, tgt_mean_auc:0.679133, mean_auc:0.752517,
#                AUC      pAUC
# Source_0  0.798500  0.650000
# Source_1  0.947200  0.841053
# Source_2  0.732000  0.580526
# Target_0  0.722700  0.558947
# Target_1  0.755400  0.637368
# Target_2  0.559300  0.530526
# mean      0.752517  0.633070
# h_mean    0.734424  0.619005
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-23 11:28:03,315 - pytorch_modeler.py - INFO - epoch:38/100, tr_loss:0.045623, src_loss:0.816722, src_mean_auc:0.825900, tgt_loss:0.477993, tgt_mean_auc:0.679133, mean_auc:0.752517,
#                AUC      pAUC
# Source_0  0.798500  0.650000
# Source_1  0.947200  0.841053
# Source_2  0.732000  0.580526
# Target_0  0.722700  0.558947
# Target_1  0.755400  0.637368
# Target_2  0.559300  0.530526
# mean      0.752517  0.633070
# h_mean    0.734424  0.619005
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-23 11:28:39,302 - pytorch_modeler.py - INFO - epoch:39/100, tr_loss:0.032794, src_loss:0.816722, src_mean_auc:0.825900, tgt_loss:0.477993, tgt_mean_auc:0.679133, mean_auc:0.752517,
#                AUC      pAUC
# Source_0  0.798500  0.650000
# Source_1  0.947200  0.841053
# Source_2  0.732000  0.580526
# Target_0  0.722700  0.558947
# Target_1  0.755400  0.637368
# Target_2  0.559300  0.530526
# mean      0.752517  0.633070
# h_mean    0.734424  0.619005
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 100%|██████████| 600/600 [00:57<00:00, 10.38it/s]
# 100%|██████████| 600/600 [00:58<00:00, 10.33it/s]
# 2021-10-23 11:31:11,183 - pytorch_modeler.py - INFO - epoch:40/100, tr_loss:0.034482, src_loss:0.903146, src_mean_auc:0.814867, tgt_loss:0.481336, tgt_mean_auc:0.673900, mean_auc:0.744383,
#                AUC      pAUC
# Source_0  0.753300  0.614737
# Source_1  0.974400  0.893684
# Source_2  0.716900  0.540000
# Target_0  0.705600  0.634211
# Target_1  0.723700  0.671053
# Target_2  0.592400  0.547368
# mean      0.744383  0.650175
# h_mean    0.728533  0.632151
# 100%|██████████| 45/45 [00:36<00:00,  1.25it/s]
# 2021-10-23 11:31:47,309 - pytorch_modeler.py - INFO - epoch:41/100, tr_loss:0.033551, src_loss:0.903146, src_mean_auc:0.814867, tgt_loss:0.481336, tgt_mean_auc:0.673900, mean_auc:0.744383,
#                AUC      pAUC
# Source_0  0.753300  0.614737
# Source_1  0.974400  0.893684
# Source_2  0.716900  0.540000
# Target_0  0.705600  0.634211
# Target_1  0.723700  0.671053
# Target_2  0.592400  0.547368
# mean      0.744383  0.650175
# h_mean    0.728533  0.632151
# 100%|██████████| 45/45 [00:36<00:00,  1.24it/s]
# 2021-10-23 11:32:23,635 - pytorch_modeler.py - INFO - epoch:42/100, tr_loss:0.032293, src_loss:0.903146, src_mean_auc:0.814867, tgt_loss:0.481336, tgt_mean_auc:0.673900, mean_auc:0.744383,
#                AUC      pAUC
# Source_0  0.753300  0.614737
# Source_1  0.974400  0.893684
# Source_2  0.716900  0.540000
# Target_0  0.705600  0.634211
# Target_1  0.723700  0.671053
# Target_2  0.592400  0.547368
# mean      0.744383  0.650175
# h_mean    0.728533  0.632151
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-23 11:32:59,613 - pytorch_modeler.py - INFO - epoch:43/100, tr_loss:0.032043, src_loss:0.903146, src_mean_auc:0.814867, tgt_loss:0.481336, tgt_mean_auc:0.673900, mean_auc:0.744383,
#                AUC      pAUC
# Source_0  0.753300  0.614737
# Source_1  0.974400  0.893684
# Source_2  0.716900  0.540000
# Target_0  0.705600  0.634211
# Target_1  0.723700  0.671053
# Target_2  0.592400  0.547368
# mean      0.744383  0.650175
# h_mean    0.728533  0.632151
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-23 11:33:35,533 - pytorch_modeler.py - INFO - epoch:44/100, tr_loss:0.034155, src_loss:0.903146, src_mean_auc:0.814867, tgt_loss:0.481336, tgt_mean_auc:0.673900, mean_auc:0.744383,
#                AUC      pAUC
# Source_0  0.753300  0.614737
# Source_1  0.974400  0.893684
# Source_2  0.716900  0.540000
# Target_0  0.705600  0.634211
# Target_1  0.723700  0.671053
# Target_2  0.592400  0.547368
# mean      0.744383  0.650175
# h_mean    0.728533  0.632151
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-23 11:34:11,222 - pytorch_modeler.py - INFO - epoch:45/100, tr_loss:0.025604, src_loss:0.903146, src_mean_auc:0.814867, tgt_loss:0.481336, tgt_mean_auc:0.673900, mean_auc:0.744383,
#                AUC      pAUC
# Source_0  0.753300  0.614737
# Source_1  0.974400  0.893684
# Source_2  0.716900  0.540000
# Target_0  0.705600  0.634211
# Target_1  0.723700  0.671053
# Target_2  0.592400  0.547368
# mean      0.744383  0.650175
# h_mean    0.728533  0.632151
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-23 11:34:46,981 - pytorch_modeler.py - INFO - epoch:46/100, tr_loss:0.025925, src_loss:0.903146, src_mean_auc:0.814867, tgt_loss:0.481336, tgt_mean_auc:0.673900, mean_auc:0.744383,
#                AUC      pAUC
# Source_0  0.753300  0.614737
# Source_1  0.974400  0.893684
# Source_2  0.716900  0.540000
# Target_0  0.705600  0.634211
# Target_1  0.723700  0.671053
# Target_2  0.592400  0.547368
# mean      0.744383  0.650175
# h_mean    0.728533  0.632151
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-23 11:35:22,731 - pytorch_modeler.py - INFO - epoch:47/100, tr_loss:0.029543, src_loss:0.903146, src_mean_auc:0.814867, tgt_loss:0.481336, tgt_mean_auc:0.673900, mean_auc:0.744383,
#                AUC      pAUC
# Source_0  0.753300  0.614737
# Source_1  0.974400  0.893684
# Source_2  0.716900  0.540000
# Target_0  0.705600  0.634211
# Target_1  0.723700  0.671053
# Target_2  0.592400  0.547368
# mean      0.744383  0.650175
# h_mean    0.728533  0.632151
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-23 11:35:58,303 - pytorch_modeler.py - INFO - epoch:48/100, tr_loss:0.034300, src_loss:0.903146, src_mean_auc:0.814867, tgt_loss:0.481336, tgt_mean_auc:0.673900, mean_auc:0.744383,
#                AUC      pAUC
# Source_0  0.753300  0.614737
# Source_1  0.974400  0.893684
# Source_2  0.716900  0.540000
# Target_0  0.705600  0.634211
# Target_1  0.723700  0.671053
# Target_2  0.592400  0.547368
# mean      0.744383  0.650175
# h_mean    0.728533  0.632151
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-23 11:36:34,020 - pytorch_modeler.py - INFO - epoch:49/100, tr_loss:0.028068, src_loss:0.903146, src_mean_auc:0.814867, tgt_loss:0.481336, tgt_mean_auc:0.673900, mean_auc:0.744383,
#                AUC      pAUC
# Source_0  0.753300  0.614737
# Source_1  0.974400  0.893684
# Source_2  0.716900  0.540000
# Target_0  0.705600  0.634211
# Target_1  0.723700  0.671053
# Target_2  0.592400  0.547368
# mean      0.744383  0.650175
# h_mean    0.728533  0.632151
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 100%|██████████| 600/600 [00:57<00:00, 10.49it/s]
# 100%|██████████| 600/600 [00:57<00:00, 10.39it/s]
# 2021-10-23 11:39:04,409 - pytorch_modeler.py - INFO - epoch:50/100, tr_loss:0.025447, src_loss:0.819451, src_mean_auc:0.812300, tgt_loss:0.441264, tgt_mean_auc:0.701000, mean_auc:0.756650,
#                AUC      pAUC
# Source_0  0.768700  0.601053
# Source_1  0.935800  0.797368
# Source_2  0.732400  0.568421
# Target_0  0.753900  0.615263
# Target_1  0.775900  0.653684
# Target_2  0.573200  0.538947
# mean      0.756650  0.629123
# h_mean    0.741223  0.619341
# 100%|██████████| 45/45 [00:34<00:00,  1.29it/s]
# 2021-10-23 11:39:39,303 - pytorch_modeler.py - INFO - epoch:51/100, tr_loss:0.027335, src_loss:0.819451, src_mean_auc:0.812300, tgt_loss:0.441264, tgt_mean_auc:0.701000, mean_auc:0.756650,
#                AUC      pAUC
# Source_0  0.768700  0.601053
# Source_1  0.935800  0.797368
# Source_2  0.732400  0.568421
# Target_0  0.753900  0.615263
# Target_1  0.775900  0.653684
# Target_2  0.573200  0.538947
# mean      0.756650  0.629123
# h_mean    0.741223  0.619341
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-23 11:40:15,082 - pytorch_modeler.py - INFO - epoch:52/100, tr_loss:0.025171, src_loss:0.819451, src_mean_auc:0.812300, tgt_loss:0.441264, tgt_mean_auc:0.701000, mean_auc:0.756650,
#                AUC      pAUC
# Source_0  0.768700  0.601053
# Source_1  0.935800  0.797368
# Source_2  0.732400  0.568421
# Target_0  0.753900  0.615263
# Target_1  0.775900  0.653684
# Target_2  0.573200  0.538947
# mean      0.756650  0.629123
# h_mean    0.741223  0.619341
# 100%|██████████| 45/45 [00:35<00:00,  1.25it/s]
# 2021-10-23 11:40:50,974 - pytorch_modeler.py - INFO - epoch:53/100, tr_loss:0.031051, src_loss:0.819451, src_mean_auc:0.812300, tgt_loss:0.441264, tgt_mean_auc:0.701000, mean_auc:0.756650,
#                AUC      pAUC
# Source_0  0.768700  0.601053
# Source_1  0.935800  0.797368
# Source_2  0.732400  0.568421
# Target_0  0.753900  0.615263
# Target_1  0.775900  0.653684
# Target_2  0.573200  0.538947
# mean      0.756650  0.629123
# h_mean    0.741223  0.619341
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-23 11:41:26,786 - pytorch_modeler.py - INFO - epoch:54/100, tr_loss:0.029308, src_loss:0.819451, src_mean_auc:0.812300, tgt_loss:0.441264, tgt_mean_auc:0.701000, mean_auc:0.756650,
#                AUC      pAUC
# Source_0  0.768700  0.601053
# Source_1  0.935800  0.797368
# Source_2  0.732400  0.568421
# Target_0  0.753900  0.615263
# Target_1  0.775900  0.653684
# Target_2  0.573200  0.538947
# mean      0.756650  0.629123
# h_mean    0.741223  0.619341
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-23 11:42:02,350 - pytorch_modeler.py - INFO - epoch:55/100, tr_loss:0.022431, src_loss:0.819451, src_mean_auc:0.812300, tgt_loss:0.441264, tgt_mean_auc:0.701000, mean_auc:0.756650,
#                AUC      pAUC
# Source_0  0.768700  0.601053
# Source_1  0.935800  0.797368
# Source_2  0.732400  0.568421
# Target_0  0.753900  0.615263
# Target_1  0.775900  0.653684
# Target_2  0.573200  0.538947
# mean      0.756650  0.629123
# h_mean    0.741223  0.619341
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-23 11:42:38,037 - pytorch_modeler.py - INFO - epoch:56/100, tr_loss:0.026384, src_loss:0.819451, src_mean_auc:0.812300, tgt_loss:0.441264, tgt_mean_auc:0.701000, mean_auc:0.756650,
#                AUC      pAUC
# Source_0  0.768700  0.601053
# Source_1  0.935800  0.797368
# Source_2  0.732400  0.568421
# Target_0  0.753900  0.615263
# Target_1  0.775900  0.653684
# Target_2  0.573200  0.538947
# mean      0.756650  0.629123
# h_mean    0.741223  0.619341
# 100%|██████████| 45/45 [00:34<00:00,  1.29it/s]
# 2021-10-23 11:43:12,955 - pytorch_modeler.py - INFO - epoch:57/100, tr_loss:0.023221, src_loss:0.819451, src_mean_auc:0.812300, tgt_loss:0.441264, tgt_mean_auc:0.701000, mean_auc:0.756650,
#                AUC      pAUC
# Source_0  0.768700  0.601053
# Source_1  0.935800  0.797368
# Source_2  0.732400  0.568421
# Target_0  0.753900  0.615263
# Target_1  0.775900  0.653684
# Target_2  0.573200  0.538947
# mean      0.756650  0.629123
# h_mean    0.741223  0.619341
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-23 11:43:48,041 - pytorch_modeler.py - INFO - epoch:58/100, tr_loss:0.021303, src_loss:0.819451, src_mean_auc:0.812300, tgt_loss:0.441264, tgt_mean_auc:0.701000, mean_auc:0.756650,
#                AUC      pAUC
# Source_0  0.768700  0.601053
# Source_1  0.935800  0.797368
# Source_2  0.732400  0.568421
# Target_0  0.753900  0.615263
# Target_1  0.775900  0.653684
# Target_2  0.573200  0.538947
# mean      0.756650  0.629123
# h_mean    0.741223  0.619341
# 100%|██████████| 45/45 [00:34<00:00,  1.29it/s]
# 2021-10-23 11:44:22,955 - pytorch_modeler.py - INFO - epoch:59/100, tr_loss:0.023024, src_loss:0.819451, src_mean_auc:0.812300, tgt_loss:0.441264, tgt_mean_auc:0.701000, mean_auc:0.756650,
#                AUC      pAUC
# Source_0  0.768700  0.601053
# Source_1  0.935800  0.797368
# Source_2  0.732400  0.568421
# Target_0  0.753900  0.615263
# Target_1  0.775900  0.653684
# Target_2  0.573200  0.538947
# mean      0.756650  0.629123
# h_mean    0.741223  0.619341
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 100%|██████████| 600/600 [00:58<00:00, 10.29it/s]
# 100%|██████████| 600/600 [00:58<00:00, 10.27it/s]
# 2021-10-23 11:46:54,782 - pytorch_modeler.py - INFO - epoch:60/100, tr_loss:0.021266, src_loss:0.815626, src_mean_auc:0.792500, tgt_loss:0.679585, tgt_mean_auc:0.642733, mean_auc:0.717617,
#                AUC      pAUC
# Source_0  0.759900  0.594211
# Source_1  0.927000  0.811053
# Source_2  0.690600  0.553684
# Target_0  0.677900  0.582105
# Target_1  0.755200  0.603684
# Target_2  0.495100  0.538947
# mean      0.717617  0.613947
# h_mean    0.692695  0.602905
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-23 11:47:30,329 - pytorch_modeler.py - INFO - epoch:61/100, tr_loss:0.025276, src_loss:0.815626, src_mean_auc:0.792500, tgt_loss:0.679585, tgt_mean_auc:0.642733, mean_auc:0.717617,
#                AUC      pAUC
# Source_0  0.759900  0.594211
# Source_1  0.927000  0.811053
# Source_2  0.690600  0.553684
# Target_0  0.677900  0.582105
# Target_1  0.755200  0.603684
# Target_2  0.495100  0.538947
# mean      0.717617  0.613947
# h_mean    0.692695  0.602905
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-23 11:48:05,854 - pytorch_modeler.py - INFO - epoch:62/100, tr_loss:0.024186, src_loss:0.815626, src_mean_auc:0.792500, tgt_loss:0.679585, tgt_mean_auc:0.642733, mean_auc:0.717617,
#                AUC      pAUC
# Source_0  0.759900  0.594211
# Source_1  0.927000  0.811053
# Source_2  0.690600  0.553684
# Target_0  0.677900  0.582105
# Target_1  0.755200  0.603684
# Target_2  0.495100  0.538947
# mean      0.717617  0.613947
# h_mean    0.692695  0.602905
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-23 11:48:41,184 - pytorch_modeler.py - INFO - epoch:63/100, tr_loss:0.019772, src_loss:0.815626, src_mean_auc:0.792500, tgt_loss:0.679585, tgt_mean_auc:0.642733, mean_auc:0.717617,
#                AUC      pAUC
# Source_0  0.759900  0.594211
# Source_1  0.927000  0.811053
# Source_2  0.690600  0.553684
# Target_0  0.677900  0.582105
# Target_1  0.755200  0.603684
# Target_2  0.495100  0.538947
# mean      0.717617  0.613947
# h_mean    0.692695  0.602905
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-23 11:49:16,534 - pytorch_modeler.py - INFO - epoch:64/100, tr_loss:0.019290, src_loss:0.815626, src_mean_auc:0.792500, tgt_loss:0.679585, tgt_mean_auc:0.642733, mean_auc:0.717617,
#                AUC      pAUC
# Source_0  0.759900  0.594211
# Source_1  0.927000  0.811053
# Source_2  0.690600  0.553684
# Target_0  0.677900  0.582105
# Target_1  0.755200  0.603684
# Target_2  0.495100  0.538947
# mean      0.717617  0.613947
# h_mean    0.692695  0.602905
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-23 11:49:51,586 - pytorch_modeler.py - INFO - epoch:65/100, tr_loss:0.018817, src_loss:0.815626, src_mean_auc:0.792500, tgt_loss:0.679585, tgt_mean_auc:0.642733, mean_auc:0.717617,
#                AUC      pAUC
# Source_0  0.759900  0.594211
# Source_1  0.927000  0.811053
# Source_2  0.690600  0.553684
# Target_0  0.677900  0.582105
# Target_1  0.755200  0.603684
# Target_2  0.495100  0.538947
# mean      0.717617  0.613947
# h_mean    0.692695  0.602905
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-23 11:50:26,687 - pytorch_modeler.py - INFO - epoch:66/100, tr_loss:0.020765, src_loss:0.815626, src_mean_auc:0.792500, tgt_loss:0.679585, tgt_mean_auc:0.642733, mean_auc:0.717617,
#                AUC      pAUC
# Source_0  0.759900  0.594211
# Source_1  0.927000  0.811053
# Source_2  0.690600  0.553684
# Target_0  0.677900  0.582105
# Target_1  0.755200  0.603684
# Target_2  0.495100  0.538947
# mean      0.717617  0.613947
# h_mean    0.692695  0.602905
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-23 11:51:02,327 - pytorch_modeler.py - INFO - epoch:67/100, tr_loss:0.018880, src_loss:0.815626, src_mean_auc:0.792500, tgt_loss:0.679585, tgt_mean_auc:0.642733, mean_auc:0.717617,
#                AUC      pAUC
# Source_0  0.759900  0.594211
# Source_1  0.927000  0.811053
# Source_2  0.690600  0.553684
# Target_0  0.677900  0.582105
# Target_1  0.755200  0.603684
# Target_2  0.495100  0.538947
# mean      0.717617  0.613947
# h_mean    0.692695  0.602905
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-23 11:51:37,412 - pytorch_modeler.py - INFO - epoch:68/100, tr_loss:0.025847, src_loss:0.815626, src_mean_auc:0.792500, tgt_loss:0.679585, tgt_mean_auc:0.642733, mean_auc:0.717617,
#                AUC      pAUC
# Source_0  0.759900  0.594211
# Source_1  0.927000  0.811053
# Source_2  0.690600  0.553684
# Target_0  0.677900  0.582105
# Target_1  0.755200  0.603684
# Target_2  0.495100  0.538947
# mean      0.717617  0.613947
# h_mean    0.692695  0.602905
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-23 11:52:12,917 - pytorch_modeler.py - INFO - epoch:69/100, tr_loss:0.017988, src_loss:0.815626, src_mean_auc:0.792500, tgt_loss:0.679585, tgt_mean_auc:0.642733, mean_auc:0.717617,
#                AUC      pAUC
# Source_0  0.759900  0.594211
# Source_1  0.927000  0.811053
# Source_2  0.690600  0.553684
# Target_0  0.677900  0.582105
# Target_1  0.755200  0.603684
# Target_2  0.495100  0.538947
# mean      0.717617  0.613947
# h_mean    0.692695  0.602905
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 100%|██████████| 600/600 [00:58<00:00, 10.27it/s]
# 100%|██████████| 600/600 [00:58<00:00, 10.27it/s]
# 2021-10-23 11:54:45,572 - pytorch_modeler.py - INFO - epoch:70/100, tr_loss:0.026274, src_loss:0.853684, src_mean_auc:0.793533, tgt_loss:0.640416, tgt_mean_auc:0.691767, mean_auc:0.742650,
#                AUC      pAUC
# Source_0  0.811800  0.718421
# Source_1  0.888400  0.808421
# Source_2  0.680400  0.566842
# Target_0  0.756900  0.656316
# Target_1  0.735900  0.628421
# Target_2  0.582500  0.556842
# mean      0.742650  0.655877
# h_mean    0.729575  0.644893
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-23 11:55:20,812 - pytorch_modeler.py - INFO - epoch:71/100, tr_loss:0.022621, src_loss:0.853684, src_mean_auc:0.793533, tgt_loss:0.640416, tgt_mean_auc:0.691767, mean_auc:0.742650,
#                AUC      pAUC
# Source_0  0.811800  0.718421
# Source_1  0.888400  0.808421
# Source_2  0.680400  0.566842
# Target_0  0.756900  0.656316
# Target_1  0.735900  0.628421
# Target_2  0.582500  0.556842
# mean      0.742650  0.655877
# h_mean    0.729575  0.644893
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-23 11:55:56,018 - pytorch_modeler.py - INFO - epoch:72/100, tr_loss:0.018320, src_loss:0.853684, src_mean_auc:0.793533, tgt_loss:0.640416, tgt_mean_auc:0.691767, mean_auc:0.742650,
#                AUC      pAUC
# Source_0  0.811800  0.718421
# Source_1  0.888400  0.808421
# Source_2  0.680400  0.566842
# Target_0  0.756900  0.656316
# Target_1  0.735900  0.628421
# Target_2  0.582500  0.556842
# mean      0.742650  0.655877
# h_mean    0.729575  0.644893
# 100%|██████████| 45/45 [00:35<00:00,  1.26it/s]
# 2021-10-23 11:56:31,674 - pytorch_modeler.py - INFO - epoch:73/100, tr_loss:0.015660, src_loss:0.853684, src_mean_auc:0.793533, tgt_loss:0.640416, tgt_mean_auc:0.691767, mean_auc:0.742650,
#                AUC      pAUC
# Source_0  0.811800  0.718421
# Source_1  0.888400  0.808421
# Source_2  0.680400  0.566842
# Target_0  0.756900  0.656316
# Target_1  0.735900  0.628421
# Target_2  0.582500  0.556842
# mean      0.742650  0.655877
# h_mean    0.729575  0.644893
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-23 11:57:06,880 - pytorch_modeler.py - INFO - epoch:74/100, tr_loss:0.017226, src_loss:0.853684, src_mean_auc:0.793533, tgt_loss:0.640416, tgt_mean_auc:0.691767, mean_auc:0.742650,
#                AUC      pAUC
# Source_0  0.811800  0.718421
# Source_1  0.888400  0.808421
# Source_2  0.680400  0.566842
# Target_0  0.756900  0.656316
# Target_1  0.735900  0.628421
# Target_2  0.582500  0.556842
# mean      0.742650  0.655877
# h_mean    0.729575  0.644893
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-23 11:57:42,435 - pytorch_modeler.py - INFO - epoch:75/100, tr_loss:0.016471, src_loss:0.853684, src_mean_auc:0.793533, tgt_loss:0.640416, tgt_mean_auc:0.691767, mean_auc:0.742650,
#                AUC      pAUC
# Source_0  0.811800  0.718421
# Source_1  0.888400  0.808421
# Source_2  0.680400  0.566842
# Target_0  0.756900  0.656316
# Target_1  0.735900  0.628421
# Target_2  0.582500  0.556842
# mean      0.742650  0.655877
# h_mean    0.729575  0.644893
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-23 11:58:17,818 - pytorch_modeler.py - INFO - epoch:76/100, tr_loss:0.022909, src_loss:0.853684, src_mean_auc:0.793533, tgt_loss:0.640416, tgt_mean_auc:0.691767, mean_auc:0.742650,
#                AUC      pAUC
# Source_0  0.811800  0.718421
# Source_1  0.888400  0.808421
# Source_2  0.680400  0.566842
# Target_0  0.756900  0.656316
# Target_1  0.735900  0.628421
# Target_2  0.582500  0.556842
# mean      0.742650  0.655877
# h_mean    0.729575  0.644893
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-23 11:58:52,890 - pytorch_modeler.py - INFO - epoch:77/100, tr_loss:0.021131, src_loss:0.853684, src_mean_auc:0.793533, tgt_loss:0.640416, tgt_mean_auc:0.691767, mean_auc:0.742650,
#                AUC      pAUC
# Source_0  0.811800  0.718421
# Source_1  0.888400  0.808421
# Source_2  0.680400  0.566842
# Target_0  0.756900  0.656316
# Target_1  0.735900  0.628421
# Target_2  0.582500  0.556842
# mean      0.742650  0.655877
# h_mean    0.729575  0.644893
# 100%|██████████| 45/45 [00:34<00:00,  1.31it/s]
# 2021-10-23 11:59:27,374 - pytorch_modeler.py - INFO - epoch:78/100, tr_loss:0.019872, src_loss:0.853684, src_mean_auc:0.793533, tgt_loss:0.640416, tgt_mean_auc:0.691767, mean_auc:0.742650,
#                AUC      pAUC
# Source_0  0.811800  0.718421
# Source_1  0.888400  0.808421
# Source_2  0.680400  0.566842
# Target_0  0.756900  0.656316
# Target_1  0.735900  0.628421
# Target_2  0.582500  0.556842
# mean      0.742650  0.655877
# h_mean    0.729575  0.644893
# 100%|██████████| 45/45 [00:34<00:00,  1.31it/s]
# 2021-10-23 12:00:01,876 - pytorch_modeler.py - INFO - epoch:79/100, tr_loss:0.018416, src_loss:0.853684, src_mean_auc:0.793533, tgt_loss:0.640416, tgt_mean_auc:0.691767, mean_auc:0.742650,
#                AUC      pAUC
# Source_0  0.811800  0.718421
# Source_1  0.888400  0.808421
# Source_2  0.680400  0.566842
# Target_0  0.756900  0.656316
# Target_1  0.735900  0.628421
# Target_2  0.582500  0.556842
# mean      0.742650  0.655877
# h_mean    0.729575  0.644893
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 100%|██████████| 600/600 [00:57<00:00, 10.36it/s]
# 100%|██████████| 600/600 [00:57<00:00, 10.38it/s]
# 2021-10-23 12:02:32,194 - pytorch_modeler.py - INFO - epoch:80/100, tr_loss:0.016371, src_loss:0.790182, src_mean_auc:0.803167, tgt_loss:0.547951, tgt_mean_auc:0.695200, mean_auc:0.749183,
#                AUC      pAUC
# Source_0  0.765500  0.610000
# Source_1  0.917900  0.822632
# Source_2  0.726100  0.581579
# Target_0  0.739400  0.595263
# Target_1  0.753900  0.612632
# Target_2  0.592300  0.543158
# mean      0.749183  0.627544
# h_mean    0.737081  0.616793
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-23 12:03:07,296 - pytorch_modeler.py - INFO - epoch:81/100, tr_loss:0.013194, src_loss:0.790182, src_mean_auc:0.803167, tgt_loss:0.547951, tgt_mean_auc:0.695200, mean_auc:0.749183,
#                AUC      pAUC
# Source_0  0.765500  0.610000
# Source_1  0.917900  0.822632
# Source_2  0.726100  0.581579
# Target_0  0.739400  0.595263
# Target_1  0.753900  0.612632
# Target_2  0.592300  0.543158
# mean      0.749183  0.627544
# h_mean    0.737081  0.616793
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-23 12:03:42,762 - pytorch_modeler.py - INFO - epoch:82/100, tr_loss:0.012966, src_loss:0.790182, src_mean_auc:0.803167, tgt_loss:0.547951, tgt_mean_auc:0.695200, mean_auc:0.749183,
#                AUC      pAUC
# Source_0  0.765500  0.610000
# Source_1  0.917900  0.822632
# Source_2  0.726100  0.581579
# Target_0  0.739400  0.595263
# Target_1  0.753900  0.612632
# Target_2  0.592300  0.543158
# mean      0.749183  0.627544
# h_mean    0.737081  0.616793
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-23 12:04:18,033 - pytorch_modeler.py - INFO - epoch:83/100, tr_loss:0.014564, src_loss:0.790182, src_mean_auc:0.803167, tgt_loss:0.547951, tgt_mean_auc:0.695200, mean_auc:0.749183,
#                AUC      pAUC
# Source_0  0.765500  0.610000
# Source_1  0.917900  0.822632
# Source_2  0.726100  0.581579
# Target_0  0.739400  0.595263
# Target_1  0.753900  0.612632
# Target_2  0.592300  0.543158
# mean      0.749183  0.627544
# h_mean    0.737081  0.616793
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-23 12:04:53,363 - pytorch_modeler.py - INFO - epoch:84/100, tr_loss:0.018885, src_loss:0.790182, src_mean_auc:0.803167, tgt_loss:0.547951, tgt_mean_auc:0.695200, mean_auc:0.749183,
#                AUC      pAUC
# Source_0  0.765500  0.610000
# Source_1  0.917900  0.822632
# Source_2  0.726100  0.581579
# Target_0  0.739400  0.595263
# Target_1  0.753900  0.612632
# Target_2  0.592300  0.543158
# mean      0.749183  0.627544
# h_mean    0.737081  0.616793
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-23 12:05:28,511 - pytorch_modeler.py - INFO - epoch:85/100, tr_loss:0.016382, src_loss:0.790182, src_mean_auc:0.803167, tgt_loss:0.547951, tgt_mean_auc:0.695200, mean_auc:0.749183,
#                AUC      pAUC
# Source_0  0.765500  0.610000
# Source_1  0.917900  0.822632
# Source_2  0.726100  0.581579
# Target_0  0.739400  0.595263
# Target_1  0.753900  0.612632
# Target_2  0.592300  0.543158
# mean      0.749183  0.627544
# h_mean    0.737081  0.616793
# 100%|██████████| 45/45 [00:35<00:00,  1.29it/s]
# 2021-10-23 12:06:03,546 - pytorch_modeler.py - INFO - epoch:86/100, tr_loss:0.014929, src_loss:0.790182, src_mean_auc:0.803167, tgt_loss:0.547951, tgt_mean_auc:0.695200, mean_auc:0.749183,
#                AUC      pAUC
# Source_0  0.765500  0.610000
# Source_1  0.917900  0.822632
# Source_2  0.726100  0.581579
# Target_0  0.739400  0.595263
# Target_1  0.753900  0.612632
# Target_2  0.592300  0.543158
# mean      0.749183  0.627544
# h_mean    0.737081  0.616793
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-23 12:06:38,746 - pytorch_modeler.py - INFO - epoch:87/100, tr_loss:0.015529, src_loss:0.790182, src_mean_auc:0.803167, tgt_loss:0.547951, tgt_mean_auc:0.695200, mean_auc:0.749183,
#                AUC      pAUC
# Source_0  0.765500  0.610000
# Source_1  0.917900  0.822632
# Source_2  0.726100  0.581579
# Target_0  0.739400  0.595263
# Target_1  0.753900  0.612632
# Target_2  0.592300  0.543158
# mean      0.749183  0.627544
# h_mean    0.737081  0.616793
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-23 12:07:13,833 - pytorch_modeler.py - INFO - epoch:88/100, tr_loss:0.012774, src_loss:0.790182, src_mean_auc:0.803167, tgt_loss:0.547951, tgt_mean_auc:0.695200, mean_auc:0.749183,
#                AUC      pAUC
# Source_0  0.765500  0.610000
# Source_1  0.917900  0.822632
# Source_2  0.726100  0.581579
# Target_0  0.739400  0.595263
# Target_1  0.753900  0.612632
# Target_2  0.592300  0.543158
# mean      0.749183  0.627544
# h_mean    0.737081  0.616793
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-23 12:07:49,037 - pytorch_modeler.py - INFO - epoch:89/100, tr_loss:0.017575, src_loss:0.790182, src_mean_auc:0.803167, tgt_loss:0.547951, tgt_mean_auc:0.695200, mean_auc:0.749183,
#                AUC      pAUC
# Source_0  0.765500  0.610000
# Source_1  0.917900  0.822632
# Source_2  0.726100  0.581579
# Target_0  0.739400  0.595263
# Target_1  0.753900  0.612632
# Target_2  0.592300  0.543158
# mean      0.749183  0.627544
# h_mean    0.737081  0.616793
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 100%|██████████| 600/600 [00:57<00:00, 10.37it/s]
# 100%|██████████| 600/600 [00:58<00:00, 10.29it/s]
# 2021-10-23 12:10:20,416 - pytorch_modeler.py - INFO - epoch:90/100, tr_loss:0.013103, src_loss:0.844369, src_mean_auc:0.812300, tgt_loss:0.550621, tgt_mean_auc:0.664100, mean_auc:0.738200,
#                AUC      pAUC
# Source_0  0.773800  0.606842
# Source_1  0.907700  0.828421
# Source_2  0.755400  0.603158
# Target_0  0.698200  0.604737
# Target_1  0.703000  0.602105
# Target_2  0.591100  0.558947
# mean      0.738200  0.634035
# h_mean    0.726014  0.623930
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-23 12:10:55,657 - pytorch_modeler.py - INFO - epoch:91/100, tr_loss:0.010353, src_loss:0.844369, src_mean_auc:0.812300, tgt_loss:0.550621, tgt_mean_auc:0.664100, mean_auc:0.738200,
#                AUC      pAUC
# Source_0  0.773800  0.606842
# Source_1  0.907700  0.828421
# Source_2  0.755400  0.603158
# Target_0  0.698200  0.604737
# Target_1  0.703000  0.602105
# Target_2  0.591100  0.558947
# mean      0.738200  0.634035
# h_mean    0.726014  0.623930
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-23 12:11:31,245 - pytorch_modeler.py - INFO - epoch:92/100, tr_loss:0.012354, src_loss:0.844369, src_mean_auc:0.812300, tgt_loss:0.550621, tgt_mean_auc:0.664100, mean_auc:0.738200,
#                AUC      pAUC
# Source_0  0.773800  0.606842
# Source_1  0.907700  0.828421
# Source_2  0.755400  0.603158
# Target_0  0.698200  0.604737
# Target_1  0.703000  0.602105
# Target_2  0.591100  0.558947
# mean      0.738200  0.634035
# h_mean    0.726014  0.623930
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-23 12:12:06,738 - pytorch_modeler.py - INFO - epoch:93/100, tr_loss:0.017156, src_loss:0.844369, src_mean_auc:0.812300, tgt_loss:0.550621, tgt_mean_auc:0.664100, mean_auc:0.738200,
#                AUC      pAUC
# Source_0  0.773800  0.606842
# Source_1  0.907700  0.828421
# Source_2  0.755400  0.603158
# Target_0  0.698200  0.604737
# Target_1  0.703000  0.602105
# Target_2  0.591100  0.558947
# mean      0.738200  0.634035
# h_mean    0.726014  0.623930
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-23 12:12:42,105 - pytorch_modeler.py - INFO - epoch:94/100, tr_loss:0.022593, src_loss:0.844369, src_mean_auc:0.812300, tgt_loss:0.550621, tgt_mean_auc:0.664100, mean_auc:0.738200,
#                AUC      pAUC
# Source_0  0.773800  0.606842
# Source_1  0.907700  0.828421
# Source_2  0.755400  0.603158
# Target_0  0.698200  0.604737
# Target_1  0.703000  0.602105
# Target_2  0.591100  0.558947
# mean      0.738200  0.634035
# h_mean    0.726014  0.623930
# 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2021-10-23 12:13:17,312 - pytorch_modeler.py - INFO - epoch:95/100, tr_loss:0.012650, src_loss:0.844369, src_mean_auc:0.812300, tgt_loss:0.550621, tgt_mean_auc:0.664100, mean_auc:0.738200,
#                AUC      pAUC
# Source_0  0.773800  0.606842
# Source_1  0.907700  0.828421
# Source_2  0.755400  0.603158
# Target_0  0.698200  0.604737
# Target_1  0.703000  0.602105
# Target_2  0.591100  0.558947
# mean      0.738200  0.634035
# h_mean    0.726014  0.623930
# 100%|██████████| 45/45 [00:35<00:00,  1.27it/s]
# 2021-10-23 12:13:52,800 - pytorch_modeler.py - INFO - epoch:96/100, tr_loss:0.015503, src_loss:0.844369, src_mean_auc:0.812300, tgt_loss:0.550621, tgt_mean_auc:0.664100, mean_auc:0.738200,
#                AUC      pAUC
# Source_0  0.773800  0.606842
# Source_1  0.907700  0.828421
# Source_2  0.755400  0.603158
# Target_0  0.698200  0.604737
# Target_1  0.703000  0.602105
# Target_2  0.591100  0.558947
# mean      0.738200  0.634035
# ...
# Source_2  0.621800  0.474737
# Target_0  0.595600  0.539474
# Target_1  0.477900  0.477895
# Target_2  0.645800  0.633684
# mean      0.597500  0.543158
# h_mean    0.589194  0.536230
# 100%|██████████| 45/45 [00:34<00:00,  1.29it/s]
# 2021-10-23 19:19:13,221 - pytorch_modeler.py - INFO - epoch:99/100, tr_loss:0.019504, src_loss:0.147294, src_mean_auc:0.621900, tgt_loss:0.185662, tgt_mean_auc:0.573100, mean_auc:0.597500,
#                AUC      pAUC
# Source_0  0.553400  0.515789
# Source_1  0.690500  0.617368
# Source_2  0.621800  0.474737
# Target_0  0.595600  0.539474
# Target_1  0.477900  0.477895
# Target_2  0.645800  0.633684
# mean      0.597500  0.543158
# h_mean    0.589194  0.536230
# 100%|██████████| 45/45 [00:34<00:00,  1.29it/s]
# 100%|██████████| 600/600 [00:58<00:00, 10.33it/s]
# 100%|██████████| 600/600 [00:58<00:00, 10.34it/s]
# 2021-10-23 19:21:44,228 - pytorch_modeler.py - INFO - epoch:100/100, tr_loss:0.017905, src_loss:0.178635, src_mean_auc:0.607467, tgt_loss:0.205676, tgt_mean_auc:0.551333, mean_auc:0.579400,
#                AUC      pAUC
# Source_0  0.376500  0.494737
# Source_1  0.734100  0.613684
# Source_2  0.711800  0.473684
# Target_0  0.488500  0.537368
# Target_1  0.471700  0.480000
# Target_2  0.693800  0.665789
# mean      0.579400  0.544211
# h_mean    0.543894  0.535326
# 2021-10-23 19:21:44,325 - 00_train.py - INFO - SAVE SUCCESS : /media/output-disk/domain_adaptation/EfficientNet/exp16/models/ToyTrain_model.pkl
# 2021-10-23 19:21:44,329 - 00_train.py - INFO - TARGET MACHINE_TYPE: fan
# 2021-10-23 19:21:44,330 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-10-23 19:21:44,332 - 00_train.py - INFO - TRAINING
# elapsed time: 5014.072392941 [sec]
# use: cuda:0
# 100%|██████████| 45/45 [04:41<00:00,  6.25s/it]
# 100%|██████████| 600/600 [01:02<00:00,  9.55it/s]
# 100%|██████████| 600/600 [01:02<00:00,  9.59it/s]
# 2021-10-23 19:28:31,184 - pytorch_modeler.py - INFO - epoch:1/100, tr_loss:0.812570, src_loss:1.914621, src_mean_auc:0.527533, tgt_loss:1.371932, tgt_mean_auc:0.457667, mean_auc:0.492600,
#                AUC      pAUC
# Source_0  0.522800  0.496316
# Source_1  0.352400  0.478421
# Source_2  0.707400  0.616316
# Target_0  0.424200  0.504737
# Target_1  0.476500  0.481579
# Target_2  0.472300  0.480526
# mean      0.492600  0.509649
# h_mean    0.471054  0.505630
# 100%|██████████| 45/45 [00:34<00:00,  1.29it/s]
# 2021-10-23 19:29:05,990 - pytorch_modeler.py - INFO - epoch:2/100, tr_loss:0.352311, src_loss:1.914621, src_mean_auc:0.527533, tgt_loss:1.371932, tgt_mean_auc:0.457667, mean_auc:0.492600,
#                AUC      pAUC
# Source_0  0.522800  0.496316
# Source_1  0.352400  0.478421
# Source_2  0.707400  0.616316
# Target_0  0.424200  0.504737
# Target_1  0.476500  0.481579
# Target_2  0.472300  0.480526
# mean      0.492600  0.509649
# h_mean    0.471054  0.505630
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-23 19:29:40,542 - pytorch_modeler.py - INFO - epoch:3/100, tr_loss:0.243440, src_loss:1.914621, src_mean_auc:0.527533, tgt_loss:1.371932, tgt_mean_auc:0.457667, mean_auc:0.492600,
#                AUC      pAUC
# Source_0  0.522800  0.496316
# Source_1  0.352400  0.478421
# Source_2  0.707400  0.616316
# Target_0  0.424200  0.504737
# Target_1  0.476500  0.481579
# Target_2  0.472300  0.480526
# mean      0.492600  0.509649
# h_mean    0.471054  0.505630
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-23 19:30:15,160 - pytorch_modeler.py - INFO - epoch:4/100, tr_loss:0.191670, src_loss:1.914621, src_mean_auc:0.527533, tgt_loss:1.371932, tgt_mean_auc:0.457667, mean_auc:0.492600,
#                AUC      pAUC
# Source_0  0.522800  0.496316
# Source_1  0.352400  0.478421
# Source_2  0.707400  0.616316
# Target_0  0.424200  0.504737
# Target_1  0.476500  0.481579
# Target_2  0.472300  0.480526
# mean      0.492600  0.509649
# h_mean    0.471054  0.505630
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-23 19:30:49,835 - pytorch_modeler.py - INFO - epoch:5/100, tr_loss:0.163676, src_loss:1.914621, src_mean_auc:0.527533, tgt_loss:1.371932, tgt_mean_auc:0.457667, mean_auc:0.492600,
#                AUC      pAUC
# Source_0  0.522800  0.496316
# Source_1  0.352400  0.478421
# Source_2  0.707400  0.616316
# Target_0  0.424200  0.504737
# Target_1  0.476500  0.481579
# Target_2  0.472300  0.480526
# mean      0.492600  0.509649
# h_mean    0.471054  0.505630
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-23 19:31:24,463 - pytorch_modeler.py - INFO - epoch:6/100, tr_loss:0.146683, src_loss:1.914621, src_mean_auc:0.527533, tgt_loss:1.371932, tgt_mean_auc:0.457667, mean_auc:0.492600,
#                AUC      pAUC
# Source_0  0.522800  0.496316
# Source_1  0.352400  0.478421
# Source_2  0.707400  0.616316
# Target_0  0.424200  0.504737
# Target_1  0.476500  0.481579
# Target_2  0.472300  0.480526
# mean      0.492600  0.509649
# h_mean    0.471054  0.505630
#   2%|▏         | 1/45 [00:00<00:34,  1.28it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 100%|██████████| 600/600 [00:58<00:00, 10.34it/s]
# 100%|██████████| 600/600 [00:57<00:00, 10.37it/s]
# 2021-10-23 20:29:25,934 - pytorch_modeler.py - INFO - epoch:80/100, tr_loss:0.012413, src_loss:1.340999, src_mean_auc:0.701367, tgt_loss:1.541927, tgt_mean_auc:0.716933, mean_auc:0.709150,
#                AUC      pAUC
# Source_0  0.558700  0.493158
# Source_1  0.784000  0.787368
# Source_2  0.761400  0.768947
# Target_0  0.604400  0.545789
# Target_1  0.846200  0.715263
# Target_2  0.700200  0.702105
# mean      0.709150  0.668772
# h_mean    0.694187  0.648448
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-23 20:30:00,534 - pytorch_modeler.py - INFO - epoch:81/100, tr_loss:0.015537, src_loss:1.340999, src_mean_auc:0.701367, tgt_loss:1.541927, tgt_mean_auc:0.716933, mean_auc:0.709150,
#                AUC      pAUC
# Source_0  0.558700  0.493158
# Source_1  0.784000  0.787368
# Source_2  0.761400  0.768947
# Target_0  0.604400  0.545789
# Target_1  0.846200  0.715263
# Target_2  0.700200  0.702105
# mean      0.709150  0.668772
# h_mean    0.694187  0.648448
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-23 20:30:35,149 - pytorch_modeler.py - INFO - epoch:82/100, tr_loss:0.012180, src_loss:1.340999, src_mean_auc:0.701367, tgt_loss:1.541927, tgt_mean_auc:0.716933, mean_auc:0.709150,
#                AUC      pAUC
# Source_0  0.558700  0.493158
# Source_1  0.784000  0.787368
# Source_2  0.761400  0.768947
# Target_0  0.604400  0.545789
# Target_1  0.846200  0.715263
# Target_2  0.700200  0.702105
# mean      0.709150  0.668772
# h_mean    0.694187  0.648448
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-23 20:31:09,792 - pytorch_modeler.py - INFO - epoch:83/100, tr_loss:0.011804, src_loss:1.340999, src_mean_auc:0.701367, tgt_loss:1.541927, tgt_mean_auc:0.716933, mean_auc:0.709150,
#                AUC      pAUC
# Source_0  0.558700  0.493158
# Source_1  0.784000  0.787368
# Source_2  0.761400  0.768947
# Target_0  0.604400  0.545789
# Target_1  0.846200  0.715263
# Target_2  0.700200  0.702105
# mean      0.709150  0.668772
# h_mean    0.694187  0.648448
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-23 20:31:44,333 - pytorch_modeler.py - INFO - epoch:84/100, tr_loss:0.012566, src_loss:1.340999, src_mean_auc:0.701367, tgt_loss:1.541927, tgt_mean_auc:0.716933, mean_auc:0.709150,
#                AUC      pAUC
# Source_0  0.558700  0.493158
# Source_1  0.784000  0.787368
# Source_2  0.761400  0.768947
# Target_0  0.604400  0.545789
# Target_1  0.846200  0.715263
# Target_2  0.700200  0.702105
# mean      0.709150  0.668772
# h_mean    0.694187  0.648448
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-23 20:32:19,036 - pytorch_modeler.py - INFO - epoch:85/100, tr_loss:0.014286, src_loss:1.340999, src_mean_auc:0.701367, tgt_loss:1.541927, tgt_mean_auc:0.716933, mean_auc:0.709150,
#                AUC      pAUC
# Source_0  0.558700  0.493158
# Source_1  0.784000  0.787368
# Source_2  0.761400  0.768947
# Target_0  0.604400  0.545789
# Target_1  0.846200  0.715263
# Target_2  0.700200  0.702105
# mean      0.709150  0.668772
# h_mean    0.694187  0.648448
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-23 20:32:53,570 - pytorch_modeler.py - INFO - epoch:86/100, tr_loss:0.007881, src_loss:1.340999, src_mean_auc:0.701367, tgt_loss:1.541927, tgt_mean_auc:0.716933, mean_auc:0.709150,
#                AUC      pAUC
# Source_0  0.558700  0.493158
# Source_1  0.784000  0.787368
# Source_2  0.761400  0.768947
# Target_0  0.604400  0.545789
# Target_1  0.846200  0.715263
# Target_2  0.700200  0.702105
# mean      0.709150  0.668772
# h_mean    0.694187  0.648448
# 100%|██████████| 45/45 [00:34<00:00,  1.31it/s]
# 2021-10-23 20:33:28,035 - pytorch_modeler.py - INFO - epoch:87/100, tr_loss:0.008098, src_loss:1.340999, src_mean_auc:0.701367, tgt_loss:1.541927, tgt_mean_auc:0.716933, mean_auc:0.709150,
#                AUC      pAUC
# Source_0  0.558700  0.493158
# Source_1  0.784000  0.787368
# Source_2  0.761400  0.768947
# Target_0  0.604400  0.545789
# Target_1  0.846200  0.715263
# Target_2  0.700200  0.702105
# mean      0.709150  0.668772
# h_mean    0.694187  0.648448
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-23 20:34:02,654 - pytorch_modeler.py - INFO - epoch:88/100, tr_loss:0.007172, src_loss:1.340999, src_mean_auc:0.701367, tgt_loss:1.541927, tgt_mean_auc:0.716933, mean_auc:0.709150,
#                AUC      pAUC
# Source_0  0.558700  0.493158
# Source_1  0.784000  0.787368
# Source_2  0.761400  0.768947
# Target_0  0.604400  0.545789
# Target_1  0.846200  0.715263
# Target_2  0.700200  0.702105
# mean      0.709150  0.668772
# h_mean    0.694187  0.648448
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-23 20:34:37,221 - pytorch_modeler.py - INFO - epoch:89/100, tr_loss:0.006709, src_loss:1.340999, src_mean_auc:0.701367, tgt_loss:1.541927, tgt_mean_auc:0.716933, mean_auc:0.709150,
#                AUC      pAUC
# Source_0  0.558700  0.493158
# Source_1  0.784000  0.787368
# Source_2  0.761400  0.768947
# Target_0  0.604400  0.545789
# Target_1  0.846200  0.715263
# Target_2  0.700200  0.702105
# mean      0.709150  0.668772
# h_mean    0.694187  0.648448
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 100%|██████████| 600/600 [00:57<00:00, 10.35it/s]
# 100%|██████████| 600/600 [00:57<00:00, 10.38it/s]
# 2021-10-23 20:37:07,607 - pytorch_modeler.py - INFO - epoch:90/100, tr_loss:0.007382, src_loss:1.598480, src_mean_auc:0.715533, tgt_loss:2.111687, tgt_mean_auc:0.696867, mean_auc:0.706200,
#                AUC      pAUC
# Source_0  0.517700  0.492632
# Source_1  0.820600  0.798947
# Source_2  0.808300  0.783684
# Target_0  0.570800  0.552105
# Target_1  0.798700  0.558947
# Target_2  0.721100  0.682632
# mean      0.706200  0.644825
# h_mean    0.683516  0.623517
# 100%|██████████| 45/45 [00:34<00:00,  1.31it/s]
# 2021-10-23 20:37:42,051 - pytorch_modeler.py - INFO - epoch:91/100, tr_loss:0.006119, src_loss:1.598480, src_mean_auc:0.715533, tgt_loss:2.111687, tgt_mean_auc:0.696867, mean_auc:0.706200,
#                AUC      pAUC
# Source_0  0.517700  0.492632
# Source_1  0.820600  0.798947
# Source_2  0.808300  0.783684
# Target_0  0.570800  0.552105
# Target_1  0.798700  0.558947
# Target_2  0.721100  0.682632
# mean      0.706200  0.644825
# h_mean    0.683516  0.623517
# 100%|██████████| 45/45 [00:34<00:00,  1.31it/s]
# 2021-10-23 20:38:16,504 - pytorch_modeler.py - INFO - epoch:92/100, tr_loss:0.005972, src_loss:1.598480, src_mean_auc:0.715533, tgt_loss:2.111687, tgt_mean_auc:0.696867, mean_auc:0.706200,
#                AUC      pAUC
# Source_0  0.517700  0.492632
# Source_1  0.820600  0.798947
# Source_2  0.808300  0.783684
# Target_0  0.570800  0.552105
# Target_1  0.798700  0.558947
# Target_2  0.721100  0.682632
# mean      0.706200  0.644825
# h_mean    0.683516  0.623517
# 100%|██████████| 45/45 [00:34<00:00,  1.31it/s]
# 2021-10-23 20:38:50,982 - pytorch_modeler.py - INFO - epoch:93/100, tr_loss:0.005167, src_loss:1.598480, src_mean_auc:0.715533, tgt_loss:2.111687, tgt_mean_auc:0.696867, mean_auc:0.706200,
#                AUC      pAUC
# Source_0  0.517700  0.492632
# Source_1  0.820600  0.798947
# Source_2  0.808300  0.783684
# Target_0  0.570800  0.552105
# Target_1  0.798700  0.558947
# Target_2  0.721100  0.682632
# mean      0.706200  0.644825
# h_mean    0.683516  0.623517
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-23 20:39:25,519 - pytorch_modeler.py - INFO - epoch:94/100, tr_loss:0.004106, src_loss:1.598480, src_mean_auc:0.715533, tgt_loss:2.111687, tgt_mean_auc:0.696867, mean_auc:0.706200,
#                AUC      pAUC
# Source_0  0.517700  0.492632
# Source_1  0.820600  0.798947
# Source_2  0.808300  0.783684
# Target_0  0.570800  0.552105
# Target_1  0.798700  0.558947
# Target_2  0.721100  0.682632
# mean      0.706200  0.644825
# h_mean    0.683516  0.623517
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-23 20:40:00,172 - pytorch_modeler.py - INFO - epoch:95/100, tr_loss:0.006195, src_loss:1.598480, src_mean_auc:0.715533, tgt_loss:2.111687, tgt_mean_auc:0.696867, mean_auc:0.706200,
#                AUC      pAUC
# Source_0  0.517700  0.492632
# Source_1  0.820600  0.798947
# Source_2  0.808300  0.783684
# Target_0  0.570800  0.552105
# Target_1  0.798700  0.558947
# Target_2  0.721100  0.682632
# mean      0.706200  0.644825
# h_mean    0.683516  0.623517
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-23 20:40:34,703 - pytorch_modeler.py - INFO - epoch:96/100, tr_loss:0.004296, src_loss:1.598480, src_mean_auc:0.715533, tgt_loss:2.111687, tgt_mean_auc:0.696867, mean_auc:0.706200,
#                AUC      pAUC
# Source_0  0.517700  0.492632
# Source_1  0.820600  0.798947
# Source_2  0.808300  0.783684
# Target_0  0.570800  0.552105
# Target_1  0.798700  0.558947
# Target_2  0.721100  0.682632
# mean      0.706200  0.644825
# h_mean    0.683516  0.623517
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-23 20:41:09,397 - pytorch_modeler.py - INFO - epoch:97/100, tr_loss:0.005673, src_loss:1.598480, src_mean_auc:0.715533, tgt_loss:2.111687, tgt_mean_auc:0.696867, mean_auc:0.706200,
#                AUC      pAUC
# Source_0  0.517700  0.492632
# Source_1  0.820600  0.798947
# Source_2  0.808300  0.783684
# Target_0  0.570800  0.552105
# Target_1  0.798700  0.558947
# Target_2  0.721100  0.682632
# mean      0.706200  0.644825
# h_mean    0.683516  0.623517
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 2021-10-23 20:41:43,921 - pytorch_modeler.py - INFO - epoch:98/100, tr_loss:0.010648, src_loss:1.598480, src_mean_auc:0.715533, tgt_loss:2.111687, tgt_mean_auc:0.696867, mean_auc:0.706200,
#                AUC      pAUC
# Source_0  0.517700  0.492632
# Source_1  0.820600  0.798947
# Source_2  0.808300  0.783684
# Target_0  0.570800  0.552105
# Target_1  0.798700  0.558947
# Target_2  0.721100  0.682632
# mean      0.706200  0.644825
# h_mean    0.683516  0.623517
# 100%|██████████| 45/45 [00:34<00:00,  1.31it/s]
# 2021-10-23 20:42:18,347 - pytorch_modeler.py - INFO - epoch:99/100, tr_loss:0.002947, src_loss:1.598480, src_mean_auc:0.715533, tgt_loss:2.111687, tgt_mean_auc:0.696867, mean_auc:0.706200,
#                AUC      pAUC
# Source_0  0.517700  0.492632
# Source_1  0.820600  0.798947
# Source_2  0.808300  0.783684
# Target_0  0.570800  0.552105
# Target_1  0.798700  0.558947
# Target_2  0.721100  0.682632
# mean      0.706200  0.644825
# h_mean    0.683516  0.623517
# 100%|██████████| 45/45 [00:34<00:00,  1.30it/s]
# 100%|██████████| 600/600 [00:57<00:00, 10.36it/s]
# 100%|██████████| 600/600 [00:57<00:00, 10.38it/s]
# 2021-10-23 20:44:48,693 - pytorch_modeler.py - INFO - epoch:100/100, tr_loss:0.006415, src_loss:1.093816, src_mean_auc:0.683500, tgt_loss:0.975568, tgt_mean_auc:0.667167, mean_auc:0.675333,
#                AUC      pAUC
# Source_0  0.491200  0.496842
# Source_1  0.814800  0.791053
# Source_2  0.744500  0.770526
# Target_0  0.489000  0.497368
# Target_1  0.822500  0.616842
# Target_2  0.690000  0.711579
# mean      0.675333  0.647368
# h_mean    0.644027  0.624237
# 2021-10-23 20:44:48,796 - 00_train.py - INFO - SAVE SUCCESS : /media/output-disk/domain_adaptation/EfficientNet/exp16/models/fan_model.pkl
# elapsed time: 4984.469067097 [sec]

# %%
#run(machine_types[0], dev_paths)

# %% [markdown]
# # run

# %% [raw]
# # debug
# import dcase_util
# import pandas as pd
#
# sample = pd.read_pickle('/media/hiroki/HDD1TB/research/DCASE_experiments/domain_adaptation/exp2/extraction_features/ToyCar_features.pkl')
# sample = sample['val_src']
#
# src_pred_df = dcase_util.make_pred_df(sample['wav_name'], sample['section_label'], sample['domain_label'], sample['label'], sample['label'])
#
# df1 = dcase_util.calc_dcase2021_task2_score(src_pred_df, prefix='Source')
# df2 = dcase_util.calc_dcase2021_task2_score(src_pred_df, prefix='Target')
# score = pd.concat([df1, df2])
# mean = pd.DataFrame([score.mean()], index=['mean'])
# hmean = scipy.stats.hmean(score, axis=0)
# hmean = pd.DataFrame([hmean], columns=['AUC', 'pAUC'], index=['h_mean'])
# score = score.append([mean, hmean])
